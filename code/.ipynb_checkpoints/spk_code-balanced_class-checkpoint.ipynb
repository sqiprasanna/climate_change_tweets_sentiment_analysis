# %%
import numpy as np
import pandas as pd
import spacy
import matplotlib.pyplot as plt 
from itertools import chain
from wordcloud import WordCloud, STOPWORDS 
from nltk.stem import PorterStemmer
import re

import cufflinks as cf
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)

# %run ./jlu_preprocessing.ipynb
# %run ./spk_preprocessing.ipynb
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %%
# data = pd.read_excel(r'C:/Users/Checkout/Desktop/SJSU/sem1/257-ML/Project/global_warming_tweets.xls')
data = pd.read_csv(r'C:/Users/Checkout/Desktop/SJSU/sem1/257-ML/Project/global_warming_tweets_main.csv', engine='python') #encoding = "cp1252"
data.head()
# Out:
#                                                tweet existence  \
# 0  Global warming report urges governments to act...       Yes
# 1  Fighting poverty and global warming in Africa ...       Yes
# 2  Carbon offsets: How a Vatican forest failed to...       Yes
# 3  Carbon offsets: How a Vatican forest failed to...       Yes
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...       Yes
#
#    existence.confidence
# 0                1.0000
# 1                1.0000
# 2                0.8786
# 3                1.0000
# 4                0.8087

# %%
data['existence'] = data['existence'].fillna('No')
data[data['existence']=="No"].tweet
# Out:
# 14      Spring storm season starting a little late thi...
# 17      Wait here's an idea: it's natural climate chan...
# 31      @New_federalists  i have it on good auth tht g...
# 32      Illegal war and the myth of global warming|My ...
# 33      the scientific community was scamed by global ...
#                               ...
# 6069    Is Global Warming A Hoax? - Find Answers to th...
# 6072    RT @brookedunne: Intl Conference of Scientists...
# 6074    Global Warming Fanatics Clash With Environment...
# 6083    RT @EPSclimate: Climate change row over the my...
# 6086    Virginia to Investigate Global Warming Scienti...
# Name: tweet, Length: 1926, dtype: object

# %%
print(data['existence'].value_counts())
# Out:
# Y      2554
# No     1926
# N      1053
# Yes     557
# Name: existence, dtype: int64

# %%
data['word_count'] = data['tweet'].apply(lambda x: len(x.split(" ")))
data = data.drop_duplicates()
data = data.dropna()
data.loc[data['existence'] == 'Y','existence'] = "Yes"
data.loc[data['existence'] == 'N','existence'] = "No"
print(data.shape)
data.dropna()
data.loc[data['existence'] == np.nan,'existence'] = "No"
print(data['existence'].value_counts())
print(data.shape)
data.head()
# Out:
# (5960, 4)
# Yes    3029
# No     2931
# Name: existence, dtype: int64
# (5960, 4)
#                                                tweet existence  \
# 0  Global warming report urges governments to act...       Yes
# 1  Fighting poverty and global warming in Africa ...       Yes
# 2  Carbon offsets: How a Vatican forest failed to...       Yes
# 3  Carbon offsets: How a Vatican forest failed to...       Yes
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...       Yes
#
#    existence.confidence  word_count
# 0                1.0000          18
# 1                1.0000           8
# 2                0.8786          12
# 3                1.0000          12
# 4                0.8087          11

# %%
data['tweet']
# Out:
# 0       Global warming report urges governments to act...
# 1       Fighting poverty and global warming in Africa ...
# 2       Carbon offsets: How a Vatican forest failed to...
# 3       Carbon offsets: How a Vatican forest failed to...
# 4       URUGUAY: Tools Needed for Those Most Vulnerabl...
#                               ...
# 6085    @bloodless_coup "The phrase 'global warming' s...
# 6086    Virginia to Investigate Global Warming Scienti...
# 6087    Global warming you tube parody you will enjoy ...
# 6088    One-Eyed Golfer: Don't dare tell me about glob...
# 6089    man made global warming a hair brained theory ...
# Name: tweet, Length: 5960, dtype: object

# %%
tweets = data["tweet"]
# tweets = tweets.drop_duplicates()
tweets
# Out:
# 0       Global warming report urges governments to act...
# 1       Fighting poverty and global warming in Africa ...
# 2       Carbon offsets: How a Vatican forest failed to...
# 3       Carbon offsets: How a Vatican forest failed to...
# 4       URUGUAY: Tools Needed for Those Most Vulnerabl...
#                               ...
# 6085    @bloodless_coup "The phrase 'global warming' s...
# 6086    Virginia to Investigate Global Warming Scienti...
# 6087    Global warming you tube parody you will enjoy ...
# 6088    One-Eyed Golfer: Don't dare tell me about glob...
# 6089    man made global warming a hair brained theory ...
# Name: tweet, Length: 5960, dtype: object

# %%
# tweets[:100]

# %%
# python -m spacy download en_core_web_sm
preprocessed_tweets,indices = preprocess_tweets(tweets)
# Out:
# {'hunger', 'increase', 'government', 'urge', 'warming', 'face', 'global', 'belgium', 'report', 'world'}
# ---
#
# {'warming', 'fight', 'poverty', 'africa', 'global'}
# ---
#
# {'vatican', 'carbon', 'warming', 'reduce', 'forest', 'offset', 'fail', 'global'}
# ---
#
# {'vatican', 'carbon', 'warming', 'reduce', 'forest', 'offset', 'fail', 'global'}
# ---
#
# {'uruguay', 'change', 'climate', 'vulnerable', 'tool', 'need'}
# ---
#
# {'warming', 'intensify', 'ocean', 'show', 'water', 'saltiness', 'global', 'cycle'}
# ---
#
# {'warming', 'evidence', 'look', 'doubter', 'message', 'global', 'denier'}
# ---
#
# {'change', 'climate', 'migratory', 'bird', 'home', 'stay', 'strategy'}
# ---
#
# {'limpopo', 'temperature', 'change', 'climate', 'bring', 'southern', 'high', 'compete', 'water', 'africa', 'southe'}
# ---
#
# {'scarcity', 'warming', 'wheat', 'rice', 'water', 'global', 'impact', 'production'}
# ---
#
# {'preliminary', 'warming', 'contribute', 'suggest', 'analysis', 'natural', 'global', 'previously'}
# ---
#
# {'perspective', 'population', 'change', 'climate', 'ecotone'}
# ---
#
# {'coastal', 'change', 'climate', 'migration', 'ventura', 'county', 'dwindle', 'whale', 'blame'}
# ---
#
# {'late', 'storm', 'season', 'little', 'year', 'warming', 'spring', 'global', 'start'}
# ---
#
# {'illness', 'say', 'government', 'warming', 'cause', 'mental', 'global', 'cancer', 'report'}
# ---
#
# {'earthday', 'warming', 'patient', 'affect', 'global', 'symptom'}
# ---
#
# {'change', 'climate', 'warming', 'idea', 'wait', 'natural', 'human', 'global', 'induce'}
# ---
#
# {'issue', 'ecosystem', 'change', 'climate', 'warming', 'have', 'measurable', 'effect', 'indicator', 'report'}
# ---
#
# {'carbon', 'change', 'year', 'warming', 'ocean', 'fast', 'chemistry', 'global'}
# ---
#
# {'complicate', 'warming', 'mountain', 'rate', 'sciencedaily', 'concl', 'topography', 'study', 'global'}
# ---
#
# {'soar', 'attribute', 'environmentalist', 'global', 'mercury', 'blame'}
# ---
#
# {'live', 'leader', 'change', 'climate', 'indigenous', 'woman', 'national'}
# ---
#
# {'increase', 'atmospher', 'warming', 'upper', 'reduce', 'reporting', 'effect', 'sediment', 'global'}
# ---
#
# {'today', 'warming', 'stat', 'news', 'effect', 'youtube', 'global'}
# ---
#
# {'read', 'warm', 'climate', 'change', 'global'}
# ---
#
# {'preliminary', 'warming', 'contribute', 'suggest', 'analysis', 'natural', 'think', 'global', 'previously'}
# ---
#
# {'explore', 'change', 'climate', 'evolution', 'science', 'scientist'}
# ---
#
# {'warming', 'eaarth', 'deal', 'stay', 'global'}
# ---
#
# {'warming', 'bad', 'allergy', 'global', 'blame'}
# ---
#
# {'good', 'warming', 'cause', 'auth', 'fungus', 'tcot', 'global', 'fortunate'}
# ---
#
# {'illegal', 'main', 'myth', 'campaign', 'election', 'platform', 'global'}
# ---
#
# {'community', 'scam', 'green', 'warming', 'scientific', 'global'}
# ---
#
# {'liberal', 'change', 'warming', 'degree', 'urinate', 'scum', 'global'}
# ---
#
# {'tlot', 'warm', 'ucot', 'tycot', 'ocra', 'tornado', 'race', 'tornadocot', 'global', 'gore', 'mississippi'}
# ---
#
# {'settle', 'scam', 'warming', 'stop', 'sussman', 'confirm', 'book', 'global'}
# ---
#
# {'angel', 'miracle', 'warming', 'cause', 'fairy', 'jesus', 'alien', 'tcot', 'human', 'exist', 'global', 'believe', 'rationalist'}
# ---
#
# {'change', 'peruvian', 'proof', 'climate', 'fall', 'killer', 'create', 'tsunami', 'fracture', 'glaci', 'lake'}
# ---
#
# {'change', 'climate', 'warming', 'science', 'algore', 'global', 'hoax', 'gore', 'hack', 'real', 'palin'}
# ---
#
# {'anti', 'warming', 'stranger', 'magazine', 'scientist', 'academic', 'nature', 'wrong', 'journal', 'global'}
# ---
#
# {'warming', 'climate', 'nasa', 'measure', 'difference', 'baloney', 'weather', 'global', 'expert', 'accord'}
# ---
#
# {'true', 'idiot', 'warming', 'forensic', 'computer', 'global', 'expert', 'belive'}
# ---
#
# {'learn', 'liberal', 'looney', 'warming', 'artic', 'alarmist', 'frost', 'bite', 'home', 'global', 'toon', 'come'}
# ---
#
# {'teaparty', 'ipcc', 'explanation', 'warming', 'enjoy', 'global', 'tube'}
# ---
#
# {'issue', 'senate', 'change', 'climate', 'reform', 'immigration', 'tale'}
# ---
#
# {'house', 'change', 'correspondent', 'green', 'climate', 'want', 'white', 'dinner', 'memo', 'report'}
# ---
#
# {'hold', 'monitor', 'people', 'reid', 'warming', 'country', 'global', 'view', 'vary'}
# ---
#
# {'april', 'challenge', 'california', 'change', 'francisco', 'climate', 'peter', 'reuter', 'henderson', 'scenario', 'source'}
# ---
#
# {'support', 'lindsay', 'today', 'change', 'climate', 'lindsey', 'graham', 'legislation'}
# ---
#
# {'issue', 'arizona', 'change', 'climate', 'congress', 'focus', 'poll', 'immigration', 'legislation', 'stall'}
# ---
#
# {'talk', 'unveile', 'schedule', 'bill', 'change', 'limbo', 'climate', 'graham', 'exit', 'put'}
# ---
#
# {'senate', 'bill', 'change', 'climate', 'stall'}
# ---
#
# {'people', 'regulate', 'change', 'climate', 'mich', 'typically', 'globa', 'opponent', 'grand', 'legislation', 'rapid', 'argue', 'world'}
# ---
#
# {'push', 'change', 'bill', 'dem', 'climate', 'cnnbrk', 'graham', 'immigration', 'imperil'}
# ---
#
# {'talk', 'cafe', 'april', 'scientifique', 'warming', 'presentation', 'present', 'global'}
# ---
#
# {'business', 'change', 'climate', 'check', 'video', 'conference'}
# ---
#
# {'valentine', 'change', 'climate', 'clip', 'tip', 'clinique', 'brilliant', 'trial', 'collagen', 'screaming', 'clinical'}
# ---
#
# {'policy', 'april', 'change', 'climate', 'update'}
# ---
#
# {'april', 'change', 'climate', 'agree', 'intensify', 'release', 'press', 'negotiator'}
# ---
#
# {'postpartisan', 'hapless', 'harry', 'reid', 'climate', 'change', 'play', 'immigration'}
# ---
#
# {'delay', 'california', 'money', 'campaign', 'warming', 'foe', 'pour', 'global'}
# ---
#
# {'policy', 'obama', 'live', 'carol', 'change', 'climate', 'browner', 'energy', 'director', 'office', 'admin', 'earth', 'chat'}
# ---
#
# {'chance', 'senate', 'change', 'bill', 'klein', 'climate', 'year', 'pass'}
# ---
#
# {'volcano', 'person', 'warming', 'hear', 'connection', 'global'}
# ---
#
# {'fact', 'change', 'warming', 'guess', 'climate', 'notice', 'nasa', 'think', 'global'}
# ---
#
# {'environmental', 'group', 'change', 'praise', 'climate', 'basic', 'give', 'qualified', 'meeting'}
# ---
#
# {'ellis', 'americans', 'april', 'good', 'warming', 'cause', 'news', 'human', 'global', 'believe'}
# ---
#
# {'million', 'warming', 'thousand', 'heart', 'earth', 'action', 'conscious', 'global'}
# ---
#
# {'datum', 'climate', 'warming', 'suggest', 'assumption', 'global'}
# ---
#
# {'fact', 'warming', 'claim', 'fiction', 'global', 'denier'}
# ---
#
# {'interview', 'cast', 'warming', 'takedown', 'fight', 'youtube', 'global', 'minnesotan'}
# ---
#
# {'delay', 'warming', 'opponent', 'effort', 'calif', 'global', 'ramp'}
# ---
#
# {'earthweek', 'people', 'bolivia', 'change', 'climate', 'aware', 'indigenous', 'conference', 'earth', 'right', 'world'}
# ---
#
# {'talk', 'sorry', 'bolivia', 'panelist', 'able', 'accept', 'climate', 'change', 'invitation'}
# ---
#
# {'global', 'debate', 'climate', 'warming', 'sue', 'scientist', 'newspaper', 'poison'}
# ---
#
# {'arrive', 'bolivia', 'people', 'group', 'change', 'climate', 'indigenous', 'conference', 'sharifkouddous', 'world'}
# ---
#
# {'grape', 'peanut', 'warming', 'rare', 'meat', 'water', 'recycling', 'global'}
# ---
#
# {'general', 'reopen', 'finding', 'motion', 'warming', 'file', 'force', 'virginia', 'attorney', 'cuccinelli', 'global'}
# ---
#
# {'warming', 'regulator', 'safety', 'silly', 'global', 'blankenship'}
# ---
#
# {'nanogen', 'change', 'climate', 'bring', 'hair', 'trial', 'collagen', 'nanofiber', 'clinical'}
# ---
#
# {'myth', 'corner', 'warm', 'certain', 'street', 'urgh', 'washington', 'counsel', 'element', 'post', 'global', 'item', 'sunday'}
# ---
#
# {'environmental', 'change', 'climate', 'commercial', 'regulation', 'implication', 'ready'}
# ---
#
# {'fellow', 'tonight', 'james', 'live', 'change', 'hansen', 'climate', 'discuss', 'heather', 'solution', 'join', 'expert', 'roger', 'real'}
# ---
#
# {'california', 'change', 'climate', 'plan', 'brace'}
# ---
#
# {'leave', 'effective', 'tackle', 'account', 'global', 'plant'}
# ---
#
# {'obama', 'warming', 'degree', 'sachs', 'well', 'fuck', 'glodman', 'shiiiiiitttt', 'plan', 'global'}
# ---
#
# {'leave', 'effective', 'tackle', 'account', 'global', 'plant'}
# ---
#
# {'listen', 'development', 'change', 'climate', 'future', 'economic', 'sustainability', 'driver'}
# ---
#
# {'blink', 'alarm', 'hague', 'change', 'climate', 'discotech', 'bell', 'frederic'}
# ---
#
# {'general', 'america', 'change', 'climate', 'pentagon', 'know', 'threaten', 'consider', 'security'}
# ---
#
# {'general', 'change', 'climate', 'screw', 'know', 'go'}
# ---
#
# {'illness', 'say', 'government', 'warming', 'cause', 'mental', 'global', 'cancer', 'report'}
# ---
#
# {'increase', 'change', 'climate', 'heat', 'wave', 'flood'}
# ---
#
# {'warming', 'remain', 'effective', 'tackle', 'global', 'plant'}
# ---
#
# {'get', 'change', 'discussion', 'climate', 'student', 'fault', 'deni', 'heated', 'global', 'class'}
# ---
#
# {'warming', 'forest', 'global', 'colorado', 'kill'}
# ---
#
# {'environmental', 'change', 'climate', 'confirm', 'occur', 'display'}
# ---
#
# {'true', 'foll', 'disappear', 'warming', 'prove', 'place', 'europe', 'global', 'prediction'}
# ---
#
# {'lesson', 'people', 'change', 'climate', 'indigenous', 'combat'}
# ---
#
# {'support', 'live', 'bill', 'change', 'climate', 'strong', 'action'}
# ---
#
# {'change', 'climate', 'indigenous', 'fight', 'tradition'}
# ---
#
# {'james', 'real', 'change', 'hansen', 'green', 'climate', 'heather', 'false', 'hope', 'solution', 'wrong', 'roger', 'go'}
# ---
#
# {'carbon', 'change', 'climate', 'absorb', 'forest', 'activist'}
# ---
#
# {'carbon', 'change', 'climate', 'absorb', 'forest', 'activist'}
# ---
#
# {'carbon', 'change', 'climate', 'absorb', 'forest', 'activist'}
# ---
#
# {'park', 'namesake', 'lose', 'change', 'climate', 'mont', 'melt', 'national', 'glaci'}
# ---
#
# {'carbon', 'change', 'climate', 'absorb', 'forest', 'activist'}
# ---
#
# {'carbon', 'change', 'climate', 'absorb', 'forest', 'activist'}
# ---
#
# {'carbon', 'change', 'climate', 'absorb', 'forest'}
# ---
#
# {'bleh', 'morning', 'change', 'york', 'climate', 'fall', 'beautiful', 'thank', 'weather'}
# ---
# {'bleh', 'morning', 'change', 'york', 'climate', 'fall', 'beautiful', 'thank', 'weather'}
# ---
#
# {'culture', 'change', 'climate', 'japan', 'familiar', 'threaten', 'blossom', 'cherry', 'environment'}
# ---
#
# {'podcast', 'change', 'climate', 'mountain', 'stretch', 'valley', 'apart', 'temp'}
# ---
#
# {'change', 'climate', 'mountain', 'stretch', 'valley', 'apart', 'temp'}
# ---
#
# {'carbon', 'change', 'climate', 'absorb', 'forest', 'activist'}
# ---
#
# {'april', 'sign', 'arctic', 'rain', 'canadian', 'global'}
# ---
#
# {'microbe', 'contribute', 'conn', 'haven', 'global'}
# ---
#
# {'microbe', 'contribute', 'conn', 'haven', 'global'}
# ---
#
# {'foreign', 'minister', 'nation', 'south', 'change', 'climate', 'secluded', 'asian', 'fight'}
# ---
#
# {'increase', 'death', 'damage', 'change', 'climate', 'property', 'heat', 'wave', 'reuters'}
# ---
#
# {'james', 'real', 'change', 'hansen', 'green', 'climate', 'heather', 'false', 'hope', 'rogers', 'solution', 'wrong', 'go'}
# ---
#
# {'leap', 'mean', 'seriously', 'change', 'climate', 'wine', 'industry', 'love', 'frog'}
# ---
#
# {'warming', 'save', 'whale', 'global', 'report'}
# ---
#
# {'change', 'climate', 'contribution', 'organic', 'mitigation', 'agriculture'}
# ---
#
# {'arctic', 'warming', 'slide', 'black', 'alaska', 'white', 'effect', 'global', 'beauty'}
# ---
#
# {'document', 'change', 'climate', 'report', 'study', 'indicator', 'impact', 'real'}
# ---
#
# {'keen', 'change', 'ceo', 'green', 'climate', 'prepare', 'canadian', 'counterpart', 'global', 'impact'}
# ---
#
# {'support', 'change', 'climate', 'huffpo', 'check', 'fight', 'biochar', 'shortage', 'post', 'food'}
# ---
#
# {'change', 'help', 'climate', 'sure', 'fight', 'whale', 'doodoo'}
# ---
#
# {'carbon', 'good', 'warm', 'warming', 'science', 'soil', 'news', 'release', 'global', 'world'}
# ---
#
# {'hmmmm', 'snow', 'april', 'today', 'york', 'warming', 'weather', 'global', 'phoenix'}
# ---
#
# {'temperature', 'level', 'lumpur', 'rise', 'high', 'malaysia', 'global', 'average'}
# ---
#
# {'change', 'climate', 'west', 'country', 'mediterranean', 'unite'}
# ---
#
# {'picken', 'estimate', 'clean', 'global', 'write', 'speed'}
# ---
#
# {'business', 'change', 'climate', 'action', 'create'}
# ---
#
# {'person', 'warming', 'degree', 'anymore', 'weather', 'global', 'surprise'}
# ---
#
# {'understand', 'change', 'climate', 'evolution', 'human', 'hear', 'dispersal', 'interesting', 'variability', 'report', 'influence'}
# ---
#
# {'pic', 'warming', 'alaska', 'effect', 'global'}
# ---
#
# {'mandate', 'change', 'step', 'climate', 'blog', 'energy', 'city', 'benchmarking', 'post', 'address'}
# ---
#
# {'like', 'stake', 'year', 'warming', 'claim', 'antarctica', 'florida', 'global', 'realdocwatson'}
# ---
#
# {'mean', 'warming', 'wine', 'industry', 'trouble', 'global', 'agriculture'}
# ---
#
# {'arctic', 'warming', 'slide', 'black', 'alaska', 'white', 'effect', 'global', 'beauty'}
# ---
#
# {'alp', 'change', 'climate', 'photo', 'peril', 'paris', 'european', 'place'}
# ---
#
# {'know', 'electoral', 'change', 'climate', 'oceanic', 'administration', 'atmospheric', 'national'}
# ---
#
# {'environmental', 'mark', 'warming', 'intensify', 'past', 'actually', 'earth', 'clean', 'global', 'week', 'report', 'world'}
# ---
#
# {'late', 'threat', 'warming', 'blair', 'round', 'news', 'frontier', 'global', 'wild'}
# ---
#
# {'relocation', 'indians', 'change', 'climate', 'prepare', 'kuna', 'sink', 'home', 'traditional'}
# ---
#
# {'buzz', 'kimberley', 'california', 'change', 'warming', 'climate', 'califor', 'wine', 'cahill', 'present', 'global', 'kill'}
# ---
#
# {'politic', 'uncajoe', 'change', 'climate', 'denial', 'digg', 'hate'}
# ---
#
# {'carbon', 'change', 'warming', 'ocean', 'fast', 'chemistry', 'global'}
# ---
#
# {'obama', 'good', 'change', 'sure', 'climate', 'agenda', 'graham', 'douche', 'imperil', 'backass', 'go', 'world'}
# ---
#
# {'resort', 'fight', 'city', 'thanksgiving', 'global', 'lake'}
# ---
#
# {'insect', 'bat', 'lizard', 'change', 'climate', 'bird', 'play', 'fight', 'important', 'eat'}
# ---
#
# {'change', 'computing', 'green', 'climate', 'contribution', 'cloud'}
# ---
#
# {'change', 'climate', 'indigenous', 'one', 'thoreau', 'invasive', 'specie', 'favor', 'extinct', 'plant'}
# ---
#
# {'season', 'alter', 'change', 'scary', 'climate', 'day', 'spring', 'early'}
# ---
#
# {'lesson', 'people', 'change', 'climate', 'indigenous', 'pre', 'morale'}
# ---
#
# {'event', 'change', 'climate', 'mobilize', 'tipping', 'science', 'point', 'fight', 'mediaglobal', 'earth', 'special', 'report'}
# ---
#
# {'warming', 'forest', 'global', 'colorado', 'kill'}
# ---
#
# {'lesson', 'arrive', 'people', 'change', 'climate', 'indigenous', 'climat', 'united', 'combat', 'nations', 'world'}
# ---
#
# {'change', 'climate', 'continent', 'vulnerable', 'service', 'meteorology', 'africa', 'gear'}
# ---
#
# {'carbon', 'mention', 'change', 'step', 'green', 'climate', 'living', 'daunting', 'gecko', 'credit'}
# ---
#
# {'fix', 'environmental', 'china', 'impact', 'expansion', 'world', 'sizable', 'rapid', 'global', 'come'}
# ---
#
# {'fix', 'environmental', 'china', 'impact', 'expansion', 'world', 'sizable', 'rapid', 'global', 'come'}
# ---
#
# {'listing', 'confront', 'change', 'york', 'green', 'examine', 'climate', 'check', 'local', 'yorker', 'go'}
# ---
#
# {'change', 'climate', 'cause', 'nasa', 'official', 'report'}
# ---
#
# {'warming', 'safety', 'call', 'silly', 'crazy', 'rule', 'coal', 'global'}
# ---
#
# {'change', 'climate', 'extend', 'human', 'health', 'impact'}
# ---
#
# {'change', 'climate', 'extend', 'human', 'health', 'impact'}
# ---
#
# {'good', 'change', 'climate', 'solnit', 'news', 'rebecca'}
# ---
#
# {'efficiency', 'alpha', 'change', 'climate', 'take', 'energy'}
# ---
#
# {'carbon', 'mention', 'change', 'step', 'green', 'climate', 'living', 'daunting', 'gecko', 'credit'}
# ---
#
# {'warming', 'climate', 'scientist', 'tell', 'explain', 'natural', 'popular', 'meteorologist', 'variability', 'global'}
# ---
#
# {'good', 'change', 'climate', 'degree', 'solnit', 'news', 'rebecca', 'inseparability'}
# ---
#
# {'change', 'shangri', 'watch', 'climate', 'mountain', 'video', 'tibetan', 'include', 'know', 'threaten', 'sacred', 'land'}
# ---
#
# {'african', 'change', 'climate', 'service', 'meteorology', 'gear'}
# ---
#
# {'season', 'change', 'climate', 'bad', 'allergy', 'report'}
# ---
#
# {'bill', 'change', 'accountability', 'climate', 'save', 'kill'}
# ---
#
# {'change', 'climate', 'farmer', 'ethiopia', 'vulnerable', 'increasingly', 'make', 'pastoralist'}
# ---
#
# {'famine', 'politic', 'compare', 'change', 'climate', 'haye', 'founder', 'news', 'earth', 'irishcentral', 'denis', 'weather', 'global', 'irish'}
# ---
#
# {'change', 'climate', 'farmer', 'ethiopia', 'vulnerable', 'increasingly', 'make', 'pastoralist'}
# ---
#
# {'earthday', 'warming', 'aware', 'consume', 'treat', 'place', 'effect', 'global', 'waste'}
# ---
#
# {'verwaayen', 'change', 'climate', 'curb', 'earth'}
# ---
#
# {'nation', 'industrial', 'change', 'climate', 'feel', 'health', 'impact', 'report'}
# ---
#
# {'nation', 'industrial', 'change', 'climate', 'feel', 'health', 'impact', 'report'}
# ---
#
# {'nation', 'industrial', 'change', 'climate', 'feel', 'health', 'impact', 'report'}
# ---
#
# {'carbon', 'mention', 'change', 'step', 'green', 'climate', 'living', 'daunting', 'gecko', 'credit'}
# ---
#
# {'carbon', 'mention', 'change', 'step', 'climate', 'green', 'living', 'daunting', 'credit', 'biofuel'}
# ---
#
# {'raise', 'change', 'climate', 'reuter', 'cost', 'allergy'}
# ---
#
# {'change', 'climate', 'international', 'asilomar', 'later', 'treat', 'curable', 'bioethicist', 'expert', 'disease'}
# ---
#
# {'change', 'climate', 'international', 'asilomar', 'later', 'treat', 'curable', 'bioethicist', 'expert', 'disease'}
# ---
#
# {'warming', 'safety', 'call', 'silly', 'crazy', 'rule', 'coal', 'global'}
# ---
#
# {'military', 'change', 'climate', 'fight', 'lead'}
# ---
#
# {'military', 'fuel', 'buyer', 'government', 'change', 'climate', 'fight', 'large', 'lead'}
# ---
#
# {'carbon', 'mention', 'change', 'step', 'climate', 'green', 'living', 'daunting', 'credit', 'biofuel'}
# ---
#
# {'main', 'goldberg', 'say', 'climate', 'cause', 'swedish', 'global', 'expert', 'fred'}
# ---
#
# {'change', 'climate', 'green', 'science', 'treat', 'curable', 'wire', 'disease'}
# ---
#
# {'listing', 'confront', 'change', 'examine', 'green', 'york', 'climate', 'check', 'local', 'thursday', 'yorker', 'go'}
# ---
#
# {'change', 'dialogue', 'climate', 'united', 'cooperation', 'seek', 'runaway', 'secretary', 'prevent', 'global', 'nations'}
# ---
# {'event', 'change', 'climate', 'nnimmo', 'bassey', 'struggle', 'important', 'environmentalist', 'nigerian'}
# ---
#
# {'military', 'change', 'climate', 'fight', 'lead'}
# ---
#
# {'evrything', 'inclde', 'issue', 'stake', 'identify', 'change', 'climate', 'affctd', 'mental', 'report', 'health', 'disease'}
# ---
#
# {'change', 'resource', 'climate', 'earth', 'cope'}
# ---
#
# {'warming', 'intensify', 'ocean', 'show', 'water', 'saltiness', 'global', 'cycle'}
# ---
#
# {'americans', 'change', 'climate', 'bauccio', 'time', 'combat', 'meal', 'week', 'fedele', 'celebrate', 'anniver'}
# ---
#
# {'support', 'cochabamba', 'people', 'live', 'change', 'climate', 'conf', 'world'}
# ---
#
# {'lot', 'push', 'change', 'climate', 'protocol', 'barrett', 'small', 'well', 'comprehensive'}
# ---
#
# {'complicate', 'warming', 'mountain', 'rate', 'topography', 'global'}
# ---
#
# {'support', 'cochabamba', 'people', 'bolivia', 'live', 'change', 'climate', 'watch', 'conference', 'world'}
# ---
#
# {'issue', 'smallpox', 'change', 'climate', 'require', 'operation', 'layer', 'universal', 'address', 'global', 'ozone'}
# ---
#
# {'subcontinent', 'boiling', 'change', 'climate', 'contain', 'point', 'spill', 'indian'}
# ---
#
# {'landslide', 'change', 'climate', 'warming', 'trigger', 'earthquake', 'world'}
# ---
#
# {'uruguay', 'change', 'climate', 'vulnerable', 'tool', 'need'}
# ---
#
# {'uruguay', 'change', 'climate', 'vulnerable', 'tool', 'need'}
# ---
#
# {'uruguay', 'change', 'climate', 'vulnerable', 'tool', 'need'}
# ---
#
# {'vatican', 'carbon', 'warming', 'reduce', 'forest', 'offset', 'fail', 'global'}
# ---
#
# {'increase', 'change', 'climate', 'ethiopia', 'poverty', 'vulnerability'}
# ---
#
# {'increase', 'change', 'climate', 'farmer', 'small', 'ethiopia', 'scale', 'poverty', 'vulnerability', 'pastoralist'}
# ---
#
# {'event', 'change', 'climate', 'nnimmo', 'bassey', 'struggle', 'important', 'environmentalist', 'nigerian'}
# ---
#
# {'event', 'change', 'climate', 'nnimmo', 'bassey', 'struggle', 'important', 'environmentalist', 'nigerian'}
# ---
#
# {'policy', 'change', 'year', 'climate', 'backgrounder', 'tackle', 'major', 'china'}
# ---
#
# {'steven', 'april', 'point', 'biologist', 'bloom', 'early', 'press', 'global', 'link'}
# ---
#
# {'steven', 'april', 'point', 'biologist', 'bloom', 'early', 'press', 'global', 'link'}
# ---
#
# {'volcano', 'warming', 'iceland', 'trigger', 'global', 'glacier', 'world'}
# ---
#
# {'volcano', 'warming', 'iceland', 'trigger', 'global', 'glacier', 'world'}
# ---
#
# {'like', 'wetter', 'change', 'warm', 'katrina', 'climate', 'level', 'future', 'rise', 'foot', 'flood'}
# ---
#
# {'sign', 'change', 'climate', 'drill', 'sheet', 'troubling', 'find', 'future', 'fast', 'geologist', 'melt', 'antarctica', 'come'}
# ---
#
# {'people', 'die', 'capitalism', 'change', 'climate', 'conference', 'claim', 'earth', 'morale', 'mother', 'world'}
# ---
#
# {'increase', 'warming', 'attack', 'global', 'gift', 'allergy'}
# ---
#
# {'environmental', 'bomb', 'issue', 'doubt', 'change', 'climate', 'africa', 'time', 'await'}
# ---
#
# {'carbon', 'ease', 'warming', 'buy', 'guilt', 'offset', 'global'}
# ---
#
# {'eye', 'cochabamba', 'havechancetospeakout', 'warming', 'alrdy', 'suffering', 'global'}
# ---
#
# {'ecomonday', 'change', 'discussion', 'climate', 'recommend', 'invasive', 'specie'}
# ---
#
# {'change', 'climate', 'migratory', 'bird', 'home', 'stay', 'strategy'}
# ---
#
# {'population', 'little', 'warming', 'cause', 'ocean', 'floor', 'oxygen', 'organism', 'despite', 'global'}
# ---
#
# {'irreversible', 'change', 'discussion', 'climate', 'security', 'destiny', 'earth', 'join', 'food'}
# ---
#
# {'change', 'york', 'climate', 'city', 'waterfront', 'consideration', 'plan'}
# ---
#
# {'mooney', 'change', 'climate', 'planet', 'combat', 'manipulate', 'geoengineere', 'danger'}
# ---
#
# {'get', 'seasonal', 'change', 'climate', 'bad', 'allergy'}
# ---
#
# {'peep', 'instead', 'warming', 'think', 'global', 'believe'}
# ---
#
# {'get', 'seasonal', 'change', 'climate', 'bad', 'allergy'}
# ---
#
# {'live', 'oceanfront', 'warming', 'property', 'advise', 'dead', 'think', 'global'}
# ---
#
# {'cap', 'help', 'warming', 'melt', 'trigger', 'global', 'volcanic', 'eruption'}
# ---
#
# {'clim', 'ellen', 'mary', 'win', 'change', 'climate', 'john', 'heart', 'harte', 'sustainability', 'address'}
# ---
#
# {'declare', 'warming', 'state', 'unequivocal', 'dept', 'human', 'global', 'induce', 'primarily'}
# ---
#
# {'change', 'bet', 'climate', 'corporation', 'conclude', 'increasingly', 'real'}
# ---
#
# {'house', 'earthday', 'branson', 'right', 'message', 'global', 'richard'}
# ---
#
# {'animal', 'warming', 'monday', 'wise', 'bad', 'cynthia', 'meat', 'make', 'global', 'bateman', 'agriculture'}
# ---
#
# {'cap', 'help', 'warming', 'melt', 'trigger', 'global', 'volcanic', 'eruption'}
# ---
#
# {'declare', 'warming', 'state', 'unequivocal', 'dept', 'human', 'global', 'induce', 'primarily'}
# ---
#
# {'cap', 'warming', 'melt', 'trigger', 'global', 'volcanic', 'eruption'}
# ---
#
# {'fix', 'kind', 'warming', 'sigh', 'idea', 'love', 'environmentalism', 'come', 'class', 'global'}
# ---
#
# {'awareness', 'increase', 'threat', 'green', 'warming', 'overview', 'revolution', 'global', 'go'}
# ---
#
# {'limpopo', 'temperature', 'change', 'climate', 'bring', 'southern', 'high', 'compete', 'water', 'africa', 'southe'}
# ---
#
# {'hekla', 'year', 'warming', 'iceland', 'spill', 'earth', 'global', 'eruption', 'strike'}
# ---
#
# {'america', 'change', 'climate', 'photo', 'place'}
# ---
#
# {'episcopal', 'issue', 'change', 'climate', 'daily', 'bangor', 'maine', 'time', 'important', 'bishop', 'lane'}
# ---
#
# {'volcano', 'change', 'climate', 'iceland', 'case', 'wonder', 'impact'}
# ---
#
# {'thing', 'discussion', 'warming', 'interest', 'heat', 'honest', 'cool', 'global'}
# ---
#
# {'pattern', 'change', 'climate', 'billion', 'bird', 'migration'}
# ---
#
# {'america', 'change', 'climate', 'photo', 'place'}
# ---
#
# {'change', 'warming', 'hazardous', 'trigger', 'spark', 'volcanic', 'global', 'cloud'}
# ---
#
# {'change', 'warming', 'hazardous', 'trigger', 'spark', 'volcanic', 'global', 'cloud'}
# ---
#
# {'volcano', 'get', 'cooling', 'warming', 'improve', 'slow', 'stratosphere', 'wonder', 'brief', 'global'}
# ---
#
# {'obama', 'thursd', 'april', 'say', 'change', 'climate', 'sydney', 'president', 'wait', 'barack', 'china'}
# ---
#
# {'jindal', 'volcano', 'change', 'read', 'climate', 'warning', 'bobby', 'paper', 'lately', 'mock', 'denier', 'think', 'start'}
# ---
#
# {'get', 'cara', 'strand', 'change', 'adapt', 'climate', 'weekend', 'preview', 'merte', 'tedxvolcano', 'sneak'}
# ---
#
# {'thing', 'change', 'larry', 'climate', 'important', 'science', 'fight', 'face', 'brilliant', 'single', 'tedxvolcano', 'socmedia'}
# ---
#
# {'thing', 'change', 'larry', 'climate', 'important', 'socent', 'green', 'science', 'fight', 'face', 'brilliant', 'single', 'tedxvolcano'}
# ---
#
# {'volcano', 'get', 'warming', 'crazy', 'europe', 'global', 'activating', 'damn', 'cloud'}
# ---
#
# {'crisis', 'change', 'larry', 'climate', 'science', 'attack', 'brilliant', 'tedxvolcano', 'exacerbate'}
# ---
#
# {'volcano', 'jonah', 'goldberg', 'warming', 'cause', 'oslo', 'iceland', 'reuters', 'thaw', 'global', 'eruption'}
# ---
#
# {'change', 'climate', 'conversation', 'indigenous', 'bring', 'voice'}
# ---
#
# {'volcano', 'awaken', 'change', 'climate', 'activity', 'volcanic', 'icelandic', 'thaw'}
# ---
#
# {'entire', 'south', 'rain', 'change', 'climate', 'nikolas', 'affect', 'amazon', 'kozloff'}
# ---
#
# {'america', 'change', 'climate', 'photo', 'place'}
# ---
#
# {'volcano', 'bury', 'hmmm', 'warming', 'iceland', 'lede', 'melt', 'global', 'glacier'}
# ---
#
# {'consensus', 'volcano', 'crisis', 'change', 'sure', 'climate', 'warn', 'melt', 'lead', 'scientist'}
# ---
#
# {'cochabamba', 'wish', 'people', 'change', 'climate', 'conference', 'earth', 'right', 'mother', 'world'}
# ---
#
# {'near', 'seasonal', 'change', 'climate', 'record', 'spring', 'bad', 'high', 'feel', 'make', 'allergy'}
# ---
#
# {'near', 'seasonal', 'change', 'climate', 'record', 'spring', 'bad', 'high', 'make', 'allergy'}
# ---
#
# {'like', 'change', 'climate', 'glaci', 'disrupt', 'thaw', 'volcanic', 'icelandic', 'eruption', 'travel'}
# ---
#
# {'summit', 'cochabamba', 'change', 'climate', 'combat', 'approach', 'offer'}
# ---
#
# {'simple', 'user', 'change', 'climate', 'power', 'remind', 'computer', 'workin', 'environment'}
# ---
#
# {'reason', 'perspective', 'renewal', 'climate', 'connecticut', 'bring', 'concern'}
# ---
# {'switch', 'warming', 'warn', 'long', 'accelerate', 'renewable', 'scientist', 'need', 'global'}
# ---
#
# {'culprit', 'pollen', 'chart', 'change', 'climate', 'count'}
# ---
#
# {'tired', 'change', 'level', 'climate', 'ground', 'coalition', 'fight', 'wait'}
# ---
#
# {'wednesday', 'season', 'change', 'climate', 'wildlife', 'report', 'release', 'national', 'allergy', 'worsen'}
# ---
#
# {'tired', 'change', 'level', 'climate', 'ground', 'coalition', 'fight', 'wait'}
# ---
#
# {'author', 'america', 'rain', 'south', 'change', 'climate', 'entire', 'planet', 'affect', 'amazon', 'nikola', 'kozloff'}
# ---
#
# {'tired', 'change', 'level', 'climate', 'ground', 'coalition', 'fight', 'wait'}
# ---
#
# {'tired', 'change', 'level', 'climate', 'ground', 'coalition', 'fight', 'wait'}
# ---
#
# {'tired', 'change', 'level', 'climate', 'ground', 'coalition', 'fight', 'wait'}
# ---
#
# {'season', 'change', 'climate', 'bad', 'allergy', 'report'}
# ---
#
# {'article', 'denialist', 'mention', 'send', 'finnish', 'purportedly', 'warming', 'refute', 'global', 'newspaper', 'cute'}
# ---
#
# {'necessary', 'nationalize', 'warming', 'energy', 'fight', 'industry', 'global'}
# ---
#
# {'volcano', 'likely', 'iceland', 'intensify', 'slow', 'vast', 'global', 'volcanic', 'eruption', 'cloud'}
# ---
#
# {'reading', 'warming', 'bad', 'allergy', 'global', 'blame'}
# ---
#
# {'leave', 'population', 'group', 'change', 'climate', 'indigenous', 'partnership', 'curb', 'forest', 'conservation'}
# ---
#
# {'problem', 'say', 'change', 'climate', 'tbagger', 'ignorant', 'think'}
# ---
#
# {'change', 'climate', 'affect', 'future', 'heat', 'miss'}
# ---
#
# {'change', 'climate', 'green', 'economy', 'build'}
# ---
#
# {'park', 'change', 'montana', 'climate', 'economy', 'threaten', 'national', 'glaci'}
# ---
#
# {'raise', 'change', 'york', 'climate', 'cost', 'allergy'}
# ---
#
# {'perspective', 'population', 'change', 'climate', 'ecotone'}
# ---
#
# {'coastal', 'change', 'climate', 'migration', 'ventura', 'county', 'dwindle', 'whale', 'blame'}
# ---
#
# {'michig', 'change', 'climate', 'kick', 'wait', 'think', 'allergy'}
# ---
#
# {'raise', 'change', 'exclusive', 'climate', 'reuter', 'cost'}
# ---
#
# {'late', 'storm', 'season', 'little', 'year', 'warming', 'spring', 'global', 'start'}
# ---
#
# {'drought', 'test', 'pastoralist', 'change', 'climate', 'kenya', 'extreme', 'perception', 'weather', 'effect'}
# ---
#
# {'throw', 'change', 'climate', 'curve', 'baseball', 'major', 'league', 'denier', 'team'}
# ---
#
# {'endanger', 'change', 'climate', 'save', 'newsweek', 'place'}
# ---
#
# {'tree', 'help', 'warming', 'reduce', 'birthday', 'absorb', 'global', 'plant'}
# ---
#
# {'multiple', 'bill', 'change', 'states', 'climate', 'kerry', 'green', 'united', 'benefit', 'energy', 'lead'}
# ---
#
# {'change', 'computing', 'green', 'climate', 'internet', 'fight'}
# ---
#
# {'cleantechnica', 'business', 'change', 'climate', 'action', 'create'}
# ---
#
# {'change', 'computing', 'green', 'climate', 'internet', 'fight', 'software'}
# ---
#
# {'document', 'change', 'climate', 'leak', 'call', 'tackle'}
# ---
#
# {'endanger', 'change', 'climate', 'save', 'newsweek', 'place'}
# ---
#
# {'change', 'climate', 'stop', 'reinvent', 'city'}
# ---
#
# {'park', 'change', 'climate', 'continue', 'melt', 'national', 'icon', 'glaci'}
# ---
#
# {'endanger', 'change', 'climate', 'save', 'newsweek', 'place'}
# ---
#
# {'endanger', 'change', 'climate', 'save', 'newsweek', 'place'}
# ---
#
# {'threat', 'culture', 'change', 'climate', 'face', 'arabia', 'dhabi', 'society', 'expert', 'flood'}
# ---
#
# {'say', 'change', 'active', 'climate', 'president', 'humani', 'tackle', 'china', 'vice'}
# ---
#
# {'say', 'change', 'active', 'climate', 'tackle', 'china'}
# ---
#
# {'asia', 'change', 'climate', 'study', 'hard'}
# ---
#
# {'change', 'help', 'climate', 'wildlife', 'habitat', 'protect', 'action'}
# ---
#
# {'obama', 'change', 'climate', 'soon', 'china'}
# ---
#
# {'change', 'help', 'climate', 'wildlife', 'habitat', 'protect', 'action'}
# ---
#
# {'change', 'help', 'climate', 'wildlife', 'habitat', 'protect', 'action'}
# ---
#
# {'change', 'help', 'climate', 'wildlife', 'habitat', 'protect', 'action'}
# ---
#
# {'sign', 'change', 'climate', 'congress', 'petition', 'demand', 'action'}
# ---
#
# {'carbon', 'change', 'climate', 'legislation', 'kill'}
# ---
#
# {'obama', 'interview', 'say', 'allow', 'change', 'climate', 'wait', 'tackle', 'china'}
# ---
#
# {'government', 'warming', 'cause', 'claim', 'global', 'cancer'}
# ---
#
# {'government', 'warming', 'cause', 'claim', 'global', 'cancer'}
# ---
#
# {'change', 'climate', 'wildlife', 'habitat', 'protect'}
# ---
#
# {'california', 'change', 'climate', 'plan', 'brace'}
# ---
#
# {'change', 'help', 'climate', 'wildlife', 'habitat', 'protect', 'action'}
# ---
#
# {'work', 'greenpeace', 'warming', 'stop', 'involve', 'greenpeac', 'global'}
# ---
#
# {'change', 'help', 'climate', 'wildlife', 'habitat', 'protect', 'action'}
# ---
#
# {'illness', 'say', 'government', 'warming', 'cause', 'mental', 'global', 'cancer', 'report'}
# ---
#
# {'hold', 'company', 'change', 'climate', 'publically', 'investor', 'risk', 'warn', 'advise'}
# ---
#
# {'snake', 'change', 'climate', 'long', 'dawdle', 'aisle', 'come', 'debate', 'gore'}
# ---
#
# {'mean', 'grape', 'change', 'climate', 'trouble', 'wrath', 'agriculture'}
# ---
#
# {'goldberg', 'jonah', 'warming', 'magazine', 'bad', 'time', 'allergy', 'global', 'blame'}
# ---
#
# {'get', 'change', 'climate', 'bad', 'allergy'}
# ---
#
# {'watch', 'intensify', 'actually', 'clean', 'dim', 'global'}
# ---
#
# {'people', 'likely', 'change', 'developed', 'climate', 'cause', 'affect', 'country', 'time', 'poor', 'disaster', 'world'}
# ---
#
# {'goldberg', 'jonah', 'warming', 'magazine', 'bad', 'time', 'allergy', 'global', 'blame'}
# ---
#
# {'change', 'climate', 'management', 'science', 'italy', 'programme'}
# ---
#
# {'community', 'change', 'rural', 'climate', 'devastating', 'ethiopian', 'oxfam'}
# ---
#
# {'technology', 'development', 'warming', 'alexi', 'pollutant', 'alternative', 'spur', 'put', 'ilsen', 'global', 'price', 'believe'}
# ---
#
# {'push', 'change', 'green', 'climate', 'action', 'athlete', 'olympic'}
# ---
#
# {'work', 'greenpeace', 'warming', 'stop', 'involve', 'global'}
# ---
#
# {'change', 'climate', 'deal', 'extend', 'human', 'health', 'effect', 'impact'}
# ---
#
# {'unprecedented', 'change', 'climate', 'cause', 'ocean', 'rate', 'chemistry'}
# ---
#
# {'warming', 'bad', 'allergy', 'global', 'blame'}
# ---
#
# {'bat', 'lizard', 'change', 'climate', 'bird', 'fight', 'wire'}
# ---
#
# {'sign', 'change', 'earthday', 'climate', 'petition', 'action'}
# ---
#
# {'change', 'climate', 'treat', 'curable', 'disease'}
# ---
#
# {'herald', 'keep', 'warming', 'honest', 'vallejo', 'time', 'editorial', 'global', 'debate', 'believe'}
# ---
#
# {'work', 'member', 'challenge', 'change', 'climate', 'solution', 'address', 'motorola'}
# ---
#
# {'capitalism', 'warming', 'president', 'bolivian', 'global', 'blame'}
# ---
#
# {'like', 'immediate', 'prob', 'macro', 'warming', 'election', 'politician', 'point', 'interesting', 'solve', 'global', 'need'}
# ---
#
# {'increase', 'warming', 'attack', 'global', 'gift', 'allergy'}
# ---
#
# {'change', 'climate', 'continent', 'animation', 'effect', 'download', 'global', 'view'}
# ---
#
# {'sign', 'change', 'climate', 'hint', 'drop', 'lawmaker', 'tell', 'petition', 'know', 'ready'}
# ---
#
# {'policy', 'carbon', 'change', 'climate', 'reduction', 'goal', 'expand', 'emission'}
# ---
#
# {'declare', 'warming', 'state', 'unequivocal', 'dept', 'human', 'global', 'induce', 'primarily'}
# ---
#
# {'snowy', 'winter', 'cold', 'warming', 'earl', 'bad', 'follow', 'thank', 'allergy', 'global', 'blame', 'unusually'}
# ---
#
# {'change', 'climate', 'sarah', 'give', 'nature', 'ridiculous', 'denier', 'discovery', 'palin'}
# ---
#
# {'season', 'suck', 'change', 'read', 'climate', 'bad', 'allergy', 'report'}
# ---
#
# {'innovation', 'technology', 'change', 'climate', 'coda', 'laud', 'effort', 'pollution', 'combat', 'automotive'}
# ---
#
# {'increase', 'change', 'climate', 'report', 'claim', 'allergy', 'blame'}
# ---
#
# {'increase', 'change', 'climate', 'report', 'claim', 'allergy', 'blame'}
# ---
#
# {'april', 'chicago', 'tulip', 'warming', 'love', 'global'}
# ---
#
# {'million', 'americans', 'warming', 'globalwarme', 'bad', 'climatewire', 'global', 'hard', 'hit', 'asthma', 'allergy'}
# ---
#
# {'april', 'warming', 'nice', 'degree', 'meet', 'global', 'hellooo'}
# ---
#
# {'article', 'mention', 'adapt', 'change', 'climate', 'crop', 'rejoice', 'time', 'relative', 'agriculture', 'wild'}
# ---
#
# {'document', 'change', 'climate', 'call', 'tackle'}
# ---
#
# {'document', 'change', 'climate', 'call', 'tackle'}
# ---
#
# {'namesake', 'park', 'usgs', 'warming', 'report', 'global', 'glacier', 'go'}
# ---
#
# {'institute', 'jackson', 'change', 'climate', 'heat', 'feel', 'erwin', 'come'}
# ---
#
# {'college', 'change', 'climate', 'democracy', 'mobilise', 'lead', 'tackle', 'schumacher'}
# ---
#
# {'raise', 'change', 'exclusive', 'climate', 'cost', 'allergy'}
# ---
#
# {'million', 'environmental', 'receive', 'change', 'climate', 'impact', 'study', 'health', 'harvard'}
# ---
#
# {'hill', 'today', 'change', 'kerry', 'climate', 'lead', 'write'}
# ---
#
# {'raise', 'change', 'exclusive', 'climate', 'cost', 'allergy'}
# ---
#
# {'chouinard', 'yvon', 'clothing', 'warming', 'patagonia', 'industry', 'place', 'fortunegreen', 'global', 'start'}
# ---
#
# {'people', 'change', 'climate', 'filmmaker', 'globe', 'find', 'fight', 'travel'}
# ---
# {'people', 'change', 'climate', 'filmmaker', 'globe', 'find', 'fight', 'travel'}
# ---
#
# {'oilspill', 'america', 'gulf', 'warming', 'future', 'energy', 'fight', 'effort', 'spur', 'remake', 'global', 'harm'}
# ---
#
# {'unemployment', 'decade', 'person', 'change', 'climate', 'planet', 'catastrophic', 'think', 'life', 'average'}
# ---
#
# {'get', 'loss', 'arctic', 'warming', 'bad', 'accelerate', 'research', 'zealand', 'global', 'topnew'}
# ---
#
# {'california', 'change', 'climate', 'take', 'lead'}
# ---
#
# {'leave', 'warming', 'washington', 'effective', 'tackle', 'account', 'global', 'plant'}
# ---
#
# {'govt', 'change', 'active', 'climate', 'namibia'}
# ---
#
# {'warming', 'effective', 'tackle', 'global', 'plant'}
# ---
#
# {'change', 'climate', 'warming', 'idea', 'wait', 'natural', 'human', 'global', 'induce'}
# ---
#
# {'general', 'america', 'change', 'read', 'climate', 'threaten', 'security'}
# ---
#
# {'earthweek', 'warming', 'planet', 'glacial', 'volcanos', 'diary', 'melt', 'unplug', 'eruption', 'global'}
# ---
#
# {'military', 'general', 'change', 'climate', 'admiral', 'threaten'}
# ---
#
# {'obama', 'urge', 'change', 'climate', 'wildlife', 'drilling', 'shore', 'contribute', 'expand', 'threaten'}
# ---
#
# {'temperature', 'allgov', 'warming', 'warm', 'reach', 'frozen', 'news', 'canada', 'global'}
# ---
#
# {'illness', 'say', 'government', 'warming', 'cause', 'warmin', 'mental', 'global', 'cancer', 'report'}
# ---
#
# {'obama', 'holdren', 'pick', 'say', 'warming', 'john', 'science', 'steam', 'global', 'adviser'}
# ---
#
# {'pricy', 'change', 'year', 'climate', 'billion', 'cost', 'lyme', 'disease'}
# ---
#
# {'antarc', 'carry', 'excrement', 'australian', 'researcher', 'states', 'warming', 'united', 'check', 'topnews', 'whale', 'global'}
# ---
#
# {'illness', 'matt', 'say', 'government', 'staff', 'warming', 'cause', 'mental', 'writer', 'cover', 'global', 'cancer', 'report'}
# ---
#
# {'proble', 'warming', 'proof', 'save', 'whale', 'need', 'global', 'report'}
# ---
#
# {'grape', 'good', 'system', 'warming', 'wine', 'warn', 'effect', 'early', 'global'}
# ---
#
# {'grape', 'good', 'system', 'warming', 'wine', 'warn', 'effect', 'early', 'global'}
# ---
#
# {'change', 'climate', 'evidence', 'warming', 'show', 'global', 'indicator', 'report'}
# ---
#
# {'defense', 'change', 'resource', 'climate', 'evidence', 'warming', 'show', 'counc', 'natural', 'global', 'indicator', 'report'}
# ---
#
# {'husin', 'syed', 'warming', 'malaysia', 'want', 'know', 'effect', 'global'}
# ---
#
# {'mayeda', 'trek', 'warming', 'lori', 'preuitt', 'voyage', 'fight', 'convinced', 'star', 'home', 'whale', 'global'}
# ---
#
# {'support', 'kesner', 'fact', 'warming', 'reliable', 'case', 'writer', 'charle', 'global', 'touch', 'letter', 'recent'}
# ---
#
# {'change', 'climate', 'study', 'threaten', 'health'}
# ---
#
# {'slideshow', 'warming', 'alaska', 'effect', 'global'}
# ---
#
# {'delicate', 'grape', 'good', 'vino', 'verita', 'system', 'warming', 'wine', 'warn', 'effect', 'early', 'global'}
# ---
#
# {'change', 'help', 'climate', 'international', 'provide', 'habitat', 'specie', 'endangered', 'prevent', 'gift', 'conservation'}
# ---
#
# {'change', 'help', 'climate', 'international', 'provide', 'habitat', 'specie', 'endangered', 'prevent', 'gift', 'conservation'}
# ---
#
# {'increase', 'warming', 'ocean', 'contribute', 'council', 'warn', 'research', 'rapidly', 'national', 'global', 'acidification'}
# ---
#
# {'warming', 'province', 'threaten', 'global', 'southernmost', 'locality'}
# ---
#
# {'mean', 'warming', 'storming', 'global', 'local'}
# ---
#
# {'staff', 'mark', 'warming', 'intensify', 'past', 'actually', 'earth', 'clean', 'global', 'world'}
# ---
#
# {'million', 'datum', 'warming', 'pull', 'salinity', 'ocean', 'energy', 'show', 'renewable', 'saltiness', 'advance', 'global'}
# ---
#
# {'late', 'fix', 'november', 'steven', 'warming', 'magazine', 'energy', 'secretary', 'global', 'china'}
# ---
#
# {'carbon', 'change', 'year', 'warming', 'ocean', 'fast', 'chemistry', 'global'}
# ---
#
# {'complicate', 'warming', 'mountain', 'rate', 'sciencedaily', 'concl', 'topography', 'study', 'global'}
# ---
#
# {'soar', 'attribute', 'environmentalist', 'global', 'mercury', 'blame'}
# ---
#
# {'environmental', 'crisis', 'change', 'climate', 'warming', 'africa', 'present', 'gathering', 'global', 'monitor'}
# ---
#
# {'plane', 'help', 'warming', 'reduce', 'volcanic', 'global'}
# ---
#
# {'strong', 'ocean', 'current', 'nasa', 'despite', 'global', 'discover'}
# ---
#
# {'strong', 'ocean', 'current', 'nasa', 'despite', 'global', 'discover'}
# ---
#
# {'journey', 'distance', 'fashion', 'warming', 'cause', 'change', 'bird', 'migration', 'sourc', 'long', 'evolutionary', 'global'}
# ---
#
# {'increase', 'funniest', 'change', 'conservative', 'climate', 'core', 'heat', 'earth', 'comment'}
# ---
#
# {'rhode', 'flounder', 'marine', 'warming', 'affect', 'narragansett', 'island', 'long', 'scientist', 'life', 'global', 'winter'}
# ---
#
# {'stupid', 'james', 'redd', 'warming', 'locally', 'environmentally', 'doubter', 'architect', 'theimer', 'know', 'global'}
# ---
#
# {'indonesia', 'tree', 'help', 'warming', 'reduce', 'planting', 'look', 'pre', 'natural', 'program', 'global', 'maintain'}
# ---
#
# {'endanger', 'change', 'climate', 'earth', 'health', 'report'}
# ---
#
# {'chapmanu', 'say', 'change', 'climate', 'cause', 'matter', 'deal', 'cubeyond', 'wlliam', 'happen'}
# ---
#
# {'redistribution', 'warming', 'cause', 'way', 'animal', 'focus', 'specie', 'global', 'plant', 'chew'}
# ---
#
# {'military', 'change', 'climate', 'fight', 'lead'}
# ---
#
# {'period', 'stunner', 'royal', 'warming', 'climate', 'chan', 'activity', 'hazardous', 'geosphere', 'exceptional', 'society', 'global', 'link'}
# ---
#
# {'gunther', 'marc', 'warming', 'rarely', 'fight', 'poverty', 'africa', 'global', 'view', 'comment'}
# ---
#
# {'military', 'change', 'climate', 'fight', 'reuter', 'lead'}
# ---
#
# {'change', 'climate', 'day', 'spring', 'early', 'come'}
# ---
#
# {'supercomputer', 'change', 'climate', 'nasa', 'launch'}
# ---
#
# {'policy', 'environmental', 'limit', 'change', 'climate', 'excellent', 'option', 'economic'}
# ---
#
# {'tonight', 'community', 'family', 'change', 'discuss', 'climate', 'child', 'woman'}
# ---
#
# {'boomer', 'anonymous', 'baby', 'warming', 'enjoy', 'large', 'tackle', 'peace', 'global'}
# ---
#
# {'warming', 'intensify', 'ocean', 'treehugger', 'show', 'water', 'saltiness', 'global', 'cycle'}
# ---
#
# {'esty', 'change', 'greenhouse', 'climate', 'system', 'daniel', 'bring', 'trade', 'plan', 'emission'}
# ---
#
# {'military', 'government', 'change', 'climate', 'fight', 'washington', 'reuters', 'large', 'lead'}
# ---
#
# {'warming', 'bird', 'migration', 'science', 'implicate', 'codex', 'global', 'shorten'}
# ---
#
# {'supercomputer', 'change', 'climate', 'earth', 'gift'}
# ---
#
# {'esty', 'change', 'greenhouse', 'climate', 'system', 'daniel', 'bring', 'trade', 'plan', 'emission'}
# ---
#
# {'warming', 'biologist', 'bloom', 'early', 'global', 'link'}
# ---
#
# {'plant', 'central', 'say', 'flower', 'researcher', 'warming', 'wisconsin', 'biologist', 'bloom', 'early', 'global', 'link'}
# ---
#
# {'cochabamba', 'bolivia', 'april', 'capitalism', 'warming', 'president', 'news', 'bolivian', 'service', 'global', 'blame', 'environment'}
# ---
#
# {'site', 'uruguay', 'change', 'climate', 'geopolitic', 'vulnerable', 'tool', 'acosta', 'global', 'need'}
# ---
#
# {'volcano', 'explosive', 'warming', 'idea', 'cure', 'global'}
# ---
#
# {'live', 'leader', 'change', 'climate', 'indigenous', 'woman', 'national'}
# ---
#
# {'series', 'change', 'climate', 'worldnew', 'city', 'happen'}
# ---
#
# {'vatican', 'carbon', 'warming', 'reduce', 'science', 'christian', 'scheme', 'forest', 'offset', 'fail', 'global', 'monitor'}
# ---
#
# {'carbon', 'ease', 'warming', 'buy', 'guilt', 'offset', 'global'}
# ---
#
# {'mooney', 'change', 'climate', 'planet', 'combat', 'manipulate', 'geoengineere', 'danger'}
# ---
#
# {'volcano', 'warming', 'green', 'bird', 'nasa', 'alisa', 'captur', 'transportation', 'opar', 'global', 'satellite', 'icelandic', 'impact'}
# ---
#
# {'england', 'warming', 'bird', 'southern', 'suffer', 'global'}
# ---
#
# {'get', 'change', 'climate', 'focus', 'video'}
# ---
#
# {'volcano', 'warming', 'trigger', 'volcanic', 'global', 'cloud'}
# ---
#
# {'alter', 'collapse', 'warming', 'financial', 'traffic', 'european', 'global', 'blame'}
# ---
#
# {'environmental', 'make', 'sense', 'warming', 'oppose', 'effort', 'republicans', 'global'}
# ---
#
# {'change', 'climate', 'nuclear', 'solution', 'energy', 'safe', 'secure'}
# ---
#
# {'volcano', 'eyjafjoell', 'warming', 'trigger', 'global'}
# ---
#
# {'declare', 'warming', 'state', 'unequivocal', 'dept', 'human', 'global', 'induce', 'primarily'}
# ---
#
# {'climate', 'warming', 'unequivocal', 'action', 'release', 'global', 'report'}
# ---
#
# {'cap', 'help', 'warming', 'melt', 'trigger', 'global', 'volcanic', 'eruption'}
# ---
# {'change', 'climate', 'photo', 'tell', 'dare', 'real'}
# ---
#
# {'climate', 'warming', 'brian', 'treehugger', 'unequivocal', 'action', 'merchant', 'release', 'brooklyn', 'global', 'report'}
# ---
#
# {'volcano', 'hekla', 'warming', 'nature', 'global', 'icelandic', 'earthquake', 'mother'}
# ---
#
# {'volcano', 'warming', 'trouble', 'global', 'blame'}
# ---
#
# {'reminder', 'warming', 'agree', 'scientist', 'politician', 'nearly', 'health', 'global', 'debate'}
# ---
#
# {'volcano', 'hekla', 'warming', 'earth', 'ashtag', 'global', 'icelandic', 'earthquake', 'mother'}
# ---
#
# {'change', 'climate', 'biden', 'romm', 'quote'}
# ---
#
# {'change', 'climate', 'green', 'stop', 'living', 'idea', 'reinvent', 'city'}
# ---
#
# {'cleantechnica', 'throw', 'change', 'climate', 'curve', 'baseball', 'major', 'league', 'denier', 'team'}
# ---
#
# {'warming', 'pollution', 'lack', 'global', 'pirate'}
# ---
#
# {'decade', 'migrating', 'change', 'warming', 'billion', 'bird', 'estimate', 'global', 'habit'}
# ---
#
# {'system', 'warming', 'tell', 'reuter', 'melt', 'magmatic', 'global', 'influence'}
# ---
#
# {'increase', 'atmospher', 'warming', 'upper', 'reduce', 'reporting', 'effect', 'sediment', 'global'}
# ---
#
# {'thing', 'good', 'warming', 'heat', 'lessens', 'block', 'volcanic', 'global', 'travel'}
# ---
#
# {'warming', 'news', 'pollution', 'clean', 'global', 'speed'}
# ---
#
# {'document', 'change', 'climate', 'leak', 'call', 'regime', 'tackle', 'global'}
# ---
#
# {'help', 'warming', 'pollution', 'clean', 'downswe', 'global', 'speed', 'aerosol'}
# ---
#
# {'help', 'warming', 'pollution', 'clean', 'downswe', 'global', 'speed', 'aerosol'}
# ---
#
# {'today', 'warming', 'stat', 'news', 'effect', 'youtube', 'global'}
# ---
#
# {'read', 'warm', 'climate', 'change', 'global'}
# ---
#
# {'archive', 'today', 'greenhous', 'warming', 'blog', 'reduce', 'tackle', 'present', 'global'}
# ---
#
# {'change', 'climate', 'coda', 'effort', 'laud', 'pollution', 'combat', 'automotive'}
# ---
#
# {'get', 'indyposte', 'austral', 'warming', 'blog', 'ocean', 'scientist', 'weird', 'study', 'saltiness', 'global', 'conduct', 'blame'}
# ---
#
# {'explore', 'change', 'climate', 'evolution', 'science', 'scientist'}
# ---
#
# {'explore', 'change', 'climate', 'evolution', 'science', 'scientist'}
# ---
#
# {'tired', 'change', 'level', 'climate', 'ground', 'coalition', 'fight', 'wait'}
# ---
#
# {'social', 'prof', 'money', 'mazmanian', 'change', 'sppd', 'adaption', 'climate', 'state', 'justice', 'press', 'need', 'keston'}
# ---
#
# {'volcano', 'warming', 'iceland', 'unlikely', 'slow', 'scientist', 'global'}
# ---
#
# {'explore', 'change', 'climate', 'evolution', 'science', 'scientist'}
# ---
#
# {'volcano', 'warming', 'iceland', 'unlikely', 'cooling', 'slow', 'scientist', 'paris', 'volcanic', 'global', 'eruption'}
# ---
#
# {'bizarre', 'bat', 'threat', 'warming', 'history', 'unio', 'face', 'follow', 'european', 'cricket', 'london', 'global'}
# ---
#
# {'volcano', 'afpapril', 'warming', 'unlikely', 'slow', 'eumesat', 'ingham', 'image', 'global', 'satellite', 'richard'}
# ---
#
# {'explore', 'change', 'climate', 'evolution', 'science', 'scientist'}
# ---
#
# {'year', 'preach', 'warming', 'climate', 'teach', 'effect', 'catastrophic', 'global'}
# ---
#
# {'explore', 'change', 'climate', 'evolution', 'science', 'scientist'}
# ---
#
# {'obama', 'say', 'warming', 'president', 'wait', 'tackle', 'barack', 'commit', 'global', 'china', 'world'}
# ---
#
# {'warming', 'takei', 'solution', 'energy', 'university', 'alumnus', 'milton', 'renewable', 'deal', 'global', 'possible'}
# ---
#
# {'change', 'warming', 'climate', 'impact', 'effect', 'predict', 'youtube', 'global'}
# ---
#
# {'read', 'warming', 'fight', 'effect', 'post', 'global'}
# ---
#
# {'warming', 'news', 'poverty', 'battle', 'global', 'online'}
# ---
#
# {'warming', 'bad', 'allergy', 'global', 'blame'}
# ---
#
# {'partner', 'change', 'climate', 'fight', 'trade', 'important', 'germany'}
# ---
#
# ...
# ---
#
# {'change', 'climate', 'continent', 'vulnerable', 'service', 'meteorology', 'africa', 'gear'}
# ---
#
# {'carbon', 'mention', 'change', 'step', 'green', 'climate', 'living', 'daunting', 'gecko', 'credit'}
# ---
#
# {'fix', 'environmental', 'china', 'impact', 'expansion', 'world', 'sizable', 'rapid', 'global', 'come'}
# ---
#
# {'fix', 'environmental', 'china', 'impact', 'expansion', 'world', 'sizable', 'rapid', 'global', 'come'}
# ---
#
# {'listing', 'confront', 'change', 'york', 'green', 'examine', 'climate', 'check', 'local', 'yorker', 'go'}
# ---
#
# {'social', 'change', 'climate', 'cause', 'nasa', 'ftsn', 'official', 'report'}
# ---
#
# {'warming', 'safety', 'call', 'silly', 'crazy', 'rule', 'coal', 'global'}
# ---
#
# {'change', 'climate', 'extend', 'human', 'health', 'impact'}
# ---
#
# {'change', 'climate', 'extend', 'human', 'health', 'impact'}
# ---
#
# {'good', 'change', 'climate', 'solnit', 'news', 'rebecca'}
# ---
#
# {'efficiency', 'alpha', 'change', 'climate', 'take', 'energy'}
# ---
#
# {'carbon', 'mention', 'change', 'step', 'green', 'climate', 'living', 'daunting', 'gecko', 'credit'}
# ---
#
# {'warming', 'climate', 'scientist', 'tell', 'explain', 'natural', 'popular', 'meteorologist', 'variability', 'global'}
# ---
#
# {'good', 'change', 'climate', 'degree', 'solnit', 'news', 'rebecca', 'inseparability'}
# ---
#
# {'change', 'shangri', 'watch', 'climate', 'mountain', 'earthday', 'video', 'tibetan', 'include', 'know', 'threaten', 'sacred', 'land'}
# ---
#
# {'african', 'change', 'climate', 'service', 'meteorology', 'gear'}
# ---
#
# {'change', 'earthday', 'climate', 'economist', 'economy'}
# ---
#
# {'change', 'earthday', 'climate', 'economist', 'economy'}
# ---
#
# {'season', 'change', 'climate', 'bad', 'allergy', 'report'}
# ---
#
# {'bill', 'change', 'accountability', 'climate', 'save', 'kill'}
# ---
#
# {'change', 'earthday', 'climate', 'farmer', 'ethiopia', 'vulnerable', 'increasingly', 'make', 'pastoralist'}
# ---
#
# {'famine', 'politic', 'compare', 'change', 'climate', 'haye', 'founder', 'news', 'earth', 'irishcentral', 'denis', 'weather', 'global', 'irish'}
# ---
#
# {'change', 'earthday', 'climate', 'farmer', 'ethiopia', 'vulnerable', 'increasingly', 'make', 'pastoralist'}
# ---
#
# {'earthday', 'warming', 'aware', 'consume', 'treat', 'place', 'effect', 'global', 'waste'}
# ---
#
# {'verwaayen', 'change', 'earthday', 'climate', 'green', 'curb', 'earth'}
# ---
#
# {'nation', 'industrial', 'change', 'climate', 'feel', 'health', 'impact', 'report'}
# ---
#
# {'nation', 'industrial', 'change', 'climate', 'feel', 'health', 'impact', 'report'}
# ---
#
# {'nation', 'industrial', 'change', 'climate', 'feel', 'health', 'impact', 'report'}
# ---
#
# {'carbon', 'mention', 'change', 'step', 'green', 'climate', 'living', 'daunting', 'gecko', 'credit'}
# ---
#
# {'carbon', 'mention', 'change', 'step', 'climate', 'green', 'living', 'daunting', 'credit', 'biofuel'}
# ---
#
# {'raise', 'change', 'climate', 'reuters', 'cost', 'allergy'}
# ---
#
# {'change', 'climate', 'international', 'asilomar', 'later', 'treat', 'curable', 'bioethicist', 'expert', 'disease'}
# ---
#
# {'change', 'climate', 'international', 'asilomar', 'later', 'treat', 'curable', 'bioethicist', 'expert', 'disease'}
# ---
#
# {'warming', 'safety', 'call', 'silly', 'crazy', 'rule', 'coal', 'global'}
# ---
#
# {'military', 'change', 'climate', 'fight', 'lead', 'envnewsnet'}
# ---
#
# {'military', 'fuel', 'buyer', 'government', 'change', 'climate', 'fight', 'large', 'lead'}
# ---
#
# {'carbon', 'mention', 'change', 'step', 'climate', 'green', 'living', 'daunting', 'credit', 'biofuel'}
# ---
#
# {'main', 'goldberg', 'say', 'climate', 'cause', 'swedish', 'global', 'expert', 'fred'}
# ---
#
# {'warming', 'fight', 'energy', 'poverty', 'africa', 'global'}
# ---
#
# {'change', 'climate', 'green', 'science', 'treat', 'curable', 'sustainability', 'wire', 'disease'}
# ---
#
# {'change', 'climate', 'energy', 'time', 'tackle', 'wind'}
# ---
#
# {'listing', 'confront', 'change', 'examine', 'green', 'york', 'climate', 'check', 'local', 'thursday', 'yorker', 'go'}
# ---
#
# {'change', 'dialogue', 'climate', 'united', 'cooperation', 'seek', 'runaway', 'secretary', 'prevent', 'global', 'nations'}
# ---
#
# {'vatican', 'carbon', 'warming', 'reduce', 'forest', 'offset', 'fail', 'global'}
# ---
#
# {'vatican', 'carbon', 'warming', 'reduce', 'forest', 'offset', 'fail', 'global'}
# ---
#
# {'event', 'change', 'climate', 'nnimmo', 'bassey', 'struggle', 'important', 'environmentalist', 'nigerian'}
# ---
#
# {'military', 'change', 'climate', 'fight', 'lead'}
# ---
#
# {'evrything', 'inclde', 'issue', 'stake', 'identify', 'change', 'climate', 'affctd', 'mental', 'report', 'health', 'disease'}
# ---
#
# {'change', 'resource', 'climate', 'earth', 'cope'}
# ---
#
# {'warming', 'intensify', 'ocean', 'show', 'water', 'saltiness', 'global', 'cycle'}
# ---
#
# {'americans', 'change', 'climate', 'bauccio', 'time', 'combat', 'meal', 'week', 'fedele', 'celebrate', 'anniver'}
# ---
#
# {'support', 'cochabamba', 'people', 'live', 'change', 'climate', 'conf', 'world'}
# ---
#
# {'lot', 'push', 'change', 'climate', 'protocol', 'barrett', 'small', 'well', 'comprehensive'}
# ---
#
# {'complicate', 'warming', 'mountain', 'rate', 'topography', 'global'}
# ---
#
# {'support', 'cochabamba', 'people', 'bolivia', 'live', 'change', 'climate', 'watch', 'conference', 'world'}
# ---
#
# {'issue', 'smallpox', 'change', 'climate', 'require', 'operation', 'layer', 'universal', 'address', 'global', 'ozone'}
# ---
#
# {'main', 'bolivia', 'destruction', 'capitalism', 'earthday', 'warming', 'cause', 'green', 'president', 'earth', 'global'}
# ---
#
# {'subcontinent', 'boiling', 'change', 'climate', 'contain', 'point', 'spill', 'indian'}
# ---
#
# {'landslide', 'change', 'climate', 'warming', 'trigger', 'earthquake', 'world'}
# ---
#
# {'cleantech', 'uruguay', 'change', 'climate', 'vulnerable', 'tool', 'need'}
# ---
#
# {'uruguay', 'change', 'climate', 'vulnerable', 'tool', 'need'}
# ---
#
# {'uruguay', 'change', 'climate', 'vulnerable', 'tool', 'need'}
# ---
#
# {'vatican', 'carbon', 'warming', 'reduce', 'forest', 'offset', 'fail', 'global'}
# ---
#
# {'vatican', 'carbon', 'warming', 'reduce', 'forest', 'offset', 'fail', 'global'}
# ---
#
# {'increase', 'solar', 'change', 'climate', 'ethiopia', 'poverty', 'vulnerability', 'africa'}
# ---
#
# {'increase', 'change', 'climate', 'farmer', 'small', 'ethiopia', 'africa', 'scale', 'poverty', 'vulnerability', 'pastoralist'}
# ---
#
# {'event', 'change', 'climate', 'nnimmo', 'bassey', 'struggle', 'important', 'environmentalist', 'nigerian'}
# ---
#
# {'event', 'change', 'climate', 'nnimmo', 'bassey', 'struggle', 'important', 'environmentalist', 'nigerian'}
# ---
#
# {'warming', 'intensify', 'ocean', 'show', 'water', 'saltiness', 'global', 'cycle'}
# ---
#
# {'policy', 'chinagreen', 'change', 'year', 'climate', 'backgrounder', 'tackle', 'major', 'china'}
# ---
#
# {'steven', 'april', 'point', 'biologist', 'bloom', 'early', 'press', 'global', 'link'}
# ---
#
# {'steven', 'april', 'point', 'biologist', 'bloom', 'early', 'press', 'global', 'link'}
# ---
#
# {'warming', 'evidence', 'look', 'doubter', 'message', 'global', 'denier'}
# ---
#
# {'warming', 'evidence', 'look', 'doubter', 'message', 'global', 'denier'}
# ---
#
# {'warming', 'evidence', 'look', 'doubter', 'message', 'global', 'denier'}
# ---
#
# {'volcano', 'warming', 'iceland', 'trigger', 'global', 'glacier', 'world'}
# ---
#
# {'volcano', 'warming', 'iceland', 'trigger', 'global', 'glacier', 'world'}
# ---
#
# {'like', 'wetter', 'change', 'warm', 'katrina', 'climate', 'level', 'future', 'rise', 'foot', 'flood'}
# ---
#
# {'sign', 'change', 'climate', 'drill', 'sheet', 'troubling', 'find', 'future', 'fast', 'geologist', 'melt', 'antarctica', 'come'}
# ---
#
# {'people', 'die', 'capitalism', 'change', 'climate', 'conference', 'claim', 'earth', 'morale', 'mother', 'world'}
# ---
#
# {'increase', 'warming', 'attack', 'global', 'gift', 'allergy'}
# ---
#
# {'environmental', 'bomb', 'issue', 'doubt', 'change', 'climate', 'africa', 'time', 'await'}
# ---
#
# {'carbon', 'ease', 'warming', 'buy', 'guilt', 'offset', 'global'}
# ---
#
# {'eye', 'cochabamba', 'havechancetospeakout', 'cmpcc', 'warming', 'alrdy', 'suffering', 'global'}
# ---
#
# {'ecomonday', 'change', 'discussion', 'climate', 'recommend', 'invasive', 'specie'}
# ---
#
# {'change', 'climate', 'migratory', 'bird', 'proof', 'warming', 'green', 'home', 'stay', 'global', 'strategy'}
# ---
#
# {'population', 'little', 'warming', 'cause', 'ocean', 'floor', 'oxygen', 'organism', 'despite', 'global'}
# ---
#
# {'irreversible', 'live', 'change', 'discussion', 'climate', 'webcast', 'security', 'destiny', 'earth', 'join', 'food'}
# ---
#
# {'change', 'york', 'climate', 'city', 'waterfront', 'consideration', 'plan'}
# ---
#
# {'mooney', 'change', 'climate', 'planet', 'combat', 'manipulate', 'geoengineere', 'danger'}
# ---
#
# {'get', 'seasonal', 'change', 'climate', 'bad', 'allergy'}
# ---
#
# {'peep', 'instead', 'warming', 'think', 'global', 'believe'}
# ---
#
# {'get', 'seasonal', 'change', 'climate', 'bad', 'allergy'}
# ---
#
# {'live', 'oceanfront', 'warming', 'property', 'advise', 'dead', 'think', 'global'}
# ---
#
# {'cap', 'help', 'warming', 'melt', 'trigger', 'global', 'volcanic', 'eruption'}
# ---
#
# {'clim', 'ellen', 'mary', 'win', 'change', 'climate', 'john', 'heart', 'harte', 'sustainability', 'address'}
# ---
#
# {'declare', 'warming', 'state', 'unequivocal', 'dept', 'human', 'global', 'induce', 'primarily'}
# ---
# {'change', 'bet', 'climate', 'corporation', 'conclude', 'increasingly', 'real'}
# ---
#
# {'house', 'earthday', 'branson', 'right', 'message', 'global', 'richard'}
# ---
#
# {'animal', 'warming', 'monday', 'wise', 'bad', 'cynthia', 'meat', 'make', 'global', 'bateman', 'agriculture'}
# ---
#
# {'cap', 'help', 'warming', 'melt', 'trigger', 'global', 'volcanic', 'eruption'}
# ---
#
# {'declare', 'warming', 'state', 'unequivocal', 'break', 'dept', 'human', 'global', 'induce', 'primarily'}
# ---
#
# {'cap', 'warming', 'melt', 'trigger', 'global', 'volcanic', 'eruption'}
# ---
#
# {'fix', 'kind', 'warming', 'sigh', 'idea', 'love', 'environmentalism', 'come', 'class', 'global'}
# ---
#
# {'awareness', 'increase', 'threat', 'green', 'warming', 'overview', 'revolution', 'global', 'go'}
# ---
#
# {'limpopo', 'temperature', 'change', 'climate', 'bring', 'southern', 'high', 'compete', 'water', 'africa', 'southe'}
# ---
#
# {'hekla', 'year', 'warming', 'iceland', 'spill', 'earth', 'global', 'eruption', 'strike'}
# ---
#
# {'america', 'change', 'climate', 'photo', 'place'}
# ---
#
# {'episcopal', 'issue', 'change', 'climate', 'daily', 'bangor', 'maine', 'time', 'important', 'bishop', 'lane'}
# ---
#
# {'volcano', 'change', 'climate', 'iceland', 'case', 'wonder', 'impact'}
# ---
#
# {'thing', 'discussion', 'warming', 'interest', 'heat', 'honest', 'cool', 'global'}
# ---
#
# {'pattern', 'change', 'climate', 'billion', 'bird', 'migration'}
# ---
#
# {'america', 'change', 'climate', 'photo', 'place'}
# ---
#
# {'change', 'warming', 'hazardous', 'trigger', 'spark', 'volcanic', 'global', 'cloud'}
# ---
#
# {'change', 'warming', 'hazardous', 'trigger', 'spark', 'volcanic', 'global', 'cloud'}
# ---
#
# {'volcano', 'get', 'cooling', 'warming', 'improve', 'slow', 'stratosphere', 'wonder', 'brief', 'global'}
# ---
#
# {'obama', 'thursd', 'april', 'say', 'change', 'climate', 'sydney', 'president', 'wait', 'barack', 'china'}
# ---
#
# {'jindal', 'volcano', 'change', 'read', 'climate', 'warning', 'bobby', 'paper', 'lately', 'mock', 'denier', 'think', 'start'}
# ---
#
# {'get', 'cara', 'strand', 'change', 'adapt', 'climate', 'weekend', 'preview', 'merte', 'tedxvolcano', 'sneak'}
# ---
#
# {'thing', 'change', 'larry', 'climate', 'important', 'science', 'fight', 'face', 'brilliant', 'single', 'tedxvolcano', 'socmedia'}
# ---
#
# {'thing', 'change', 'larry', 'climate', 'important', 'socent', 'green', 'science', 'fight', 'face', 'brilliant', 'single', 'tedxvolcano'}
# ---
#
# {'volcano', 'get', 'warming', 'crazy', 'europe', 'global', 'activating', 'damn', 'cloud'}
# ---
#
# {'crisis', 'change', 'larry', 'climate', 'science', 'attack', 'brilliant', 'tedxvolcano', 'exacerbate'}
# ---
#
# {'america', 'change', 'climate', 'photo', 'place'}
# ---
#
# {'scarcity', 'warming', 'wheat', 'rice', 'water', 'global', 'impact', 'production'}
# ---
#
# {'volcano', 'jonah', 'goldberg', 'warming', 'cause', 'oslo', 'iceland', 'reuters', 'thaw', 'global', 'eruption'}
# ---
#
# {'scarcity', 'warming', 'wheat', 'rice', 'water', 'global', 'impact', 'production'}
# ---
#
# {'change', 'climate', 'conversation', 'indigenous', 'bring', 'voice'}
# ---
#
# {'volcano', 'awaken', 'change', 'climate', 'activity', 'volcanic', 'icelandic', 'thaw'}
# ---
#
# {'entire', 'south', 'rain', 'change', 'climate', 'nikolas', 'affect', 'amazon', 'kozloff'}
# ---
#
# {'america', 'change', 'climate', 'photo', 'place'}
# ---
#
# {'volcano', 'bury', 'hmmm', 'warming', 'iceland', 'lede', 'melt', 'global', 'glacier'}
# ---
#
# {'consensus', 'volcano', 'crisis', 'change', 'sure', 'climate', 'warn', 'melt', 'lead', 'scientist'}
# ---
#
# {'cochabamba', 'wish', 'people', 'change', 'climate', 'conference', 'earth', 'right', 'mother', 'world'}
# ---
#
# {'near', 'seasonal', 'change', 'climate', 'record', 'spring', 'bad', 'high', 'feel', 'make', 'allergy'}
# ---
#
# {'near', 'seasonal', 'change', 'climate', 'record', 'spring', 'bad', 'high', 'make', 'allergy'}
# ---
#
# {'like', 'change', 'climate', 'glaci', 'disrupt', 'thaw', 'volcanic', 'icelandic', 'eruption', 'travel'}
# ---
#
# {'summit', 'cochabamba', 'change', 'climate', 'combat', 'approach', 'offer'}
# ---
#
# {'change', 'baby', 'climate', 'sneeze', 'solution', 'sexy', 'nettle', 'make', 'root', 'tincture'}
# ---
#
# {'simple', 'user', 'change', 'climate', 'power', 'remind', 'computer', 'workin', 'environment'}
# ---
#
# {'reason', 'perspective', 'renewal', 'climate', 'connecticut', 'bring', 'concern'}
# ---
#
# {'switch', 'warming', 'warn', 'long', 'accelerate', 'renewable', 'scientist', 'need', 'global'}
# ---
#
# {'switch', 'warming', 'warn', 'long', 'accelerate', 'renewable', 'scientist', 'need', 'global'}
# ---
#
# {'culprit', 'pollen', 'chart', 'change', 'climate', 'count'}
# ---
#
# {'tired', 'change', 'level', 'climate', 'ground', 'coalition', 'fight', 'wait'}
# ---
#
# {'wednesday', 'season', 'change', 'climate', 'wildlife', 'report', 'release', 'national', 'allergy', 'worsen'}
# ---
#
# {'tired', 'change', 'level', 'climate', 'ground', 'coalition', 'fight', 'wait'}
# ---
#
# {'author', 'america', 'rain', 'south', 'change', 'climate', 'entire', 'planet', 'affect', 'amazon', 'nikola', 'kozloff'}
# ---
#
# {'cleantech', 'thing', 'warming', 'solve', 'global'}
# ---
#
# {'tired', 'change', 'level', 'climate', 'ground', 'coalition', 'fight', 'wait'}
# ---
#
# {'tired', 'change', 'level', 'climate', 'ground', 'coalition', 'fight', 'wait'}
# ---
#
# {'cleantech', 'tired', 'change', 'level', 'climate', 'ground', 'coalition', 'fight', 'wait'}
# ---
#
# {'season', 'change', 'climate', 'bad', 'allergy', 'report'}
# ---
#
# {'article', 'denialist', 'mention', 'send', 'finnish', 'purportedly', 'warming', 'refute', 'global', 'newspaper', 'cute'}
# ---
#
# {'necessary', 'nationalize', 'warming', 'energy', 'fight', 'industry', 'global'}
# ---
#
# {'preliminary', 'warming', 'contribute', 'suggest', 'analysis', 'natural', 'global', 'previously'}
# ---
#
# {'volcano', 'likely', 'iceland', 'intensify', 'slow', 'vast', 'global', 'volcanic', 'eruption', 'cloud'}
# ---
#
# {'volcano', 'likely', 'iceland', 'intensify', 'slow', 'vast', 'global', 'volcanic', 'eruption', 'cloud'}
# ---
#
# {'reading', 'warming', 'bad', 'allergy', 'global', 'blame'}
# ---
#
# {'leave', 'population', 'group', 'change', 'climate', 'indigenous', 'partnership', 'curb', 'forest', 'conservation'}
# ---
#
# {'problem', 'say', 'change', 'climate', 'tbagger', 'ignorant', 'think'}
# ---
#
# {'change', 'climate', 'affect', 'future', 'heat', 'miss', 'environment'}
# ---
#
# {'change', 'climate', 'green', 'economy', 'build'}
# ---
#
# {'park', 'change', 'montana', 'climate', 'economy', 'threaten', 'national', 'glaci'}
# ---
#
# {'raise', 'change', 'york', 'climate', 'cost', 'allergy'}
# ---
#
# {'perspective', 'population', 'change', 'climate', 'ecotone', 'city', 'environment'}
# ---
#
# {'coastal', 'change', 'climate', 'migration', 'ventura', 'county', 'dwindle', 'whale', 'blame'}
# ---
#
# {'michig', 'change', 'climate', 'kick', 'wait', 'think', 'allergy'}
# ---
#
# {'raise', 'change', 'exclusive', 'climate', 'reuters', 'cost'}
# ---

# %% [markdown]
# ## Modeling

# %%
new_data = data.iloc[indices]

# %%
prepr_tweets = [" ".join(each) for each in preprocessed_tweets]
new_data['cleaned_tweet'] = prepr_tweets
new_data.head()

# %%
len(prepr_tweets), data.shape, new_data.shape

# %%
# TF IDF
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split
import collections, numpy

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(new_data['cleaned_tweet'].astype('U'))

tf = TfidfVectorizer()
text_tf = tf.fit_transform(new_data['cleaned_tweet'].astype('U'))
# print(text_tf)

# %%
new_data.isna().sum()

# %%
# compute similarity using cosine similarity
cos_sim=cosine_similarity(text_tf, text_tf)
print(cos_sim)

# %%
# splitting data 

X_train, X_test, y_train, y_test = train_test_split(cos_sim, new_data['existence'], test_size=0.2, random_state=33)
print(" Test Data Shape:", X_test.shape)
print(" Train Data Shape:",X_train.shape)

# %%
pos = (y_test == 'Yes').sum()
neg = (y_test == 'No').sum()
postrain = (y_train == 'Yes').sum()
negtrain = (y_train == 'No').sum()
total = pos + neg
print(" Test Data Positive Sentiments :", pos)
print(" Test Data Negative Sentiments :",neg)
print(" Train Data Positive Sentiments :", postrain)
print(" Train Data Positive Sentiments :",negtrain)
new_data['existence'].value_counts()

# %%
# perform algoritma KNN
from sklearn.metrics import accuracy_score, cohen_kappa_score
from sklearn.metrics import precision_score, auc,recall_score, f1_score,roc_curve,confusion_matrix, classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm
from sklearn.model_selection import cross_val_score
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.svm import LinearSVC

# %%
clfs = [
    svm.SVC(kernel='linear').fit(X_train, y_train),
#     LinearSVC().fit(X_train, y_train),
    DecisionTreeClassifier().fit(X_train, y_train),
    KNeighborsClassifier(n_neighbors=7).fit(X_train, y_train)
]

# %%
MLA_columns = []
MLA_compare = pd.DataFrame(columns = MLA_columns)

# %%
row_index = 0
for clf in clfs:
    print('===============================================\n')
    print("**********{}***********".format(clf.__class__.__name__))
    predicted = clf.predict(X_test)
    tn, fp, fn, tp = confusion_matrix(y_test, predicted).ravel()
    MLA_name = clf.__class__.__name__
    MLA_compare.loc[row_index,'MLA Name'] = MLA_name
    MLA_compare.loc[row_index, 'MLA Train Accuracy'] = round(clf.score(X_train, y_train), 2)
    MLA_compare.loc[row_index, 'MLA Test Accuracy'] = round( accuracy_score(y_test,predicted), 2)
    MLA_compare.loc[row_index, 'MLA Precision'] = round( precision_score(y_test,predicted, average="binary", pos_label="Yes"), 2)
    MLA_compare.loc[row_index, 'MLA Recall'] = round( recall_score(y_test,predicted, average="binary", pos_label="Yes"), 2)
    MLA_compare.loc[row_index, 'MLA F1 Score'] = round( f1_score(y_test,predicted, average="binary", pos_label="Yes"), 2)
    MLA_compare.loc[row_index, 'error_rate'] = round( 1-accuracy_score(y_test,predicted), 2)
    MLA_compare.loc[row_index, 'cross val score'] = cross_val_score(clf, cos_sim,new_data['existence'], cv=10).mean()
    plot_conf_matrix(y_test, predicted)
    row_index+=1

# %%
print('MLA Precision', round( precision_score(y_test,predicted, average='macro'), 2))
print('MLA Recall', round( recall_score(y_test,predicted, average="macro"), 2))
print('MLA F1 Score', round( f1_score(y_test,predicted, average="macro"), 2))

# %%
MLA_compare.sort_values(by = ['MLA Test Accuracy'], ascending = False, inplace = True)
MLA_compare
