# %%
import numpy as np
import pandas as pd
import spacy
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import Perceptron, LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, ConfusionMatrixDisplay 

# %run ./jlu_preprocessing.ipynb

# %% [markdown]
# ## Reading Data

# %% [markdown]
# Original Data

# %%
original_data = pd.read_excel('global_warming_tweets.xls')
print(original_data.shape)
original_data.drop(columns=["existence.confidence"], inplace=True)
original_data.drop_duplicates(subset=["tweet"], inplace=True)

data = original_data

print(data.shape)
data.head()
# Out:
# (6090, 3)
# (5541, 2)
#                                                tweet existence
# 0  Global warming report urges governments to act...       Yes
# 1  Fighting poverty and global warming in Africa ...       Yes
# 2  Carbon offsets: How a Vatican forest failed to...       Yes
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...       Yes
# 5  RT @sejorg: RT @JaymiHeimbuch: Ocean Saltiness...       Yes

# %% [markdown]
# Web Scraped Data

# %%
# rawScrapedTweets = []

# with open("scrapedTweets.txt") as fh:
#     d = fh.read()
#     rawScrapedTweets = d.split('\n')

# scrapedTweets = pd.DataFrame(rawScrapedTweets, columns=["tweets"])

# print(scrapedTweets.shape)
# scrapedTweets.head()

# %% [markdown]
# ## Data Exploration

# %%
size = len(data["existence"])
cnt = [0, 0, 0]

for val in data["existence"]:
    if val == "N" or val == "No":
        cnt[0] += 1
    elif pd.isnull(val):
        cnt[1] += 1
    elif val == "Yes" or val == "Y":
        cnt[2] += 1

plt.figure(figsize=(3,3))
plt.xticks(np.arange(3), ["No", "N/A", "Yes"])
plt.xlabel("Classes")
plt.ylabel("Frequencies")
plt.title("Distribution of Classes")
plt.bar(np.arange(3), cnt)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# Running Algorithms

# %%
from itertools import chain
from wordcloud import WordCloud, STOPWORDS 

def generateWordCloud(tweets):
    allwords = " ".join(set(chain.from_iterable(tweets)))
    wordcloud = WordCloud(width = 600, height = 600, 
                    background_color ='white', 
                    stopwords = set(STOPWORDS), 
                    min_font_size = 10).generate(allwords)

    plt.axis("off") 
    plt.tight_layout(pad = 0) 

    plt.figure(figsize = (7, 7), facecolor = 'white', edgecolor='blue') 
    plt.imshow(wordcloud) 

    plt.show()

# %%
def genCloud(data, labels):
    data = data[data["existence"].apply(lambda x: x in labels)]
    tweets = data['tweet']

    # Convert all to lowercase
    tweets = [splitWords(t) for t in tweets]

    # Process tweets through spaCy pipeline
    tweets, indices = spacyPipeline(tweets)

    generateWordCloud(tweets)

# %%
# genCloud(data, ["Yes", "Y"])

# %%
# genCloud(data, ["No", "N"])

# %% [markdown]
# ## Functions

# %%
def cross_val(X_train, Y_train, X_test, Y_test, model):
    num_cv = 5

    scoring = ['accuracy', 'precision', 'recall']
    cv = cross_validate(model, X_train, Y_train, cv=num_cv, return_train_score=True, scoring=scoring, n_jobs=-1)
    
    train_scores = []
    test_scores = []
    
    for metric in scoring:
        train_scores.append(np.mean(cv[f"train_{metric}"]))
        test_scores.append(np.mean(cv[f"test_{metric}"]))
        
    mean_scores = pd.DataFrame((train_scores, test_scores), columns=scoring, index=["train", "test"])
    
    return cv, mean_scores

# %%
def plot_cross_val(cv):    
    folds = 5
    metrics = ["accuracy", "precision", "recall"]
    colors = ["r", "g", "b"]
    for time_ in ["train", "test"]:
        plt.figure(figsize=(4,4))
        for num, metric in enumerate(metrics):
            indexer = f"{time_}_{metric}"
            plt.plot(np.arange(folds), cv[indexer], color=colors[num])
        
        plt.legend(metrics, loc="upper left")
        plt.title(f"Scores during {time_} time")
        plt.show()

# %% [markdown]
# Source: https://stackoverflow.com/questions/61325314/how-to-change-plot-confusion-matrix-default-figure-size-in-sklearn-metrics-packa

# %%
def pred(X_train, Y_train, X_test, Y_test, model):
    clf = model.fit(X_train, Y_train)
    pred = model.predict(X_train)
    pred2 = model.predict(X_test)
    
    conf_mat = confusion_matrix(y_true=Y_train, y_pred=pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=conf_mat)
    disp.plot()
    
    fig = disp.ax_.get_figure()
    fig.set_figwidth(3)
    fig.set_figheight(3)
    
    conf_mat2 = confusion_matrix(y_true=Y_test, y_pred=pred2)
    disp2 = ConfusionMatrixDisplay(confusion_matrix=conf_mat2)
    disp2.plot()
    
    fig2 = disp2.ax_.get_figure()
    fig2.set_figwidth(3)
    fig2.set_figheight(3)

# %% [markdown]
# ## Testing

# %% [markdown]
# Preprocessing

# %% [markdown]
# > Note: I am combining the "No" and "N/A" classes together into one.

# %%
# %run ./jlu_preprocessing.ipynb

X, Y = preprocess(data, verbose=True)
X
# Out:
# Global warming report urges governments act BRUSSELS Belgium (AP) The world faces increased hunger and [link]
# locs:  {'belgium', 'brussels'}
# {'report', 'government', 'act', 'face', 'hunger', 'urge', 'increase', 'world'}
# ---
#
# Fighting poverty and global warming Africa [link]
# locs:  {'africa'}
# {'fight', 'poverty'}
# ---
#
# Carbon offsets How Vatican forest failed reduce global warming [link]
# locs:  set()
# {'forest', 'carbon', 'reduce', 'offset', 'fail'}
# ---
#
# URUGUAY Tools Needed for Those Most Vulnerable Climate Change [link]
# locs:  set()
# {'tool', 'need', 'vulnerable'}
# ---
#
# @sejorg @Jaymi Heimbuch Ocean Saltiness Shows Global Warming Intensifying Our Water Cycle [link]
# locs:  set()
# {'saltiness', 'water', 'cycle', 'intensify', 'ocean', 'show'}
# ---
#
# Global warming evidence all around message global warming deniers and doubters Just look around our [link]
# locs:  set()
# {'denier', 'evidence', 'message', 'look', 'doubter'}
# ---
#
# Migratory Birds' New Climate Change Strategy Stay Home [link]
# locs:  set()
# {'new', 'stay', 'home', 'strategy', 'migratory', 'birds'}
# ---
#
# Southern Africa Competing for Limpopo Water Climate change will bring higher temperatures Southe... [link]
# locs:  {'africa', 'southern'}
# {'competing', 'water', 'bring', 'temperature', 'high'}
# ---
#
# Global warming impact wheat rice production India Ludhiana Apr Scarcity water will have serious [link]
# locs:  {'india'}
# {'impact', 'water', 'wheat', 'scarcity', 'production', 'rice'}
# ---
#
# How solve this global warming thing? [link]
# locs:  set()
# {'thing', 'solve'}
# ---
#
# Blog preliminary analysis suggests that natural gas could contribute far more global warming than previously [link]
# locs:  set()
# {'preliminary', 'suggest', 'natural', 'previously', 'gas', 'contribute', 'blog', 'far', 'analysis'}
# ---
#
# Ecotone Climate change from population perspective [link]
# locs:  set()
# {'perspective', 'population'}
# ---
#
# Climate change blamed coastal whale migration dwindles Ventura County.. [link]
# locs:  {'county', 'ventura'}
# {'whale', 'coastal', 'migration', 'blame', 'dwindle'}
# ---
#
# Spring storm season starting little late this year??? Must global warming
# locs:  set()
# {'little', 'year', 'storm', 'season', 'start', 'late', 'spring'}
# ---
#
# Government Report Says Global Warming May Cause Cancer Mental Illness. CNSNews.com [link]
# locs:  set()
# {'report', 'mental', 'illness', 'say', 'government', 'cancer', 'cause'}
# ---
#
# For Earth Day Global warming could affect patient symptoms [link]
# locs:  set()
# {'symptom', 'earth', 'day', 'patient', 'affect'}
# ---
#
# Wait here's idea it's natural climate change not human induced global warming. [link]
# locs:  set()
# {'idea', 'natural', 'induce', 'wait', 'human'}
# ---
#
# EPA issues report U.S. climate change indicators warming having measurable effect across ecosystems [link]
# locs:  {'u.s.'}
# {'issue', 'report', 'ecosystem', 'measurable', 'effect', 'indicator', 'have'}
# ---
#
# QUT researchers track climate change [link]
# locs:  set()
# {'researcher', 'track'}
# ---
#
# Global Warming Ocean chemistry changing faster than has 800 000 years And that's because the carbon ... [link]
# locs:  set()
# {'fast', 'year', 'change', 'ocean', 'carbon', 'chemistry'}
# ---
#
# Topography Mountains Could Complicate Rates Global Warming Science Daily (Apr. 2010) new study concl... [link]
# locs:  set()
# {'science', 'new', 'study', 'mountain', 'daily', 'complicate', 'topography', 'rate'}
# ---
#
# Soaring mercury Blame global warming Agartala Apr Environmentalists have attributed the [link]
# locs:  set()
# {'attribute', 'environmentalists', 'soar', 'mercury', 'blame'}
# ---
#
# @WGof NYC Leader National Indigenous Women's Org Climate Change Not Just abt the Climate its abt Lives bit.ly/9GdzRw
# locs:  set()
# {'national', 'live', 'indigenous', 'women', 'org', 'leader'}
# ---
#
# @Greg Mitch has there been any reporting the increase sediment upper atmospher could reduce global warming effect reducing sun
# locs:  set()
# {'report', 'sun', 'effect', 'sediment', 'upper', 'reduce', 'increase'}
# ---
#
# effects global warming You Tube Effects Global Warming Stats Back with more news for you today. It's ama... [link]
# locs:  set()
# {'stats', 'effects', 'news', 'tube', 'effect', 'today'}
# ---
#
# It's global climate change-not warming. Read www.associatedcontent.com/article/2872954/global_climate_change_not_global_warming.html
# locs:  set()
# {'read'}
# ---
#
# preliminary analysis suggests that natural gas could contribute far more global warming than previously thought. [link]
# locs:  set()
# {'preliminary', 'suggest', 'natural', 'previously', 'think', 'gas', 'contribute', 'far', 'analysis'}
# ---
#
# SCIENCE Scientists explore the evolution climate change [link]
# locs:  set()
# {'science', 'evolution', 'explore', 'scientist'}
# ---
#
# Eaarth global warming here stay how will deal with it? [link]
# locs:  set()
# {'deal', 'stay'}
# ---
#
# Allergies Worse Than Ever? Blame Global Warming [link]
# locs:  set()
# {'blame', 'bad', 'allergy'}
# ---
#
# @New_federalists have good auth tht global warming also causes toe fungus. all fortunate tht thr global warming tcot
# locs:  set()
# {'toe', 'good', 'fungus', 'fortunate', 'cause'}
# ---
#
# Illegal war and the myth global warming main campaign platform for this election will the illegal [link]
# locs:  set()
# {'myth', 'campaign', 'illegal', 'main', 'election', 'war', 'platform'}
# ---
#
# the scientific community was scamed global green gov warming scam.
# locs:  set()
# {'green', 'scientific', 'community', 'scam', 'gov'}
# ---
#
# truly Fat ASS Gore should get the Scam Artist Award the decade with his Global Warming and Energy Credits worth close Billion.
# locs:  set()
# {'decade', 'energy', 'billion', 'fat', 'artist', 'close', 'gore', 'truly', 'scam', 'worth', 'ass', 'award', 'credits'}
# ---
#
# degrees NYC. please urinate next liberal global warming /climate change scum you see.
# locs:  set()
# {'degrees', 'liberal', 'urinate', 'scum'}
# ---
#
# @virgiltexas Hey Gore see these tornadoes racing across Mississippi? much for global warming tornadocot ocra sgp gop ucot tlot tycot
# locs:  {'mississippi'}
# {'race', 'gore', 'tornado', 'hey'}
# ---
#
# justinbiebersucks and global warming farce
# locs:  set()
# {'farce'}
# ---
#
# One Stop Book Stop Confirmed Global warming 'settled' scam WND.com Sussman's book the ... [link]
# locs:  set()
# {'settle', 'stop', 'confirmed', 'book', 'scam'}
# ---
#
# Rationalists' who believe aliens exist global warming=caused humans might well believe Jesus miracles angels fairies tcot
# locs:  set()
# {'alien', 'exist', 'angel', 'rationalist', 'fairy', 'believe', 'cause', 'miracle', 'human'}
# ---
#
# Air ban led flawed computer models. Global warming come mind? [link]
# locs:  set()
# {'flawed', 'ban', 'computer', 'air', 'come', 'model', 'lead', 'mind'}
# ---
#
# Proof there's climate change. @jazgar 75-ft killer tsunami created Peruvian LAKE when glacier fractures falls Into the lake
# locs:  set()
# {'lake', 'glacier', 'tsunami', 'killer', 'fracture', 'create', 'proof', 'fall'}
# ---
#
# @OTOOLEFAN REAL science. Not Algore's climate change 'science' hacks with their man-made global warming hoax. Gore=Palin
# locs:  set()
# {'science', 'real', 'hack', 'hoax', 'gore', 'man'}
# ---
#
# 30000 Anti-Global Warming Scientists Can't Wrong Stranger ... Nature Magazine the academic journal that int... [link]
# locs:  set()
# {'int', 'stranger', 'wrong', 'anti', 'academic', 'journal', 'magazine', 'scientists', 'nature'}
# ---
#
# Global Warming Baloney According the experts NASA the difference between weather and climate measure ... [link]
# locs:  set()
# {'expert', 'accord', 'baloney', 'difference', 'weather', 'measure'}
# ---
#
# computer forensics experts are there still any idiots out there that belive global warming true? [link]
# locs:  set()
# {'expert', 'forensic', 'true', 'idiot', 'computer'}
# ---
#
# Liberal Looney Toons Global Warming Alarmist Comes Home With Artic Frost Bite Gather.com they wont learn huh? lo... [link]
# locs:  set()
# {'frost', 'liberal', 'home', 'lo', 'learn', 'bite', 'alarmist', 'come', 'huh'}
# ---
#
# Despite Climategate LEFT investing heavily global warming hysteria new way impose nat'l international controls human freedom.
# locs:  set()
# {'impose', 'despite', 'new', 'heavily', 'way', 'freedom', 'controls', 'left', 'human', 'invest', 'hysteria', 'international'}
# ---
#
# Global warming you tube explanation you will enjoy IPCC teaparty [link]
# locs:  set()
# {'tube', 'enjoy', 'explanation'}
# ---
#
# Immigration Reform and Climate Change Tale Two Issues the Senate [link]
# locs:  set()
# {'tale', 'issues', 'senate', 'reform', 'immigration'}
# ---
#
# Memo The White House Correspondents Dinner You Want Green Report Climate Change I'd never on... [link]
# locs:  set()
# {'report', 'green', 'memo', 'white', 'want', 'correspondents', 'dinner', 'house'}
# ---
#
# Views Global Warming Vary Three Countries (Angus Reid Global Monitor) People three countries hold [link]
# locs:  set()
# {'hold', 'monitor', 'views', 'countries', 'vary', 'country', 'people'}
# ---
#
# SCENARIOS-Challenges California climate change law Source Reuters Peter Henderson SAN FRANCISCO April ... [link]
# locs:  set()
# {'source', 'challenges', 'scenarios', 'law', 'peter'}
# ---
#
# The Climate Lindsay Graham's Support for Climate Change Legislation Has Changed Today Lindsey Graham ... [link]
# locs:  set()
# {'support', 'graham', 'change', 'today', 'legislation'}
# ---
#
# Arizona's immigration law climate change legislation stalling--Which issue should Congress focus now? Poll [link]
# locs:  {'arizona'}
# {'issue', 'focus', 'congress', 'immigration', 'law', 'poll', 'stalling', 'legislation'}
# ---
#
# Graham's exit from talks puts climate change bill limbo climate-change bill that was scheduled unveile... [link]
# locs:  set()
# {'put', 'graham', 'limbo', 'schedule', 'exit', 'bill', 'talk'}
# ---
#
# Climate change bill stalls Senate [link]
# locs:  set()
# {'bill', 'senate', 'stall'}
# ---
#
# Peoples World GRAND RAPIDS Mich. Opponents climate change legislation typically argue that regulating globa... [link]
# locs:  set()
# {'typically', 'regulate', 'peoples', 'grand', 'argue', 'legislation', 'opponents', 'rapids', 'world'}
# ---
#
# cnnbrk Sen. Graham's move imperils Dems' push for immigration climate change bills. [link]
# locs:  set()
# {'graham', 'immigration', 'imperil', 'bill', 'push'}
# ---
#
# Cafe Scientifique presents global warming talk film The April Cafe Scientifique presentation will the [link]
# locs:  {'scientifique', 'cafe'}
# {'presentation', 'film', 'present', 'talk'}
# ---
#
# Check this video out The Business Climate Change Conference 2009 [link]
# locs:  set()
# {'conference', 'check', 'video', 'business'}
# ---
#
# Brilliant Tips For Valentine's Day Screaming ... Climate Change clinical trials collagen clinique clip... [link]
# locs:  set()
# {'clip', 'valentine', 'collagen', 'screaming', 'clinical', 'day', 'tips', 'brilliant', 'trial'}
# ---
#
# USA Climate Change Policy Update April 2010 [link]
# locs:  set()
# {'policy', 'update'}
# ---
#
# Press Releases April 2010 Climate change negotiators agree intensified [link]
# locs:  set()
# {'agree', 'press', 'intensify', 'negotiator', 'releases'}
# ---
#
# @Sooper Mexican Global warming. Clearly.
# locs:  set()
# {'clearly'}
# ---
#
# Post Partisan Harry Reid's hapless play immigration and climate change [link]
# locs:  set()
# {'partisan', 'hapless', 'immigration', 'harry', 'play', 'post'}
# ---
#
# Foes California's global warming law pour money into campaign delay [link]
# locs:  {'california'}
# {'foes', 'law', 'money', 'pour', 'campaign', 'delay'}
# ---
#
# Earth Day Live Chat with Carol Browner Director the Office Energy and Climate Change Policy for the Obama Admin [link]
# locs:  set()
# {'carol', 'browner', 'policy', 'live', 'energy', 'admin', 'office', 'earth', 'day', 'chat', 'director'}
# ---
#
# Klein '50-50' chance that the Senate passes climate change bill this year? [link]
# locs:  set()
# {'chance', 'senate', 'year', 'pass', 'bill'}
# ---
#
# @andychrism Yes. have heard least one person make the connection between the volcano and global warming.
# locs:  set()
# {'volcano', 'person', 'hear', 'yes', 'connection'}
# ---
#
# @redostoneage NASAs changing Facts Guess they thought you wouldnt notice global warming climate change eco [link]
# locs:  set()
# {'think', 'change', 'guess', 'fact', 'notice'}
# ---
#
# religious spin climate change.[link]
# locs:  set()
# {'spin', 'religious'}
# ---
#
# Environmental Groups Praise BASIC Meeting Climate Change Environmental groups are giving qualified praise a... [link]
# locs:  set()
# {'group', 'qualified', 'give', 'praise', 'environmental', 'meeting', 'basic'}
# ---
#
# Only Third Americans Believe Global Warming Human-Caused Bob Ellis April 26th 2010 Good news What... [link]
# locs:  set()
# {'news', 'good', 'believe', 'bob', 'cause', 'human'}
# ---
#
# Global Warming the Heart Earth Day over. it? Thousands perhaps millions conscious actions t... [link]
# locs:  set()
# {'conscious', 'earth', 'day', 'heart', 'action', 'thousand', 'million', 't'}
# ---
#
# climate data that suggests global warming and then the assumption that our doing. [link]
# locs:  set()
# {'datum', 'suggest', 'assumption'}
# ---
#
# Global Warming Fiction fact? Deniers claim either that there global warming that not due ... [link]
# locs:  set()
# {'claim', 'denier', 'fact', 'fiction'}
# ---
#
# @The BCast The B-Cast Interview Minnesotans for Global Warming' Fight You Tube Takedowns [link]
# locs:  set()
# {'cast', 'fight', 'tube', 'b', 'interview'}
# ---
#
# Opponents ramp effort delay Calif. global warming law [link]
# locs:  set()
# {'effort', 'law', 'opponent', 'ramp', 'delay'}
# ---
#
# How many are aware the World People's Conference Climate Change and Earth Rights Bolivia Earth Week Indigenous 1stNations
# locs:  set()
# {'week', 'rights', 'indigenous', 'earth', 'conference', 'aware', 'people', 'world'}
# ---
#
# Sorry won't able accept the invitation panelist Bolivia Climate Change Talks [link]
# locs:  set()
# {'talks', 'invitation', 'accept', 'sorry', 'panelist', 'able'}
# ---
#
# @GClugo @guardianscience Climate scientist sues newspaper for 'poisoning' global warming debate [link]
# locs:  set()
# {'newspaper', 'scientist', 'poisoning', 'sue', 'debate'}
# ---
#
# sharifkouddous Indigenous groups from across Bolivia arriving World People's conference climate change [link]
# locs:  {'bolivia'}
# {'group', 'arrive', 'indigenous', 'conference', 'people', 'world'}
# ---
#
# Recycling Water Meat and Global Warming Peanuts Rare Grapes ... [link]
# locs:  set()
# {'recycling', 'meat', 'water', 'rare', 'grape', 'peanuts'}
# ---
#
# Great article [link]
# locs:  set()
# {'article', 'great'}
# ---
#
# Cuccinelli files motion force EPA reopen global warming finding Virginia Attorney General Ken Cuccinelli ha... [link]
# locs:  {'virginia'}
# {'ha', 'motion', 'general', 'file', 'reopen', 'ken', 'attorney', 'force', 'find'}
# ---
#
# Don Blankenship Mine Safety Regulators Silly Global Warming [link]
# locs:  set()
# {'don', 'regulator', 'safety', 'silly'}
# ---
#
# Bring Back The Hair That You Once Had With Nanogen's Nanofibers ... ... Climate Change clinical trials collagen ... [link]
# locs:  set()
# {'collagen', 'bring', 'clinical', 'hair', 'trial'}
# ---
#
# Street-corner Global-warming Counsel Urgh certain elements this item Sunday's Washington Post Myths... [link]
# locs:  set()
# {'item', 'certain', 'corner', 'myths', 'element', 'counsel', 'post', 'street'}
# ---
#
# religious take climate change [link]
# locs:  set()
# {'religious'}
# ---
#
# Are you ready for the climate change? PLI with Environmental Regulation Commercial Implications 2010 How the... [link]
# locs:  set()
# {'commercial', 'regulation', 'implications', 'ready', 'environmental'}
# ---
#
# LIVE TONIGHT Fellow Heather Rogers joins Climate Change Expert James Hansen discuss REAL solutions Climate... [link]
# locs:  set()
# {'fellow', 'expert', 'rogers', 'live', 'real', 'discuss', 'join', 'solution', 'heather', 'tonight'}
# ---
#
# Plan California Braces for Climate Change. [link]
# locs:  set()
# {'braces', 'plan'}
# ---
#
# Plants effective way tackling global warming Washington Apr Plant leaves account for less than one per [link]
# locs:  set()
# {'tackle', 'plant', 'account', 'leave', 'way', 'effective'}
# ---
#
# @angiemartinez it's about degrees out here NYC shiiiiiitttt fuck glodman/sachs Obama better get plan this global warming
# locs:  set()
# {'degree', 'plan', 'well', 'fuck'}
# ---
#
# Climate change sustainability will key driver future economic development. Listen [link]
# locs:  set()
# {'sustainability', 'development', 'listen', 'key', 'economic', 'driver', 'future'}
# ---
#
# Frederic Hague PEN climate change isn't just alarm bell. It's whole blinking discotech
# locs:  set()
# {'blink', 'bell', 'alarm', 'pen'}
# ---
#
# Generals say Climate Change Threatens America's Security The Pentagon has made well known that consider... [link]
# locs:  set()
# {'pentagon', 'general', 'security', 'know', 'consider', 'threatens'}
# ---
#
# Even the generals know climate change going screw us. [link]
# locs:  set()
# {'screw', 'general', 'know', 'go'}
# ---
#
# Government Report Says Global Warming May Cause Cancer Mental Illness [link]
# locs:  set()
# {'report', 'mental', 'illness', 'say', 'government', 'cancer', 'cause'}
# ---
#
# @disturbedwater Climate change increases heat waves floods EPA [link]
# locs:  set()
# {'wave', 'heat', 'flood', 'increase'}
# ---
#
# @sciencedaily Plants remain effective way tackling global warming [link]
# locs:  set()
# {'tackle', 'plant', 'way', 'effective', 'remain'}
# ---
#
# far that class have gotten into heated discussion with global climate change denier and student that nothing their fault.
# locs:  set()
# {'class', 'get', 'student', 'heated', 'far', 'deni', 'fault', 'discussion'}
# ---
#
# @Newsweek Global Warming Kills Forests Colorado [link]
# locs:  set()
# {'forests', 'kills'}
# ---
#
# EPA Confirms Climate Changing another display the sea change that has occurred the Environmental P... [link]
# locs:  set()
# {'confirms', 'change', 'sea', 'occur', 'display', 'environmental', 'p'}
# ---
#
# Must See Places Before They Disappear Europe...[PICS] Global Warming Predictions prove true the foll... [link]
# locs:  set()
# {'foll', 'place', 'predictions', 'prove', 'true', 'disappear'}
# ---
#
# @quixotecenter Combating climate change lessons from the indigenous peoples [link]
# locs:  set()
# {'people', 'combat', 'lesson', 'indigenous'}
# ---
#
# @chrisdodd live CT. Please support the climate bill and strong action climate change
# locs:  set()
# {'support', 'ct', 'live', 'strong', 'action', 'bill'}
# ---
#
# @nicnunes @EPSclimate Indigenous tradition used fight climate change [link]
# locs:  set()
# {'tradition', 'indigenous', 'fight'}
# ---
#
# @danlatorre James Hansen/Heather Rogers Green Gone Wrong False Hope Real Solutions Climate Change 7pm 4/30 [link]
# locs:  set()
# {'rogers', 'green', 'hope', 'false', 'wrong', 'real', 'heather', 'p.m.', 'gone', 'solutions'}
# ---
#
# CLIMATE CHANGE Forests Not for Absorbing Carbon Say Activists [link]
# locs:  set()
# {'activists', 'forest', 'absorb', 'carbon'}
# ---
#
# Climate change melts two glaciers BILLINGS Mont. Glacier National Park has lost two more its namesake [link]
# locs:  set()
# {'national', 'glacier', 'melt', 'namesake', 'lose', 'billings', 'park'}
# ---
#
# CLIMATE CHANGE Forests Not for Absorbing Carbon [link]
# locs:  set()
# {'forest', 'absorbing', 'carbon'}
# ---
#
# @danielsaudade What beautiful fall weather this morning New York Thanks climate change Bleh
# locs:  {'new', 'york'}
# {'thank', 'morning', 'weather', 'beautiful', 'fall'}
# ---
#
# What beautiful fall weather this morning New York Thanks climate change Bleh
# locs:  {'new', 'york'}
# {'thank', 'morning', 'weather', 'beautiful', 'fall'}
# ---
#
# Climate Change Threatens Japan's Cherry Blossoms Environment ... you aren't familiar with the culture Japan... [link]
# locs:  {'japan'}
# {'cherry', 'culture', 'familiar', 'threaten', 'environment', 'blossoms'}
# ---
#
# Wed @sciam podcast Mountain Vs. Valley Temps Stretch Apart With Climate Change [link]
# locs:  set()
# {'podcast', 'mountain', 'vs', 'valley', 'apart', 'stretch', 'd', 'temps'}
# ---
#
# Mountain Vs. Valley Temps Stretch Apart With Climate Change [link]
# locs:  set()
# {'mountain', 'vs', 'valley', 'apart', 'stretch', 'temps'}
# ---
#
# Arctic rain April 'is sign global warming' The Canadian Arctic has been hit rain sign that the [link]
# locs:  set()
# {'hit', 'rain', 'sign', 'arctic'}
# ---
#
# Microbes Contribute Less Global Warming New Haven Conn. [link]
# locs:  set()
# {'haven', 'new', 'contribute', 'microbe'}
# ---
#
# South Asian nations fight climate change Foreign ministers eight South Asian nations met this secluded H... [link]
# locs:  set()
# {'nation', 'foreign', 'fight', 'meet', 'h', 'minister', 'secluded', 'south'}
# ---
#
# Climate change increases heat waves floods WASHINGTON (Reuters) Deaths from heat waves property damage from [link]
# locs:  {'washington'}
# {'damage', 'flood', 'property', 'heat', 'death', 'wave', 'increase'}
# ---
#
# James Hansen Heather Rogers Green Gone Wrong False Hope Real Solutions Climate Change 7pm 4/30 @Demos_Org [link]
# locs:  set()
# {'rogers', 'green', 'hope', 'false', 'wrong', 'real', 'heather', 'p.m.', 'gone', 'solutions'}
# ---
#
# LOVE FROG's LEAP Seriously. @grist What climate change means for the wine industry (via @theclimatedesk) [link]
# locs:  set()
# {'seriously', 'leap', 'mean', 'industry', 'love', 'frog', 'wine'}
# ---
#
# Report Save the Whales and They'll Save from Global Warming [link]
# locs:  set()
# {'report', 'whales', 'save'}
# ---
#
# @indiaenvportal The contribution organic agriculture climate change mitigation [link]
# locs:  set()
# {'organic', 'mitigation', 'contribution', 'agriculture'}
# ---
#
# Arctic Beauty Black and White Alaska Before the Effects Global Warming [Slide Show] Toward the end Wor... [link]
# locs:  set()
# {'beauty', 'white', 'end', 'effects', 'black', 'slide', 'arctic'}
# ---
#
# EPA report documents very real impacts from climate change indicators studied [link]
# locs:  set()
# {'report', 'impact', 'real', 'document', 'study', 'indicator'}
# ---
#
# Canadian CEOs more keen green than global counterparts preparing for impacts climate change...[link]
# locs:  set()
# {'impact', 'green', 'keen', 'prepare', 'counterpart'}
# ---
#
# @carbonmarket Ask the G20 support biochar. Fight climate change food shortage Check this Huff Po post [link]
# locs:  {'g20'}
# {'support', 'fight', 'food', 'check', 'shortage', 'post', 'huff', 'ask'}
# ---
#
# @christellar Whale Doo Doo could help fight climate change? Sure Why not [link]
# locs:  set()
# {'help', 'sure', 'fight', 'whale'}
# ---
#
# Global warming science good news Soils release less carbon than though world warms [link]
# locs:  set()
# {'science', 'carbon', 'warm', 'news', 'good', 'soil', 'world', 'release'}
# ---
#
# April 27th Phoenix has weather might snow New York today.. Hmmmm.. Global warming MUCH
# locs:  {'new', 'york', 'phoenix'}
# {'today', 'weather', 'snow'}
# ---
#
# Higher temperature sea level due global warming KUALA LUMPUR Malaysia's average temperature has risen 1.1 [link]
# locs:  set()
# {'average', 'sea', 'rise', 'temperature', 'level', 'high'}
# ---
#
# West Mediterranean countries unite climate change (AFP) [link]
# locs:  {'mediterranean', 'west'}
# {'unite', 'country'}
# ---
#
# Cleaner Air Could Speed Global Warming Hugh Pickens writes \Scientists estimate that the Clean Air Act has cut [link]
# locs:  set()
# {'cut', 'speed', 'clean', 'act', 'air', 'write', 'estimate'}
# ---
#
# 000 Businesses Create New for Climate Change Action [link]
# locs:  set()
# {'action', 'new', 'create', 'business'}
# ---
#
# Person Snow then degrees the same day? Weather doesn't even surprise anymore. Person That's why global warming will win.
# locs:  set()
# {'win', 'snow', 'person', 'day', 'degree', 'surprise', 'anymore', 'weather'}
# ---
#
# Just heard interesting report report understanding climate change/climate variability influence human evolution and dispersal
# locs:  set()
# {'interesting', 'report', 'dispersal', 'variability', 'evolution', 'influence', 'hear', 'understand', 'human'}
# ---
#
# @jerryjamesstone Alaska Before the Effects Global Warming [pics] [link]
# locs:  set()
# {'effects', 'pic'}
# ---
#
# New blog post Mandating energy benchmarking The next step for cities addressing climate change? [link]
# locs:  set()
# {'new', 'energy', 'city', 'mandate', 'step', 'blog', 'post', 'address'}
# ---
#
# Real DocWatson global warming Antarctica and stake claim now will like Florida few years
# locs:  {'antarctica', 'florida'}
# {'real', 'like', 'year', 'claim', 'stake'}
# ---
#
# How much trouble does global warming mean for agriculture? Just ask the wine industry. [link]
# locs:  set()
# {'mean', 'agriculture', 'industry', 'wine', 'trouble', 'ask'}
# ---
#
# Arctic Beauty Black and White Alaska Before the Effects Global Warming [Slide Show] [link]
# locs:  set()
# {'beauty', 'white', 'effects', 'black', 'slide', 'arctic'}
# ---
#
# Climate Change From Paris the Alps European Places Peril (photos) [link]
# locs:  {'paris'}
# {'places', 'photo', 'peril', 'alps'}
# ---
#
# How Climate Change Will Change The Electoral Map The National Oceanic and Atmospheric Administration isn't known ... [link]
# locs:  set()
# {'national', 'administration', 'map', 'know', 'atmospheric', 'electoral', 'oceanic'}
# ---
#
# Report Cleaner Air Could Actually Intensify Global Warming much the world marked Earth Day this past week the Environmental...
# locs:  {'earth'}
# {'week', 'report', 'day', 'air', 'intensify', 'cleaner', 'past', 'mark', 'environmental', 'actually', 'world'}
# ---
#
# Global warming threat after all Tim Blair rounds the latest news from the wild frontiers global [link]
# locs:  set()
# {'wild', 'threat', 'news', 'round', 'frontier', 'late'}
# ---
#
# Kuna Indians Prepare For Relocation Traditional Homes Sink Due Climate Change [link]
# locs:  set()
# {'homes', 'sink', 'traditional', 'relocation', 'prepare'}
# ---
#
# How Global Warming Killing California's Wine Buzz Dr. Kimberley Cahill presented Climate Change Califor... [link]
# locs:  {'california'}
# {'present', 'buzz', 'kill', 'wine'}
# ---
#
# @uncajoe uncajoe PLZ Digg Climate Hate The Politics Climate Change Denial H... [link]
# locs:  set()
# {'h', 'politics', 'denial', 'hate'}
# ---
#
# GLOBAL WARMING Ocean chemistry changing faster than has 800 000 years And that's because the carbon [link]
# locs:  set()
# {'fast', 'year', 'change', 'ocean', 'carbon', 'chemistry'}
# ---
#
# Good going douche. I'm sure there climate change your backass world Graham move imperils Obama agenda [link]
# locs:  set()
# {'sure', 'graham', 'good', 'douche', 'going', 'imperil', 'agenda', 'world'}
# ---
#
# Ski resorts fight global warming SALT LAKE CITY (AP) Ski resorts across the U.S. are using this Thanksgiving [link]
# locs:  {'u.s.'}
# {'lake', 'resort', 'fight', 'ski', 'salt', 'thanksgiving', 'city'}
# ---
#
# Bats Birds and Lizards Can Fight Climate Change Eating Insects Birds bats and lizards may play important... [link]
# locs:  set()
# {'fight', 'important', 'bat', 'eating', 'play', 'lizard', 'birds', 'insect'}
# ---
#
# @indiaenvportal Make green cloud computing and its contribution climate change [link]
# locs:  set()
# {'computing', 'green', 'cloud', 'contribution'}
# ---
#
# @Heidi Ames Climate change favors invasive species over indigenous ones. 30% plants Thoreau saw are now extinct. [link]
# locs:  set()
# {'plant', 'extinct', 'favor', 'indigenous', 'specie', 'invasive', 'see', 'one'}
# ---
#
# scary @Climate Project Climate change altering U.S. seasons Spring days early [link]
# locs:  {'u.s.'}
# {'scary', 'season', 'project', 'day', 'spring', 'early', 'alter'}
# ---
#
# @thompsonPLC @boliviaun Pres Evo Morales @LATimes climate change lessons from indigenous peoples [link]
# locs:  set()
# {'lesson', 'people', 'pres', 'indigenous'}
# ---
#
# Media Global report special Tipping Point Earth Day event Science and art mobilize fight climate change [link]
# locs:  set()
# {'point', 'report', 'event', 'tipping', 'special', 'science', 'fight', 'mobilize', 'earth', 'day', 'art', 'media'}
# ---
#
# review yesterday's discussions [link]
# locs:  set()
# {'review', 'discussion', 'yesterday'}
# ---
#
# Global Warming Kills Forests Colorado [link]
# locs:  set()
# {'forests', 'kills'}
# ---
#
# Combating climate change lessons from the world's indigenous peoples When arrived the United Nations climat... [link]
# locs:  set()
# {'united', 'nations', 'lesson', 'indigenous', 'arrive', 'people', 'world', 'combat'}
# ---
#
# Africa Meteorology Services Gear for Climate Change the continent most vulnerable climate c... [link]
# locs:  set()
# {'vulnerable', 'c', 'meteorology', 'continent', 'gear', 'services'}
# ---
#
# GECKO first steps greener living all seems daunting Climate change. Carbon credits. Not mention ... [link]
# locs:  set()
# {'live', 'greener', 'credit', 'gecko', 'step', 'carbon', 'daunt', 'mention'}
# ---
#
# China The Key Fixing Global Warming With rapid expansion comes sizable environmental impact the world's [link]
# locs:  {'china'}
# {'impact', 'key', 'rapid', 'sizable', 'fixing', 'come', 'environmental', 'world', 'expansion'}
# ---
#
# Now PBS Going Green New York Examining how New Yorkers are confronting climate change Check local listings [link]
# locs:  set()
# {'new', 'green', 'check', 'go', 'local', 'examine', 'listing', 'confront'}
# ---
#
# Official NASA Report Sun Causes Climate Change [link]
# locs:  set()
# {'causes', 'report', 'sun', 'official'}
# ---
#
# @Tree Hugger @huffpostgreen well this just crazy Coal CEO Calls Mine Safety Rules 'As Silly Global Warming' [link]
# locs:  set()
# {'crazy', 'rules', 'silly', 'coal', 'call', 'safety'}
# ---
#
# @sciam Impacts Climate Change Extend Human Health [link]
# locs:  set()
# {'health', 'impact', 'human', 'extend'}
# ---
#
# Impacts Climate Change Extend Human Health [link]
# locs:  set()
# {'health', 'impact', 'human', 'extend'}
# ---
#
# The good news about the very bad news (about climate change) Rebecca Solnit [link]
# locs:  set()
# {'bad', 'news', 'good'}
# ---
#
# Alpha Phi Alpha Takes Climate Change and Energy Efficiency [link]
# locs:  set()
# {'energy', 'phi', 'take', 'alpha', 'efficiency'}
# ---
#
# Natural variability does not explain global warming climate scientists tell popular meteorologist [link]
# locs:  set()
# {'scientist', 'meteorologist', 'variability', 'explain', 'natural', 'popular', 'tell'}
# ---
#
# Rebecca Solnit 350 Degrees Inseparability The Good News About the Very Bad News (About Climate Change) [link]
# locs:  set()
# {'inseparability', 'news', 'good', 'degree', 'bad'}
# ---
#
# Watch video Climate change threatens sacred Tibetan mountain including land known Shangri-La [link]
# locs:  set()
# {'sacred', 'know', 'mountain', 'watch', 'threaten', 'land', 'la', 'include', 'video'}
# ---
#
# African Meteorology Services Gear for Climate Change. (america.gov) IRI [link]
# locs:  set()
# {'gear', 'meteorology', 'services'}
# ---
#
# Economists Say Climate Change Bad For Economy [link]
# locs:  set()
# {'economy', 'economist', 'bad'}
# ---
#
# Report Allergy Season Get Worse with Climate Change (Time.com) [link]
# locs:  set()
# {'report', 'bad', 'season', 'allergy'}
# ---
#
# Kill Bill Save the Climate Change Accountability Act [link]
# locs:  set()
# {'kill', 'save', 'act', 'accountability', 'bill'}
# ---
#
# @Oxfam Climate change makes farmers pastoralists Ethiopia increasingly vulnerable [link]
# locs:  {'ethiopia'}
# {'farmer', 'vulnerable', 'increasingly', 'make'}
# ---
#
# Denis Hayes founder Earth Day compares global climate change Irish Famine (Irish Central) News Weather Politics [link]
# locs:  set()
# {'famine', 'politics', 'central', 'news', 'earth', 'day', 'compare', 'weather', 'founder'}
# ---
#
# @Oxfam Climate change makes farmers pastoralists Ethiopia increasingly vulnerable [link]
# locs:  {'ethiopia'}
# {'farmer', 'vulnerable', 'increasingly', 'make'}
# ---
#
# ITS EARTHDAY aware what you consume waste how you treat this place. only have can see global warming effect
# locs:  set()
# {'place', 'treat', 'waste', 'effect', 'consume', 'aware'}
# ---
#
# Earth Day Ben Verwaayen what we're doing curb climate change [link]
# locs:  set()
# {'earth', 'day', 'curb'}
# ---
#
# HEALTH U.S. and other industrial nations already feel impacts climate change report [link]
# locs:  {'u.s.'}
# {'nation', 'report', 'impact', 'health', 'feel', 'industrial'}
# ---
#
# first steps greener living all seems daunting Climate change. Carbon credits. Not mention biofuel... [link]
# locs:  set()
# {'live', 'greener', 'credit', 'step', 'carbon', 'daunt', 'mention'}
# ---
#
# Climate change could raise cost U.S. allergies (Reuters) [link]
# locs:  {'u.s.'}
# {'cost', 'raise', 'allergy'}
# ---
#
# Treating Climate Change Curable Disease Bioethicists and international law experts met Asilomar later las... [link]
# locs:  set()
# {'expert', 'treat', 'meet', 'law', 'later', 'disease', 'curable', 'international'}
# ---
#
# well this just crazy Coal CEO Calls Mine Safety Rules 'As Silly Global Warming' [link]
# locs:  set()
# {'crazy', 'rules', 'silly', 'coal', 'call', 'safety'}
# ---
#
# Military leads fight against climate change [link]
# locs:  set()
# {'military', 'lead', 'fight'}
# ---
#
# Military leads fight against climate change The U.S. military the government's largest fuel buyer leading th... [link]
# locs:  {'u.s.'}
# {'fight', 'buyer', 'government', 'large', 'military', 'fuel', 'lead'}
# ---
#
# Swedish expert says CO2 not the main cause global warming Swedish climate expert Dr. Fred Goldberg has said [link]
# locs:  set()
# {'expert', 'cause', 'say', 'main'}
# ---
#
# @greenforyou Treating Climate Change Curable Disease Wired Science Wired.com green [link]
# locs:  set()
# {'science', 'green', 'treat', 'wired', 'disease', 'curable'}
# ---
#
# [link]
# locs:  set()
# set()
# ---
#
# Thursday PBS Going Green New York Examining how New Yorkers are confronting climate change Check local listings [link]
# locs:  {'new', 'green', 'york'}
# {'check', 'local', 'go', 'examine', 'listing', 'confront'}
# ---
#
# Only Global Cooperation Can Prevent Runaway Climate Change Secretary The United Nations seeks dialogue i... [link]
# locs:  set()
# {'united', 'secretary', 'prevent', 'cooperation', 'runaway', 'seek', 'nations', 'dialogue'}
# ---
#
# @democracy_now Most Important Event Struggle Against Climate Change Nigerian Environmentalist Nnimmo Bassey [link]
# locs:  set()
# {'event', 'environmentalist', 'struggle', 'important'}
# ---
#
# Military leads fight against climate change Pew [link]
# locs:  set()
# {'military', 'lead', 'fight', 'pew'}
# ---
#
# Report identifies diseases health issues affctd climate change. Once inclde mental health evrything's stake [link]
# locs:  set()
# {'issue', 'report', 'identify', 'health', 'mental', 'stake', 'disease'}
# ---
#
# For Earth Day Resources coping with climate change [link]
# locs:  set()
# {'earth', 'day', 'cope', 'resources'}
# ---
#
# Ocean Saltiness Shows Global Warming Intensifying Our Water Cycle [link]
# locs:  set()
# {'saltiness', 'water', 'cycle', 'intensify', 'ocean', 'show'}
# ---
#
# Fedele Bauccio Combating Climate Change One Meal Time This week Americans will celebrate the 40th anniver... [link]
# locs:  set()
# {'meal', 'celebrate', 'time', 'combating', 'week'}
# ---
#
# @egeemnz @mrdannyglover support world people's conf climate change cochabamba bolivia.watch live [link]
# locs:  set()
# {'people', 'support', 'live', 'world'}
# ---
#
# Barrett better have lots small protocols climate change than pushing for one comprehensive one
# locs:  set()
# {'better', 'protocol', 'lot', 'comprehensive', 'push', 'small'}
# ---
#
# Topography mountains could complicate rates global warming [link]
# locs:  set()
# {'complicate', 'topography', 'rate', 'mountain'}
# ---
#
# @mrdannyglover support the world people's conference climate change cochabamba bolivia. watch live now [link]
# locs:  set()
# {'support', 'live', 'watch', 'conference', 'people', 'world'}
# ---
#
# Many global issues require universal co-operation address e.g. smallpox ozone layer climate change
# locs:  set()
# {'issue', 'layer', 'co', 'smallpox', 'ozone', 'operation', 'require', 'universal', 'address'}
# ---
#
# @hereisawayjose Bolivia President Global Warming [link]
# locs:  set()
# {'president'}
# ---
#
# @indiawater Boiling Point Containing the spill over climate change the Indian subcontinent [link]
# locs:  set()
# {'boil', 'point', 'subcontinent', 'spill', 'contain'}
# ---
#
# link now between and climate change but warming world could trigger earthquakes landslides... [link]
# locs:  set()
# {'landslide', 'earthquake', 'trigger', 'world'}
# ---
#
# Ethiopia Climate Change Increasing Poverty And Vulnerability [link]
# locs:  {'ethiopia'}
# {'increase', 'poverty', 'vulnerability'}
# ---
#
# Ethiopia Climate Change Increasing Poverty And Vulnerability Small-scale farmers and pastoralists i... [link]
# locs:  {'ethiopia'}
# {'vulnerability', 'farmer', 'poverty', 'scale', 'small', 'increase'}
# ---
#
# @democracy_now The Most Important Event the Struggle Against Climate Change Nigerian Environmentalist Nnimmo Bassey [link]
# locs:  set()
# {'event', 'environmentalist', 'struggle', 'important'}
# ---
#
# The Most Important Event the Struggle Against Climate Change Nigerian Environmentalist Nnimmo Bassey [link]
# locs:  set()
# {'event', 'environmentalist', 'struggle', 'important'}
# ---
#
# @energysection Backgrounder China's major policies tackle climate change since year 2000.. [link]
# locs:  set()
# {'policy', 'tackle', 'year', 'china', 'backgrounder', 'major'}
# ---
#
# biologist links early blooms global warming Associated Press April 2010 STEVENS POINT [link]
# locs:  set()
# {'point', 'press', 'associated', 'biologist', 'link', 'bloom', 'early'}
# ---
#
# Will Global Warming Make Iceland's Volcanoes Angry? Melting glaciers around the world could trigger global [link]
# locs:  set()
# {'glacier', 'trigger', 'melt', 'angry', 'volcanoes', 'world'}
# ---
#
# Climate Change Could NYC Get Katrina-Like Flood Warmer Wetter Future? Sea Level Rise Feet 70yrs [link]
# locs:  set()
# {'flood', 'warmer', 'like', 'foot', 'sea', 'rise', 'wetter', 'level', 'future'}
# ---
#
# Climate Change Geologists Drill Into Antarctica Find Troubling Signs Ice Sheets' Future Melt Could Come FAST [link]
# locs:  set()
# {'sign', 'geologist', 'melt', 'ice', 'fast', 'drill', 'come', 'sheets', 'troubling', 'find', 'future'}
# ---
#
# Either Capitalism dies Mother Earth does Evo Morales Claims the People's World Conference Climate Change [link]
# locs:  {'earth'}
# {'capitalism', 'die', 'mother', 'claim', 'conference', 'people', 'world'}
# ---
#
# @rubberstamprosk @Mother Jones Yet another gift from global warming increased allergy attacks [link]
# locs:  set()
# {'gift', 'attack', 'increase', 'allergy'}
# ---
#
# Africa Time Bomb Awaiting Africa THERE doubt that climate change environmental issue ha... [link]
# locs:  set()
# {'issue', 'ha', 'awaiting', 'time', 'doubt', 'environmental', 'bomb'}
# ---
#
# Buying carbon offsets may ease eco-guilt but not global warming [link]
# locs:  set()
# {'buy', 'guilt', 'ease', 'carbon', 'offset'}
# ---
#
# @Qorianka All Eyes Cochabamba Those alrdy suffering from global warming 'll havechancetospeakout [link]
# locs:  set()
# {'suffer', 'eye'}
# ---
#
# @Eco Steward This Eco Monday @Invasive Notes discussion climate change and invasive species recommended: [link]
# locs:  set()
# {'steward', 'recommend', 'specie', 'invasive', 'discussion', 'notes'}
# ---
#
# ocean floor populations organisms despite little oxygen. global warming cause oxygen depletion reduce biodiversity[link]
# locs:  set()
# {'despite', 'little', 'population', 'floor', 'depletion', 'organism', 'reduce', 'ocean', 'oxygen', 'cause'}
# ---
#
# Join for discussion Earth Day 4/22 Climate Change Food Security Irreversible Destiny? [link]
# locs:  set()
# {'security', 'earth', 'day', 'food', 'join', 'discussion', 'irreversible', 'destiny'}
# ---
#
# @NWF New York City's new waterfront plan will take climate change into consideration [link]
# locs:  {'new', "city's", 'york'}
# {'city', 'waterfront', 'plan', 'consideration'}
# ---
#
# Pat Mooney the Dangers Geoengineering and Manipulating the Planet Combat Climate Change [link]
# locs:  set()
# {'planet', 'geoengineering', 'dangers', 'manipulating', 'pat', 'combat'}
# ---
#
# Seasonal Allergies Getting Worse From Climate Change [link]
# locs:  set()
# {'bad', 'get', 'seasonal', 'allergy'}
# ---
#
# Just because believe global warming peeps thinks should believe god instead. Why??
# locs:  set()
# {'think', 'god', 'peep', 'instead', 'believe'}
# ---
#
# @Zener39 advise everyone who thinks global warming dead buy oceanfront property and live there. See
# locs:  set()
# {'oceanfront', 'live', 'dead', 'property', 'buy', 'think', 'advise'}
# ---
#
# Global Warming Melting Ice Caps Could Help Trigger More Volcanic Eruptions [link]
# locs:  set()
# {'trigger', 'melt', 'ice', 'volcanic', 'eruption', 'help', 'cap'}
# ---
#
# Mary Ellen Harte and John Harte Addressing Climate Change Winning the War Sustainability its heart clim... [link]
# locs:  set()
# {'win', 'john', 'sustainability', 'addressing', 'heart', 'war'}
# ---
#
# @Drudge_Report STATE DEPT. DECLARES 'Global warming unequivocal and primarily human-induced'... [link]
# locs:  set()
# {'state', 'primarily', 'unequivocal', 'dept', 'induce', 'declares', 'human'}
# ---
#
# Increasingly corporations are concluding climate change real. Betting Climate Change Wired.com [link]
# locs:  set()
# {'corporation', 'real', 'conclude', 'increasingly', 'bet'}
# ---
#
# Right Richard Branson's Earth Day message biz Get house order.Fight global warming green eco [link]
# locs:  set()
# {'green', 'fight', 'biz', 'earth', 'day', 'message', 'order', 'house', 'right'}
# ---
#
# Meat-Wise] Cynthia Bateman Meat-Wise Monday How Animal Agriculture Makes Global Warming Worse [link]
# locs:  set()
# {'meat', 'animal', 'agriculture', 'wise', 'make', 'bad'}
# ---
#
# STATE DEPT. DECLARES 'Global warming unequivocal and primarily human-induced'... [link]
# locs:  set()
# {'state', 'primarily', 'unequivocal', 'dept', 'induce', 'declares', 'human'}
# ---
#
# Global warming melting ice caps could trigger more volcanic eruptions [link]
# locs:  set()
# {'trigger', 'volcanic', 'melt', 'ice', 'eruption', 'cap'}
# ---
#
# @Lil Ferret hey came with all kinds ideas for fixing global warming Loved Environmentalism class. sighs
# locs:  set()
# {'kind', 'environmentalism', 'idea', 'class', 'loved', 'ferret', 'hey', 'sigh', 'come', 'fix'}
# ---
#
# Overview the Green Car Revolution Going Green The increasing awareness about the threat global warming... [link]
# locs:  set()
# {'green', 'overview', 'threat', 'revolution', 'awareness', 'go', 'car', 'increase'}
# ---
#
# 2nd eruption Hekla Iceland. Let's call 2010 the year the Earth struck back. This for global warming and THIS for oil spills
# locs:  {'earth'}
# {'year', 'spill', 'strike', 'eruption', 'let', 'oil'}
# ---
#
# @Newsweek Climate Change Places See Before They Americas (Photos) [link]
# locs:  set()
# {'place', 'photos'}
# ---
#
# @Episcopal Relief Bishop Lane Episcopal Dio Maine Climate change most important issue our time Bangor Daily Nws [link]
# locs:  set()
# {'issue', 'episcopal', 'relief', 'important', 'lane', 'time', 'daily', 'bishop'}
# ---
#
# @Tree Hugger case you were wondering What Impact Will The Volcano Iceland Have Climate Change? [link]
# locs:  set()
# {'wonder', 'volcano', 'impact', 'case'}
# ---
#
# Cool global warming bad enough without you heating things up. the interest honest discussion can [link]
# locs:  set()
# {'interest', 'thing', 'honest', 'discussion', 'heat', 'cool', 'bad'}
# ---
#
# @Invasive Notes @Rare WildlifeGuy Climate change Migration patterns have changed for billion birds [link]
# locs:  set()
# {'bird', 'billion', 'change', 'pattern', 'migration', 'note'}
# ---
#
# Volcanic ash cloud Global warming may trigger more volcanoes Climate change could spark more ''hazardous'' [link]
# locs:  set()
# {'volcano', 'trigger', 'volcanic', 'ash', 'spark', 'hazardous', 'cloud'}
# ---
#
# Just briefed global cooling volcanoes via @abc But wonder ... gets the stratosphere can slow/improve global warming??
# locs:  set()
# {'volcano', 'stratosphere', 'slow', 'get', 'wonder', 'cool', 'improve', 'brief'}
# ---
#
# Climate Change-ing your Allergies [link]
# locs:  set()
# {'allergy'}
# ---
#
# Obama says China can't 'wait' climate change Sydney (AFP) April 2010 President Barack Obama Thursd... [link]
# locs:  {'china'}
# {'say', 'president', 'wait'}
# ---
#
# @beckbasher @Ian DavidB @Shoq CLIMATE CHANGE DENIERS Bobby Jindal mocked volcano warnings. Read the papers lately? Start thinking for yourselves
# locs:  set()
# {'lately', 'volcano', 'warning', 'deniers', 'paper', 'bobby', 'think', 'mock', 'start', 'read'}
# ---
#
# @TEDNews Cara Mertes tedxvolcano We're all stranded this weekend. And we're getting sneak preview climate change. have adapt.
# locs:  set()
# {'strand', 'weekend', 'preview', 'get', 'sneak', 'adapt'}
# ---
#
# Larry Brilliant TEDx Volcano have fight for science the single most important thing face climate change socmedia @enviro
# locs:  set()
# {'science', 'volcano', 'fight', 'thing', 'important', 'face', 'brilliant', 'single'}
# ---
#
# Larry Brilliant TEDx Volcano have fight for science the single most important thing face climate change socent green
# locs:  set()
# {'science', 'volcano', 'green', 'fight', 'thing', 'important', 'face', 'brilliant', 'single'}
# ---
#
# Damn man that ash cloud Europe crazy they say due global warming with the volcano activating getting crazy
# locs:  {'europe'}
# {'volcano', 'ash', 'activate', 'crazy', 'get', 'damn', 'cloud', 'man'}
# ---
#
# @TEDNews Larry Brilliant tedxvolcano Climate change exacerbating all other crises our age. But climate science now under attack.
# locs:  set()
# {'science', 'crisis', 'exacerbate', 'age', 'attack', 'brilliant'}
# ---
#
# Global Warming Causes Volcano Eruptions Jonah Goldberg From Reuters OSLO (Reuters) thaw Iceland's... [link]
# locs:  set()
# {'causes', 'volcano', 'thaw', 'eruptions'}
# ---
#
# @Climates_Change Bring Indigenous Voices into the Conversation About Climate Change [link]
# locs:  set()
# {'bring', 'conversation', 'indigenous', 'voice'}
# ---
#
# Climate Change Volcanic Activity Ice Cap Thaw May Awaken Icelandic Volcanoes [link]
# locs:  set()
# {'volcanic', 'ice', 'awaken', 'thaw', 'activity', 'volcanoes', 'cap'}
# ---
#
# Rain the Amazon How South Climate Change Affects Entire -Interview Nikolas Kozloff (vid) [link]
# locs:  set()
# {'entire', 'rain', 'amazon', 'south', 'affect'}
# ---
#
# Climate Change Places See Before They Americas (Photos) [link]
# locs:  set()
# {'place', 'photos'}
# ---
#
# @bruces Hmmm they rather buried the lede here Iceland glaciers melt from global warming then volcanoes off [link]
# locs:  {'iceland'}
# {'volcanoe', 'glacier', 'bury', 'melt'}
# ---
#
# Not sure this consensus but scientist warns climate change will lead more volcano crises due melting ice. [link]
# locs:  set()
# {'scientist', 'sure', 'volcano', 'melt', 'ice', 'crisis', 'consensus', 'warn', 'lead'}
# ---
#
# Wishing was Cochabamba the People's World Conference Climate Change and the Rights Mother Earth @boliviaun
# locs:  set()
# {'rights', 'mother', 'earth', 'conference', 'people', 'wishing', 'world'}
# ---
#
# feel that already @organicnewyork Climate change making seasonal allergies worse. Near-record highs this Spring [link]
# locs:  set()
# {'record', 'seasonal', 'allergy', 'feel', 'near', 'make', 'bad', 'spring', 'high'}
# ---
#
# @organicnewyork Climate change making seasonal allergies worse. Near-record highs this Spring. [link]
# locs:  set()
# {'record', 'seasonal', 'allergy', 'near', 'make', 'bad', 'spring', 'high'}
# ---
#
# Like Icelandic volcanic eruptions disrupting your air travel? Climate change glacier thaw more it. [link]
# locs:  set()
# {'glacier', 'volcanic', 'like', 'disrupt', 'travel', 'air', 'eruption', 'thaw'}
# ---
#
# Cochabamba Summit Offers New Approach Combating Climate Change [link]
# locs:  set()
# {'new', 'approach', 'offer', 'combating', 'summit'}
# ---
#
# Climate Change Making You Sneeze [link]
# locs:  set()
# {'sneeze', 'make'}
# ---
#
# ENVIRONMENT Climate change From something simple reminding computer users power down when not workin... [link]
# locs:  set()
# {'simple', 'power', 'computer', 'user', 'remind', 'environment'}
# ---
#
# Professor?s Perspective Reasons Concerned about Climate Change Spring Connecticut brings renewal [link]
# locs:  set()
# {'bring', 'perspective', 'concern', 'renewal', 'reason', 'spring'}
# ---
#
# The need switch renewable energy Climate scientists have long warned that global warming accelerating [link]
# locs:  set()
# {'scientist', 'energy', 'accelerate', 'long', 'need', 'switch', 'warn', 'renewable'}
# ---
#
# Climate Change culprit for Off-the-Charts Pollen Counts... [link]
# locs:  set()
# {'culprit', 'counts', 'charts', 'pollen'}
# ---
#
# Coalition the Tired Waiting Fighting Climate Change Ground Level [link]
# locs:  set()
# {'fighting', 'waiting', 'ground', 'level', 'coalition', 'tired'}
# ---
#
# Allergy Season Worsen With Climate Change Report new report released Wednesday the National Wildlife... [link]
# locs:  set()
# {'national', 'report', 'new', 'season', 'allergy', 'worsen', 'wildlife', 'release'}
# ---
#
# Author Nikolas Kozloff Rain the Amazon How South America's Climate Change Affects the Entire Planet [link]
# locs:  set()
# ...
# locs:  set()
# {'importance', 'disbelieve', 'pressure', 'game', 'detractor', 'public', 'world', 'show'}
# ---
#
# Like gravity the signs global warming are reliable and unchanging. http://bit.ly/aV1SJp
# locs:  set()
# {'reliable', 'unchanging', 'sign', 'like', 'gravity'}
# ---
#
# sometimes hard predict which the outcomes climate change green revolution vs. apocalypsenow) would more exciting me.
# locs:  set()
# {'hard', 'green', 'revolution', 'exciting', 'outcome', 'predict'}
# ---
#
# Graphs Climate Change Science One Place Alternative ... http://bit.ly/defx2I
# locs:  set()
# {'science', 'alternative', 'place', 'graphs'}
# ---
#
# Finally read Krugman's Climate Change Building Green Economy NYTimes.com http://nyti.ms/cYbFoI definitely worthwhile.
# locs:  set()
# {'finally', 'worthwhile', 'green', 'read', 'economy', 'definitely', 'building'}
# ---
#
# I'm Allergic Global Warming. Literally. Treehugger Brian Merchant Brooklyn New York 04.16.10 anyone... http://bit.ly/bXMO1F
# locs:  {'new', 'york', 'brooklyn'}
# {'allergic', 'merchant', 'literally'}
# ---
#
# Google climate change chief wants price carbon http://ow.ly/1zndt
# locs:  set()
# {'chief', 'google', 'carbon', 'price', 'want'}
# ---
#
# Weekly Mulch Cochacamba Summit Combat Climate Change Innovatively Sarah Laskow Media Consortium blogger... http://bit.ly/c3IcNg
# locs:  set()
# {'blogger', 'mulch', 'weekly', 'combat', 'media', 'summit', 'consortium'}
# ---
#
# The Global Warming debate discouraging when considering human intelligence. nutcases remain unpersuaded logic evidence.
# locs:  set()
# {'nutcase', 'logic', 'intelligence', 'debate', 'discouraging', 'evidence', 'unpersuaded', 'consider', 'remain', 'human'}
# ---
#
# Cal) probably represent the views global warming skeptics. http://bit.ly/9Swo7u
# locs:  set()
# {'cal', 'probably', 'skeptic', 'view', 'represent'}
# ---
#
# Congress worked out health care. climate change next? http://bit.ly/difrSa
# locs:  set()
# {'work', 'health', 'congress', 'care'}
# ---
#
# Top Climate Scientist Under Fire for 'Exaggerating' Global Warming http://bit.ly/9Pq0gQ
# locs:  set()
# {'scientist', 'fire', 'exaggerate'}
# ---
#
# Missing' heat may affect future climate change (source Science daily) Current observational tools cannot accoun... http://bit.ly/dpPh4n
# locs:  set()
# {'current', 'science', 'source', 'tool', 'heat', 'miss', 'daily', 'observational', 'affect', 'future'}
# ---
#
# How solve this global warming thing? Nathanael Johnson Everyone watching California see how han... http://bit.ly/beGB1T
# locs:  {'california'}
# {'t', 'watch', 'thing', 'solve'}
# ---
#
# Global Warming Missing Will Return Soon Scientists cannot account for roughly half the heat that believ... http://bit.ly/aCeBNw
# locs:  set()
# {'return', 'scientist', 'soon', 'account', 'heat', 'roughly', 'half', 'miss'}
# ---
#
# 2000 Year Climate Change Evidence Inconclusive Global Warming Global warming often marketed Armageddo... http://bit.ly/dmHshb
# locs:  {'armageddo'}
# {'year', 'market', 'evidence', 'inconclusive'}
# ---
#
# Oven Dial Light Switch Carbon Lock-in and Abrupt Climate Change http://ow.ly/1ySPh
# locs:  set()
# {'abrupt', 'lock', 'oven', 'carbon', 'dial', 'switch', 'light'}
# ---
#
# Global warming monitoring needs find 'missing heat' say scientists Experts need beef ways measure th... http://bit.ly/djMocO
# locs:  set()
# {'scientist', 'expert', 'beef', 'heat', 'measure', 'monitoring', 'way', 'need', 'find', 'miss'}
# ---
#
# Have good idea reduce carbon and climate change? Let know and win 000 grant make happen. http://tinyurl.com/y353oay
# locs:  set()
# {'win', 'happen', 'idea', 'good', 'know', 'carbon', 'let', 'reduce', 'grant'}
# ---
#
# Study climate change law cites local refineries for negative health effects http://bit.ly/9yVwHz
# locs:  set()
# {'cite', 'health', 'refinery', 'law', 'study', 'local', 'effect', 'negative'}
# ---
#
# Obama pushes developing countries global warming...New pressure pope SYDNEY (AP) President Barack Obama s... http://bit.ly/aFP0pm
# locs:  {'sydney'}
# {'new', 'develop', 'pressure', 'country', 'pope', 'president', 's', 'push'}
# ---
#
# Weather Channel Promotes 'Global Warming Hoax' Conspiracy Theory http://bit.ly/aVdHpT
# locs:  set()
# {'promote', 'theory', 'hoax', 'conspiracy', 'weather', 'channel'}
# ---
#
# Support for carbon tax plan Key supporters the government's climate change policies are backing Greens plan http://oohja.com/xaJxm
# locs:  set()
# {'support', 'policy', 'greens', 'back', 'tax', 'key', 'supporter', 'government', 'carbon', 'plan'}
# ---
#
# Global Economy Global warming graph attacked study http://ow.ly/1yFiC
# locs:  set()
# {'economy', 'study', 'attack', 'graph'}
# ---
#
# @Dr_Rose Cali has been getting strange weather this year?\\ Its called law averages catching the bullshit global warming scares
# locs:  set()
# {'call', 'scare', 'strange', 'get', 'law', 'catch', 'average', 'weather', 'bullshit'}
# ---
#
# Explorer discuss global warming Renowned polar explorer and adventurer Will Steger will present free program... http://bit.ly/b4xymI
# locs:  set()
# {'program', 'discuss', 'adventurer', 'present', 'renowned', 'free', 'explorer', 'polar'}
# ---
#
# another night creepy climate change nightmares ridiculous
# locs:  set()
# {'nightmare', 'creepy', 'ridiculous', 'night'}
# ---
#
# Fuck off asshole @redostoneage @Jules Beaujolais Accumulating Evidence the Corrupted Temp Record global warming climate cha
# locs:  set()
# {'record', 'fuck', 'corrupted', 'temp', 'asshole', 'evidence', 'accumulating'}
# ---
#
# NWF series extreme weather due Global Warming led NWF scientist Amanda Staudt. http://bit.ly/9iwHsQ
# locs:  set()
# {'scientist', 'extreme', 'series', 'weather', 'lead'}
# ---
#
# Thankfully least Rio Tinto's Preston Chiaro had some positive statements global warming and clean energy. http://bit.ly/div7Xq
# locs:  set()
# {'thankfully', 'statement', 'energy', 'clean', 'positive'}
# ---
#
# global warming governor after our own hearts rather than our wallets New Jersey Gov. Chris Christie has wised ... http://bit.ly/9Sb3gX
# locs:  {'jersey', 'new'}
# {'heart', 'wise', 'governor', 'wallet'}
# ---
#
# Just posted Public's willingness pay for preventing climate change http://bit.ly/cV1ZFi b2p
# locs:  set()
# {'prevent', 'pay', 'willingness', 'public', 'post'}
# ---
#
# Mc Ewan takes global warming \Solar\ (Nan Talese/Doubleday 287 pages $26.95) Ian Mc Ewan. http://oohja.com/xaAnQ
# locs:  set()
# {'page', 'take'}
# ---
#
# @Heritage Reaching for Any Excuse Tackle Climate Change http://tinyurl.com/y23bt5s
# locs:  set()
# {'reach', 'tackle', 'excuse'}
# ---
#
# evidence malpractice' from scientists accused fabricating global warming results inquiry finds http://bit.ly/dejQ9q
# locs:  set()
# {'scientist', 'malpractice', 'evidence', 'fabricate', 'inquiry', 'result', 'find', 'accuse'}
# ---
#
# Global warming' really just about control December 2009 141 scientists sent letter the United Nations S... http://bit.ly/aaJ4Q6
# locs:  set()
# {'united', 'scientist', 'nations', 'letter', 's', 'control', 'send'}
# ---
#
# obese people really cause global warming? Otago Daily Times ... Every age and society seems creates it... http://bit.ly/am5ZqX
# locs:  set()
# {'times', 'age', 'daily', 'society', 'create', 'people', 'cause', 'obese'}
# ---
#
# climate change turning coastal countries into water worlds? http://video.pbs.org/video/1305543836/
# locs:  set()
# {'water', 'turn', 'coastal', 'country', 'world'}
# ---
#
# Daniel Esty Climate Change Plan The Huffington Post http://huff.to/bC5rrj greentech
# locs:  set()
# {'post', 'plan'}
# ---
#
# Woot @Gay Patriot @Cubachi Governor Christie will cut all $65 million from NJ's global warming fund http://is.gd/brylO awesome
# locs:  set()
# {'cut', 'governor', 'fund', 'awesome', 'patriot', 'million'}
# ---
#
# United Kingdom) Health Psychology Professor Wendy Stainton obese people really cause global warming? http://bit.ly/csuvFM
# locs:  {'united', 'kingdom'}
# {'psychology', 'health', 'cause', 'people', 'obese', 'professor'}
# ---
#
# Newt Still Defends Global Warming Commercial with Pelosi 'We Need Green ... Gingrich contends was seeking c... http://bit.ly/b7TEtD
# locs:  set()
# {'contend', 'green', 'commercial', 'newt', 'c', 'need', 'defend', 'seek'}
# ---
#
# CH-180c Calendar Global Warming and Liberalism not about having calendar about making statement http://bit.ly/bfoaod
# locs:  set()
# {'statement', 'calendar', 'liberalism', 'make', 'have'}
# ---
#
# Don Blankenship Mine Safety Regulators Silly Global Warming (Video) Treehugger Brian Merchant Brookl... http://bit.ly/cfFIhx
# locs:  set()
# {'don', 'safety', 'silly', 'regulator', 'merchant', 'video'}
# ---
#
# Global Warming Truly Not Global Gulf California Peer ... Read here. This peer-reviewed Gulf Calif... http://bit.ly/dkL6rr
# locs:  set()
# {'read', 'gulf', 'peer', 'truly', 'review'}
# ---
#
# @patrickc The very idea that they care more about safety than silly global warming. Massey Energy (29 dead miners)
# locs:  set()
# {'energy', 'idea', 'care', 'dead', 'silly', 'miner', 'safety'}
# ---
#
# Gore ambushed about GLOBAL WARMING BRILLIANT (VIDEO) Jesse Woodrow Show 04-13-2010 http://bit.ly/ddLPf9
# locs:  set()
# {'ambush', 'brilliant', 'gore', 'video'}
# ---
#
# weathercasters divided global warming Suzanne Bohan Weather forecaster Spencer Christian sits with meteo... http://bit.ly/aOxWc8
# locs:  set()
# {'sit', 'divide', 'forecaster', 'weather', 'christian'}
# ---
#
# One headline read Now it's Cow Gate expert report says claims livestock causing global warming are false. http://bit.ly/azvLxS
# locs:  set()
# {'headline', 'expert', 'report', 'false', 'say', 'gate', 'claim', 'read', 'livestock', 'cause', 'cow'}
# ---
#
# That's why removed the data that disagreed with his global warming theory. http://bit.ly/9n5cbQ
# locs:  set()
# {'remove', 'datum', 'disagree', 'theory'}
# ---
#
# @Larry Briscoe @Joseph AGallant Global Warming Activist Freezes Death Antarctica http://tinyurl.com/gf3ud tcot
# locs:  set()
# {'freezes', 'activist', 'death'}
# ---
#
# Senators prepare compromise climate change bill (Reuters) Yahoo Green http://j.mp/aU1Kqz greentech
# locs:  set()
# {'yahoo', 'green', 'senator', 'compromise', 'prepare', 'bill'}
# ---
#
# Climate Change Fraud Global warming has catastrophe have surplus people pretending know th... http://bit.ly/94dpTq
# locs:  set()
# {'surplus', 'catastrophe', 'know', 'fraud', 'people', 'pretend'}
# ---
#
# Delhi filmmaker Rohit Gandhi's documentary climate change wins ... http://bit.ly/aFg9HR
# locs:  {'delhi'}
# {'win', 'documentary', 'filmmaker'}
# ---
#
# @earthvitalsigns Ice ice baby Get the lowdown ice climate change with the next our series Just Questions... http://bit.ly/c6YR9V
# locs:  set()
# {'ice', 'baby', 'series', 'questions', 'lowdown'}
# ---
#
# Ice ice baby Get the lowdown ice climate change with the next our series Just Questions... http://bit.ly/c6YR9V
# locs:  set()
# {'ice', 'baby', 'series', 'questions', 'lowdown'}
# ---
#
# Bats birds and lizards can fight climate change http://dld.bz/Vwv
# locs:  set()
# {'bird', 'fight', 'bat', 'lizard'}
# ---
#
# Natural Resource Econ Krugman Climate Change http://bit.ly/b4IyRj
# locs:  set()
# {'natural', 'econ', 'resource'}
# ---
#
# OXFAM Senior Press Officer Climate Change 700 710 OXFAM For more Charities jobs and jobs... http://bit.ly/bx6C5j
# locs:  set()
# {'press', 'job', 'senior', 'charity', 'officer'}
# ---
#
# THE best climate change economics primer. jasencomstock: love Paul Krugman and have say makes an... http://tumblr.com/xkw8jdz7y
# locs:  set()
# {'love', 'good', 'economic', 'primer', 'make'}
# ---
#
# New post LONG HORIZONS exploration Art and Climate Change http://bit.ly/ak6JKV
# locs:  set()
# {'new', 'horizon', 'exploration', 'art', 'long', 'post'}
# ---
#
# Senate Global Warming Bill Track Six months after introducing sweeping climate change bill that flopped t... http://bit.ly/anDm5n
# locs:  set()
# {'track', 'senate', 'flop', 'introduce', 'sweeping', 'month', 'bill', 't'}
# ---
#
# @Jerry Mander Daily Kos ecojustice systems change not climate change NOT violence http://bit.ly/bBxEKB Right now our elected
# locs:  set()
# {'elect', 'daily', 'system', 'violence', 'right'}
# ---
#
# Global Warming Hoax? Find Answers this Question you think global warming hoax why would anyone... http://bit.ly/abbfvn
# locs:  set()
# {'think', 'hoax', 'question', 'answer', 'find'}
# ---
#
# Bonn Cancun'Negotiators Agree Continue Efforts International Global ... The first global warming negotia... http://bit.ly/9Jreep
# locs:  {'bonn'}
# {'efforts', 'agree', 'continue', 'international'}
# ---
#
# Thirty million years ago there were palm trees Alaska. These vanished over time due process called climate change.
# locs:  {'alaska'}
# {'ago', 'year', 'process', 'time', 'palm', 'tree', 'vanish', 'thirty', 'call', 'million'}
# ---
#
# Second Study Refutes Link Between Meat Global Warming Opposing Views The UK's Daily Telegraph declares today th... http://bit.ly/d5a3FT
# locs:  {'uk'}
# {'oppose', 'meat', 'declare', 'study', 'daily', 'second', 'view', 'today', 'telegraph', 'refute'}
# ---
#
# Global Warming Fanatics Clash With Environmentalists Red State Further proving consistent point that global w... http://bit.ly/dg07rw
# locs:  set()
# {'state', 'point', 'clash', 'prove', 'fanatics', 'environmentalists', 'w', 'red', 'consistent'}
# ---
#
# What are some major sources water pollution? Global Warming http://bit.ly/cjGmk4
# locs:  set()
# {'water', 'source', 'major', 'pollution'}
# ---
#
# @johnnyA99 'Ecocide used prosecute 'climate deniers'...on 'global warming' http://bit.ly/aKVHKZ liberalFascism News tcot 3p2
# locs:  set()
# {'prosecute', 'news', 'ecocide'}
# ---
#
# Bats Birds and Lizards Can Fight Climate Change Birds bats and lizards may play important role Earth's cl... http://ow.ly/172hQh
# locs:  {'earth'}
# {'fight', 'important', 'bat', 'cl', 'play', 'lizard', 'birds', 'role'}
# ---
#
# Bats Birds and Lizards Can Fight Climate Change Birds bats and lizards may play important role Earth's cl... http://ow.ly/172hQg
# locs:  {'earth'}
# {'fight', 'important', 'bat', 'cl', 'play', 'lizard', 'birds', 'role'}
# ---
#
# Bats Birds and Lizards Can Fight Climate Change Birds bats and lizards may play important role Earth's cl... http://ow.ly/172hQl
# locs:  {'earth'}
# {'fight', 'important', 'bat', 'cl', 'play', 'lizard', 'birds', 'role'}
# ---
#
# Bats Birds and Lizards Can Fight Climate Change Birds bats and lizards may play important role Earth's cl... http://ow.ly/172hQk
# locs:  {'earth'}
# {'fight', 'important', 'bat', 'cl', 'play', 'lizard', 'birds', 'role'}
# ---
#
# Bats Birds and Lizards Can Fight Climate Change Birds bats and lizards may play important role Earth's cl... http://ow.ly/172hQi
# locs:  {'earth'}
# {'fight', 'important', 'bat', 'cl', 'play', 'lizard', 'birds', 'role'}
# ---
#
# Global warming The fossil fuel dilemma America uses about million barrels per oil each day serve the needs... http://bit.ly/aEoudt
# locs:  {'america'}
# {'fossil', 'barrel', 'serve', 'day', 'dilemma', 'need', 'oil', 'use', 'million', 'fuel'}
# ---
#
# @EPSclimate Climate change row over the mystery the shrinking sheep http://bit.ly/d4IL0Q climate
# locs:  set()
# {'shrink', 'mystery', 'row', 'sheep'}
# ---
#
# It's and climbing NYC. August weather for the first day May Unbelievable Chalk global warming?
# locs:  set()
# {'chalk', 'climb', 'day', 'unbelievable', 'august', 'weather'}
# ---
#
# @bloodless_coup The phrase 'global warming' should abandoned favor 'climate change' Luntz says http://bit.ly/7bIY0c tcot
# locs:  set()
# {'favor', 'phrase', 'say', 'abandon'}
# ---
#
# Virginia Investigate Global Warming Scientist Mann http://bit.ly/aDlavg
# locs:  set()
# {'investigate', 'scientist'}
# ---
#
# Global warming you tube parody you will enjoy IPCC ocra http://bit.ly/bBGWhC
# locs:  set()
# {'tube', 'parody', 'enjoy'}
# ---
#
# One-Eyed Golfer Don't dare tell about global warming Twenty-five the forty-nine golfers making the cut thi... http://bit.ly/akeAxp
# locs:  set()
# {'cut', 'dare', 'tell', 'make', 'eyed', 'golfer'}
# ---
#
# man made global warming hair brained theory the scientifically challenged the IPPC has nothing back claims tcot climategate
# locs:  set()
# {'challenge', 'theory', 'brain', 'claim', 'man', 'scientifically', 'hair'}
# ---
# <4412x4389 sparse matrix of type '<class 'numpy.float64'>'
# 	with 27976 stored elements in Compressed Sparse Row format>

# %%
X_ = TruncatedSVD(n_components=2000).fit_transform(X)
X_train, X_test, Y_train, Y_test = train_test_split(X_, Y, test_size=0.2)

# %% [markdown]
# Testing

# %%
model = pred(X_train, Y_train, X_test, Y_test, Perceptron())

# %%
model = pred(X_train, Y_train, X_test, Y_test, LogisticRegression())

# %% [markdown]
# Cross Validation

# %%
cv_perceptron, mean_scores_perceptron = cross_val(X_train, Y_train, X_test, Y_test, Perceptron())
plot_cross_val(cv_perceptron)
mean_scores_perceptron
# Out:
#        accuracy  precision    recall
# train  0.883185   0.981086  0.792163
# test   0.661659   0.733566  0.552178

# %%
cv_lr, mean_scores_lr = cross_val(X_train, Y_train, X_test, Y_test, LogisticRegression())
plot_cross_val(cv_lr)
mean_scores_lr
# Out:
#        accuracy  precision    recall
# train  0.865259   0.856899  0.888066
# test   0.706152   0.703416  0.747661

# %% [markdown]
# Testing SVD

# %%
def testSVD(X, Y, n_components):
    X_ = TruncatedSVD(n_components=n_components).fit_transform(X)
    
    X_train, X_test, Y_train, Y_test = train_test_split(X_, Y, test_size=0.2)

    model = LogisticRegression()

    num_cv = 5
    
    cv = cross_validate(model, X_train, Y_train, cv=num_cv, return_train_score=True, n_jobs=-1)
    
    return np.sum(cv["test_score"])/num_cv

# %%
X_svd_test, Y_svd_test = preprocess(data)
components = np.arange(1000,X_svd_test.shape[0]-(X_svd_test.shape[0]%1000)+1000,1000)
scores = []
for num in components:
    score = testSVD(X_svd_test, Y_svd_test, num)
    scores.append(score)
    
    print(num, " | ", score)
    
plt.figure(figsize=(4,4))
plt.plot(components, scores)
plt.ylabel("Test Accuracy")
plt.xlabel("Number of Components")
plt.title("Comparing Accuracies For Different Numbers of Components")
plt.show()

# %% [markdown]
# Plot for Differing Numbers of Samples

# %%
size = X.shape[0]
inc = 1000

samples = np.arange(0, size-(size%inc), inc)
acc_scores = []
prec_scores = []
rec_scores = []

original_data_ = data
for i in range(0, size-(size%inc), inc):
    data = original_data_.sample(n=i + inc, replace=False, axis=0)
    X_sampled, Y_sampled = preprocess(data)
    X_train_, X_test_, Y_train_, Y_test_ = train_test_split(X_sampled, Y_sampled, test_size=0.2)
    cv_lr, mean_scores_lr = cross_val(X_train_, Y_train_, X_test_, Y_test_, LogisticRegression())
    acc_scores.append(mean_scores_lr.loc["test","accuracy"])
    prec_scores.append(mean_scores_lr.loc["test","precision"])
    rec_scores.append(mean_scores_lr.loc["test","recall"])    

plt.figure(figsize=(4,4))
plt.plot(samples, acc_scores)
plt.title("Accuracy for Differing Numbers of Samples")
plt.xlabel("Number of Samples")
plt.ylabel("Accuracy")
plt.show()

plt.figure(figsize=(4,4))
plt.plot(samples, prec_scores)
plt.title("Precision for Differing Numbers of Samples")
plt.xlabel("Number of Samples")
plt.ylabel("Precision")
plt.show()

plt.figure(figsize=(4,4))
plt.plot(samples, rec_scores)
plt.title("Recall for Differing Numbers of Samples")
plt.xlabel("Number of Samples")
plt.ylabel("Recall")
plt.show()
