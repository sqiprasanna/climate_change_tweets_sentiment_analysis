# %%
import numpy as np
import pandas as pd
import spacy
import matplotlib.pyplot as plt 
from itertools import chain
from wordcloud import WordCloud, STOPWORDS 
from nltk.stem import PorterStemmer
import re

import cufflinks as cf
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)

# %run ./jlu_preprocessing.ipynb
# %run ./spk_preprocessing.ipynb
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %%
# data = pd.read_excel(r'C:/Users/Checkout/Desktop/SJSU/sem1/257-ML/Project/global_warming_tweets.xls')
data = pd.read_csv(r'C:/Users/Checkout/Desktop/SJSU/sem1/257-ML/Project/global_warming_tweets_main.csv', engine='python') #encoding = "cp1252"
data.head()
# Out:
#                                                tweet existence  \
# 0  Global warming report urges governments to act...       Yes
# 1  Fighting poverty and global warming in Africa ...       Yes
# 2  Carbon offsets: How a Vatican forest failed to...       Yes
# 3  Carbon offsets: How a Vatican forest failed to...       Yes
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...       Yes
#
#    existence.confidence
# 0                1.0000
# 1                1.0000
# 2                0.8786
# 3                1.0000
# 4                0.8087

# %%
data['existence'] = data['existence'].fillna('neutral')

# %%
data[data['existence']=="No"].tweet
# Out:
# 17      Wait here's an idea: it's natural climate chan...
# 31      @New_federalists  i have it on good auth tht g...
# 32      Illegal war and the myth of global warming|My ...
# 33      the scientific community was scamed by global ...
# 35      40 degrees in NYC. please urinate on next libe...
#                               ...
# 781     Don Blankenship Calls Efforts On Mine Safety R...
# 1006    Don't be swayed by distraction of climate chan...
# 1058    Who Cares About Global Warming?: by Jackie Gin...
# 1071    Don Blankenship Called Safety Regulators "as S...
# 1072    Coal CEO Calls Mine Safety Rules 'As Silly As ...
# Name: tweet, Length: 61, dtype: object

# %%
print(data['existence'].value_counts())
# Out:
# Y          2554
# neutral    1865
# N          1053
# Yes         557
# No           61
# Name: existence, dtype: int64

# %%
data['word_count'] = data['tweet'].apply(lambda x: len(x.split(" ")))
data = data.drop_duplicates()
data = data.dropna()
data.loc[data['existence'] == 'Y','existence'] = "Yes"
data.loc[data['existence'] == 'N','existence'] = "No"
print(data.shape)
data.dropna()
data.loc[data['existence'] == np.nan,'existence'] = "No"
print(data['existence'].value_counts())
print(data.shape)
data.head()
# Out:
# (5960, 4)
# Yes        3029
# neutral    1826
# No         1105
# Name: existence, dtype: int64
# (5960, 4)
#                                                tweet existence  \
# 0  Global warming report urges governments to act...       Yes
# 1  Fighting poverty and global warming in Africa ...       Yes
# 2  Carbon offsets: How a Vatican forest failed to...       Yes
# 3  Carbon offsets: How a Vatican forest failed to...       Yes
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...       Yes
#
#    existence.confidence  word_count
# 0                1.0000          18
# 1                1.0000           8
# 2                0.8786          12
# 3                1.0000          12
# 4                0.8087          11

# %%
data['tweet']
# Out:
# 0       Global warming report urges governments to act...
# 1       Fighting poverty and global warming in Africa ...
# 2       Carbon offsets: How a Vatican forest failed to...
# 3       Carbon offsets: How a Vatican forest failed to...
# 4       URUGUAY: Tools Needed for Those Most Vulnerabl...
#                               ...
# 6085    @bloodless_coup "The phrase 'global warming' s...
# 6086    Virginia to Investigate Global Warming Scienti...
# 6087    Global warming you tube parody you will enjoy ...
# 6088    One-Eyed Golfer: Don't dare tell me about glob...
# 6089    man made global warming a hair brained theory ...
# Name: tweet, Length: 5960, dtype: object

# %%
tweets = data["tweet"]
# tweets = tweets.drop_duplicates()
tweets
# Out:
# 0       Global warming report urges governments to act...
# 1       Fighting poverty and global warming in Africa ...
# 2       Carbon offsets: How a Vatican forest failed to...
# 3       Carbon offsets: How a Vatican forest failed to...
# 4       URUGUAY: Tools Needed for Those Most Vulnerabl...
#                               ...
# 6085    @bloodless_coup "The phrase 'global warming' s...
# 6086    Virginia to Investigate Global Warming Scienti...
# 6087    Global warming you tube parody you will enjoy ...
# 6088    One-Eyed Golfer: Don't dare tell me about glob...
# 6089    man made global warming a hair brained theory ...
# Name: tweet, Length: 5960, dtype: object

# %%
# tweets[:100]

# %%
# python -m spacy download en_core_web_sm
preprocessed_tweets,indices = preprocess_tweets(tweets)
# Out:
# {'urge', 'belgium', 'world', 'face', 'report', 'global', 'hunger', 'increase', 'warming', 'government'}
# ---
#
# {'fight', 'poverty', 'global', 'warming', 'africa'}
# ---
#
# {'warming', 'offset', 'forest', 'fail', 'carbon', 'reduce', 'vatican', 'global'}
# ---
#
# {'warming', 'offset', 'forest', 'fail', 'carbon', 'reduce', 'vatican', 'global'}
# ---
#
# {'need', 'vulnerable', 'climate', 'uruguay', 'tool', 'change'}
# ---
#
# {'water', 'saltiness', 'ocean', 'cycle', 'global', 'intensify', 'warming', 'show'}
# ---
#
# {'message', 'look', 'evidence', 'doubter', 'global', 'denier', 'warming'}
# ---
#
# {'migratory', 'home', 'strategy', 'climate', 'bird', 'change', 'stay'}
# ---
#
# {'southern', 'water', 'high', 'compete', 'climate', 'southe', 'limpopo', 'change', 'temperature', 'africa', 'bring'}
# ---
#
# {'scarcity', 'water', 'wheat', 'production', 'global', 'impact', 'rice', 'warming'}
# ---
#
# {'previously', 'suggest', 'natural', 'contribute', 'preliminary', 'warming', 'global', 'analysis'}
# ---
#
# {'ecotone', 'perspective', 'climate', 'population', 'change'}
# ---
#
# {'coastal', 'climate', 'blame', 'whale', 'dwindle', 'ventura', 'change', 'county', 'migration'}
# ---
#
# {'spring', 'season', 'year', 'storm', 'start', 'warming', 'global', 'little', 'late'}
# ---
#
# {'mental', 'say', 'cancer', 'report', 'illness', 'global', 'warming', 'government', 'cause'}
# ---
#
# {'earthday', 'symptom', 'patient', 'affect', 'global', 'warming'}
# ---
#
# {'induce', 'human', 'wait', 'idea', 'natural', 'climate', 'warming', 'global', 'change'}
# ---
#
# {'measurable', 'effect', 'ecosystem', 'report', 'have', 'climate', 'indicator', 'warming', 'issue', 'change'}
# ---
#
# {'ocean', 'year', 'chemistry', 'fast', 'carbon', 'global', 'warming', 'change'}
# ---
#
# {'concl', 'complicate', 'study', 'sciencedaily', 'topography', 'warming', 'global', 'rate', 'mountain'}
# ---
#
# {'environmentalist', 'blame', 'soar', 'attribute', 'global', 'mercury'}
# ---
#
# {'national', 'woman', 'leader', 'change', 'climate', 'live', 'indigenous'}
# ---
#
# {'upper', 'atmospher', 'sediment', 'effect', 'reporting', 'increase', 'reduce', 'warming', 'global'}
# ---
#
# {'news', 'today', 'effect', 'stat', 'global', 'youtube', 'warming'}
# ---
#
# {'warm', 'climate', 'global', 'change', 'read'}
# ---
#
# {'previously', 'think', 'suggest', 'natural', 'contribute', 'preliminary', 'warming', 'global', 'analysis'}
# ---
#
# {'explore', 'evolution', 'scientist', 'climate', 'science', 'change'}
# ---
#
# {'eaarth', 'deal', 'global', 'warming', 'stay'}
# ---
#
# {'allergy', 'bad', 'global', 'blame', 'warming'}
# ---
#
# {'auth', 'fungus', 'tcot', 'global', 'good', 'fortunate', 'warming', 'cause'}
# ---
#
# {'myth', 'main', 'campaign', 'illegal', 'platform', 'election', 'global'}
# ---
#
# {'warming', 'green', 'scientific', 'scam', 'community', 'global'}
# ---
#
# {'degree', 'liberal', 'scum', 'urinate', 'warming', 'global', 'change'}
# ---
#
# {'warm', 'race', 'ucot', 'gore', 'tornado', 'tornadocot', 'mississippi', 'ocra', 'global', 'tycot', 'tlot'}
# ---
#
# {'warming', 'settle', 'book', 'scam', 'stop', 'global', 'sussman', 'confirm'}
# ---
#
# {'fairy', 'human', 'believe', 'rationalist', 'exist', 'alien', 'miracle', 'jesus', 'tcot', 'angel', 'warming', 'global', 'cause'}
# ---
#
# {'proof', 'create', 'tsunami', 'glaci', 'lake', 'fall', 'climate', 'fracture', 'killer', 'change', 'peruvian'}
# ---
#
# {'hack', 'warming', 'gore', 'palin', 'climate', 'global', 'real', 'algore', 'science', 'change', 'hoax'}
# ---
#
# {'wrong', 'academic', 'scientist', 'journal', 'nature', 'anti', 'global', 'stranger', 'magazine', 'warming'}
# ---
#
# {'nasa', 'difference', 'weather', 'baloney', 'climate', 'global', 'measure', 'accord', 'warming', 'expert'}
# ---
#
# {'true', 'warming', 'expert', 'belive', 'forensic', 'computer', 'global', 'idiot'}
# ---
#
# {'home', 'frost', 'toon', 'liberal', 'bite', 'artic', 'come', 'looney', 'global', 'warming', 'alarmist', 'learn'}
# ---
#
# {'ipcc', 'explanation', 'global', 'warming', 'teaparty', 'tube', 'enjoy'}
# ---
#
# {'reform', 'immigration', 'senate', 'climate', 'tale', 'issue', 'change'}
# ---
#
# {'house', 'dinner', 'green', 'memo', 'correspondent', 'report', 'white', 'climate', 'change', 'want'}
# ---
#
# {'people', 'reid', 'hold', 'vary', 'country', 'global', 'warming', 'view', 'monitor'}
# ---
#
# {'reuter', 'scenario', 'california', 'april', 'francisco', 'challenge', 'climate', 'source', 'henderson', 'change', 'peter'}
# ---
#
# {'today', 'legislation', 'lindsay', 'support', 'climate', 'graham', 'change', 'lindsey'}
# ---
#
# {'immigration', 'congress', 'arizona', 'focus', 'poll', 'legislation', 'climate', 'stall', 'issue', 'change'}
# ---
#
# {'bill', 'schedule', 'limbo', 'put', 'exit', 'talk', 'climate', 'graham', 'unveile', 'change'}
# ---
#
# {'bill', 'senate', 'climate', 'stall', 'change'}
# ---
#
# {'people', 'mich', 'world', 'regulate', 'rapid', 'argue', 'legislation', 'typically', 'climate', 'opponent', 'grand', 'change', 'globa'}
# ---
#
# {'bill', 'cnnbrk', 'immigration', 'dem', 'imperil', 'climate', 'graham', 'push', 'change'}
# ---
#
# {'scientifique', 'presentation', 'april', 'talk', 'warming', 'global', 'cafe', 'present'}
# ---
#
# {'check', 'business', 'climate', 'conference', 'video', 'change'}
# ---
#
# {'collagen', 'tip', 'valentine', 'clinique', 'clip', 'climate', 'screaming', 'clinical', 'trial', 'change', 'brilliant'}
# ---
#
# {'april', 'policy', 'climate', 'update', 'change'}
# ---
#
# {'release', 'press', 'negotiator', 'april', 'climate', 'intensify', 'change', 'agree'}
# ---
#
# {'reid', 'immigration', 'hapless', 'play', 'postpartisan', 'climate', 'harry', 'change'}
# ---
#
# {'money', 'california', 'campaign', 'global', 'pour', 'foe', 'warming', 'delay'}
# ---
#
# {'earth', 'obama', 'carol', 'energy', 'chat', 'director', 'admin', 'office', 'policy', 'climate', 'live', 'change', 'browner'}
# ---
#
# {'bill', 'chance', 'pass', 'year', 'senate', 'climate', 'klein', 'change'}
# ---
#
# {'person', 'volcano', 'connection', 'warming', 'global', 'hear'}
# ---
#
# {'nasa', 'think', 'guess', 'climate', 'fact', 'warming', 'global', 'change', 'notice'}
# ---
#
# {'give', 'environmental', 'qualified', 'change', 'basic', 'meeting', 'climate', 'praise', 'group'}
# ---
#
# {'news', 'americans', 'human', 'believe', 'april', 'global', 'good', 'warming', 'ellis', 'cause'}
# ---
#
# {'heart', 'conscious', 'action', 'million', 'global', 'thousand', 'warming', 'earth'}
# ---
#
# {'suggest', 'assumption', 'climate', 'global', 'warming', 'datum'}
# ---
#
# {'claim', 'fiction', 'global', 'fact', 'denier', 'warming'}
# ---
#
# {'minnesotan', 'fight', 'cast', 'interview', 'youtube', 'warming', 'global', 'takedown'}
# ---
#
# {'ramp', 'calif', 'effort', 'opponent', 'warming', 'global', 'delay'}
# ---
#
# {'people', 'world', 'aware', 'earthweek', 'bolivia', 'climate', 'conference', 'change', 'right', 'indigenous', 'earth'}
# ---
#
# {'sorry', 'panelist', 'accept', 'able', 'invitation', 'bolivia', 'climate', 'talk', 'change'}
# ---
#
# {'debate', 'scientist', 'newspaper', 'sue', 'poison', 'climate', 'warming', 'global'}
# ---
#
# {'people', 'world', 'change', 'bolivia', 'sharifkouddous', 'conference', 'climate', 'indigenous', 'arrive', 'group'}
# ---
#
# {'water', 'rare', 'peanut', 'recycling', 'grape', 'warming', 'global', 'meat'}
# ---
#
# {'reopen', 'attorney', 'cuccinelli', 'finding', 'force', 'general', 'motion', 'warming', 'global', 'file', 'virginia'}
# ---
#
# {'safety', 'blankenship', 'silly', 'regulator', 'warming', 'global'}
# ---
#
# {'nanogen', 'collagen', 'nanofiber', 'hair', 'climate', 'clinical', 'trial', 'change', 'bring'}
# ---
#
# {'warm', 'washington', 'myth', 'certain', 'sunday', 'corner', 'post', 'counsel', 'street', 'item', 'urgh', 'global', 'element'}
# ---
#
# {'commercial', 'regulation', 'environmental', 'implication', 'climate', 'ready', 'change'}
# ---
#
# {'roger', 'hansen', 'fellow', 'heather', 'discuss', 'join', 'james', 'climate', 'live', 'real', 'solution', 'change', 'tonight', 'expert'}
# ---
#
# {'california', 'plan', 'climate', 'change', 'brace'}
# ---
#
# {'leave', 'effective', 'tackle', 'plant', 'account', 'global'}
# ---
#
# {'degree', 'obama', 'fuck', 'well', 'glodman', 'sachs', 'shiiiiiitttt', 'plan', 'warming', 'global'}
# ---
#
# {'leave', 'effective', 'tackle', 'plant', 'account', 'global'}
# ---
#
# {'future', 'development', 'listen', 'driver', 'economic', 'climate', 'sustainability', 'change'}
# ---
#
# {'frederic', 'bell', 'hague', 'climate', 'discotech', 'blink', 'change', 'alarm'}
# ---
#
# {'consider', 'pentagon', 'america', 'know', 'climate', 'security', 'general', 'threaten', 'change'}
# ---
#
# {'go', 'screw', 'know', 'climate', 'general', 'change'}
# ---
#
# {'mental', 'say', 'cancer', 'report', 'illness', 'global', 'warming', 'government', 'cause'}
# ---
#
# {'wave', 'heat', 'climate', 'increase', 'flood', 'change'}
# ---
# {'effective', 'tackle', 'plant', 'global', 'warming', 'remain'}
# ---
#
# {'deni', 'discussion', 'fault', 'class', 'climate', 'student', 'get', 'global', 'change', 'heated'}
# ---
#
# {'forest', 'global', 'warming', 'kill', 'colorado'}
# ---
#
# {'environmental', 'display', 'climate', 'change', 'confirm', 'occur'}
# ---
#
# {'true', 'europe', 'foll', 'disappear', 'prediction', 'prove', 'global', 'warming', 'place'}
# ---
#
# {'people', 'change', 'lesson', 'climate', 'indigenous', 'combat'}
# ---
#
# {'bill', 'action', 'strong', 'support', 'climate', 'live', 'change'}
# ---
#
# {'fight', 'tradition', 'climate', 'change', 'indigenous'}
# ---
#
# {'wrong', 'go', 'roger', 'green', 'hansen', 'heather', 'james', 'false', 'climate', 'real', 'solution', 'change', 'hope'}
# ---
#
# {'absorb', 'forest', 'activist', 'carbon', 'climate', 'change'}
# ---
#
# {'absorb', 'forest', 'activist', 'carbon', 'climate', 'change'}
# ---
#
# {'absorb', 'forest', 'activist', 'carbon', 'climate', 'change'}
# ---
#
# {'mont', 'national', 'glaci', 'melt', 'namesake', 'climate', 'lose', 'change', 'park'}
# ---
#
# {'absorb', 'forest', 'activist', 'carbon', 'climate', 'change'}
# ---
#
# {'absorb', 'forest', 'activist', 'carbon', 'climate', 'change'}
# ---
#
# {'absorb', 'forest', 'carbon', 'climate', 'change'}
# ---
#
# {'weather', 'beautiful', 'morning', 'thank', 'bleh', 'fall', 'climate', 'york', 'change'}
# ---
#
# {'weather', 'beautiful', 'morning', 'thank', 'bleh', 'fall', 'climate', 'york', 'change'}
# ---
#
# {'culture', 'environment', 'familiar', 'climate', 'blossom', 'japan', 'cherry', 'threaten', 'change'}
# ---
#
# {'temp', 'change', 'apart', 'mountain', 'climate', 'podcast', 'valley', 'stretch'}
# ---
#
# {'temp', 'change', 'apart', 'mountain', 'climate', 'valley', 'stretch'}
# ---
#
# {'absorb', 'forest', 'activist', 'carbon', 'climate', 'change'}
# ---
#
# {'sign', 'rain', 'april', 'arctic', 'global', 'canadian'}
# ---
#
# {'contribute', 'conn', 'global', 'haven', 'microbe'}
# ---
#
# {'contribute', 'conn', 'global', 'haven', 'microbe'}
# ---
#
# {'asian', 'foreign', 'minister', 'fight', 'secluded', 'climate', 'south', 'nation', 'change'}
# ---
#
# {'wave', 'heat', 'property', 'death', 'climate', 'damage', 'increase', 'reuters', 'change'}
# ---
#
# {'wrong', 'go', 'green', 'hansen', 'heather', 'rogers', 'james', 'false', 'climate', 'real', 'solution', 'change', 'hope'}
# ---
#
# {'wine', 'leap', 'mean', 'love', 'climate', 'seriously', 'frog', 'change', 'industry'}
# ---
#
# {'save', 'report', 'global', 'warming', 'whale'}
# ---
#
# {'agriculture', 'organic', 'mitigation', 'contribution', 'climate', 'change'}
# ---
#
# {'slide', 'effect', 'beauty', 'white', 'black', 'arctic', 'warming', 'global', 'alaska'}
# ---
#
# {'study', 'document', 'report', 'climate', 'impact', 'real', 'indicator', 'change'}
# ---
#
# {'green', 'counterpart', 'keen', 'change', 'ceo', 'climate', 'impact', 'global', 'prepare', 'canadian'}
# ---
#
# {'shortage', 'huffpo', 'biochar', 'food', 'fight', 'check', 'post', 'support', 'climate', 'change'}
# ---
#
# {'sure', 'help', 'change', 'fight', 'climate', 'doodoo', 'whale'}
# ---
#
# {'soil', 'news', 'release', 'warm', 'world', 'science', 'carbon', 'global', 'good', 'warming'}
# ---
#
# {'weather', 'snow', 'phoenix', 'today', 'hmmmm', 'april', 'york', 'warming', 'global'}
# ---
#
# {'high', 'temperature', 'average', 'level', 'rise', 'global', 'malaysia', 'lumpur'}
# ---
#
# {'west', 'mediterranean', 'country', 'climate', 'unite', 'change'}
# ---
#
# {'clean', 'write', 'speed', 'picken', 'global', 'estimate'}
# ---
#
# {'create', 'action', 'business', 'climate', 'change'}
# ---
#
# {'degree', 'weather', 'anymore', 'person', 'surprise', 'warming', 'global'}
# ---
#
# {'evolution', 'human', 'understand', 'dispersal', 'report', 'influence', 'climate', 'interesting', 'change', 'hear', 'variability'}
# ---
#
# {'effect', 'pic', 'global', 'warming', 'alaska'}
# ---
#
# {'step', 'mandate', 'energy', 'address', 'benchmarking', 'post', 'climate', 'blog', 'change', 'city'}
# ---
#
# {'claim', 'stake', 'year', 'like', 'realdocwatson', 'antarctica', 'global', 'florida', 'warming'}
# ---
#
# {'trouble', 'agriculture', 'wine', 'mean', 'warming', 'global', 'industry'}
# ---
#
# {'slide', 'effect', 'beauty', 'white', 'black', 'arctic', 'warming', 'global', 'alaska'}
# ---
#
# {'photo', 'european', 'peril', 'paris', 'climate', 'alp', 'place', 'change'}
# ---
#
# {'national', 'atmospheric', 'administration', 'know', 'electoral', 'climate', 'oceanic', 'change'}
# ---
#
# {'clean', 'warming', 'week', 'mark', 'world', 'environmental', 'report', 'past', 'intensify', 'actually', 'global', 'earth'}
# ---
#
# {'blair', 'news', 'wild', 'round', 'frontier', 'global', 'threat', 'warming', 'late'}
# ---
#
# {'home', 'traditional', 'kuna', 'change', 'indians', 'sink', 'climate', 'relocation', 'prepare'}
# ---
#
# {'wine', 'change', 'california', 'kimberley', 'cahill', 'califor', 'climate', 'global', 'buzz', 'warming', 'kill', 'present'}
# ---
#
# {'digg', 'politic', 'denial', 'climate', 'uncajoe', 'change', 'hate'}
# ---
#
# {'ocean', 'chemistry', 'fast', 'carbon', 'global', 'warming', 'change'}
# ---
#
# {'obama', 'sure', 'go', 'backass', 'world', 'graham', 'imperil', 'agenda', 'climate', 'douche', 'good', 'change'}
# ---
#
# {'lake', 'fight', 'resort', 'global', 'thanksgiving', 'city'}
# ---
#
# {'insect', 'lizard', 'fight', 'important', 'bat', 'climate', 'play', 'bird', 'change', 'eat'}
# ---
#
# {'green', 'computing', 'contribution', 'climate', 'cloud', 'change'}
# ---
#
# {'extinct', 'plant', 'one', 'favor', 'thoreau', 'specie', 'climate', 'invasive', 'change', 'indigenous'}
# ---
#
# {'season', 'alter', 'day', 'climate', 'early', 'scary', 'change', 'spring'}
# ---
#
# {'people', 'pre', 'lesson', 'morale', 'climate', 'change', 'indigenous'}
# ---
#
# {'mobilize', 'event', 'point', 'mediaglobal', 'science', 'report', 'fight', 'tipping', 'climate', 'special', 'change', 'earth'}
# ---
#
# {'forest', 'global', 'warming', 'kill', 'colorado'}
# ---
#
# {'nations', 'people', 'indigenous', 'world', 'climat', 'united', 'lesson', 'climate', 'change', 'arrive', 'combat'}
# ---
#
# {'gear', 'meteorology', 'vulnerable', 'continent', 'climate', 'service', 'change', 'africa'}
# ---
#
# {'step', 'daunting', 'gecko', 'credit', 'green', 'mention', 'living', 'carbon', 'climate', 'change'}
# ---
#
# {'environmental', 'china', 'world', 'rapid', 'fix', 'come', 'sizable', 'impact', 'global', 'expansion'}
# ---
#
# {'environmental', 'china', 'world', 'rapid', 'fix', 'come', 'sizable', 'impact', 'global', 'expansion'}
# ---
#
# {'local', 'go', 'green', 'examine', 'listing', 'check', 'climate', 'york', 'confront', 'change', 'yorker'}
# ---
#
# {'nasa', 'change', 'report', 'climate', 'official', 'cause'}
# ---
#
# {'rule', 'safety', 'crazy', 'silly', 'coal', 'warming', 'global', 'call'}
# ---
#
# {'extend', 'human', 'climate', 'impact', 'health', 'change'}
# ---
#
# {'extend', 'human', 'climate', 'impact', 'health', 'change'}
# ---
#
# {'news', 'rebecca', 'climate', 'good', 'change', 'solnit'}
# ---
#
# {'energy', 'climate', 'alpha', 'change', 'efficiency', 'take'}
# ---
#
# {'step', 'daunting', 'gecko', 'credit', 'green', 'mention', 'living', 'carbon', 'climate', 'change'}
# ---
#
# {'tell', 'scientist', 'explain', 'natural', 'popular', 'climate', 'global', 'meteorologist', 'warming', 'variability'}
# ---
#
# {'degree', 'news', 'inseparability', 'rebecca', 'climate', 'good', 'change', 'solnit'}
# ---
#
# {'land', 'tibetan', 'threaten', 'know', 'shangri', 'climate', 'sacred', 'watch', 'include', 'video', 'change', 'mountain'}
# ---
#
# {'gear', 'meteorology', 'african', 'climate', 'service', 'change'}
# ---
#
# {'allergy', 'bad', 'season', 'report', 'climate', 'change'}
# ---
#
# {'bill', 'save', 'accountability', 'climate', 'kill', 'change'}
# ---
#
# {'farmer', 'ethiopia', 'pastoralist', 'vulnerable', 'increasingly', 'climate', 'change', 'make'}
# ---
#
# {'famine', 'news', 'weather', 'irishcentral', 'change', 'denis', 'irish', 'politic', 'compare', 'climate', 'founder', 'global', 'haye', 'earth'}
# ---
#
# {'farmer', 'ethiopia', 'pastoralist', 'vulnerable', 'increasingly', 'climate', 'change', 'make'}
# ---
#
# {'treat', 'effect', 'waste', 'aware', 'consume', 'global', 'warming', 'earthday', 'place'}
# ---
#
# {'climate', 'verwaayen', 'change', 'curb', 'earth'}
# ---
#
# {'industrial', 'feel', 'nation', 'report', 'climate', 'impact', 'health', 'change'}
# ---
#
# {'industrial', 'feel', 'nation', 'report', 'climate', 'impact', 'health', 'change'}
# ---
#
# {'industrial', 'feel', 'nation', 'report', 'climate', 'impact', 'health', 'change'}
# ---
# {'step', 'daunting', 'gecko', 'credit', 'green', 'mention', 'living', 'carbon', 'climate', 'change'}
# ---
#
# {'step', 'daunting', 'credit', 'mention', 'green', 'biofuel', 'living', 'carbon', 'climate', 'change'}
# ---
#
# {'reuter', 'allergy', 'cost', 'climate', 'change', 'raise'}
# ---
#
# {'asilomar', 'later', 'curable', 'international', 'treat', 'bioethicist', 'climate', 'disease', 'change', 'expert'}
# ---
#
# {'asilomar', 'later', 'curable', 'international', 'treat', 'bioethicist', 'climate', 'disease', 'change', 'expert'}
# ---
#
# {'rule', 'safety', 'crazy', 'silly', 'coal', 'warming', 'global', 'call'}
# ---
#
# {'military', 'fight', 'climate', 'lead', 'change'}
# ---
#
# {'military', 'buyer', 'fight', 'large', 'climate', 'lead', 'change', 'fuel', 'government'}
# ---
#
# {'step', 'daunting', 'credit', 'mention', 'green', 'biofuel', 'living', 'carbon', 'climate', 'change'}
# ---
#
# {'swedish', 'say', 'fred', 'main', 'climate', 'goldberg', 'global', 'cause', 'expert'}
# ---
#
# {'wire', 'curable', 'treat', 'green', 'climate', 'disease', 'science', 'change'}
# ---
#
# {'local', 'go', 'green', 'examine', 'listing', 'thursday', 'check', 'climate', 'york', 'confront', 'change', 'yorker'}
# ---
#
# {'nations', 'secretary', 'cooperation', 'seek', 'united', 'dialogue', 'prevent', 'climate', 'runaway', 'global', 'change'}
# ---
#
# {'event', 'nnimmo', 'bassey', 'environmentalist', 'important', 'climate', 'nigerian', 'change', 'struggle'}
# ---
#
# {'military', 'fight', 'climate', 'lead', 'change'}
# ---
#
# {'inclde', 'identify', 'stake', 'mental', 'affctd', 'report', 'health', 'climate', 'disease', 'issue', 'change', 'evrything'}
# ---
#
# {'resource', 'cope', 'climate', 'change', 'earth'}
# ---
#
# {'water', 'saltiness', 'ocean', 'cycle', 'global', 'intensify', 'warming', 'show'}
# ---
#
# {'anniver', 'week', 'americans', 'time', 'celebrate', 'fedele', 'climate', 'meal', 'bauccio', 'change', 'combat'}
# ---
#
# {'cochabamba', 'people', 'world', 'conf', 'support', 'climate', 'live', 'change'}
# ---
#
# {'barrett', 'change', 'well', 'push', 'climate', 'small', 'lot', 'protocol', 'comprehensive'}
# ---
#
# {'complicate', 'topography', 'warming', 'global', 'rate', 'mountain'}
# ---
#
# {'cochabamba', 'people', 'world', 'support', 'climate', 'conference', 'bolivia', 'watch', 'live', 'change'}
# ---
#
# {'operation', 'require', 'address', 'smallpox', 'change', 'climate', 'global', 'ozone', 'issue', 'layer', 'universal'}
# ---
#
# {'point', 'subcontinent', 'boiling', 'indian', 'spill', 'contain', 'climate', 'change'}
# ---
#
# {'earthquake', 'world', 'trigger', 'landslide', 'climate', 'warming', 'change'}
# ---
#
# {'need', 'vulnerable', 'climate', 'uruguay', 'tool', 'change'}
# ---
#
# {'need', 'vulnerable', 'climate', 'uruguay', 'tool', 'change'}
# ---
#
# {'need', 'vulnerable', 'climate', 'uruguay', 'tool', 'change'}
# ---
#
# {'warming', 'offset', 'forest', 'fail', 'carbon', 'reduce', 'vatican', 'global'}
# ---
#
# {'ethiopia', 'poverty', 'climate', 'vulnerability', 'increase', 'change'}
# ---
#
# {'farmer', 'ethiopia', 'pastoralist', 'scale', 'poverty', 'climate', 'vulnerability', 'increase', 'small', 'change'}
# ---
#
# {'event', 'nnimmo', 'bassey', 'environmentalist', 'important', 'climate', 'nigerian', 'change', 'struggle'}
# ---
#
# {'event', 'nnimmo', 'bassey', 'environmentalist', 'important', 'climate', 'nigerian', 'change', 'struggle'}
# ---
#
# {'tackle', 'year', 'china', 'backgrounder', 'policy', 'major', 'climate', 'change'}
# ---
#
# {'point', 'press', 'bloom', 'april', 'steven', 'early', 'biologist', 'global', 'link'}
# ---
#
# {'point', 'press', 'bloom', 'april', 'steven', 'early', 'biologist', 'global', 'link'}
# ---
#
# {'glacier', 'world', 'volcano', 'trigger', 'iceland', 'global', 'warming'}
# ---
#
# {'glacier', 'world', 'volcano', 'trigger', 'iceland', 'global', 'warming'}
# ---
#
# {'warm', 'foot', 'future', 'level', 'like', 'katrina', 'climate', 'wetter', 'rise', 'flood', 'change'}
# ---
#
# {'sign', 'geologist', 'future', 'melt', 'come', 'fast', 'climate', 'troubling', 'find', 'antarctica', 'change', 'drill', 'sheet'}
# ---
#
# {'mother', 'people', 'claim', 'world', 'morale', 'die', 'capitalism', 'conference', 'climate', 'change', 'earth'}
# ---
#
# {'allergy', 'attack', 'gift', 'global', 'increase', 'warming'}
# ---
#
# {'await', 'time', 'environmental', 'doubt', 'climate', 'issue', 'change', 'bomb', 'africa'}
# ---
#
# {'offset', 'buy', 'carbon', 'global', 'warming', 'guilt', 'ease'}
# ---
#
# {'cochabamba', 'suffering', 'havechancetospeakout', 'eye', 'alrdy', 'warming', 'global'}
# ---
#
# {'discussion', 'specie', 'climate', 'ecomonday', 'recommend', 'invasive', 'change'}
# ---
#
# {'migratory', 'home', 'strategy', 'climate', 'bird', 'change', 'stay'}
# ---
#
# {'despite', 'ocean', 'oxygen', 'global', 'population', 'warming', 'organism', 'floor', 'little', 'cause'}
# ---
#
# {'discussion', 'join', 'food', 'climate', 'destiny', 'security', 'irreversible', 'change', 'earth'}
# ---
#
# {'consideration', 'plan', 'climate', 'waterfront', 'york', 'change', 'city'}
# ---
#
# {'manipulate', 'planet', 'geoengineere', 'combat', 'climate', 'danger', 'change', 'mooney'}
# ---
#
# {'allergy', 'bad', 'climate', 'get', 'change', 'seasonal'}
# ---
#
# {'think', 'instead', 'believe', 'global', 'peep', 'warming'}
# ---
#
# {'allergy', 'bad', 'climate', 'get', 'change', 'seasonal'}
# ---
#
# {'think', 'property', 'dead', 'global', 'live', 'oceanfront', 'warming', 'advise'}
# ---
#
# {'volcanic', 'help', 'trigger', 'melt', 'global', 'warming', 'cap', 'eruption'}
# ---
#
# {'heart', 'address', 'john', 'win', 'clim', 'harte', 'climate', 'mary', 'sustainability', 'change', 'ellen'}
# ---
#
# {'state', 'induce', 'declare', 'human', 'dept', 'primarily', 'unequivocal', 'global', 'warming'}
# ---
#
# {'conclude', 'bet', 'increasingly', 'climate', 'real', 'corporation', 'change'}
# ---
#
# {'house', 'message', 'richard', 'branson', 'global', 'earthday', 'right'}
# ---
#
# {'agriculture', 'bad', 'monday', 'wise', 'cynthia', 'animal', 'global', 'warming', 'meat', 'make', 'bateman'}
# ---
#
# {'volcanic', 'help', 'trigger', 'melt', 'global', 'warming', 'cap', 'eruption'}
# ---
#
# {'state', 'induce', 'declare', 'human', 'dept', 'primarily', 'unequivocal', 'global', 'warming'}
# ---
#
# {'volcanic', 'trigger', 'melt', 'global', 'warming', 'cap', 'eruption'}
# ---
#
# {'environmentalism', 'sigh', 'idea', 'class', 'come', 'fix', 'love', 'kind', 'warming', 'global'}
# ---
#
# {'overview', 'go', 'green', 'revolution', 'threat', 'increase', 'awareness', 'warming', 'global'}
# ---
#
# {'southern', 'water', 'high', 'compete', 'climate', 'southe', 'limpopo', 'change', 'temperature', 'africa', 'bring'}
# ---
#
# {'hekla', 'year', 'spill', 'strike', 'iceland', 'warming', 'global', 'earth', 'eruption'}
# ---
#
# {'photo', 'change', 'america', 'climate', 'place'}
# ---
#
# {'maine', 'time', 'bangor', 'episcopal', 'bishop', 'important', 'climate', 'lane', 'issue', 'change', 'daily'}
# ---
#
# {'volcano', 'iceland', 'climate', 'impact', 'wonder', 'case', 'change'}
# ---
#
# {'heat', 'discussion', 'honest', 'cool', 'thing', 'interest', 'global', 'warming'}
# ---
#
# {'billion', 'migration', 'climate', 'bird', 'change', 'pattern'}
# ---
#
# {'photo', 'change', 'america', 'climate', 'place'}
# ---
#
# {'warming', 'volcanic', 'spark', 'hazardous', 'trigger', 'cloud', 'global', 'change'}
# ---
#
# {'warming', 'volcanic', 'spark', 'hazardous', 'trigger', 'cloud', 'global', 'change'}
# ---
#
# {'stratosphere', 'improve', 'cooling', 'volcano', 'brief', 'slow', 'get', 'wonder', 'warming', 'global'}
# ---
#
# {'obama', 'wait', 'say', 'china', 'april', 'barack', 'sydney', 'thursd', 'climate', 'change', 'president'}
# ---
#
# {'think', 'jindal', 'volcano', 'mock', 'warning', 'paper', 'start', 'climate', 'lately', 'denier', 'change', 'bobby', 'read'}
# ---
#
# {'weekend', 'sneak', 'preview', 'cara', 'strand', 'tedxvolcano', 'climate', 'get', 'merte', 'change', 'adapt'}
# ---
#
# {'socmedia', 'larry', 'single', 'face', 'change', 'tedxvolcano', 'fight', 'thing', 'climate', 'science', 'important', 'brilliant'}
# ---
#
# {'larry', 'single', 'green', 'face', 'socent', 'change', 'tedxvolcano', 'fight', 'thing', 'climate', 'science', 'important', 'brilliant'}
# ---
#
# {'warming', 'europe', 'crazy', 'volcano', 'damn', 'activating', 'get', 'cloud', 'global'}
# ---
#
# {'crisis', 'larry', 'attack', 'tedxvolcano', 'climate', 'exacerbate', 'science', 'change', 'brilliant'}
# ---
#
# {'jonah', 'volcano', 'oslo', 'iceland', 'global', 'thaw', 'goldberg', 'reuters', 'warming', 'cause', 'eruption'}
# ---
#
# {'conversation', 'change', 'voice', 'climate', 'indigenous', 'bring'}
# ---
#
# {'volcanic', 'awaken', 'volcano', 'activity', 'climate', 'icelandic', 'thaw', 'change'}
# ---
#
# {'nikolas', 'entire', 'amazon', 'rain', 'kozloff', 'affect', 'climate', 'south', 'change'}
# ---
#
# {'photo', 'change', 'america', 'climate', 'place'}
# ---
#
# {'glacier', 'volcano', 'bury', 'lede', 'melt', 'iceland', 'warming', 'global', 'hmmm'}
# ---
#
# {'consensus', 'sure', 'scientist', 'volcano', 'melt', 'climate', 'lead', 'warn', 'change', 'crisis'}
# ---
#
# {'cochabamba', 'mother', 'earth', 'people', 'world', 'climate', 'conference', 'change', 'right', 'wish'}
# ---
#
# {'record', 'allergy', 'bad', 'high', 'feel', 'climate', 'near', 'change', 'spring', 'seasonal', 'make'}
# ---
#
# {'record', 'allergy', 'bad', 'high', 'climate', 'near', 'change', 'spring', 'seasonal', 'make'}
# ---
#
# {'volcanic', 'travel', 'glaci', 'like', 'disrupt', 'climate', 'thaw', 'icelandic', 'change', 'eruption'}
# ---
#
# {'cochabamba', 'approach', 'summit', 'offer', 'climate', 'change', 'combat'}
# ---
#
# {'remind', 'environment', 'power', 'change', 'climate', 'computer', 'simple', 'workin', 'user'}
# ---
#
# {'reason', 'renewal', 'perspective', 'climate', 'connecticut', 'concern', 'bring'}
# ---
#
# {'need', 'warming', 'scientist', 'renewable', 'switch', 'long', 'warn', 'global', 'accelerate'}
# ---
#
# {'pollen', 'chart', 'culprit', 'climate', 'count', 'change'}
# ---
#
# {'wait', 'coalition', 'fight', 'ground', 'climate', 'tired', 'level', 'change'}
# ---
#
# {'release', 'national', 'allergy', 'season', 'wildlife', 'report', 'wednesday', 'climate', 'worsen', 'change'}
# ---
#
# {'wait', 'coalition', 'fight', 'ground', 'climate', 'tired', 'level', 'change'}
# ---
#
# {'planet', 'entire', 'rain', 'change', 'kozloff', 'america', 'affect', 'climate', 'south', 'nikola', 'amazon', 'author'}
# ---
#
# {'wait', 'coalition', 'fight', 'ground', 'climate', 'tired', 'level', 'change'}
# ---
# {'wait', 'coalition', 'fight', 'ground', 'climate', 'tired', 'level', 'change'}
# ---
#
# {'wait', 'coalition', 'fight', 'ground', 'climate', 'tired', 'level', 'change'}
# ---
#
# {'allergy', 'bad', 'season', 'report', 'climate', 'change'}
# ---
#
# {'denialist', 'send', 'mention', 'cute', 'finnish', 'refute', 'newspaper', 'purportedly', 'global', 'article', 'warming'}
# ---
#
# {'energy', 'nationalize', 'fight', 'necessary', 'warming', 'global', 'industry'}
# ---
#
# {'volcanic', 'volcano', 'likely', 'iceland', 'slow', 'intensify', 'cloud', 'global', 'vast', 'eruption'}
# ---
#
# {'allergy', 'bad', 'reading', 'blame', 'warming', 'global'}
# ---
#
# {'leave', 'partnership', 'forest', 'conservation', 'climate', 'population', 'change', 'curb', 'indigenous', 'group'}
# ---
#
# {'think', 'ignorant', 'problem', 'say', 'tbagger', 'climate', 'change'}
# ---
#
# {'heat', 'future', 'affect', 'climate', 'miss', 'change'}
# ---
#
# {'build', 'green', 'economy', 'climate', 'change'}
# ---
#
# {'national', 'economy', 'glaci', 'climate', 'montana', 'threaten', 'change', 'park'}
# ---
#
# {'allergy', 'cost', 'climate', 'york', 'change', 'raise'}
# ---
#
# {'ecotone', 'perspective', 'climate', 'population', 'change'}
# ---
#
# {'coastal', 'climate', 'blame', 'whale', 'dwindle', 'ventura', 'change', 'county', 'migration'}
# ---
#
# {'think', 'allergy', 'wait', 'climate', 'michig', 'kick', 'change'}
# ---
#
# {'reuter', 'cost', 'climate', 'change', 'raise', 'exclusive'}
# ---
#
# {'spring', 'season', 'year', 'storm', 'start', 'warming', 'global', 'little', 'late'}
# ---
#
# {'weather', 'perception', 'effect', 'pastoralist', 'extreme', 'drought', 'kenya', 'test', 'climate', 'change'}
# ---
#
# {'baseball', 'curve', 'major', 'team', 'climate', 'throw', 'league', 'change', 'denier'}
# ---
#
# {'endanger', 'newsweek', 'save', 'change', 'climate', 'place'}
# ---
#
# {'plant', 'tree', 'absorb', 'help', 'birthday', 'reduce', 'warming', 'global'}
# ---
#
# {'bill', 'states', 'energy', 'green', 'united', 'multiple', 'climate', 'lead', 'kerry', 'benefit', 'change'}
# ---
#
# {'internet', 'green', 'computing', 'fight', 'climate', 'change'}
# ---
#
# {'create', 'action', 'business', 'climate', 'change', 'cleantechnica'}
# ---
#
# {'internet', 'green', 'computing', 'fight', 'climate', 'software', 'change'}
# ---
#
# {'tackle', 'leak', 'document', 'climate', 'change', 'call'}
# ---
#
# {'endanger', 'newsweek', 'save', 'change', 'climate', 'place'}
# ---
#
# {'stop', 'climate', 'reinvent', 'change', 'city'}
# ---
#
# {'national', 'continue', 'glaci', 'melt', 'icon', 'climate', 'change', 'park'}
# ---
#
# {'endanger', 'newsweek', 'save', 'change', 'climate', 'place'}
# ---
#
# {'endanger', 'newsweek', 'save', 'change', 'climate', 'place'}
# ---
#
# {'dhabi', 'society', 'face', 'culture', 'climate', 'threat', 'arabia', 'flood', 'change', 'expert'}
# ---
#
# {'tackle', 'china', 'say', 'active', 'vice', 'humani', 'climate', 'change', 'president'}
# ---
#
# {'tackle', 'china', 'say', 'active', 'climate', 'change'}
# ---
#
# {'study', 'climate', 'hard', 'asia', 'change'}
# ---
#
# {'wildlife', 'help', 'protect', 'action', 'climate', 'habitat', 'change'}
# ---
#
# {'obama', 'soon', 'china', 'climate', 'change'}
# ---
#
# {'wildlife', 'help', 'protect', 'action', 'climate', 'habitat', 'change'}
# ---
#
# {'wildlife', 'help', 'protect', 'action', 'climate', 'habitat', 'change'}
# ---
#
# {'wildlife', 'help', 'protect', 'action', 'climate', 'habitat', 'change'}
# ---
#
# {'sign', 'petition', 'congress', 'demand', 'action', 'climate', 'change'}
# ---
#
# {'legislation', 'carbon', 'climate', 'kill', 'change'}
# ---
#
# {'obama', 'tackle', 'china', 'say', 'wait', 'interview', 'climate', 'allow', 'change'}
# ---
#
# {'claim', 'cancer', 'global', 'warming', 'government', 'cause'}
# ---
#
# {'claim', 'cancer', 'global', 'warming', 'government', 'cause'}
# ---
#
# {'wildlife', 'protect', 'climate', 'habitat', 'change'}
# ---
#
# {'california', 'plan', 'climate', 'change', 'brace'}
# ---
#
# {'wildlife', 'help', 'protect', 'action', 'climate', 'habitat', 'change'}
# ---
#
# {'warming', 'involve', 'greenpeace', 'work', 'stop', 'global', 'greenpeac'}
# ---
#
# {'wildlife', 'help', 'protect', 'action', 'climate', 'habitat', 'change'}
# ---
#
# {'mental', 'say', 'cancer', 'report', 'illness', 'global', 'warming', 'government', 'cause'}
# ---
#
# {'company', 'hold', 'risk', 'publically', 'change', 'climate', 'investor', 'warn', 'advise'}
# ---
#
# {'debate', 'gore', 'dawdle', 'aisle', 'long', 'come', 'snake', 'climate', 'change'}
# ---
#
# {'trouble', 'agriculture', 'mean', 'grape', 'climate', 'wrath', 'change'}
# ---
#
# {'allergy', 'bad', 'jonah', 'time', 'blame', 'magazine', 'goldberg', 'warming', 'global'}
# ---
#
# {'allergy', 'bad', 'climate', 'get', 'change'}
# ---
#
# {'clean', 'watch', 'intensify', 'actually', 'global', 'dim'}
# ---
#
# {'people', 'time', 'world', 'country', 'affect', 'likely', 'climate', 'developed', 'change', 'disaster', 'poor', 'cause'}
# ---
#
# {'allergy', 'bad', 'jonah', 'time', 'blame', 'magazine', 'goldberg', 'warming', 'global'}
# ---
#
# {'italy', 'programme', 'management', 'climate', 'science', 'change'}
# ---
#
# {'change', 'oxfam', 'climate', 'ethiopian', 'community', 'devastating', 'rural'}
# ---
#
# {'believe', 'pollutant', 'development', 'put', 'spur', 'technology', 'ilsen', 'price', 'warming', 'global', 'alexi', 'alternative'}
# ---
#
# {'athlete', 'green', 'olympic', 'action', 'climate', 'push', 'change'}
# ---
#
# {'warming', 'involve', 'greenpeace', 'work', 'stop', 'global'}
# ---
#
# {'extend', 'human', 'effect', 'deal', 'climate', 'impact', 'health', 'change'}
# ---
#
# {'ocean', 'unprecedented', 'chemistry', 'climate', 'change', 'rate', 'cause'}
# ---
#
# {'allergy', 'bad', 'global', 'blame', 'warming'}
# ---
#
# {'wire', 'lizard', 'fight', 'bat', 'climate', 'bird', 'change'}
# ---
#
# {'sign', 'petition', 'action', 'climate', 'earthday', 'change'}
# ---
#
# {'curable', 'treat', 'climate', 'disease', 'change'}
# ---
#
# {'debate', 'time', 'believe', 'editorial', 'vallejo', 'herald', 'honest', 'global', 'warming', 'keep'}
# ---
#
# {'address', 'motorola', 'climate', 'challenge', 'work', 'solution', 'member', 'change'}
# ---
#
# {'warming', 'blame', 'capitalism', 'bolivian', 'global', 'president'}
# ---
#
# {'need', 'point', 'warming', 'immediate', 'like', 'politician', 'solve', 'global', 'election', 'interesting', 'prob', 'macro'}
# ---
#
# {'allergy', 'attack', 'gift', 'global', 'increase', 'warming'}
# ---
#
# {'effect', 'animation', 'continent', 'climate', 'global', 'change', 'view', 'download'}
# ---
#
# {'sign', 'tell', 'petition', 'hint', 'know', 'drop', 'climate', 'ready', 'lawmaker', 'change'}
# ---
#
# {'reduction', 'expand', 'policy', 'carbon', 'climate', 'change', 'goal', 'emission'}
# ---
#
# {'state', 'induce', 'declare', 'human', 'dept', 'primarily', 'unequivocal', 'global', 'warming'}
# ---
#
# {'cold', 'allergy', 'bad', 'winter', 'thank', 'snowy', 'earl', 'follow', 'global', 'blame', 'warming', 'unusually'}
# ---
#
# {'give', 'palin', 'discovery', 'nature', 'climate', 'sarah', 'denier', 'change', 'ridiculous'}
# ---
#
# {'allergy', 'bad', 'season', 'suck', 'report', 'climate', 'change', 'read'}
# ---
#
# {'pollution', 'automotive', 'change', 'technology', 'effort', 'climate', 'coda', 'laud', 'innovation', 'combat'}
# ---
#
# {'allergy', 'claim', 'report', 'climate', 'blame', 'increase', 'change'}
# ---
#
# {'allergy', 'claim', 'report', 'climate', 'blame', 'increase', 'change'}
# ---
#
# {'chicago', 'tulip', 'april', 'love', 'warming', 'global'}
# ---
#
# {'climatewire', 'allergy', 'bad', 'americans', 'hit', 'globalwarme', 'million', 'global', 'hard', 'warming', 'asthma'}
# ---
#
# {'degree', 'hellooo', 'meet', 'april', 'nice', 'warming', 'global'}
# ---
#
# {'crop', 'relative', 'mention', 'agriculture', 'wild', 'time', 'rejoice', 'climate', 'article', 'change', 'adapt'}
# ---
#
# {'tackle', 'document', 'climate', 'change', 'call'}
# ---
#
# {'tackle', 'document', 'climate', 'change', 'call'}
# ---
#
# {'glacier', 'go', 'report', 'namesake', 'usgs', 'warming', 'global', 'park'}
# ---
#
# {'heat', 'feel', 'institute', 'jackson', 'come', 'climate', 'erwin', 'change'}
# ---
#
# {'democracy', 'tackle', 'mobilise', 'college', 'schumacher', 'climate', 'lead', 'change'}
# ---
#
# {'allergy', 'cost', 'climate', 'change', 'raise', 'exclusive'}
# ---
#
# {'study', 'environmental', 'receive', 'million', 'climate', 'impact', 'harvard', 'health', 'change'}
# ---
#
# {'today', 'hill', 'write', 'climate', 'lead', 'kerry', 'change'}
# ---
#
# {'allergy', 'cost', 'climate', 'change', 'raise', 'exclusive'}
# ---
#
# {'clothing', 'patagonia', 'start', 'global', 'chouinard', 'yvon', 'warming', 'place', 'industry', 'fortunegreen'}
# ---
#
# {'people', 'travel', 'filmmaker', 'fight', 'globe', 'climate', 'find', 'change'}
# ---
#
# {'people', 'travel', 'filmmaker', 'fight', 'globe', 'climate', 'find', 'change'}
# ---
# {'gulf', 'future', 'energy', 'spur', 'fight', 'effort', 'america', 'harm', 'remake', 'warming', 'global', 'oilspill'}
# ---
#
# {'think', 'person', 'planet', 'decade', 'life', 'unemployment', 'average', 'climate', 'catastrophic', 'change'}
# ---
#
# {'bad', 'research', 'arctic', 'topnew', 'zealand', 'loss', 'warming', 'global', 'get', 'accelerate'}
# ---
#
# {'california', 'climate', 'lead', 'change', 'take'}
# ---
#
# {'washington', 'effective', 'tackle', 'leave', 'plant', 'account', 'warming', 'global'}
# ---
#
# {'active', 'govt', 'climate', 'namibia', 'change'}
# ---
#
# {'effective', 'tackle', 'plant', 'warming', 'global'}
# ---
#
# {'induce', 'human', 'wait', 'idea', 'natural', 'climate', 'warming', 'global', 'change'}
# ---
#
# {'america', 'climate', 'security', 'general', 'threaten', 'change', 'read'}
# ---
#
# {'glacial', 'planet', 'eruption', 'melt', 'earthweek', 'diary', 'global', 'volcanos', 'warming', 'unplug'}
# ---
#
# {'admiral', 'military', 'climate', 'general', 'threaten', 'change'}
# ---
#
# {'urge', 'obama', 'wildlife', 'contribute', 'expand', 'climate', 'shore', 'threaten', 'change', 'drilling'}
# ---
#
# {'warm', 'news', 'frozen', 'reach', 'allgov', 'canada', 'warming', 'global', 'temperature'}
# ---
#
# {'mental', 'say', 'cancer', 'report', 'warmin', 'illness', 'global', 'warming', 'government', 'cause'}
# ---
#
# {'obama', 'holdren', 'say', 'science', 'john', 'adviser', 'pick', 'global', 'warming', 'steam'}
# ---
#
# {'lyme', 'year', 'billion', 'cost', 'pricy', 'climate', 'disease', 'change'}
# ---
#
# {'carry', 'states', 'researcher', 'antarc', 'check', 'united', 'global', 'excrement', 'topnews', 'warming', 'whale', 'australian'}
# ---
#
# {'writer', 'staff', 'mental', 'say', 'matt', 'cancer', 'report', 'illness', 'cover', 'global', 'warming', 'government', 'cause'}
# ---
#
# {'need', 'proof', 'save', 'report', 'global', 'warming', 'whale', 'proble'}
# ---
#
# {'wine', 'warming', 'effect', 'grape', 'early', 'good', 'system', 'warn', 'global'}
# ---
#
# {'wine', 'warming', 'effect', 'grape', 'early', 'good', 'system', 'warn', 'global'}
# ---
#
# {'evidence', 'change', 'report', 'climate', 'indicator', 'warming', 'global', 'show'}
# ---
#
# {'defense', 'counc', 'evidence', 'natural', 'change', 'resource', 'report', 'climate', 'indicator', 'warming', 'global', 'show'}
# ---
#
# {'syed', 'effect', 'know', 'warming', 'global', 'malaysia', 'husin', 'want'}
# ---
#
# {'lori', 'home', 'voyage', 'preuitt', 'star', 'convinced', 'fight', 'global', 'mayeda', 'warming', 'whale', 'trek'}
# ---
#
# {'writer', 'reliable', 'support', 'kesner', 'global', 'fact', 'touch', 'case', 'warming', 'recent', 'letter', 'charle'}
# ---
#
# {'study', 'climate', 'health', 'threaten', 'change'}
# ---
#
# {'effect', 'slideshow', 'warming', 'global', 'alaska'}
# ---
#
# {'wine', 'warming', 'verita', 'delicate', 'effect', 'vino', 'grape', 'early', 'good', 'system', 'warn', 'global'}
# ---
#
# {'provide', 'international', 'gift', 'help', 'endangered', 'specie', 'conservation', 'prevent', 'climate', 'habitat', 'change'}
# ---
#
# {'provide', 'international', 'gift', 'help', 'endangered', 'specie', 'conservation', 'prevent', 'climate', 'habitat', 'change'}
# ---
#
# {'rapidly', 'national', 'council', 'ocean', 'research', 'contribute', 'acidification', 'global', 'increase', 'warn', 'warming'}
# ---
#
# {'threaten', 'global', 'province', 'southernmost', 'locality', 'warming'}
# ---
#
# {'storming', 'local', 'mean', 'global', 'warming'}
# ---
#
# {'clean', 'warming', 'staff', 'mark', 'world', 'past', 'intensify', 'actually', 'global', 'earth'}
# ---
#
# {'saltiness', 'ocean', 'energy', 'renewable', 'pull', 'salinity', 'million', 'advance', 'warming', 'global', 'show', 'datum'}
# ---
#
# {'november', 'secretary', 'energy', 'china', 'steven', 'fix', 'global', 'magazine', 'warming', 'late'}
# ---
#
# {'ocean', 'year', 'chemistry', 'fast', 'carbon', 'global', 'warming', 'change'}
# ---
#
# {'concl', 'complicate', 'study', 'sciencedaily', 'topography', 'warming', 'global', 'rate', 'mountain'}
# ---
#
# {'environmentalist', 'blame', 'soar', 'attribute', 'global', 'mercury'}
# ---
#
# {'gathering', 'environmental', 'present', 'climate', 'warming', 'global', 'change', 'crisis', 'africa', 'monitor'}
# ---
#
# {'volcanic', 'help', 'reduce', 'warming', 'global', 'plane'}
# ---
#
# {'nasa', 'despite', 'ocean', 'strong', 'discover', 'global', 'current'}
# ---
#
# {'nasa', 'despite', 'ocean', 'strong', 'discover', 'global', 'current'}
# ---
#
# {'evolutionary', 'fashion', 'long', 'sourc', 'journey', 'bird', 'global', 'warming', 'distance', 'change', 'cause', 'migration'}
# ---
#
# {'heat', 'climate', 'core', 'increase', 'conservative', 'comment', 'change', 'earth', 'funniest'}
# ---
#
# {'winter', 'scientist', 'life', 'marine', 'island', 'flounder', 'affect', 'long', 'global', 'rhode', 'warming', 'narragansett'}
# ---
#
# {'architect', 'locally', 'theimer', 'stupid', 'redd', 'doubter', 'james', 'know', 'environmentally', 'warming', 'global'}
# ---
#
# {'look', 'tree', 'natural', 'help', 'pre', 'indonesia', 'program', 'reduce', 'maintain', 'planting', 'warming', 'global'}
# ---
#
# {'endanger', 'report', 'climate', 'health', 'change', 'earth'}
# ---
#
# {'chapmanu', 'wlliam', 'happen', 'say', 'deal', 'climate', 'matter', 'cubeyond', 'change', 'cause'}
# ---
#
# {'way', 'plant', 'chew', 'focus', 'specie', 'animal', 'global', 'warming', 'redistribution', 'cause'}
# ---
#
# {'military', 'fight', 'climate', 'lead', 'change'}
# ---
#
# {'society', 'exceptional', 'period', 'hazardous', 'stunner', 'activity', 'royal', 'climate', 'chan', 'warming', 'global', 'geosphere', 'link'}
# ---
#
# {'comment', 'rarely', 'gunther', 'fight', 'poverty', 'global', 'marc', 'warming', 'view', 'africa'}
# ---
#
# {'reuter', 'military', 'fight', 'climate', 'lead', 'change'}
# ---
#
# {'day', 'come', 'climate', 'early', 'change', 'spring'}
# ---
#
# {'nasa', 'supercomputer', 'climate', 'launch', 'change'}
# ---
#
# {'limit', 'option', 'environmental', 'excellent', 'economic', 'policy', 'climate', 'change'}
# ---
#
# {'woman', 'discuss', 'climate', 'family', 'child', 'change', 'community', 'tonight'}
# ---
#
# {'tackle', 'boomer', 'peace', 'baby', 'anonymous', 'large', 'warming', 'global', 'enjoy'}
# ---
#
# {'treehugger', 'water', 'saltiness', 'ocean', 'cycle', 'global', 'intensify', 'warming', 'show'}
# ---
#
# {'greenhouse', 'trade', 'esty', 'emission', 'daniel', 'climate', 'plan', 'system', 'change', 'bring'}
# ---
#
# {'washington', 'military', 'fight', 'large', 'climate', 'lead', 'reuters', 'change', 'government'}
# ---
#
# {'implicate', 'codex', 'science', 'migration', 'global', 'bird', 'warming', 'shorten'}
# ---
#
# {'gift', 'supercomputer', 'climate', 'change', 'earth'}
# ---
#
# {'greenhouse', 'trade', 'esty', 'emission', 'daniel', 'climate', 'plan', 'system', 'change', 'bring'}
# ---
#
# {'warming', 'bloom', 'early', 'biologist', 'global', 'link'}
# ---
#
# {'warming', 'researcher', 'plant', 'bloom', 'say', 'wisconsin', 'early', 'central', 'flower', 'biologist', 'global', 'link'}
# ---
#
# {'cochabamba', 'news', 'warming', 'environment', 'april', 'bolivia', 'blame', 'capitalism', 'service', 'bolivian', 'global', 'president'}
# ---
#
# {'need', 'acosta', 'vulnerable', 'site', 'climate', 'geopolitic', 'uruguay', 'tool', 'global', 'change'}
# ---
#
# {'volcano', 'idea', 'cure', 'explosive', 'warming', 'global'}
# ---
#
# {'national', 'woman', 'leader', 'change', 'climate', 'live', 'indigenous'}
# ---
#
# {'happen', 'series', 'worldnew', 'climate', 'change', 'city'}
# ---
#
# {'warming', 'scheme', 'offset', 'forest', 'fail', 'science', 'christian', 'carbon', 'reduce', 'vatican', 'global', 'monitor'}
# ---
#
# {'offset', 'buy', 'carbon', 'global', 'warming', 'guilt', 'ease'}
# ---
#
# {'manipulate', 'planet', 'geoengineere', 'combat', 'climate', 'danger', 'change', 'mooney'}
# ---
#
# {'nasa', 'warming', 'transportation', 'captur', 'green', 'volcano', 'opar', 'satellite', 'bird', 'impact', 'icelandic', 'global', 'alisa'}
# ---
#
# {'warming', 'southern', 'england', 'bird', 'global', 'suffer'}
# ---
#
# {'focus', 'climate', 'get', 'video', 'change'}
# ---
#
# {'warming', 'volcanic', 'volcano', 'trigger', 'cloud', 'global'}
# ---
#
# {'traffic', 'collapse', 'european', 'alter', 'financial', 'global', 'blame', 'warming'}
# ---
#
# {'oppose', 'environmental', 'republicans', 'sense', 'effort', 'warming', 'global', 'make'}
# ---
#
# {'energy', 'secure', 'climate', 'solution', 'change', 'safe', 'nuclear'}
# ---
#
# {'volcano', 'trigger', 'eyjafjoell', 'warming', 'global'}
# ---
#
# {'state', 'induce', 'declare', 'human', 'dept', 'primarily', 'unequivocal', 'global', 'warming'}
# ---
#
# {'release', 'report', 'action', 'unequivocal', 'climate', 'warming', 'global'}
# ---
#
# {'volcanic', 'help', 'trigger', 'melt', 'global', 'warming', 'cap', 'eruption'}
# ---
#
# {'tell', 'photo', 'climate', 'real', 'change', 'dare'}
# ---
#
# {'release', 'treehugger', 'merchant', 'report', 'action', 'brooklyn', 'unequivocal', 'climate', 'brian', 'warming', 'global'}
# ---
#
# {'mother', 'earthquake', 'hekla', 'volcano', 'nature', 'global', 'icelandic', 'warming'}
# ---
#
# {'trouble', 'volcano', 'blame', 'warming', 'global'}
# ---
#
# {'debate', 'scientist', 'reminder', 'politician', 'nearly', 'health', 'warming', 'global', 'agree'}
# ---
#
# {'mother', 'earthquake', 'hekla', 'volcano', 'global', 'ashtag', 'icelandic', 'warming', 'earth'}
# ---
#
# {'romm', 'climate', 'quote', 'biden', 'change'}
# ---
#
# {'green', 'idea', 'living', 'stop', 'climate', 'reinvent', 'change', 'city'}
# ---
#
# {'baseball', 'curve', 'major', 'team', 'climate', 'throw', 'league', 'change', 'denier', 'cleantechnica'}
# ---
#
# {'pirate', 'pollution', 'lack', 'global', 'warming'}
# ---
#
# {'warming', 'migrating', 'habit', 'decade', 'billion', 'bird', 'global', 'change', 'estimate'}
# ---
#
# {'reuter', 'tell', 'magmatic', 'melt', 'global', 'system', 'warming', 'influence'}
# ---
#
# {'upper', 'atmospher', 'sediment', 'effect', 'reporting', 'increase', 'reduce', 'warming', 'global'}
# ---
# {'heat', 'block', 'volcanic', 'travel', 'lessens', 'thing', 'good', 'warming', 'global'}
# ---
#
# {'clean', 'news', 'pollution', 'speed', 'warming', 'global'}
# ---
#
# {'tackle', 'leak', 'document', 'regime', 'climate', 'global', 'change', 'call'}
# ---
#
# {'clean', 'pollution', 'downswe', 'help', 'speed', 'warming', 'global', 'aerosol'}
# ---
#
# {'clean', 'pollution', 'downswe', 'help', 'speed', 'warming', 'global', 'aerosol'}
# ---
#
# {'news', 'today', 'effect', 'stat', 'global', 'youtube', 'warming'}
# ---
#
# {'warm', 'climate', 'global', 'change', 'read'}
# ---
#
# {'tackle', 'today', 'archive', 'global', 'reduce', 'blog', 'greenhous', 'warming', 'present'}
# ---
#
# {'pollution', 'automotive', 'effort', 'climate', 'coda', 'laud', 'change', 'combat'}
# ---
#
# {'blog', 'study', 'saltiness', 'ocean', 'scientist', 'indyposte', 'austral', 'conduct', 'blame', 'get', 'weird', 'warming', 'global'}
# ---
#
# {'explore', 'evolution', 'scientist', 'climate', 'science', 'change'}
# ---
#
# {'explore', 'evolution', 'scientist', 'climate', 'science', 'change'}
# ---
#
# {'wait', 'coalition', 'fight', 'ground', 'climate', 'tired', 'level', 'change'}
# ---
#
# {'need', 'adaption', 'keston', 'state', 'press', 'justice', 'mazmanian', 'money', 'social', 'prof', 'climate', 'change', 'sppd'}
# ---
#
# {'scientist', 'volcano', 'unlikely', 'iceland', 'slow', 'warming', 'global'}
# ---
#
# {'explore', 'evolution', 'scientist', 'climate', 'science', 'change'}
# ---
#
# {'volcanic', 'scientist', 'volcano', 'cooling', 'paris', 'unlikely', 'iceland', 'slow', 'warming', 'global', 'eruption'}
# ---
#
# {'history', 'unio', 'face', 'european', 'bizarre', 'bat', 'global', 'cricket', 'threat', 'warming', 'follow', 'london'}
# ---
#
# {'ingham', 'volcano', 'eumesat', 'satellite', 'image', 'afpapril', 'richard', 'unlikely', 'slow', 'warming', 'global'}
# ---
#
# {'explore', 'evolution', 'scientist', 'climate', 'science', 'change'}
# ---
#
# {'effect', 'year', 'climate', 'global', 'catastrophic', 'warming', 'teach', 'preach'}
# ---
#
# {'explore', 'evolution', 'scientist', 'climate', 'science', 'change'}
# ---
#
# {'obama', 'tackle', 'world', 'wait', 'say', 'china', 'barack', 'warming', 'global', 'president', 'commit'}
# ---
#
# {'warming', 'possible', 'energy', 'takei', 'renewable', 'university', 'milton', 'alumnus', 'deal', 'solution', 'global'}
# ---
#
# {'effect', 'climate', 'global', 'impact', 'youtube', 'warming', 'change', 'predict'}
# ---
#
# {'effect', 'post', 'fight', 'warming', 'global', 'read'}
# ---
#
# {'news', 'online', 'battle', 'poverty', 'global', 'warming'}
# ---
#
# {'allergy', 'bad', 'global', 'blame', 'warming'}
# ---
#
# {'trade', 'change', 'partner', 'fight', 'climate', 'germany', 'important'}
# ---
#
# ...
# ---
#
# {'house', 'obama', 'fuck', 'bulb', 'solve', 'truth', 'brian', 'warming', 'global', 'change', 'light'}
# ---
#
# {'donate', 'quiz', 'haiti', 'minute', 'celebrate', 'action', 'climate', 'change', 'earth'}
# ---
#
# {'refer', 'average', 'thought', 'global', 'rise', 'warming'}
# ---
#
# {'mainstream', 'year', 'decade', 'journalism', 'global', 'warming', 'call', 'advocacy'}
# ---
#
# {'cochabamba', 'hollywood', 'star', 'politician', 'join', 'summit', 'guardian', 'bolivia', 'global', 'warming', 'cool'}
# ---
#
# {'nasa', 'worthless', 'gawker', 'completely', 'warming', 'global', 'maybe'}
# ---
#
# {'naughton', 'american', 'homework', 'help', 'come', 'million', 'global', 'tomorrow', 'warming', 'schoolchil', 'earth'}
# ---
#
# {'comedian', 'know', 'joke', 'warming', 'global', 'datum'}
# ---
#
# {'fellow', 'excellent', 'liberal', 'cultism', 'tcot', 'article', 'warming', 'global'}
# ---
#
# {'earth', 'carol', 'energy', 'chat', 'pre', 'assist', 'join', 'climate', 'live', 'tomorrow', 'change', 'browner'}
# ---
#
# {'intl', 'public', 'perception', 'convention', 'biotech', 'climate', 'global', 'hunger', 'agricultural', 'highlight', 'change'}
# ---
#
# {'open', 'morale', 'climate', 'conference', 'change', 'tiquipaya'}
# ---
#
# {'weather', 'visual', 'complete', 'climate', 'guide', 'recommend', 'encyclopedia', 'change'}
# ---
#
# {'need', 'hit', 'river', 'california', 'climate', 'video', 'change', 'disaster', 'delta'}
# ---
#
# {'teen', 'youth', 'shop', 'fight', 'inconvenient', 'climate', 'stop', 'change'}
# ---
#
# {'teen', 'youth', 'shop', 'fight', 'inconvenient', 'climate', 'stop', 'change'}
# ---
#
# {'write', 'examiner', 'ipcc', 'richard', 'capture', 'interview', 'global', 'warming', 'exclusive'}
# ---
#
# {'warm', 'dutch', 'researcher', 'sarian', 'amount', 'say', 'lake', 'large', 'climate', 'kosten', 'change'}
# ---
#
# {'join', 'global', 'valero', 'stop', 'warming', 'kill', 'want'}
# ---
#
# {'think', 'volcano', 'trigger', 'climate', 'global', 'warming', 'change'}
# ---
#
# {'message', 'pollution', 'folk', 'switch', 'fight', 'climate', 'global', 'warming', 'change'}
# ---
#
# {'care', 'point', 'willing', 'prove', 'climate', 'find', 'prostitute', 'change'}
# ---
#
# {'think', 'datafolha', 'believe', 'responsible', 'brazzil', 'real', 'warming', 'global', 'show', 'brazilian'}
# ---
#
# {'company', 'effect', 'major', 'global', 'reduce', 'warming'}
# ---
# {'issue', 'natural', 'life', 'affect', 'child', 'global', 'warming', 'disaster'}
# ---
#
# {'change', 'leadership', 'summit', 'climate', 'reduce', 'role', 'highlight', 'innovation', 'biotechnology', 'emission'}
# ---
#
# {'tackle', 'warming', 'help', 'court', 'attractive', 'global', 'nuisance', 'federal'}
# ---
#
# {'tackle', 'youth', 'inconvenient', 'climate', 'change'}
# ---
#
# {'eyjafjallajokull', 'volcano', 'discuss', 'erupt', 'volc', 'iceland', 'global', 'warming', 'cause'}
# ---
#
# {'cochabamba', 'star', 'interview', 'bolivia', 'climate', 'conference', 'pocahontas', 'watch', 'change'}
# ---
#
# {'tell', 'hoot', 'global', 'ocregister', 'blog', 'warming', 'exactly'}
# ---
#
# {'address', 'win', 'climate', 'sustainability', 'change'}
# ---
#
# {'think', 'profit', 'class', 'economist', 'confuse', 'talk', 'global', 'good', 'warming', 'view'}
# ---
#
# {'environmentalism', 'claim', 'carrie', 'environmentalist', 'moral', 'ethanol', 'global', 'lukas', 'warming', 'dark'}
# ---
#
# {'look', 'shortage', 'islamabad', 'water', 'second', 'treaty', 'climate', 'indus', 'south', 'asia', 'change', 'call'}
# ---
#
# {'volcano', 'iceland', 'warming', 'global', 'cause'}
# ---
#
# {'dumb', 'buyer', 'better', 'climate', 'change', 'loser'}
# ---
#
# {'today', 'usgs', 'desert', 'climate', 'vegas', 'change', 'workshop'}
# ---
#
# {'mother', 'jones', 'slate', 'wire', 'atlantic', 'report', 'climate', 'back', 'launch', 'impact', 'change', 'response'}
# ---
#
# {'mother', 'jones', 'slate', 'wire', 'atlantic', 'report', 'climate', 'back', 'launch', 'impact', 'change', 'response'}
# ---
#
# {'people', 'sister', 'thank', 'world', 'summit', 'partcipation', 'climate', 'earthright', 'global', 'change', 'indigenous'}
# ---
#
# {'cutie', 'evolution', 'slowly', 'start', 'climate', 'change', 'polarbear'}
# ---
#
# {'alarmism', 'short', 'time', 'world', 'reach', 'apex', 'global', 'run', 'warming'}
# ---
#
# {'washington', 'time', 'world', 'rucker', 'rothbard', 'delegate', 'gather', 'global', 'weak', 'link', 'warming'}
# ---
#
# {'different', 'thing', 'climate', 'atmosphere', 'increase', 'warming', 'global', 'change', 'cause'}
# ---
#
# {'ppls', 'people', 'world', 'earthweek', 'bolivia', 'climate', 'conference', 'earthday', 'change'}
# ---
#
# {'warm', 'feel', 'fantasy', 'like', 'fight', 'global', 'good', 'youtube', 'video'}
# ---
#
# {'monday', 'corner', 'rasmussen', 'voter', 'report', 'april', 'global', 'seriously', 'warming', 'skeptic'}
# ---
#
# {'news', 'announce', 'rehabilitate', 'panel', 'scientist', 'volcanic', 'sue', 'brkg', 'climate', 'get', 'iceland', 'change', 'eruption'}
# ---
#
# {'record', 'set', 'april', 'prove', 'warming', 'global', 'heatwave'}
# ---
#
# {'myth', 'ashe', 'decade', 'oslo', 'cause', 'climat', 'come', 'turn', 'global', 'thaw', 'reuters', 'warming', 'cap'}
# ---
#
# {'alarmism', 'short', 'pollution', 'time', 'world', 'global', 'run', 'warming'}
# ---
#
# {'treehugger', 'earthquake', 'effect', 'environment', 'economic', 'climate', 'political', 'change'}
# ---
#
# {'bill', 'time', 'cool', 'changin', 'talk', 'warming', 'global', 'mckibben'}
# ---
#
# {'hominid', 'climate', 'past', 'change', 'adapt'}
# ---
#
# {'news', 'history', 'environment', 'natural', 'site', 'great', 'climate', 'aspect', 'break', 'change', 'earth'}
# ---
#
# {'send', 'smoke', 'news', 'signal', 'gore', 'volcano', 'algore', 'nowplaying', 'msnbc', 'carter', 'jimmy', 'tcot', 'glenn', 'warming', 'global', 'beck'}
# ---
#
# {'send', 'smoke', 'news', 'signal', 'gore', 'volcano', 'algore', 'msnbc', 'carter', 'jimmy', 'tcot', 'glenn', 'nowplaye', 'warming', 'global', 'beck'}
# ---
#
# {'european', 'jerk', 'knee', 'prison', 'come', 'discredit', 'warming', 'global', 'alarmist', 'government'}
# ---
#
# {'mother', 'people', 'pablo', 'world', 'summit', 'climate', 'solon', 'bolivian', 'change', 'right', 'ambassador', 'earth'}
# ---
#
# {'sign', 'earth', 'heat', 'miss', 'eventually', 'climate', 'reappear', 'change', 'concern'}
# ---
#
# {'comedian', 'know', 'joke', 'warming', 'global', 'datum'}
# ---
#
# {'slap', 'summit', 'april', 'ecuador', 'bolivia', 'climate', 'slice', 'million', 'change', 'dollar'}
# ---
#
# {'people', 'hold', 'bolivia', 'climate', 'conference', 'change', 'alternative'}
# ---
#
# {'doubleday', 'mcewan', 'page', 'talese', 'global', 'take'}
# ---
#
# {'oxburgh', 'balance', 'say', 'fraud', 'climate', 'global', 'quote', 'warming', 'change'}
# ---
#
# {'post', 'climate', 'illuminate', 'science', 'change'}
# ---
#
# {'democrat', 'homosexuality', 'eciu', 'party', 'news', 'acorn', 'dncc', 'nambla', 'abortion', 'support', 'tcot', 'warming', 'global', 'prostitution', 'beck'}
# ---
#
# {'event', 'energy', 'green', 'talk', 'climate', 'change', 'earth'}
# ---
#
# {'event', 'embrace', 'farmington', 'energy', 'green', 'library', 'talk', 'climate', 'community', 'change', 'earth'}
# ---
#
# {'power', 'climate', 'solution', 'change', 'nuclear'}
# ---
#
# {'percent', 'statewide', 'reporter', 'poll', 'skeptical', 'vegas', 'nevadan', 'warming', 'global', 'show'}
# ---
#
# {'allergy', 'bad', 'gore', 'climate', 'blame', 'solar', 'system', 'change', 'seasonal', 'make'}
# ---
#
# {'tackle', 'excuse', 'reach', 'climate', 'change'}
# ---
#
# {'human', 'volcano', 'contribute', 'emit', 'relation', 'iceland', 'farce', 'joke', 'wonder', 'warming', 'global', 'lie'}
# ---
#
# {'martin', 'scientist', 'ree', 'theory', 'rush', 'defend', 'royal', 'runaway', 'discredit', 'warming', 'global', 'president'}
# ---
#
# {'wrong', 'guru', 'volcano', 'climate', 'iceland', 'get', 'rant', 'fact', 'change', 'probly'}
# ---
#
# {'gore', 'come', 'tcot', 'blame', 'warming', 'global', 'eruption'}
# ---
#
# {'detractor', 'importance', 'disbelieve', 'public', 'experien', 'world', 'pressure', 'global', 'game', 'warming', 'show'}
# ---
#
# {'sign', 'gravity', 'like', 'reliable', 'unchanging', 'warming', 'global'}
# ---
#
# {'apocalypsenow', 'green', 'revolution', 'outcome', 'climate', 'hard', 'change', 'exciting', 'predict'}
# ---
#
# {'place', 'climate', 'graph', 'science', 'change', 'alternative'}
# ---
#
# {'build', 'green', 'economy', 'finally', 'krugman', 'climate', 'definitely', 'worthwhile', 'change', 'read'}
# ---
#
# {'treehugger', 'merchant', 'allergic', 'brooklyn', 'global', 'york', 'brian', 'warming', 'literally'}
# ---
#
# {'google', 'chief', 'carbon', 'climate', 'price', 'change', 'want'}
# ---
#
# {'consortium', 'summit', 'mulch', 'medium', 'innovatively', 'climate', 'weekly', 'laskow', 'sarah', 'cochacamba', 'change', 'combat', 'blogger'}
# ---
#
# {'debate', 'intelligence', 'consider', 'human', 'unpersuade', 'nutcase', 'evidence', 'logic', 'remain', 'discourage', 'global', 'warming'}
# ---
#
# {'global', 'represent', 'probably', 'warming', 'skeptic', 'view'}
# ---
#
# {'care', 'congress', 'climate', 'work', 'health', 'change'}
# ---
#
# {'fire', 'scientist', 'climate', 'warming', 'global', 'exaggerate'}
# ---
#
# {'heat', 'future', 'observational', 'affect', 'climate', 'miss', 'source', 'accoun', 'tool', 'science', 'change', 'current', 'daily'}
# ---
#
# {'johnson', 'thing', 'california', 'solve', 'nathanael', 'watch', 'warming', 'global'}
# ---
#
# {'half', 'heat', 'soon', 'scientist', 'believ', 'account', 'miss', 'global', 'roughly', 'warming', 'return'}
# ---
#
# {'inconclusive', 'year', 'evidence', 'market', 'armageddo', 'climate', 'warming', 'global', 'change'}
# ---
#
# {'abrupt', 'lock', 'dial', 'switch', 'carbon', 'climate', 'oven', 'change', 'light'}
# ---
#
# {'need', 'heat', 'beef', 'way', 'scientist', 'monitoring', 'miss', 'global', 'find', 'measure', 'warming', 'expert'}
# ---
#
# {'happen', 'idea', 'know', 'carbon', 'climate', 'reduce', 'good', 'change', 'grant'}
# ---
#
# {'local', 'study', 'cite', 'effect', 'negative', 'climate', 'refinery', 'health', 'change'}
# ---
#
# {'obama', 'warming', 'pope', 'country', 'pressure', 'barack', 'sydney', 'push', 'global', 'president', 'develop'}
# ---
#
# {'weather', 'promote', 'conspiracy', 'theory', 'global', 'channel', 'warming', 'hoax'}
# ---
#
# {'green', 'change', 'carbon', 'support', 'climate', 'policy', 'back', 'plan', 'supporter', 'government'}
# ---
#
# {'warming', 'study', 'attack', 'economy', 'graph', 'global'}
# ---
#
# {'weather', 'strange', 'bullshit', 'average', 'catch', 'get', 'warming', 'global', 'call', 'scare', 'cali'}
# ---
#
# {'renowned', 'discuss', 'polar', 'explorer', 'global', 'steger', 'adventurer', 'free', 'program', 'warming', 'present'}
# ---
#
# {'nightmare', 'climate', 'night', 'change', 'creepy', 'ridiculous'}
# ---
#
# {'record', 'temp', 'fuck', 'evidence', 'asshole', 'climate', 'corrupted', 'accumulate', 'warming', 'global'}
# ---
#
# {'weather', 'staudt', 'scientist', 'series', 'extreme', 'amanda', 'warming', 'global'}
# ---
#
# {'clean', 'thankfully', 'statement', 'energy', 'global', 'positive', 'warming', 'preston', 'tinto', 'chiaro'}
# ---
#
# {'christie', 'heart', 'wallet', 'chris', 'governor', 'global', 'warming', 'jersey', 'wise'}
# ---
#
# {'public', 'post', 'prevent', 'climate', 'willingness', 'change'}
# ---
#
# {'doubleday', 'mcewan', 'page', 'talese', 'global', 'take'}
# ---
#
# {'tackle', 'excuse', 'reach', 'climate', 'change'}
# ---
#
# {'scientist', 'evidence', 'fabricate', 'inquiry', 'global', 'find', 'warming', 'accuse', 'result', 'malpractice'}
# ---
#
# {'nations', 'send', 'scientist', 'control', 'december', 'united', 'global', 'warming', 'letter'}
# ---
# {'people', 'society', 'create', 'time', 'daily', 'obese', 'otago', 'global', 'warming', 'cause'}
# ---
#
# {'coastal', 'water', 'world', 'country', 'turn', 'climate', 'change'}
# ---
#
# {'greentech', 'esty', 'post', 'daniel', 'climate', 'plan', 'huffington', 'change'}
# ---
#
# {'awesome', 'fund', 'governor', 'million', 'global', 'warming', 'christie', 'woot'}
# ---
#
# {'warming', 'people', 'stainton', 'psychology', 'obese', 'united', 'kingdom', 'wendy', 'health', 'professor', 'global', 'cause'}
# ---
#
# {'need', 'pelosi', 'commercial', 'green', 'seek', 'newt', 'defend', 'gingrich', 'global', 'contend', 'warming'}
# ---
#
# {'calendar', 'liberalism', 'statement', 'have', 'global', 'warming', 'make'}
# ---
#
# {'treehugger', 'merchant', 'safety', 'blankenship', 'video', 'silly', 'brian', 'regulator', 'warming', 'global', 'brookl'}
# ---
#
# {'gulf', 'truly', 'peer', 'california', 'review', 'calif', 'global', 'warming', 'read'}
# ---
#
# {'care', 'safety', 'energy', 'idea', 'silly', 'dead', 'massey', 'warming', 'global', 'miner'}
# ---
#
# {'jesse', 'gore', 'woodrow', 'video', 'global', 'ambush', 'warming', 'brilliant'}
# ---
#
# {'weather', 'bohan', 'divide', 'meteo', 'spencer', 'christian', 'sit', 'global', 'weathercaster', 'suzanne', 'warming', 'forecaster'}
# ---
#
# {'warming', 'claim', 'livestock', 'say', 'report', 'headline', 'read', 'false', 'cowgate', 'global', 'cause', 'expert'}
# ---
#
# {'theory', 'disagree', 'global', 'remove', 'warming', 'datum'}
# ---
#
# {'death', 'activist', 'tcot', 'antarctica', 'global', 'warming', 'freeze'}
# ---
#
# {'bill', 'green', 'greentech', 'yahoo', 'compromise', 'senator', 'prepare', 'climate', 'reuters', 'change'}
# ---
#
# {'people', 'pretend', 'fraud', 'surplus', 'know', 'climate', 'global', 'catastrophe', 'warming', 'change'}
# ---
#
# {'documentary', 'win', 'filmmaker', 'gandhi', 'climate', 'delhi', 'change', 'rohit'}
# ---
#
# {'series', 'baby', 'question', 'climate', 'lowdown', 'change'}
# ---
#
# {'series', 'baby', 'question', 'climate', 'lowdown', 'change'}
# ---
#
# {'lizard', 'fight', 'bat', 'climate', 'bird', 'change'}
# ---
#
# {'econ', 'natural', 'krugman', 'resource', 'climate', 'change'}
# ---
#
# {'econ', 'natural', 'krugman', 'resource', 'climate', 'change'}
# ---
#
# {'job', 'press', 'charity', 'climate', 'oxfam', 'senior', 'officer', 'change'}
# ---
#
# {'jasencomstock', 'primer', 'paul', 'krugman', 'economic', 'love', 'climate', 'good', 'change', 'make'}
# ---
#
# {'horizon', 'change', 'long', 'post', 'climate', 'exploration'}
# ---
#
# {'join', 'global', 'valero', 'stop', 'warming', 'kill', 'want'}
# ---
#
# {'bill', 'track', 'introduce', 'senate', 'sweeping', 'global', 'climate', 'flop', 'warming', 'change', 'month'}
# ---
#
# {'elect', 'violence', 'ecojustice', 'climate', 'system', 'daily', 'change', 'right'}
# ---
#
# {'think', 'question', 'global', 'find', 'answer', 'warming', 'hoax'}
# ---
#
# {'international', 'continue', 'effort', 'bonn', 'warming', 'global', 'negotia', 'agree'}
# ---
#
# {'process', 'vanish', 'thirty', 'tree', 'year', 'time', 'palm', 'million', 'climate', 'change', 'call', 'alaska'}
# ---
#
# {'intl', 'warm', 'scientist', 'challenge', 'conference', 'global'}
# ---
#
# {'oppose', 'study', 'today', 'refute', 'declare', 'second', 'telegraph', 'global', 'warming', 'meat', 'view', 'daily'}
# ---
#
# {'point', 'fanatic', 'clash', 'consistent', 'environmentalist', 'prove', 'global', 'warming', 'redstate'}
# ---
#
# {'pollution', 'water', 'major', 'source', 'warming', 'global'}
# ---
#
# {'news', 'ecocide', 'prosecute', 'liberalfascism', 'tcot', 'climate', 'warming', 'global'}
# ---
#
# {'lizard', 'fight', 'important', 'bat', 'climate', 'play', 'role', 'bird', 'change', 'earth'}
# ---
#
# {'lizard', 'fight', 'important', 'bat', 'climate', 'play', 'role', 'bird', 'change', 'earth'}
# ---
#
# {'lizard', 'fight', 'important', 'bat', 'climate', 'play', 'role', 'bird', 'change', 'earth'}
# ---
#
# {'lizard', 'fight', 'important', 'bat', 'climate', 'play', 'role', 'bird', 'change', 'earth'}
# ---
#
# {'lizard', 'fight', 'important', 'bat', 'climate', 'play', 'role', 'bird', 'change', 'earth'}
# ---
#
# {'need', 'dilemma', 'fossil', 'america', 'use', 'million', 'global', 'barrel', 'serve', 'warming', 'fuel'}
# ---
#
# {'shrink', 'climate', 'mystery', 'change', 'sheep'}
# ---
#
# {'weather', 'climb', 'unbelievable', 'global', 'warming', 'august', 'chalk'}
# ---
#
# {'luntz', 'say', 'favor', 'change', 'abandon', 'tcot', 'climate', 'global', 'warming', 'phrase'}
# ---
#
# {'warm', 'investigate', 'scientist', 'mann', 'global', 'virginia'}
# ---
#
# {'ipcc', 'global', 'ocra', 'parody', 'warming', 'tube', 'enjoy'}
# ---
#
# {'tell', 'eyed', 'golfer', 'warming', 'global', 'dare', 'make'}
# ---
#
# {'brain', 'claim', 'scientifically', 'theory', 'hair', 'ippc', 'tcot', 'challenge', 'global', 'climategate', 'warming'}
# ---

# %% [markdown]
# ## Modeling

# %%
new_data = data.iloc[indices]

# %%
prepr_tweets = [" ".join(each) for each in preprocessed_tweets]
new_data['cleaned_tweet'] = prepr_tweets
new_data.head()
# Out:
#                                                tweet existence  \
# 0  Global warming report urges governments to act...       Yes
# 1  Fighting poverty and global warming in Africa ...       Yes
# 2  Carbon offsets: How a Vatican forest failed to...       Yes
# 3  Carbon offsets: How a Vatican forest failed to...       Yes
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...       Yes
#
#    existence.confidence  word_count  \
# 0                1.0000          18
# 1                1.0000           8
# 2                0.8786          12
# 3                1.0000          12
# 4                0.8087          11
#
#                                        cleaned_tweet
# 0  urge belgium world face report global hunger i...
# 1                fight poverty global warming africa
# 2  warming offset forest fail carbon reduce vatic...
# 3  warming offset forest fail carbon reduce vatic...
# 4        need vulnerable climate uruguay tool change

# %%
len(prepr_tweets), data.shape, new_data.shape
# Out:
# (5544, (5960, 4), (5544, 5))

# %%
# TF IDF
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split
import collections, numpy

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(new_data['cleaned_tweet'].astype('U'))

tf = TfidfVectorizer()
text_tf = tf.fit_transform(new_data['cleaned_tweet'].astype('U'))
# print(text_tf)

# %%
new_data.isna().sum()
# Out:
# tweet                   0
# existence               0
# existence.confidence    0
# word_count              0
# cleaned_tweet           0
# dtype: int64

# %%
# compute similarity using cosine similarity
cos_sim=cosine_similarity(text_tf, text_tf)
print(cos_sim)
# Out:
# [[1.         0.03273816 0.02203327 ... 0.02147607 0.02021837 0.0164164 ]
#  [0.03273816 1.         0.03854919 ... 0.03757431 0.03537386 0.02872197]
#  [0.02203327 0.03854919 1.         ... 0.02528807 0.02380713 0.01933031]
#  ...
#  [0.02147607 0.03757431 0.02528807 ... 1.         0.02320507 0.01884147]
#  [0.02021837 0.03537386 0.02380713 ... 0.02320507 1.         0.01773806]
#  [0.0164164  0.02872197 0.01933031 ... 0.01884147 0.01773806 1.        ]]

# %%
# splitting data 

X_train, X_test, y_train, y_test = train_test_split(cos_sim, new_data['existence'], test_size=0.2, random_state=33)
print(" Test Data Shape:", X_test.shape)
print(" Train Data Shape:",X_train.shape)
# Out:
#  Test Data Shape: (1109, 5544)
#  Train Data Shape: (4435, 5544)

# %%
pos = (y_test == 'Yes').sum()
neg = (y_test == 'No').sum()
postrain = (y_train == 'Yes').sum()
negtrain = (y_train == 'No').sum()
total = pos + neg
print(" Test Data Positive Sentiments :", pos)
print(" Test Data Negative Sentiments :",neg)
print(" Train Data Positive Sentiments :", postrain)
print(" Train Data Positive Sentiments :",negtrain)
new_data['existence'].value_counts()
# Out:
#  Test Data Positive Sentiments : 588
#  Test Data Negative Sentiments : 198
#  Train Data Positive Sentiments : 2261
#  Train Data Positive Sentiments : 817
# Yes        2849
# neutral    1680
# No         1015
# Name: existence, dtype: int64

# %%
# perform algoritma KNN
from sklearn.metrics import accuracy_score, cohen_kappa_score
from sklearn.metrics import precision_score, auc,recall_score, f1_score,roc_curve,confusion_matrix, classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm
from sklearn.model_selection import cross_val_score
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.svm import LinearSVC

# %%
clfs = [
    svm.SVC(kernel='linear').fit(X_train, y_train),
#     LinearSVC().fit(X_train, y_train),
    DecisionTreeClassifier().fit(X_train, y_train),
    KNeighborsClassifier(n_neighbors=7).fit(X_train, y_train)
]

# %%
MLA_columns = []
MLA_compare = pd.DataFrame(columns = MLA_columns)

# %%
row_index = 0
for clf in clfs:
    print('===============================================\n')
    print("**********{}***********".format(clf.__class__.__name__))
    predicted = clf.predict(X_test)
#     tn, fp, fn, tp = confusion_matrix(y_test, predicted).ravel()
    MLA_name = clf.__class__.__name__
    MLA_compare.loc[row_index,'MLA Name'] = MLA_name
    MLA_compare.loc[row_index, 'MLA Train Accuracy'] = round(clf.score(X_train, y_train), 2)
    MLA_compare.loc[row_index, 'MLA Test Accuracy'] = round( accuracy_score(y_test,predicted), 2)
    MLA_compare.loc[row_index, 'MLA Precision'] = round( precision_score(y_test,predicted, average="macro"), 2)
    MLA_compare.loc[row_index, 'MLA Recall'] = round( recall_score(y_test,predicted, average="macro"), 2)
    MLA_compare.loc[row_index, 'MLA F1 Score'] = round( f1_score(y_test,predicted, average="macro"), 2)
    MLA_compare.loc[row_index, 'error_rate'] = round( 1-accuracy_score(y_test,predicted), 2)
    MLA_compare.loc[row_index, 'cross val score'] = cross_val_score(clf, cos_sim,new_data['existence'], cv=10).mean()
    row_index+=1
# Out:
# ===============================================
#
# **********SVC***********

# %%
MLA_compare.sort_values(by = ['MLA Test Accuracy'], ascending = False, inplace = True)
MLA_compare

# %% [markdown]
# ## Random Under Sampling

# %%
from imblearn.over_sampling import RandomOverSampler,SMOTE
from imblearn.under_sampling import RandomUnderSampler

# %%
# splitting data 

X_train, X_test, y_train, y_test = train_test_split(cos_sim, new_data['existence'], test_size=0.2, random_state=33)
print(" Test Data Shape:", X_test.shape)
print(" Train Data Shape:",X_train.shape)

# %%
X_train,y_train = RandomUnderSampler(random_state = 21).fit_resample(X_train,y_train)
# X_train,y_train = RandomOverSampler(random_state = 21).fit_resample(X_train,y_train)

# %%
X_train.shape, y_train.shape

# %%
under_MLA_columns = []
under_MLA_compare = pd.DataFrame(columns = under_MLA_columns)

# %%
under_clfs = [
    svm.SVC(kernel='linear').fit(X_train, y_train),
#     LinearSVC(C=0.0001).fit(X_train, y_train),
    DecisionTreeClassifier().fit(X_train, y_train),
    KNeighborsClassifier(n_neighbors=7).fit(X_train, y_train)
]

# %%
row_index = 0
for clf in under_clfs:
    print('===============================================\n')
    print("**********{}***********".format(clf.__class__.__name__))
    predicted = clf.predict(X_test)
#     tn, fp, fn, tp = confusion_matrix(y_test, predicted).ravel()
    under_MLA_name = clf.__class__.__name__
    under_MLA_compare.loc[row_index,'MLA Name'] = under_MLA_name
    under_MLA_compare.loc[row_index, 'MLA Train Accuracy'] = round(clf.score(X_train, y_train), 2)
    under_MLA_compare.loc[row_index, 'MLA Test Accuracy'] = round( accuracy_score(y_test,predicted), 2)
    under_MLA_compare.loc[row_index, 'MLA Precision'] = round( precision_score(y_test,predicted, average="macro"), 2)
    under_MLA_compare.loc[row_index, 'MLA Recall'] = round( recall_score(y_test,predicted, average="macro"), 2)
    under_MLA_compare.loc[row_index, 'MLA F1 Score'] = round( f1_score(y_test,predicted, average="macro"), 2)
    under_MLA_compare.loc[row_index, 'error_rate'] = round( 1-accuracy_score(y_test,predicted), 2)
    under_MLA_compare.loc[row_index, 'cross val score'] = cross_val_score(clf, cos_sim,new_data['existence'], cv=10).mean()
    row_index+=1

# %%
under_MLA_compare.sort_values(by = ['MLA Test Accuracy'], ascending = False, inplace = True)
under_MLA_compare

# %% [markdown]
# ## Random Over Sampling

# %%
# splitting data 

X_train, X_test, y_train, y_test = train_test_split(cos_sim, new_data['existence'], test_size=0.2, random_state=33)
print(" Test Data Shape:", X_test.shape)
print(" Train Data Shape:",X_train.shape)

# %%
# Xtrain,ytrain = RandomUnderSampler(random_state = 21).fit_resample(X_train,y_train)
X_train,y_train = RandomOverSampler(random_state = 21).fit_resample(X_train,y_train)

# %%
X_train.shape, y_train.shape

# %%
over_MLA_columns = []
over_MLA_compare = pd.DataFrame(columns = over_MLA_columns)

# %%
over_clfs = [
    svm.SVC(kernel='linear').fit(X_train, y_train),
#     LinearSVC(C=0.0001).fit(X_train, y_train),

    DecisionTreeClassifier().fit(X_train, y_train),
    KNeighborsClassifier(n_neighbors=7).fit(X_train, y_train)
]

# %%
row_index = 0
for clf in over_clfs:
    print('===============================================\n')
    print("**********{}***********".format(clf.__class__.__name__))
    predicted = clf.predict(X_test)
#     tn, fp, fn, tp = confusion_matrix(y_test, predicted).ravel()
    over_MLA_name = clf.__class__.__name__
    over_MLA_compare.loc[row_index,'MLA Name'] = over_MLA_name
    over_MLA_compare.loc[row_index, 'MLA Train Accuracy'] = round(clf.score(X_train, y_train), 2)
    over_MLA_compare.loc[row_index, 'MLA Test Accuracy'] = round( accuracy_score(y_test,predicted), 2)
    over_MLA_compare.loc[row_index, 'MLA Precision'] = round( precision_score(y_test,predicted, average="macro"), 2)
    over_MLA_compare.loc[row_index, 'MLA Recall'] = round( recall_score(y_test,predicted, average="macro"), 2)
    over_MLA_compare.loc[row_index, 'MLA F1 Score'] = round( f1_score(y_test,predicted, average="macro"), 2)
    over_MLA_compare.loc[row_index, 'error_rate'] = round( 1-accuracy_score(y_test,predicted), 2)
    over_MLA_compare.loc[row_index, 'cross val score'] = cross_val_score(clf, cos_sim,new_data['existence'], cv=10).mean()
    row_index+=1

# %% [markdown]
# ## SMOTE

# %%
# splitting data 
X_train, X_test, y_train, y_test = train_test_split(cos_sim, new_data['existence'], test_size=0.2, random_state=33)
print(" Test Data Shape:", X_test.shape)
print(" Train Data Shape:",X_train.shape)

# %%
from imblearn.over_sampling import SMOTE

oversample = SMOTE(k_neighbors=5)
X_train,y_train = oversample.fit_resample(X_train,y_train)
X_train.shape,y_train.shape

# %%
SMOTE_MLA_columns = []
SMOTE_MLA_compare = pd.DataFrame(columns = SMOTE_MLA_columns)

# %%
smote_clfs = [
    svm.SVC(kernel='linear').fit(X_train, y_train),
#     LinearSVC(C=0.0001).fit(X_train, y_train),

    DecisionTreeClassifier().fit(X_train, y_train),
    KNeighborsClassifier(n_neighbors=7).fit(X_train, y_train)
]

# %%
row_index = 0
for clf in smote_clfs:
    print('===============================================\n')
    print("**********{}***********".format(clf.__class__.__name__))
    predicted = clf.predict(X_test)
#     tn, fp, fn, tp = confusion_matrix(y_test, predicted).ravel()
    SMOTE_MLA_name = clf.__class__.__name__
    SMOTE_MLA_compare.loc[row_index,'MLA Name'] = SMOTE_MLA_name
    SMOTE_MLA_compare.loc[row_index, 'MLA Train Accuracy'] = round(clf.score(X_train, y_train), 2)
    SMOTE_MLA_compare.loc[row_index, 'MLA Test Accuracy'] = round( accuracy_score(y_test,predicted), 2)
    SMOTE_MLA_compare.loc[row_index, 'MLA Precision'] = round( precision_score(y_test,predicted, average="macro"), 2)
    SMOTE_MLA_compare.loc[row_index, 'MLA Recall'] = round( recall_score(y_test,predicted, average="macro"), 2)
    SMOTE_MLA_compare.loc[row_index, 'MLA F1 Score'] = round( f1_score(y_test,predicted, average="macro"), 2)
    SMOTE_MLA_compare.loc[row_index, 'error_rate'] = round( 1-accuracy_score(y_test,predicted), 2)
    SMOTE_MLA_compare.loc[row_index, 'cross val score'] = cross_val_score(clf, cos_sim,new_data['existence'], cv=10).mean()
    row_index+=1

# %%
MLA_compare

# %%
under_MLA_compare

# %%
over_MLA_compare

# %%
SMOTE_MLA_compare

# %%
# import pickle
# # pickling the vectorizer
# pickle.dump(tf, open('vectorizer', 'wb'))
# # pickling the model
# pickle.dump(clfs[0], open('svm_classifier_89', 'wb'))
