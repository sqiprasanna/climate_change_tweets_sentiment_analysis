# %%
import numpy as np
import pandas as pd
import spacy
import matplotlib.pyplot as plt 
from itertools import chain
from wordcloud import WordCloud, STOPWORDS 
from nltk.stem import PorterStemmer
import re

import cufflinks as cf
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)

# %run ./jlu_preprocessing.ipynb
# %run ./spk_preprocessing.ipynb
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %%
# data = pd.read_excel(r'C:/Users/Checkout/Desktop/SJSU/sem1/257-ML/Project/global_warming_tweets.xls')
data = pd.read_csv(r'global_warming_tweets.csv', engine='python') #encoding = "cp1252"
data.head()
# Out:
#                                                tweet existence  \
# 0  Global warming report urges governments to act...       Yes
# 1  Fighting poverty and global warming in Africa ...       Yes
# 2  Carbon offsets: How a Vatican forest failed to...       Yes
# 3  Carbon offsets: How a Vatican forest failed to...       Yes
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...       Yes
#
#    existence.confidence
# 0                1.0000
# 1                1.0000
# 2                0.8786
# 3                1.0000
# 4                0.8087

# %%
data['existence'] = data['existence'].fillna('neutral')

# %%
data[data['existence']=="No"].tweet
# Out:
# 17      Wait here's an idea: it's natural climate chan...
# 31      @New_federalists  i have it on good auth tht g...
# 32      Illegal war and the myth of global warming|My ...
# 33      the scientific community was scamed by global ...
# 35      40 degrees in NYC. please urinate on next libe...
#                               ...
# 781     Don Blankenship Calls Efforts On Mine Safety R...
# 1006    Don't be swayed by distraction of climate chan...
# 1058    Who Cares About Global Warming?: by Jackie Gin...
# 1071    Don Blankenship Called Safety Regulators "as S...
# 1072    Coal CEO Calls Mine Safety Rules 'As Silly As ...
# Name: tweet, Length: 61, dtype: object

# %%
print(data['existence'].value_counts())
# Out:
# Y          2554
# neutral    1865
# N          1053
# Yes         557
# No           61
# Name: existence, dtype: int64

# %%
data['word_count'] = data['tweet'].apply(lambda x: len(x.split(" ")))
data = data.drop_duplicates()
data = data.dropna()
data.loc[data['existence'] == 'Y','existence'] = "Yes"
data.loc[data['existence'] == 'N','existence'] = "No"
print(data.shape)
data.dropna()
data.loc[data['existence'] == np.nan,'existence'] = "No"
print(data['existence'].value_counts())
print(data.shape)
data.head()
# Out:
# (5960, 4)
# Yes        3029
# neutral    1826
# No         1105
# Name: existence, dtype: int64
# (5960, 4)
#                                                tweet existence  \
# 0  Global warming report urges governments to act...       Yes
# 1  Fighting poverty and global warming in Africa ...       Yes
# 2  Carbon offsets: How a Vatican forest failed to...       Yes
# 3  Carbon offsets: How a Vatican forest failed to...       Yes
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...       Yes
#
#    existence.confidence  word_count
# 0                1.0000          18
# 1                1.0000           8
# 2                0.8786          12
# 3                1.0000          12
# 4                0.8087          11

# %%
data['tweet']
# Out:
# 0       Global warming report urges governments to act...
# 1       Fighting poverty and global warming in Africa ...
# 2       Carbon offsets: How a Vatican forest failed to...
# 3       Carbon offsets: How a Vatican forest failed to...
# 4       URUGUAY: Tools Needed for Those Most Vulnerabl...
#                               ...
# 6085    @bloodless_coup "The phrase 'global warming' s...
# 6086    Virginia to Investigate Global Warming Scienti...
# 6087    Global warming you tube parody you will enjoy ...
# 6088    One-Eyed Golfer: Don't dare tell me about glob...
# 6089    man made global warming a hair brained theory ...
# Name: tweet, Length: 5960, dtype: object

# %%
tweets = data["tweet"]
# tweets = tweets.drop_duplicates()
tweets
# Out:
# 0       Global warming report urges governments to act...
# 1       Fighting poverty and global warming in Africa ...
# 2       Carbon offsets: How a Vatican forest failed to...
# 3       Carbon offsets: How a Vatican forest failed to...
# 4       URUGUAY: Tools Needed for Those Most Vulnerabl...
#                               ...
# 6085    @bloodless_coup "The phrase 'global warming' s...
# 6086    Virginia to Investigate Global Warming Scienti...
# 6087    Global warming you tube parody you will enjoy ...
# 6088    One-Eyed Golfer: Don't dare tell me about glob...
# 6089    man made global warming a hair brained theory ...
# Name: tweet, Length: 5960, dtype: object

# %%
# tweets[:100]

# %%
# python -m spacy download en_core_web_sm
preprocessed_tweets,indices = preprocess_tweets(tweets)
# Out:
# {'belgium', 'increase', 'global', 'face', 'warming', 'report', 'hunger', 'urge', 'government', 'world'}
# ---
#
# {'poverty', 'global', 'fight', 'africa', 'warming'}
# ---
#
# {'offset', 'carbon', 'global', 'warming', 'vatican', 'reduce', 'fail', 'forest'}
# ---
#
# {'offset', 'carbon', 'global', 'warming', 'vatican', 'reduce', 'fail', 'forest'}
# ---
#
# {'uruguay', 'tool', 'need', 'vulnerable', 'climate', 'change'}
# ---
#
# {'saltiness', 'cycle', 'water', 'intensify', 'global', 'warming', 'ocean', 'show'}
# ---
#
# {'message', 'denier', 'global', 'look', 'warming', 'evidence', 'doubter'}
# ---
#
# {'stay', 'bird', 'strategy', 'migratory', 'climate', 'change', 'home'}
# ---
#
# {'southe', 'compete', 'high', 'southern', 'water', 'limpopo', 'africa', 'temperature', 'bring', 'climate', 'change'}
# ---
#
# {'wheat', 'rice', 'water', 'global', 'warming', 'production', 'impact', 'scarcity'}
# ---
#
# {'analysis', 'global', 'warming', 'previously', 'natural', 'suggest', 'contribute', 'preliminary'}
# ---
#
# {'population', 'climate', 'change', 'perspective', 'ecotone'}
# ---
#
# {'county', 'blame', 'ventura', 'migration', 'whale', 'dwindle', 'coastal', 'climate', 'change'}
# ---
#
# {'little', 'late', 'global', 'year', 'warming', 'storm', 'season', 'start', 'spring'}
# ---
#
# {'cause', 'cancer', 'global', 'mental', 'warming', 'say', 'report', 'illness', 'government'}
# ---
#
# {'global', 'warming', 'affect', 'symptom', 'earthday', 'patient'}
# ---
#
# {'idea', 'human', 'induce', 'wait', 'global', 'warming', 'natural', 'climate', 'change'}
# ---
#
# {'effect', 'have', 'measurable', 'indicator', 'warming', 'issue', 'report', 'climate', 'change', 'ecosystem'}
# ---
#
# {'carbon', 'global', 'warming', 'fast', 'year', 'chemistry', 'ocean', 'change'}
# ---
#
# {'concl', 'sciencedaily', 'topography', 'mountain', 'global', 'warming', 'study', 'rate', 'complicate'}
# ---
#
# {'blame', 'attribute', 'mercury', 'environmentalist', 'global', 'soar'}
# ---
#
# {'indigenous', 'leader', 'woman', 'national', 'live', 'climate', 'change'}
# ---
#
# {'upper', 'reporting', 'effect', 'increase', 'global', 'warming', 'sediment', 'atmospher', 'reduce'}
# ---
#
# {'today', 'news', 'effect', 'global', 'warming', 'youtube', 'stat'}
# ---
#
# {'global', 'warm', 'read', 'climate', 'change'}
# ---
#
# {'analysis', 'global', 'warming', 'previously', 'natural', 'suggest', 'think', 'contribute', 'preliminary'}
# ---
#
# {'explore', 'scientist', 'evolution', 'science', 'climate', 'change'}
# ---
#
# {'stay', 'eaarth', 'global', 'warming', 'deal'}
# ---
#
# {'blame', 'global', 'warming', 'allergy', 'bad'}
# ---
#
# {'cause', 'fortunate', 'global', 'tcot', 'warming', 'fungus', 'good', 'auth'}
# ---
#
# {'election', 'campaign', 'global', 'main', 'platform', 'illegal', 'myth'}
# ---
#
# {'green', 'global', 'warming', 'community', 'scam', 'scientific'}
# ---
#
# {'scum', 'global', 'degree', 'warming', 'liberal', 'change', 'urinate'}
# ---
#
# {'ucot', 'tornado', 'tlot', 'global', 'mississippi', 'race', 'warm', 'tornadocot', 'tycot', 'ocra', 'gore'}
# ---
#
# {'stop', 'confirm', 'global', 'warming', 'book', 'scam', 'sussman', 'settle'}
# ---
#
# {'miracle', 'cause', 'human', 'global', 'tcot', 'warming', 'exist', 'alien', 'angel', 'jesus', 'fairy', 'rationalist', 'believe'}
# ---
#
# {'fall', 'killer', 'proof', 'tsunami', 'fracture', 'peruvian', 'glaci', 'climate', 'create', 'change', 'lake'}
# ---
#
# {'hack', 'algore', 'palin', 'global', 'science', 'warming', 'real', 'hoax', 'climate', 'change', 'gore'}
# ---
#
# {'academic', 'scientist', 'global', 'warming', 'stranger', 'anti', 'nature', 'journal', 'magazine', 'wrong'}
# ---
#
# {'nasa', 'weather', 'accord', 'global', 'measure', 'warming', 'baloney', 'expert', 'climate', 'difference'}
# ---
#
# {'idiot', 'global', 'forensic', 'warming', 'true', 'expert', 'computer', 'belive'}
# ---
#
# {'learn', 'alarmist', 'global', 'warming', 'looney', 'come', 'liberal', 'toon', 'frost', 'artic', 'bite', 'home'}
# ---
#
# {'teaparty', 'global', 'explanation', 'warming', 'enjoy', 'tube', 'ipcc'}
# ---
#
# {'tale', 'issue', 'immigration', 'reform', 'senate', 'climate', 'change'}
# ---
#
# {'green', 'correspondent', 'dinner', 'report', 'memo', 'white', 'climate', 'house', 'change', 'want'}
# ---
#
# {'global', 'country', 'warming', 'hold', 'people', 'monitor', 'view', 'reid', 'vary'}
# ---
#
# {'francisco', 'april', 'henderson', 'california', 'peter', 'reuter', 'scenario', 'challenge', 'climate', 'change', 'source'}
# ---
#
# {'today', 'graham', 'lindsey', 'legislation', 'support', 'climate', 'lindsay', 'change'}
# ---
#
# {'focus', 'stall', 'arizona', 'congress', 'issue', 'legislation', 'immigration', 'climate', 'change', 'poll'}
# ---
#
# {'graham', 'limbo', 'talk', 'exit', 'bill', 'unveile', 'schedule', 'climate', 'change', 'put'}
# ---
#
# {'stall', 'bill', 'senate', 'climate', 'change'}
# ---
#
# {'rapid', 'globa', 'mich', 'typically', 'regulate', 'argue', 'legislation', 'world', 'people', 'grand', 'opponent', 'climate', 'change'}
# ---
#
# {'graham', 'imperil', 'push', 'bill', 'immigration', 'dem', 'cnnbrk', 'climate', 'change'}
# ---
#
# {'talk', 'april', 'global', 'scientifique', 'warming', 'presentation', 'cafe', 'present'}
# ---
#
# {'business', 'check', 'conference', 'climate', 'change', 'video'}
# ---
#
# {'tip', 'collagen', 'clinique', 'clinical', 'trial', 'valentine', 'change', 'climate', 'clip', 'brilliant', 'screaming'}
# ---
#
# {'april', 'policy', 'update', 'climate', 'change'}
# ---
#
# {'negotiator', 'april', 'intensify', 'release', 'climate', 'agree', 'change', 'press'}
# ---
#
# {'hapless', 'postpartisan', 'play', 'change', 'immigration', 'harry', 'climate', 'reid'}
# ---
#
# {'money', 'pour', 'california', 'delay', 'campaign', 'global', 'warming', 'foe'}
# ---
#
# {'obama', 'energy', 'director', 'carol', 'climate', 'office', 'live', 'chat', 'policy', 'admin', 'earth', 'change', 'browner'}
# ---
#
# {'climate', 'year', 'bill', 'pass', 'senate', 'chance', 'change', 'klein'}
# ---
#
# {'person', 'volcano', 'global', 'hear', 'connection', 'warming'}
# ---
#
# {'guess', 'nasa', 'global', 'fact', 'warming', 'think', 'notice', 'climate', 'change'}
# ---
#
# {'qualified', 'give', 'basic', 'group', 'environmental', 'meeting', 'praise', 'climate', 'change'}
# ---
#
# {'ellis', 'cause', 'news', 'april', 'human', 'global', 'americans', 'warming', 'good', 'believe'}
# ---
#
# {'global', 'million', 'warming', 'action', 'thousand', 'conscious', 'earth', 'heart'}
# ---
#
# {'global', 'assumption', 'warming', 'suggest', 'climate', 'datum'}
# ---
#
# {'claim', 'denier', 'fiction', 'global', 'fact', 'warming'}
# ---
#
# {'global', 'minnesotan', 'warming', 'fight', 'takedown', 'cast', 'youtube', 'interview'}
# ---
#
# {'effort', 'delay', 'calif', 'global', 'warming', 'ramp', 'opponent'}
# ---
#
# {'indigenous', 'earthweek', 'aware', 'right', 'climate', 'earth', 'world', 'people', 'bolivia', 'conference', 'change'}
# ---
#
# {'sorry', 'invitation', 'talk', 'able', 'accept', 'panelist', 'bolivia', 'climate', 'change'}
# ---
#
# {'scientist', 'sue', 'global', 'warming', 'debate', 'climate', 'poison', 'newspaper'}
# ---
#
# {'indigenous', 'arrive', 'climate', 'group', 'world', 'bolivia', 'people', 'sharifkouddous', 'conference', 'change'}
# ---
#
# {'peanut', 'water', 'global', 'warming', 'meat', 'grape', 'recycling', 'rare'}
# ---
#
# {'attorney', 'cuccinelli', 'force', 'file', 'virginia', 'global', 'reopen', 'warming', 'general', 'motion', 'finding'}
# ---
#
# {'safety', 'global', 'warming', 'silly', 'regulator', 'blankenship'}
# ---
#
# {'hair', 'collagen', 'nanogen', 'nanofiber', 'trial', 'bring', 'climate', 'change', 'clinical'}
# ---
#
# {'corner', 'street', 'urgh', 'counsel', 'sunday', 'item', 'element', 'global', 'certain', 'warm', 'myth', 'post', 'washington'}
# ---
#
# {'implication', 'regulation', 'commercial', 'environmental', 'climate', 'ready', 'change'}
# ---
#
# {'fellow', 'join', 'discuss', 'solution', 'live', 'expert', 'heather', 'real', 'roger', 'tonight', 'climate', 'change', 'james', 'hansen'}
# ---
#
# {'brace', 'california', 'plan', 'climate', 'change'}
# ---
#
# {'leave', 'plant', 'global', 'effective', 'account', 'tackle'}
# ---
#
# {'obama', 'glodman', 'well', 'shiiiiiitttt', 'sachs', 'fuck', 'degree', 'global', 'warming', 'plan'}
# ---
#
# {'leave', 'plant', 'global', 'effective', 'account', 'tackle'}
# ---
#
# {'future', 'sustainability', 'listen', 'economic', 'climate', 'change', 'development', 'driver'}
# ---
#
# {'alarm', 'discotech', 'frederic', 'bell', 'hague', 'climate', 'blink', 'change'}
# ---
#
# {'threaten', 'security', 'pentagon', 'general', 'america', 'know', 'consider', 'climate', 'change'}
# ---
#
# {'screw', 'go', 'general', 'know', 'climate', 'change'}
# ---
# {'cause', 'cancer', 'global', 'mental', 'warming', 'say', 'report', 'illness', 'government'}
# ---
#
# {'heat', 'increase', 'climate', 'flood', 'wave', 'change'}
# ---
#
# {'plant', 'global', 'effective', 'remain', 'warming', 'tackle'}
# ---
#
# {'get', 'class', 'global', 'student', 'heated', 'climate', 'deni', 'fault', 'discussion', 'change'}
# ---
#
# {'colorado', 'kill', 'global', 'warming', 'forest'}
# ---
#
# {'display', 'confirm', 'occur', 'environmental', 'climate', 'change'}
# ---
#
# {'europe', 'global', 'warming', 'place', 'true', 'foll', 'prediction', 'prove', 'disappear'}
# ---
#
# {'indigenous', 'combat', 'people', 'climate', 'change', 'lesson'}
# ---
#
# {'strong', 'action', 'bill', 'live', 'support', 'climate', 'change'}
# ---
#
# {'indigenous', 'fight', 'climate', 'tradition', 'change'}
# ---
#
# {'green', 'go', 'hope', 'solution', 'false', 'heather', 'real', 'roger', 'wrong', 'climate', 'change', 'james', 'hansen'}
# ---
#
# {'absorb', 'carbon', 'activist', 'climate', 'forest', 'change'}
# ---
#
# {'absorb', 'carbon', 'activist', 'climate', 'forest', 'change'}
# ---
#
# {'absorb', 'carbon', 'activist', 'climate', 'forest', 'change'}
# ---
#
# {'lose', 'mont', 'park', 'namesake', 'national', 'glaci', 'climate', 'change', 'melt'}
# ---
#
# {'absorb', 'carbon', 'activist', 'climate', 'forest', 'change'}
# ---
#
# {'absorb', 'carbon', 'activist', 'climate', 'forest', 'change'}
# ---
#
# {'absorb', 'carbon', 'climate', 'forest', 'change'}
# ---
#
# {'fall', 'morning', 'weather', 'thank', 'beautiful', 'york', 'climate', 'bleh', 'change'}
# ---
#
# {'fall', 'morning', 'weather', 'thank', 'beautiful', 'york', 'climate', 'bleh', 'change'}
# ---
#
# {'threaten', 'familiar', 'blossom', 'environment', 'change', 'culture', 'cherry', 'climate', 'japan'}
# ---
#
# {'stretch', 'apart', 'mountain', 'podcast', 'climate', 'change', 'valley', 'temp'}
# ---
#
# {'stretch', 'apart', 'mountain', 'climate', 'change', 'valley', 'temp'}
# ---
#
# {'absorb', 'carbon', 'activist', 'climate', 'forest', 'change'}
# ---
#
# {'april', 'global', 'rain', 'sign', 'arctic', 'canadian'}
# ---
#
# {'microbe', 'global', 'haven', 'conn', 'contribute'}
# ---
#
# {'microbe', 'global', 'haven', 'conn', 'contribute'}
# ---
#
# {'south', 'nation', 'foreign', 'fight', 'secluded', 'minister', 'climate', 'change', 'asian'}
# ---
#
# {'property', 'heat', 'increase', 'climate', 'death', 'damage', 'reuters', 'wave', 'change'}
# ---
#
# {'rogers', 'green', 'go', 'hope', 'solution', 'false', 'heather', 'real', 'wrong', 'climate', 'change', 'james', 'hansen'}
# ---
#
# {'seriously', 'wine', 'climate', 'industry', 'mean', 'love', 'frog', 'leap', 'change'}
# ---
#
# {'global', 'warming', 'report', 'whale', 'save'}
# ---
#
# {'contribution', 'organic', 'mitigation', 'agriculture', 'climate', 'change'}
# ---
#
# {'black', 'beauty', 'slide', 'effect', 'global', 'warming', 'alaska', 'arctic', 'white'}
# ---
#
# {'indicator', 'report', 'document', 'impact', 'study', 'real', 'climate', 'change'}
# ---
#
# {'prepare', 'green', 'ceo', 'global', 'keen', 'counterpart', 'impact', 'climate', 'change', 'canadian'}
# ---
#
# {'shortage', 'check', 'biochar', 'fight', 'food', 'support', 'post', 'climate', 'huffpo', 'change'}
# ---
#
# {'sure', 'fight', 'help', 'whale', 'doodoo', 'climate', 'change'}
# ---
#
# {'soil', 'news', 'carbon', 'global', 'science', 'warming', 'good', 'warm', 'world', 'release'}
# ---
#
# {'today', 'phoenix', 'snow', 'hmmmm', 'april', 'weather', 'global', 'warming', 'york'}
# ---
#
# {'high', 'rise', 'global', 'malaysia', 'temperature', 'average', 'level', 'lumpur'}
# ---
#
# {'west', 'unite', 'country', 'climate', 'mediterranean', 'change'}
# ---
#
# {'picken', 'speed', 'clean', 'write', 'global', 'estimate'}
# ---
#
# {'business', 'action', 'climate', 'create', 'change'}
# ---
#
# {'person', 'surprise', 'weather', 'degree', 'global', 'warming', 'anymore'}
# ---
#
# {'understand', 'human', 'dispersal', 'evolution', 'hear', 'report', 'variability', 'influence', 'climate', 'change', 'interesting'}
# ---
#
# {'effect', 'global', 'warming', 'pic', 'alaska'}
# ---
#
# {'energy', 'address', 'step', 'blog', 'city', 'mandate', 'benchmarking', 'post', 'climate', 'change'}
# ---
#
# {'claim', 'florida', 'realdocwatson', 'global', 'warming', 'year', 'antarctica', 'stake', 'like'}
# ---
#
# {'wine', 'global', 'warming', 'industry', 'trouble', 'agriculture', 'mean'}
# ---
#
# {'black', 'beauty', 'slide', 'effect', 'global', 'warming', 'alaska', 'arctic', 'white'}
# ---
#
# {'place', 'european', 'paris', 'photo', 'alp', 'climate', 'change', 'peril'}
# ---
#
# {'atmospheric', 'electoral', 'oceanic', 'know', 'national', 'administration', 'climate', 'change'}
# ---
#
# {'clean', 'mark', 'intensify', 'past', 'global', 'actually', 'warming', 'report', 'environmental', 'world', 'earth', 'week'}
# ---
#
# {'news', 'late', 'wild', 'global', 'warming', 'threat', 'frontier', 'round', 'blair'}
# ---
#
# {'prepare', 'kuna', 'indians', 'traditional', 'climate', 'sink', 'relocation', 'change', 'home'}
# ---
#
# {'kimberley', 'buzz', 'present', 'california', 'wine', 'califor', 'global', 'warming', 'change', 'climate', 'kill', 'cahill'}
# ---
#
# {'uncajoe', 'hate', 'politic', 'digg', 'climate', 'change', 'denial'}
# ---
#
# {'carbon', 'global', 'warming', 'fast', 'chemistry', 'ocean', 'change'}
# ---
#
# {'obama', 'sure', 'graham', 'imperil', 'agenda', 'douche', 'go', 'backass', 'good', 'world', 'climate', 'change'}
# ---
#
# {'city', 'thanksgiving', 'global', 'fight', 'resort', 'lake'}
# ---
#
# {'bat', 'lizard', 'important', 'bird', 'play', 'fight', 'insect', 'climate', 'change', 'eat'}
# ---
#
# {'cloud', 'contribution', 'green', 'change', 'climate', 'computing'}
# ---
#
# {'indigenous', 'extinct', 'plant', 'favor', 'specie', 'thoreau', 'one', 'climate', 'invasive', 'change'}
# ---
#
# {'scary', 'alter', 'early', 'day', 'climate', 'season', 'change', 'spring'}
# ---
#
# {'indigenous', 'morale', 'pre', 'people', 'climate', 'change', 'lesson'}
# ---
#
# {'tipping', 'mobilize', 'point', 'fight', 'science', 'climate', 'mediaglobal', 'report', 'event', 'special', 'earth', 'change'}
# ---
#
# {'colorado', 'kill', 'global', 'warming', 'forest'}
# ---
#
# {'indigenous', 'arrive', 'climat', 'combat', 'nations', 'united', 'world', 'people', 'climate', 'change', 'lesson'}
# ---
#
# {'continent', 'service', 'meteorology', 'vulnerable', 'africa', 'gear', 'climate', 'change'}
# ---
#
# {'credit', 'green', 'step', 'carbon', 'mention', 'living', 'daunting', 'gecko', 'climate', 'change'}
# ---
#
# {'expansion', 'china', 'global', 'fix', 'come', 'environmental', 'impact', 'world', 'rapid', 'sizable'}
# ---
#
# {'expansion', 'china', 'global', 'fix', 'come', 'environmental', 'impact', 'world', 'rapid', 'sizable'}
# ---
#
# {'local', 'green', 'go', 'examine', 'confront', 'check', 'yorker', 'york', 'listing', 'climate', 'change'}
# ---
#
# {'cause', 'nasa', 'report', 'official', 'climate', 'change'}
# ---
#
# {'coal', 'safety', 'rule', 'crazy', 'global', 'warming', 'call', 'silly'}
# ---
#
# {'health', 'human', 'extend', 'impact', 'climate', 'change'}
# ---
#
# {'health', 'human', 'extend', 'impact', 'climate', 'change'}
# ---
#
# {'news', 'rebecca', 'good', 'climate', 'change', 'solnit'}
# ---
#
# {'take', 'energy', 'efficiency', 'climate', 'alpha', 'change'}
# ---
#
# {'credit', 'green', 'step', 'carbon', 'mention', 'living', 'daunting', 'gecko', 'climate', 'change'}
# ---
#
# {'scientist', 'meteorologist', 'global', 'warming', 'variability', 'tell', 'natural', 'explain', 'climate', 'popular'}
# ---
#
# {'news', 'rebecca', 'degree', 'good', 'change', 'climate', 'solnit', 'inseparability'}
# ---
#
# {'threaten', 'mountain', 'climate', 'know', 'sacred', 'shangri', 'tibetan', 'watch', 'include', 'change', 'land', 'video'}
# ---
#
# {'service', 'meteorology', 'african', 'gear', 'climate', 'change'}
# ---
#
# {'climate', 'report', 'season', 'allergy', 'change', 'bad'}
# ---
#
# {'bill', 'accountability', 'save', 'climate', 'kill', 'change'}
# ---
#
# {'farmer', 'make', 'pastoralist', 'increasingly', 'ethiopia', 'vulnerable', 'climate', 'change'}
# ---
#
# {'denis', 'irish', 'compare', 'news', 'haye', 'weather', 'global', 'politic', 'climate', 'founder', 'irishcentral', 'famine', 'earth', 'change'}
# ---
#
# {'farmer', 'make', 'pastoralist', 'increasingly', 'ethiopia', 'vulnerable', 'climate', 'change'}
# ---
#
# {'waste', 'effect', 'treat', 'aware', 'global', 'place', 'warming', 'earthday', 'consume'}
# ---
#
# {'curb', 'climate', 'verwaayen', 'earth', 'change'}
# ---
#
# {'health', 'nation', 'feel', 'industrial', 'report', 'impact', 'climate', 'change'}
# ---
#
# {'health', 'nation', 'feel', 'industrial', 'report', 'impact', 'climate', 'change'}
# ---
# {'health', 'nation', 'feel', 'industrial', 'report', 'impact', 'climate', 'change'}
# ---
#
# {'credit', 'green', 'step', 'carbon', 'mention', 'living', 'daunting', 'gecko', 'climate', 'change'}
# ---
#
# {'biofuel', 'credit', 'green', 'step', 'carbon', 'mention', 'living', 'daunting', 'climate', 'change'}
# ---
#
# {'cost', 'reuter', 'raise', 'climate', 'allergy', 'change'}
# ---
#
# {'asilomar', 'curable', 'treat', 'disease', 'later', 'international', 'bioethicist', 'expert', 'climate', 'change'}
# ---
#
# {'asilomar', 'curable', 'treat', 'disease', 'later', 'international', 'bioethicist', 'expert', 'climate', 'change'}
# ---
#
# {'coal', 'safety', 'rule', 'crazy', 'global', 'warming', 'call', 'silly'}
# ---
#
# {'lead', 'fight', 'climate', 'military', 'change'}
# ---
#
# {'buyer', 'lead', 'fight', 'climate', 'fuel', 'government', 'large', 'military', 'change'}
# ---
#
# {'biofuel', 'credit', 'green', 'step', 'carbon', 'mention', 'living', 'daunting', 'climate', 'change'}
# ---
#
# {'cause', 'goldberg', 'global', 'main', 'say', 'fred', 'swedish', 'expert', 'climate'}
# ---
#
# {'green', 'curable', 'treat', 'disease', 'science', 'wire', 'climate', 'change'}
# ---
#
# {'local', 'green', 'go', 'examine', 'confront', 'check', 'yorker', 'york', 'listing', 'climate', 'thursday', 'change'}
# ---
#
# {'cooperation', 'secretary', 'global', 'seek', 'nations', 'dialogue', 'prevent', 'runaway', 'climate', 'change', 'united'}
# ---
#
# {'important', 'struggle', 'nigerian', 'bassey', 'environmentalist', 'nnimmo', 'event', 'climate', 'change'}
# ---
#
# {'lead', 'fight', 'climate', 'military', 'change'}
# ---
#
# {'health', 'identify', 'affctd', 'evrything', 'inclde', 'disease', 'mental', 'issue', 'report', 'stake', 'climate', 'change'}
# ---
#
# {'cope', 'resource', 'climate', 'earth', 'change'}
# ---
#
# {'saltiness', 'cycle', 'water', 'intensify', 'global', 'warming', 'ocean', 'show'}
# ---
#
# {'meal', 'anniver', 'time', 'americans', 'combat', 'celebrate', 'fedele', 'climate', 'change', 'bauccio', 'week'}
# ---
#
# {'live', 'conf', 'world', 'support', 'people', 'climate', 'change', 'cochabamba'}
# ---
#
# {'small', 'well', 'protocol', 'push', 'lot', 'climate', 'change', 'barrett', 'comprehensive'}
# ---
#
# {'topography', 'mountain', 'global', 'warming', 'rate', 'complicate'}
# ---
#
# {'climate', 'watch', 'live', 'world', 'support', 'people', 'bolivia', 'conference', 'change', 'cochabamba'}
# ---
#
# {'address', 'require', 'global', 'issue', 'universal', 'layer', 'operation', 'climate', 'ozone', 'change', 'smallpox'}
# ---
#
# {'subcontinent', 'point', 'spill', 'indian', 'contain', 'boiling', 'climate', 'change'}
# ---
#
# {'landslide', 'earthquake', 'warming', 'world', 'climate', 'change', 'trigger'}
# ---
#
# {'uruguay', 'tool', 'need', 'vulnerable', 'climate', 'change'}
# ---
#
# {'uruguay', 'tool', 'need', 'vulnerable', 'climate', 'change'}
# ---
#
# {'uruguay', 'tool', 'need', 'vulnerable', 'climate', 'change'}
# ---
#
# {'offset', 'carbon', 'global', 'warming', 'vatican', 'reduce', 'fail', 'forest'}
# ---
#
# {'poverty', 'vulnerability', 'increase', 'ethiopia', 'climate', 'change'}
# ---
#
# {'farmer', 'poverty', 'small', 'vulnerability', 'increase', 'scale', 'pastoralist', 'ethiopia', 'climate', 'change'}
# ---
#
# {'important', 'struggle', 'nigerian', 'bassey', 'environmentalist', 'nnimmo', 'event', 'climate', 'change'}
# ---
#
# {'important', 'struggle', 'nigerian', 'bassey', 'environmentalist', 'nnimmo', 'event', 'climate', 'change'}
# ---
#
# {'backgrounder', 'china', 'major', 'year', 'policy', 'climate', 'change', 'tackle'}
# ---
#
# {'steven', 'biologist', 'april', 'point', 'global', 'press', 'link', 'early', 'bloom'}
# ---
#
# {'steven', 'biologist', 'april', 'point', 'global', 'press', 'link', 'early', 'bloom'}
# ---
#
# {'volcano', 'iceland', 'global', 'warming', 'glacier', 'world', 'trigger'}
# ---
#
# {'volcano', 'iceland', 'global', 'warming', 'glacier', 'world', 'trigger'}
# ---
#
# {'future', 'katrina', 'rise', 'flood', 'warm', 'level', 'foot', 'wetter', 'climate', 'change', 'like'}
# ---
#
# {'geologist', 'future', 'troubling', 'sheet', 'fast', 'sign', 'come', 'antarctica', 'find', 'drill', 'climate', 'change', 'melt'}
# ---
#
# {'claim', 'conference', 'morale', 'climate', 'capitalism', 'die', 'mother', 'world', 'people', 'earth', 'change'}
# ---
#
# {'attack', 'increase', 'gift', 'global', 'warming', 'allergy'}
# ---
#
# {'bomb', 'await', 'time', 'africa', 'issue', 'change', 'environmental', 'climate', 'doubt'}
# ---
#
# {'offset', 'carbon', 'global', 'guilt', 'warming', 'ease', 'buy'}
# ---
#
# {'alrdy', 'global', 'warming', 'suffering', 'havechancetospeakout', 'eye', 'cochabamba'}
# ---
#
# {'specie', 'climate', 'recommend', 'ecomonday', 'discussion', 'invasive', 'change'}
# ---
#
# {'stay', 'bird', 'strategy', 'migratory', 'climate', 'change', 'home'}
# ---
#
# {'oxygen', 'cause', 'little', 'organism', 'global', 'floor', 'population', 'warming', 'ocean', 'despite'}
# ---
#
# {'destiny', 'join', 'security', 'climate', 'irreversible', 'food', 'earth', 'change', 'discussion'}
# ---
#
# {'city', 'york', 'plan', 'waterfront', 'consideration', 'climate', 'change'}
# ---
#
# {'geoengineere', 'manipulate', 'combat', 'climate', 'danger', 'planet', 'mooney', 'change'}
# ---
#
# {'get', 'seasonal', 'climate', 'allergy', 'change', 'bad'}
# ---
#
# {'instead', 'global', 'warming', 'think', 'peep', 'believe'}
# ---
#
# {'get', 'seasonal', 'climate', 'allergy', 'change', 'bad'}
# ---
#
# {'property', 'dead', 'oceanfront', 'global', 'warming', 'live', 'think', 'advise'}
# ---
#
# {'cap', 'volcanic', 'global', 'warming', 'help', 'trigger', 'eruption', 'melt'}
# ---
#
# {'clim', 'address', 'sustainability', 'john', 'mary', 'ellen', 'win', 'harte', 'climate', 'change', 'heart'}
# ---
#
# {'primarily', 'human', 'global', 'induce', 'warming', 'state', 'dept', 'declare', 'unequivocal'}
# ---
#
# {'increasingly', 'corporation', 'real', 'conclude', 'climate', 'bet', 'change'}
# ---
#
# {'message', 'branson', 'right', 'global', 'richard', 'earthday', 'house'}
# ---
#
# {'cynthia', 'animal', 'make', 'wise', 'monday', 'global', 'warming', 'meat', 'agriculture', 'bad', 'bateman'}
# ---
#
# {'cap', 'volcanic', 'global', 'warming', 'help', 'trigger', 'eruption', 'melt'}
# ---
#
# {'primarily', 'human', 'global', 'induce', 'warming', 'state', 'dept', 'declare', 'unequivocal'}
# ---
#
# {'cap', 'volcanic', 'global', 'warming', 'trigger', 'eruption', 'melt'}
# ---
#
# {'idea', 'class', 'global', 'fix', 'warming', 'come', 'sigh', 'love', 'environmentalism', 'kind'}
# ---
#
# {'green', 'go', 'increase', 'revolution', 'global', 'warming', 'awareness', 'threat', 'overview'}
# ---
#
# {'southe', 'compete', 'high', 'southern', 'water', 'limpopo', 'africa', 'temperature', 'bring', 'climate', 'change'}
# ---
#
# {'strike', 'iceland', 'global', 'hekla', 'year', 'warming', 'spill', 'earth', 'eruption'}
# ---
#
# {'place', 'america', 'photo', 'climate', 'change'}
# ---
#
# {'bangor', 'important', 'episcopal', 'time', 'daily', 'climate', 'issue', 'maine', 'lane', 'bishop', 'change'}
# ---
#
# {'volcano', 'iceland', 'wonder', 'case', 'impact', 'climate', 'change'}
# ---
#
# {'heat', 'cool', 'thing', 'global', 'warming', 'interest', 'honest', 'discussion'}
# ---
#
# {'bird', 'billion', 'pattern', 'migration', 'climate', 'change'}
# ---
#
# {'place', 'america', 'photo', 'climate', 'change'}
# ---
#
# {'cloud', 'volcanic', 'hazardous', 'spark', 'global', 'warming', 'trigger', 'change'}
# ---
#
# {'cloud', 'volcanic', 'hazardous', 'spark', 'global', 'warming', 'trigger', 'change'}
# ---
#
# {'get', 'volcano', 'slow', 'brief', 'global', 'stratosphere', 'wonder', 'warming', 'cooling', 'improve'}
# ---
#
# {'obama', 'china', 'thursd', 'april', 'president', 'wait', 'say', 'climate', 'change', 'sydney', 'barack'}
# ---
#
# {'volcano', 'lately', 'denier', 'jindal', 'mock', 'warning', 'paper', 'climate', 'think', 'read', 'bobby', 'change', 'start'}
# ---
#
# {'get', 'adapt', 'merte', 'preview', 'cara', 'strand', 'weekend', 'climate', 'change', 'sneak', 'tedxvolcano'}
# ---
#
# {'important', 'larry', 'thing', 'socmedia', 'fight', 'face', 'science', 'single', 'change', 'climate', 'brilliant', 'tedxvolcano'}
# ---
#
# {'important', 'green', 'larry', 'thing', 'fight', 'face', 'science', 'single', 'change', 'socent', 'climate', 'brilliant', 'tedxvolcano'}
# ---
#
# {'damn', 'cloud', 'get', 'volcano', 'europe', 'crazy', 'global', 'warming', 'activating'}
# ---
#
# {'attack', 'larry', 'crisis', 'science', 'change', 'exacerbate', 'climate', 'brilliant', 'tedxvolcano'}
# ---
# {'oslo', 'cause', 'volcano', 'jonah', 'goldberg', 'iceland', 'global', 'warming', 'reuters', 'thaw', 'eruption'}
# ---
#
# {'conversation', 'indigenous', 'voice', 'bring', 'climate', 'change'}
# ---
#
# {'volcano', 'awaken', 'volcanic', 'icelandic', 'change', 'climate', 'thaw', 'activity'}
# ---
#
# {'south', 'nikolas', 'amazon', 'kozloff', 'rain', 'affect', 'entire', 'climate', 'change'}
# ---
#
# {'place', 'america', 'photo', 'climate', 'change'}
# ---
#
# {'bury', 'volcano', 'iceland', 'global', 'warming', 'hmmm', 'glacier', 'lede', 'melt'}
# ---
#
# {'sure', 'volcano', 'scientist', 'lead', 'consensus', 'crisis', 'warn', 'climate', 'change', 'melt'}
# ---
#
# {'right', 'climate', 'mother', 'earth', 'world', 'people', 'wish', 'conference', 'change', 'cochabamba'}
# ---
#
# {'high', 'make', 'feel', 'near', 'record', 'seasonal', 'climate', 'allergy', 'change', 'bad', 'spring'}
# ---
#
# {'high', 'make', 'near', 'record', 'seasonal', 'climate', 'allergy', 'change', 'bad', 'spring'}
# ---
#
# {'disrupt', 'volcanic', 'icelandic', 'travel', 'change', 'glaci', 'climate', 'thaw', 'eruption', 'like'}
# ---
#
# {'combat', 'change', 'approach', 'climate', 'offer', 'summit', 'cochabamba'}
# ---
#
# {'user', 'power', 'environment', 'remind', 'simple', 'computer', 'climate', 'change', 'workin'}
# ---
#
# {'connecticut', 'reason', 'concern', 'renewal', 'bring', 'climate', 'perspective'}
# ---
#
# {'renewable', 'switch', 'scientist', 'long', 'warn', 'global', 'warming', 'accelerate', 'need'}
# ---
#
# {'pollen', 'count', 'culprit', 'climate', 'change', 'chart'}
# ---
#
# {'coalition', 'tired', 'fight', 'wait', 'ground', 'level', 'climate', 'change'}
# ---
#
# {'wednesday', 'climate', 'report', 'national', 'wildlife', 'release', 'season', 'allergy', 'change', 'worsen'}
# ---
#
# {'coalition', 'tired', 'fight', 'wait', 'ground', 'level', 'climate', 'change'}
# ---
#
# {'author', 'south', 'nikola', 'kozloff', 'amazon', 'rain', 'america', 'affect', 'entire', 'planet', 'climate', 'change'}
# ---
#
# {'coalition', 'tired', 'fight', 'wait', 'ground', 'level', 'climate', 'change'}
# ---
#
# {'coalition', 'tired', 'fight', 'wait', 'ground', 'level', 'climate', 'change'}
# ---
#
# {'coalition', 'tired', 'fight', 'wait', 'ground', 'level', 'climate', 'change'}
# ---
#
# {'climate', 'report', 'season', 'allergy', 'change', 'bad'}
# ---
#
# {'finnish', 'purportedly', 'refute', 'article', 'global', 'mention', 'warming', 'denialist', 'cute', 'send', 'newspaper'}
# ---
#
# {'energy', 'fight', 'global', 'industry', 'nationalize', 'warming', 'necessary'}
# ---
#
# {'cloud', 'volcano', 'slow', 'volcanic', 'iceland', 'intensify', 'global', 'vast', 'eruption', 'likely'}
# ---
#
# {'blame', 'global', 'warming', 'reading', 'allergy', 'bad'}
# ---
#
# {'leave', 'indigenous', 'curb', 'partnership', 'group', 'population', 'conservation', 'climate', 'forest', 'change'}
# ---
#
# {'problem', 'tbagger', 'say', 'think', 'climate', 'change', 'ignorant'}
# ---
#
# {'future', 'heat', 'miss', 'affect', 'climate', 'change'}
# ---
#
# {'green', 'climate', 'change', 'economy', 'build'}
# ---
#
# {'threaten', 'park', 'national', 'glaci', 'montana', 'climate', 'change', 'economy'}
# ---
#
# {'cost', 'york', 'raise', 'climate', 'allergy', 'change'}
# ---
#
# {'population', 'climate', 'change', 'perspective', 'ecotone'}
# ---
#
# {'county', 'blame', 'ventura', 'migration', 'whale', 'dwindle', 'coastal', 'climate', 'change'}
# ---
#
# {'wait', 'kick', 'think', 'climate', 'allergy', 'change', 'michig'}
# ---
#
# {'cost', 'reuter', 'exclusive', 'raise', 'climate', 'change'}
# ---
#
# {'little', 'late', 'global', 'year', 'warming', 'storm', 'season', 'start', 'spring'}
# ---
#
# {'drought', 'effect', 'test', 'weather', 'kenya', 'pastoralist', 'perception', 'climate', 'change', 'extreme'}
# ---
#
# {'baseball', 'curve', 'major', 'denier', 'change', 'league', 'team', 'climate', 'throw'}
# ---
#
# {'endanger', 'place', 'newsweek', 'save', 'climate', 'change'}
# ---
#
# {'absorb', 'plant', 'birthday', 'global', 'warming', 'help', 'reduce', 'tree'}
# ---
#
# {'kerry', 'energy', 'lead', 'green', 'multiple', 'benefit', 'bill', 'states', 'climate', 'change', 'united'}
# ---
#
# {'green', 'internet', 'fight', 'change', 'climate', 'computing'}
# ---
#
# {'business', 'cleantechnica', 'action', 'climate', 'create', 'change'}
# ---
#
# {'green', 'internet', 'fight', 'change', 'software', 'climate', 'computing'}
# ---
#
# {'call', 'document', 'leak', 'climate', 'change', 'tackle'}
# ---
#
# {'endanger', 'place', 'newsweek', 'save', 'climate', 'change'}
# ---
#
# {'stop', 'reinvent', 'city', 'climate', 'change'}
# ---
#
# {'icon', 'park', 'change', 'national', 'glaci', 'climate', 'continue', 'melt'}
# ---
#
# {'endanger', 'place', 'newsweek', 'save', 'climate', 'change'}
# ---
#
# {'endanger', 'place', 'newsweek', 'save', 'climate', 'change'}
# ---
#
# {'society', 'dhabi', 'face', 'flood', 'threat', 'culture', 'expert', 'climate', 'arabia', 'change'}
# ---
#
# {'active', 'china', 'president', 'humani', 'say', 'vice', 'climate', 'change', 'tackle'}
# ---
#
# {'active', 'china', 'say', 'climate', 'change', 'tackle'}
# ---
#
# {'hard', 'asia', 'study', 'climate', 'change'}
# ---
#
# {'action', 'help', 'habitat', 'wildlife', 'climate', 'change', 'protect'}
# ---
#
# {'obama', 'china', 'soon', 'climate', 'change'}
# ---
#
# {'action', 'help', 'habitat', 'wildlife', 'climate', 'change', 'protect'}
# ---
#
# {'action', 'help', 'habitat', 'wildlife', 'climate', 'change', 'protect'}
# ---
#
# {'action', 'help', 'habitat', 'wildlife', 'climate', 'change', 'protect'}
# ---
#
# {'petition', 'congress', 'action', 'demand', 'sign', 'climate', 'change'}
# ---
#
# {'carbon', 'legislation', 'climate', 'kill', 'change'}
# ---
#
# {'obama', 'china', 'wait', 'say', 'allow', 'climate', 'change', 'tackle', 'interview'}
# ---
#
# {'claim', 'cause', 'cancer', 'global', 'warming', 'government'}
# ---
#
# {'claim', 'cause', 'cancer', 'global', 'warming', 'government'}
# ---
#
# {'habitat', 'wildlife', 'climate', 'change', 'protect'}
# ---
#
# {'brace', 'california', 'plan', 'climate', 'change'}
# ---
#
# {'action', 'help', 'habitat', 'wildlife', 'climate', 'change', 'protect'}
# ---
#
# {'stop', 'involve', 'global', 'warming', 'greenpeac', 'greenpeace', 'work'}
# ---
#
# {'action', 'help', 'habitat', 'wildlife', 'climate', 'change', 'protect'}
# ---
#
# {'cause', 'cancer', 'global', 'mental', 'warming', 'say', 'report', 'illness', 'government'}
# ---
#
# {'company', 'publically', 'risk', 'warn', 'investor', 'hold', 'climate', 'advise', 'change'}
# ---
#
# {'long', 'snake', 'come', 'aisle', 'debate', 'climate', 'change', 'dawdle', 'gore'}
# ---
#
# {'mean', 'trouble', 'wrath', 'agriculture', 'grape', 'climate', 'change'}
# ---
#
# {'blame', 'goldberg', 'jonah', 'time', 'global', 'warming', 'magazine', 'allergy', 'bad'}
# ---
#
# {'get', 'climate', 'allergy', 'change', 'bad'}
# ---
#
# {'clean', 'dim', 'intensify', 'actually', 'global', 'watch'}
# ---
#
# {'developed', 'cause', 'time', 'country', 'poor', 'affect', 'world', 'people', 'disaster', 'climate', 'change', 'likely'}
# ---
#
# {'blame', 'goldberg', 'jonah', 'time', 'global', 'warming', 'magazine', 'allergy', 'bad'}
# ---
#
# {'management', 'science', 'italy', 'programme', 'climate', 'change'}
# ---
#
# {'ethiopian', 'rural', 'devastating', 'community', 'climate', 'oxfam', 'change'}
# ---
#
# {'alternative', 'spur', 'alexi', 'technology', 'development', 'global', 'ilsen', 'warming', 'price', 'pollutant', 'believe', 'put'}
# ---
#
# {'green', 'push', 'olympic', 'action', 'athlete', 'climate', 'change'}
# ---
#
# {'stop', 'involve', 'global', 'warming', 'greenpeace', 'work'}
# ---
#
# {'health', 'effect', 'human', 'extend', 'impact', 'deal', 'climate', 'change'}
# ---
#
# {'cause', 'unprecedented', 'ocean', 'chemistry', 'rate', 'climate', 'change'}
# ---
#
# {'blame', 'global', 'warming', 'allergy', 'bad'}
# ---
#
# {'bat', 'lizard', 'bird', 'fight', 'wire', 'climate', 'change'}
# ---
#
# {'petition', 'action', 'sign', 'earthday', 'climate', 'change'}
# ---
#
# {'curable', 'treat', 'disease', 'climate', 'change'}
# ---
#
# {'debate', 'time', 'global', 'herald', 'warming', 'keep', 'vallejo', 'editorial', 'honest', 'believe'}
# ---
#
# {'address', 'solution', 'motorola', 'challenge', 'climate', 'change', 'work', 'member'}
# ---
#
# {'bolivian', 'blame', 'president', 'global', 'warming', 'capitalism'}
# ---
#
# {'election', 'like', 'solve', 'point', 'global', 'warming', 'politician', 'macro', 'need', 'interesting', 'immediate', 'prob'}
# ---
#
# {'attack', 'increase', 'gift', 'global', 'warming', 'allergy'}
# ---
#
# {'continent', 'effect', 'animation', 'global', 'climate', 'download', 'change', 'view'}
# ---
#
# {'petition', 'hint', 'lawmaker', 'change', 'tell', 'sign', 'drop', 'climate', 'ready', 'know'}
# ---
#
# {'emission', 'carbon', 'expand', 'policy', 'goal', 'climate', 'change', 'reduction'}
# ---
#
# {'primarily', 'human', 'global', 'induce', 'warming', 'state', 'dept', 'declare', 'unequivocal'}
# ---
#
# {'snowy', 'blame', 'earl', 'global', 'thank', 'warming', 'unusually', 'winter', 'follow', 'allergy', 'cold', 'bad'}
# ---
#
# {'ridiculous', 'denier', 'give', 'palin', 'nature', 'sarah', 'climate', 'discovery', 'change'}
# ---
#
# {'climate', 'report', 'suck', 'read', 'season', 'allergy', 'change', 'bad'}
# ---
#
# {'effort', 'coda', 'technology', 'combat', 'climate', 'pollution', 'automotive', 'change', 'laud', 'innovation'}
# ---
#
# {'claim', 'blame', 'increase', 'report', 'climate', 'allergy', 'change'}
# ---
#
# {'claim', 'blame', 'increase', 'report', 'climate', 'allergy', 'change'}
# ---
#
# {'april', 'global', 'chicago', 'warming', 'love', 'tulip'}
# ---
#
# {'globalwarme', 'hard', 'global', 'americans', 'warming', 'asthma', 'climatewire', 'bad', 'allergy', 'million', 'hit'}
# ---
#
# {'april', 'nice', 'global', 'degree', 'warming', 'hellooo', 'meet'}
# ---
#
# {'rejoice', 'adapt', 'relative', 'time', 'article', 'wild', 'mention', 'agriculture', 'crop', 'climate', 'change'}
# ---
#
# {'call', 'document', 'climate', 'change', 'tackle'}
# ---
# {'call', 'document', 'climate', 'change', 'tackle'}
# ---
#
# {'usgs', 'go', 'park', 'global', 'warming', 'namesake', 'report', 'glacier'}
# ---
#
# {'heat', 'feel', 'come', 'jackson', 'institute', 'climate', 'erwin', 'change'}
# ---
#
# {'democracy', 'college', 'lead', 'mobilise', 'schumacher', 'climate', 'change', 'tackle'}
# ---
#
# {'cost', 'exclusive', 'raise', 'climate', 'allergy', 'change'}
# ---
#
# {'health', 'environmental', 'study', 'receive', 'impact', 'harvard', 'climate', 'change', 'million'}
# ---
#
# {'today', 'lead', 'write', 'hill', 'climate', 'change', 'kerry'}
# ---
#
# {'cost', 'exclusive', 'raise', 'climate', 'allergy', 'change'}
# ---
#
# {'fortunegreen', 'chouinard', 'patagonia', 'global', 'warming', 'industry', 'place', 'yvon', 'clothing', 'start'}
# ---
#
# {'fight', 'filmmaker', 'travel', 'change', 'people', 'climate', 'globe', 'find'}
# ---
#
# {'fight', 'filmmaker', 'travel', 'change', 'people', 'climate', 'globe', 'find'}
# ---
#
# {'spur', 'effort', 'energy', 'future', 'harm', 'fight', 'global', 'warming', 'oilspill', 'america', 'remake', 'gulf'}
# ---
#
# {'person', 'life', 'unemployment', 'average', 'think', 'planet', 'climate', 'change', 'decade', 'catastrophic'}
# ---
#
# {'zealand', 'get', 'global', 'research', 'warming', 'accelerate', 'arctic', 'topnew', 'loss', 'bad'}
# ---
#
# {'take', 'lead', 'california', 'climate', 'change'}
# ---
#
# {'leave', 'plant', 'global', 'warming', 'effective', 'account', 'washington', 'tackle'}
# ---
#
# {'namibia', 'active', 'govt', 'climate', 'change'}
# ---
#
# {'plant', 'global', 'warming', 'effective', 'tackle'}
# ---
#
# {'idea', 'human', 'induce', 'wait', 'global', 'warming', 'natural', 'climate', 'change'}
# ---
#
# {'threaten', 'security', 'general', 'america', 'read', 'climate', 'change'}
# ---
#
# {'unplug', 'earthweek', 'global', 'warming', 'diary', 'planet', 'glacial', 'eruption', 'melt', 'volcanos'}
# ---
#
# {'threaten', 'climate', 'general', 'military', 'change', 'admiral'}
# ---
#
# {'threaten', 'obama', 'climate', 'shore', 'urge', 'expand', 'wildlife', 'drilling', 'change', 'contribute'}
# ---
#
# {'news', 'frozen', 'global', 'warming', 'reach', 'temperature', 'warm', 'allgov', 'canada'}
# ---
#
# {'cause', 'cancer', 'global', 'mental', 'warming', 'say', 'report', 'illness', 'government', 'warmin'}
# ---
#
# {'obama', 'adviser', 'john', 'pick', 'global', 'warming', 'science', 'say', 'holdren', 'steam'}
# ---
#
# {'disease', 'cost', 'billion', 'year', 'climate', 'change', 'pricy', 'lyme'}
# ---
#
# {'antarc', 'check', 'carry', 'global', 'warming', 'excrement', 'states', 'whale', 'researcher', 'topnews', 'australian', 'united'}
# ---
#
# {'cause', 'cancer', 'matt', 'cover', 'global', 'mental', 'warming', 'say', 'report', 'illness', 'government', 'staff', 'writer'}
# ---
#
# {'proble', 'proof', 'global', 'warming', 'report', 'whale', 'save', 'need'}
# ---
#
# {'effect', 'wine', 'warn', 'global', 'warming', 'good', 'system', 'grape', 'early'}
# ---
#
# {'effect', 'wine', 'warn', 'global', 'warming', 'good', 'system', 'grape', 'early'}
# ---
#
# {'indicator', 'global', 'warming', 'report', 'evidence', 'show', 'climate', 'change'}
# ---
#
# {'resource', 'indicator', 'global', 'defense', 'warming', 'report', 'counc', 'natural', 'evidence', 'show', 'climate', 'change'}
# ---
#
# {'syed', 'husin', 'effect', 'global', 'malaysia', 'warming', 'know', 'want'}
# ---
#
# {'convinced', 'mayeda', 'star', 'preuitt', 'voyage', 'global', 'fight', 'warming', 'whale', 'trek', 'lori', 'home'}
# ---
#
# {'touch', 'global', 'fact', 'warming', 'charle', 'case', 'reliable', 'support', 'recent', 'kesner', 'letter', 'writer'}
# ---
#
# {'threaten', 'health', 'study', 'climate', 'change'}
# ---
#
# {'effect', 'slideshow', 'global', 'warming', 'alaska'}
# ---
#
# {'vino', 'verita', 'effect', 'wine', 'warn', 'global', 'warming', 'good', 'system', 'grape', 'early', 'delicate'}
# ---
#
# {'specie', 'provide', 'gift', 'international', 'help', 'conservation', 'prevent', 'habitat', 'endangered', 'climate', 'change'}
# ---
#
# {'specie', 'provide', 'gift', 'international', 'help', 'conservation', 'prevent', 'habitat', 'endangered', 'climate', 'change'}
# ---
#
# {'rapidly', 'council', 'increase', 'global', 'acidification', 'warming', 'research', 'warn', 'ocean', 'national', 'contribute'}
# ---
#
# {'threaten', 'global', 'southernmost', 'warming', 'locality', 'province'}
# ---
#
# {'local', 'global', 'warming', 'storming', 'mean'}
# ---
#
# {'clean', 'mark', 'intensify', 'past', 'global', 'actually', 'warming', 'world', 'staff', 'earth'}
# ---
#
# {'renewable', 'saltiness', 'energy', 'pull', 'global', 'warming', 'advance', 'salinity', 'ocean', 'show', 'datum', 'million'}
# ---
#
# {'steven', 'energy', 'china', 'late', 'secretary', 'global', 'fix', 'warming', 'magazine', 'november'}
# ---
#
# {'carbon', 'global', 'warming', 'fast', 'year', 'chemistry', 'ocean', 'change'}
# ---
#
# {'concl', 'sciencedaily', 'topography', 'mountain', 'global', 'warming', 'study', 'rate', 'complicate'}
# ---
#
# {'blame', 'attribute', 'mercury', 'environmentalist', 'global', 'soar'}
# ---
#
# {'gathering', 'crisis', 'global', 'climate', 'africa', 'environmental', 'warming', 'monitor', 'present', 'change'}
# ---
#
# {'volcanic', 'plane', 'global', 'warming', 'help', 'reduce'}
# ---
#
# {'strong', 'discover', 'nasa', 'global', 'ocean', 'despite', 'current'}
# ---
#
# {'strong', 'discover', 'nasa', 'global', 'ocean', 'despite', 'current'}
# ---
#
# {'cause', 'bird', 'long', 'global', 'journey', 'fashion', 'warming', 'migration', 'distance', 'evolutionary', 'change', 'sourc'}
# ---
#
# {'heat', 'increase', 'conservative', 'earth', 'core', 'comment', 'funniest', 'climate', 'change'}
# ---
#
# {'life', 'rhode', 'island', 'scientist', 'long', 'global', 'warming', 'affect', 'marine', 'flounder', 'narragansett', 'winter'}
# ---
#
# {'architect', 'locally', 'environmentally', 'stupid', 'theimer', 'james', 'global', 'warming', 'know', 'redd', 'doubter'}
# ---
#
# {'program', 'maintain', 'global', 'look', 'warming', 'help', 'planting', 'pre', 'natural', 'reduce', 'indonesia', 'tree'}
# ---
#
# {'health', 'endanger', 'climate', 'report', 'earth', 'change'}
# ---
#
# {'cause', 'chapmanu', 'wlliam', 'cubeyond', 'say', 'matter', 'deal', 'happen', 'climate', 'change'}
# ---
#
# {'animal', 'focus', 'way', 'cause', 'plant', 'specie', 'redistribution', 'global', 'warming', 'chew'}
# ---
#
# {'lead', 'fight', 'climate', 'military', 'change'}
# ---
#
# {'chan', 'society', 'hazardous', 'geosphere', 'stunner', 'global', 'warming', 'activity', 'link', 'period', 'exceptional', 'climate', 'royal'}
# ---
#
# {'gunther', 'poverty', 'global', 'fight', 'africa', 'warming', 'rarely', 'comment', 'marc', 'view'}
# ---
#
# {'lead', 'fight', 'reuter', 'climate', 'military', 'change'}
# ---
#
# {'day', 'come', 'change', 'climate', 'early', 'spring'}
# ---
#
# {'launch', 'nasa', 'supercomputer', 'climate', 'change'}
# ---
#
# {'limit', 'climate', 'environmental', 'policy', 'economic', 'change', 'option', 'excellent'}
# ---
#
# {'discuss', 'child', 'family', 'woman', 'community', 'tonight', 'climate', 'change'}
# ---
#
# {'baby', 'global', 'warming', 'boomer', 'enjoy', 'anonymous', 'large', 'peace', 'tackle'}
# ---
#
# {'saltiness', 'treehugger', 'cycle', 'water', 'intensify', 'global', 'warming', 'ocean', 'show'}
# ---
#
# {'emission', 'trade', 'greenhouse', 'daniel', 'climate', 'plan', 'system', 'bring', 'esty', 'change'}
# ---
#
# {'lead', 'fight', 'climate', 'large', 'government', 'reuters', 'military', 'washington', 'change'}
# ---
#
# {'shorten', 'implicate', 'bird', 'global', 'warming', 'science', 'migration', 'codex'}
# ---
#
# {'gift', 'supercomputer', 'climate', 'earth', 'change'}
# ---
#
# {'emission', 'trade', 'greenhouse', 'daniel', 'climate', 'plan', 'system', 'bring', 'esty', 'change'}
# ---
#
# {'biologist', 'global', 'warming', 'link', 'early', 'bloom'}
# ---
#
# {'plant', 'biologist', 'global', 'central', 'warming', 'say', 'flower', 'link', 'wisconsin', 'researcher', 'early', 'bloom'}
# ---
#
# {'bolivian', 'blame', 'news', 'service', 'april', 'president', 'global', 'warming', 'environment', 'capitalism', 'bolivia', 'cochabamba'}
# ---
#
# {'geopolitic', 'uruguay', 'tool', 'global', 'site', 'need', 'vulnerable', 'climate', 'change', 'acosta'}
# ---
#
# {'idea', 'cure', 'volcano', 'global', 'warming', 'explosive'}
# ---
#
# {'indigenous', 'leader', 'woman', 'national', 'live', 'climate', 'change'}
# ---
#
# {'worldnew', 'series', 'city', 'happen', 'climate', 'change'}
# ---
#
# {'scheme', 'offset', 'carbon', 'global', 'warming', 'science', 'vatican', 'christian', 'reduce', 'fail', 'monitor', 'forest'}
# ---
#
# {'offset', 'carbon', 'global', 'guilt', 'warming', 'ease', 'buy'}
# ---
#
# {'geoengineere', 'manipulate', 'combat', 'climate', 'danger', 'planet', 'mooney', 'change'}
# ---
#
# {'volcano', 'opar', 'captur', 'icelandic', 'green', 'bird', 'nasa', 'global', 'warming', 'impact', 'alisa', 'transportation', 'satellite'}
# ---
# {'suffer', 'bird', 'southern', 'global', 'warming', 'england'}
# ---
#
# {'get', 'focus', 'climate', 'change', 'video'}
# ---
#
# {'cloud', 'volcano', 'volcanic', 'global', 'warming', 'trigger'}
# ---
#
# {'blame', 'alter', 'financial', 'global', 'warming', 'european', 'collapse', 'traffic'}
# ---
#
# {'sense', 'effort', 'republicans', 'make', 'global', 'warming', 'environmental', 'oppose'}
# ---
#
# {'energy', 'safe', 'solution', 'secure', 'climate', 'change', 'nuclear'}
# ---
#
# {'eyjafjoell', 'volcano', 'global', 'warming', 'trigger'}
# ---
#
# {'primarily', 'human', 'global', 'induce', 'warming', 'state', 'dept', 'declare', 'unequivocal'}
# ---
#
# {'global', 'action', 'warming', 'report', 'release', 'climate', 'unequivocal'}
# ---
#
# {'cap', 'volcanic', 'global', 'warming', 'help', 'trigger', 'eruption', 'melt'}
# ---
#
# {'dare', 'tell', 'photo', 'real', 'climate', 'change'}
# ---
#
# {'brian', 'treehugger', 'brooklyn', 'global', 'action', 'warming', 'report', 'merchant', 'release', 'climate', 'unequivocal'}
# ---
#
# {'volcano', 'icelandic', 'earthquake', 'global', 'hekla', 'warming', 'nature', 'mother'}
# ---
#
# {'blame', 'volcano', 'global', 'warming', 'trouble'}
# ---
#
# {'health', 'scientist', 'global', 'warming', 'politician', 'reminder', 'nearly', 'debate', 'agree'}
# ---
#
# {'volcano', 'icelandic', 'earthquake', 'global', 'hekla', 'warming', 'ashtag', 'mother', 'earth'}
# ---
#
# {'biden', 'romm', 'climate', 'quote', 'change'}
# ---
#
# {'idea', 'stop', 'reinvent', 'green', 'city', 'living', 'climate', 'change'}
# ---
#
# {'baseball', 'curve', 'major', 'denier', 'cleantechnica', 'change', 'league', 'team', 'climate', 'throw'}
# ---
#
# {'global', 'pollution', 'pirate', 'warming', 'lack'}
# ---
#
# {'habit', 'bird', 'migrating', 'global', 'billion', 'warming', 'estimate', 'change', 'decade'}
# ---
#
# {'magmatic', 'global', 'reuter', 'warming', 'tell', 'system', 'influence', 'melt'}
# ---
#
# {'upper', 'reporting', 'effect', 'increase', 'global', 'warming', 'sediment', 'atmospher', 'reduce'}
# ---
#
# {'volcanic', 'heat', 'lessens', 'thing', 'global', 'warming', 'travel', 'good', 'block'}
# ---
#
# {'speed', 'news', 'clean', 'global', 'pollution', 'warming'}
# ---
#
# {'global', 'call', 'document', 'leak', 'climate', 'regime', 'change', 'tackle'}
# ---
#
# {'aerosol', 'speed', 'clean', 'global', 'warming', 'pollution', 'help', 'downswe'}
# ---
#
# {'aerosol', 'speed', 'clean', 'global', 'warming', 'pollution', 'help', 'downswe'}
# ---
#
# {'today', 'news', 'effect', 'global', 'warming', 'youtube', 'stat'}
# ---
#
# {'global', 'warm', 'read', 'climate', 'change'}
# ---
#
# {'today', 'blog', 'global', 'greenhous', 'warming', 'reduce', 'archive', 'present', 'tackle'}
# ---
#
# {'effort', 'coda', 'combat', 'climate', 'pollution', 'automotive', 'change', 'laud'}
# ---
#
# {'austral', 'saltiness', 'blame', 'get', 'scientist', 'indyposte', 'weird', 'blog', 'global', 'conduct', 'warming', 'ocean', 'study'}
# ---
#
# {'explore', 'scientist', 'evolution', 'science', 'climate', 'change'}
# ---
#
# {'explore', 'scientist', 'evolution', 'science', 'climate', 'change'}
# ---
#
# {'coalition', 'tired', 'fight', 'wait', 'ground', 'level', 'climate', 'change'}
# ---
#
# {'money', 'justice', 'mazmanian', 'social', 'state', 'keston', 'sppd', 'need', 'climate', 'change', 'adaption', 'prof', 'press'}
# ---
#
# {'volcano', 'slow', 'scientist', 'iceland', 'unlikely', 'global', 'warming'}
# ---
#
# {'explore', 'scientist', 'evolution', 'science', 'climate', 'change'}
# ---
#
# {'volcano', 'slow', 'volcanic', 'scientist', 'iceland', 'unlikely', 'global', 'warming', 'cooling', 'paris', 'eruption'}
# ---
#
# {'bat', 'history', 'unio', 'global', 'face', 'warming', 'london', 'threat', 'bizarre', 'european', 'follow', 'cricket'}
# ---
#
# {'volcano', 'slow', 'ingham', 'unlikely', 'afpapril', 'global', 'warming', 'richard', 'image', 'satellite', 'eumesat'}
# ---
#
# {'explore', 'scientist', 'evolution', 'science', 'climate', 'change'}
# ---
#
# {'effect', 'global', 'teach', 'warming', 'year', 'climate', 'preach', 'catastrophic'}
# ---
#
# {'explore', 'scientist', 'evolution', 'science', 'climate', 'change'}
# ---
#
# {'obama', 'china', 'president', 'global', 'wait', 'warming', 'say', 'commit', 'world', 'tackle', 'barack'}
# ---
#
# {'renewable', 'energy', 'alumnus', 'solution', 'takei', 'global', 'warming', 'possible', 'deal', 'university', 'milton'}
# ---
#
# {'predict', 'effect', 'global', 'warming', 'impact', 'youtube', 'climate', 'change'}
# ---
#
# {'effect', 'global', 'fight', 'warming', 'post', 'read'}
# ---
#
# {'battle', 'poverty', 'news', 'global', 'warming', 'online'}
# ---
#
# {'blame', 'global', 'warming', 'allergy', 'bad'}
# ---
#
# {'trade', 'important', 'fight', 'partner', 'climate', 'change', 'germany'}
# ---
#
# ...
# ---
#
# {'obama', 'bulb', 'brian', 'solve', 'fuck', 'global', 'warming', 'light', 'truth', 'house', 'change'}
# ---
#
# {'minute', 'donate', 'climate', 'action', 'celebrate', 'haiti', 'earth', 'change', 'quiz'}
# ---
#
# {'thought', 'rise', 'global', 'warming', 'refer', 'average'}
# ---
#
# {'global', 'decade', 'warming', 'year', 'call', 'advocacy', 'mainstream', 'journalism'}
# ---
#
# {'hollywood', 'join', 'star', 'cool', 'guardian', 'global', 'warming', 'politician', 'bolivia', 'summit', 'cochabamba'}
# ---
#
# {'nasa', 'gawker', 'completely', 'global', 'warming', 'maybe', 'worthless'}
# ---
#
# {'tomorrow', 'american', 'schoolchil', 'global', 'million', 'warming', 'help', 'come', 'naughton', 'earth', 'homework'}
# ---
#
# {'global', 'warming', 'comedian', 'joke', 'datum', 'know'}
# ---
#
# {'cultism', 'fellow', 'article', 'global', 'tcot', 'warming', 'liberal', 'excellent'}
# ---
#
# {'tomorrow', 'energy', 'assist', 'join', 'carol', 'earth', 'pre', 'live', 'chat', 'climate', 'change', 'browner'}
# ---
#
# {'public', 'highlight', 'convention', 'agricultural', 'global', 'perception', 'biotech', 'hunger', 'intl', 'climate', 'change'}
# ---
#
# {'open', 'morale', 'climate', 'tiquipaya', 'conference', 'change'}
# ---
#
# {'encyclopedia', 'weather', 'recommend', 'complete', 'visual', 'guide', 'climate', 'change'}
# ---
#
# {'delta', 'california', 'river', 'need', 'disaster', 'climate', 'change', 'hit', 'video'}
# ---
#
# {'teen', 'stop', 'inconvenient', 'youth', 'fight', 'shop', 'climate', 'change'}
# ---
#
# {'teen', 'stop', 'inconvenient', 'youth', 'fight', 'shop', 'climate', 'change'}
# ---
#
# {'capture', 'examiner', 'write', 'global', 'exclusive', 'warming', 'richard', 'interview', 'ipcc'}
# ---
#
# {'kosten', 'dutch', 'amount', 'say', 'warm', 'researcher', 'large', 'climate', 'change', 'sarian', 'lake'}
# ---
#
# {'stop', 'join', 'global', 'warming', 'kill', 'valero', 'want'}
# ---
#
# {'volcano', 'global', 'warming', 'climate', 'think', 'trigger', 'change'}
# ---
#
# {'message', 'switch', 'folk', 'global', 'fight', 'warming', 'pollution', 'climate', 'change'}
# ---
#
# {'point', 'prostitute', 'change', 'care', 'climate', 'prove', 'find', 'willing'}
# ---
#
# {'responsible', 'brazilian', 'global', 'warming', 'think', 'believe', 'real', 'show', 'datafolha', 'brazzil'}
# ---
#
# {'company', 'major', 'effect', 'global', 'warming', 'reduce'}
# ---
#
# {'life', 'global', 'warming', 'issue', 'affect', 'child', 'natural', 'disaster'}
# ---
#
# {'emission', 'role', 'highlight', 'leadership', 'reduce', 'biotechnology', 'climate', 'change', 'summit', 'innovation'}
# ---
#
# {'attractive', 'global', 'warming', 'help', 'court', 'federal', 'nuisance', 'tackle'}
# ---
#
# {'inconvenient', 'youth', 'climate', 'change', 'tackle'}
# ---
#
# {'cause', 'volcano', 'iceland', 'discuss', 'volc', 'global', 'warming', 'erupt', 'eyjafjallajokull'}
# ---
#
# {'star', 'pocahontas', 'conference', 'climate', 'bolivia', 'interview', 'watch', 'change', 'cochabamba'}
# ---
#
# {'exactly', 'blog', 'global', 'warming', 'tell', 'hoot', 'ocregister'}
# ---
#
# {'address', 'sustainability', 'win', 'climate', 'change'}
# ---
#
# {'confuse', 'talk', 'class', 'global', 'warming', 'economist', 'good', 'think', 'view', 'profit'}
# ---
#
# {'claim', 'moral', 'ethanol', 'dark', 'environmentalist', 'global', 'warming', 'environmentalism', 'carrie', 'lukas'}
# ---
#
# {'shortage', 'treaty', 'south', 'water', 'second', 'asia', 'look', 'call', 'islamabad', 'climate', 'change', 'indus'}
# ---
#
# {'volcano', 'cause', 'iceland', 'global', 'warming'}
# ---
#
# {'better', 'buyer', 'dumb', 'loser', 'climate', 'change'}
# ---
#
# {'usgs', 'today', 'workshop', 'desert', 'climate', 'change', 'vegas'}
# ---
#
# {'launch', 'back', 'response', 'jones', 'mother', 'report', 'wire', 'impact', 'atlantic', 'climate', 'change', 'slate'}
# ---
#
# {'launch', 'back', 'response', 'jones', 'mother', 'report', 'wire', 'impact', 'atlantic', 'climate', 'change', 'slate'}
# ---
#
# {'indigenous', 'sister', 'thank', 'global', 'earthright', 'world', 'people', 'climate', 'change', 'summit', 'partcipation'}
# ---
#
# {'cutie', 'polarbear', 'evolution', 'slowly', 'climate', 'change', 'start'}
# ---
#
# {'apex', 'time', 'global', 'short', 'warming', 'reach', 'run', 'world', 'alarmism'}
# ---
#
# {'gather', 'rucker', 'rothbard', 'time', 'global', 'warming', 'delegate', 'link', 'world', 'weak', 'washington'}
# ---
#
# {'cause', 'thing', 'increase', 'global', 'different', 'warming', 'atmosphere', 'climate', 'change'}
# ---
#
# {'earthweek', 'climate', 'ppls', 'world', 'people', 'bolivia', 'earthday', 'conference', 'change'}
# ---
#
# {'like', 'fight', 'global', 'feel', 'good', 'warm', 'youtube', 'fantasy', 'video'}
# ---
#
# {'corner', 'seriously', 'rasmussen', 'april', 'monday', 'global', 'warming', 'report', 'skeptic', 'voter'}
# ---
# {'get', 'news', 'brkg', 'scientist', 'sue', 'iceland', 'volcanic', 'eruption', 'rehabilitate', 'announce', 'climate', 'change', 'panel'}
# ---
#
# {'heatwave', 'april', 'global', 'warming', 'record', 'set', 'prove'}
# ---
#
# {'oslo', 'cause', 'cap', 'global', 'turn', 'warming', 'climat', 'come', 'myth', 'reuters', 'ashe', 'thaw', 'decade'}
# ---
#
# {'time', 'global', 'short', 'warming', 'pollution', 'run', 'world', 'alarmism'}
# ---
#
# {'treehugger', 'effect', 'earthquake', 'climate', 'environment', 'political', 'economic', 'change'}
# ---
#
# {'changin', 'talk', 'cool', 'time', 'global', 'warming', 'bill', 'mckibben'}
# ---
#
# {'adapt', 'hominid', 'past', 'climate', 'change'}
# ---
#
# {'news', 'history', 'site', 'environment', 'earth', 'great', 'aspect', 'natural', 'climate', 'break', 'change'}
# ---
#
# {'carter', 'volcano', 'beck', 'news', 'glenn', 'smoke', 'algore', 'jimmy', 'global', 'tcot', 'warming', 'send', 'nowplaying', 'msnbc', 'signal', 'gore'}
# ---
#
# {'carter', 'volcano', 'beck', 'news', 'glenn', 'smoke', 'algore', 'jimmy', 'global', 'tcot', 'warming', 'send', 'msnbc', 'nowplaye', 'signal', 'gore'}
# ---
#
# {'discredit', 'alarmist', 'global', 'prison', 'warming', 'come', 'knee', 'government', 'european', 'jerk'}
# ---
#
# {'bolivian', 'right', 'people', 'mother', 'earth', 'world', 'ambassador', 'solon', 'climate', 'change', 'summit', 'pablo'}
# ---
#
# {'heat', 'concern', 'miss', 'climate', 'reappear', 'sign', 'eventually', 'earth', 'change'}
# ---
#
# {'global', 'warming', 'comedian', 'joke', 'datum', 'know'}
# ---
#
# {'slice', 'april', 'dollar', 'million', 'ecuador', 'bolivia', 'climate', 'summit', 'change', 'slap'}
# ---
#
# {'alternative', 'climate', 'hold', 'people', 'bolivia', 'conference', 'change'}
# ---
#
# {'take', 'doubleday', 'talese', 'mcewan', 'global', 'page'}
# ---
#
# {'balance', 'global', 'warming', 'fraud', 'say', 'oxburgh', 'climate', 'quote', 'change'}
# ---
#
# {'science', 'illuminate', 'post', 'climate', 'change'}
# ---
#
# {'prostitution', 'democrat', 'beck', 'news', 'acorn', 'dncc', 'party', 'global', 'tcot', 'warming', 'nambla', 'homosexuality', 'support', 'abortion', 'eciu'}
# ---
#
# {'energy', 'talk', 'green', 'earth', 'event', 'climate', 'change'}
# ---
#
# {'embrace', 'energy', 'talk', 'green', 'earth', 'library', 'community', 'event', 'farmington', 'climate', 'change'}
# ---
#
# {'power', 'solution', 'climate', 'change', 'nuclear'}
# ---
#
# {'nevadan', 'reporter', 'vegas', 'global', 'skeptical', 'warming', 'show', 'percent', 'statewide', 'poll'}
# ---
#
# {'blame', 'make', 'gore', 'seasonal', 'system', 'climate', 'allergy', 'change', 'bad', 'solar'}
# ---
#
# {'reach', 'excuse', 'climate', 'change', 'tackle'}
# ---
#
# {'volcano', 'iceland', 'human', 'lie', 'global', 'relation', 'warming', 'wonder', 'farce', 'joke', 'emit', 'contribute'}
# ---
#
# {'discredit', 'scientist', 'ree', 'president', 'global', 'warming', 'defend', 'runaway', 'martin', 'royal', 'theory', 'rush'}
# ---
#
# {'get', 'volcano', 'iceland', 'fact', 'rant', 'probly', 'guru', 'wrong', 'climate', 'change'}
# ---
#
# {'blame', 'global', 'tcot', 'warming', 'come', 'eruption', 'gore'}
# ---
#
# {'public', 'global', 'warming', 'pressure', 'world', 'importance', 'experien', 'detractor', 'show', 'game', 'disbelieve'}
# ---
#
# {'global', 'warming', 'unchanging', 'sign', 'reliable', 'gravity', 'like'}
# ---
#
# {'predict', 'apocalypsenow', 'hard', 'green', 'revolution', 'outcome', 'exciting', 'climate', 'change'}
# ---
#
# {'alternative', 'graph', 'place', 'science', 'climate', 'change'}
# ---
#
# {'worthwhile', 'green', 'definitely', 'finally', 'read', 'climate', 'krugman', 'change', 'economy', 'build'}
# ---
#
# {'brian', 'treehugger', 'literally', 'brooklyn', 'global', 'warming', 'allergic', 'york', 'merchant'}
# ---
#
# {'carbon', 'google', 'price', 'chief', 'climate', 'change', 'want'}
# ---
#
# {'mulch', 'cochacamba', 'medium', 'blogger', 'combat', 'innovatively', 'consortium', 'sarah', 'weekly', 'laskow', 'climate', 'change', 'summit'}
# ---
#
# {'nutcase', 'unpersuade', 'discourage', 'human', 'global', 'warming', 'remain', 'intelligence', 'consider', 'debate', 'logic', 'evidence'}
# ---
#
# {'probably', 'global', 'warming', 'skeptic', 'view', 'represent'}
# ---
#
# {'health', 'change', 'care', 'climate', 'congress', 'work'}
# ---
#
# {'scientist', 'global', 'warming', 'exaggerate', 'fire', 'climate'}
# ---
#
# {'future', 'heat', 'observational', 'daily', 'miss', 'science', 'tool', 'affect', 'climate', 'change', 'accoun', 'source', 'current'}
# ---
#
# {'nathanael', 'thing', 'california', 'solve', 'global', 'warming', 'johnson', 'watch'}
# ---
#
# {'roughly', 'scientist', 'soon', 'heat', 'believ', 'global', 'miss', 'warming', 'account', 'half', 'return'}
# ---
#
# {'market', 'inconclusive', 'global', 'climate', 'year', 'warming', 'armageddo', 'evidence', 'change'}
# ---
#
# {'switch', 'dial', 'carbon', 'lock', 'light', 'abrupt', 'climate', 'oven', 'change'}
# ---
#
# {'way', 'heat', 'scientist', 'beef', 'global', 'miss', 'warming', 'measure', 'expert', 'need', 'monitoring', 'find'}
# ---
#
# {'idea', 'grant', 'carbon', 'good', 'know', 'reduce', 'happen', 'climate', 'change'}
# ---
#
# {'health', 'refinery', 'local', 'effect', 'climate', 'study', 'negative', 'cite', 'change'}
# ---
#
# {'obama', 'push', 'global', 'country', 'develop', 'warming', 'pope', 'president', 'sydney', 'pressure', 'barack'}
# ---
#
# {'weather', 'global', 'warming', 'channel', 'hoax', 'promote', 'theory', 'conspiracy'}
# ---
#
# {'back', 'supporter', 'green', 'carbon', 'plan', 'government', 'support', 'policy', 'climate', 'change'}
# ---
#
# {'graph', 'attack', 'global', 'warming', 'study', 'economy'}
# ---
#
# {'get', 'catch', 'scare', 'bullshit', 'weather', 'cali', 'global', 'warming', 'call', 'strange', 'average'}
# ---
#
# {'explorer', 'discuss', 'program', 'adventurer', 'global', 'steger', 'warming', 'free', 'polar', 'present', 'renowned'}
# ---
#
# {'night', 'ridiculous', 'nightmare', 'creepy', 'climate', 'change'}
# ---
#
# {'asshole', 'fuck', 'corrupted', 'global', 'warming', 'record', 'accumulate', 'climate', 'evidence', 'temp'}
# ---
#
# {'scientist', 'series', 'weather', 'global', 'warming', 'staudt', 'amanda', 'extreme'}
# ---
#
# {'tinto', 'energy', 'thankfully', 'preston', 'chiaro', 'positive', 'statement', 'clean', 'global', 'warming'}
# ---
#
# {'governor', 'wallet', 'wise', 'chris', 'global', 'warming', 'heart', 'jersey', 'christie'}
# ---
#
# {'public', 'prevent', 'post', 'willingness', 'climate', 'change'}
# ---
#
# {'take', 'doubleday', 'talese', 'mcewan', 'global', 'page'}
# ---
#
# {'reach', 'excuse', 'climate', 'change', 'tackle'}
# ---
#
# {'scientist', 'result', 'fabricate', 'accuse', 'global', 'warming', 'malpractice', 'find', 'evidence', 'inquiry'}
# ---
#
# {'scientist', 'global', 'december', 'warming', 'control', 'send', 'letter', 'nations', 'united'}
# ---
#
# {'cause', 'society', 'time', 'global', 'daily', 'warming', 'obese', 'people', 'otago', 'create'}
# ---
#
# {'water', 'country', 'turn', 'world', 'coastal', 'climate', 'change'}
# ---
#
# {'greentech', 'daniel', 'climate', 'huffington', 'plan', 'post', 'esty', 'change'}
# ---
#
# {'woot', 'governor', 'awesome', 'global', 'warming', 'fund', 'million', 'christie'}
# ---
#
# {'health', 'kingdom', 'psychology', 'cause', 'stainton', 'global', 'warming', 'obese', 'people', 'professor', 'wendy', 'united'}
# ---
#
# {'contend', 'newt', 'pelosi', 'green', 'commercial', 'global', 'gingrich', 'warming', 'seek', 'defend', 'need'}
# ---
#
# {'liberalism', 'have', 'make', 'statement', 'global', 'warming', 'calendar'}
# ---
#
# {'brian', 'treehugger', 'safety', 'global', 'warming', 'silly', 'regulator', 'merchant', 'blankenship', 'brookl', 'video'}
# ---
#
# {'california', 'peer', 'global', 'review', 'warming', 'calif', 'gulf', 'truly', 'read'}
# ---
#
# {'idea', 'energy', 'safety', 'dead', 'global', 'warming', 'care', 'silly', 'miner', 'massey'}
# ---
#
# {'video', 'global', 'warming', 'ambush', 'woodrow', 'jesse', 'brilliant', 'gore'}
# ---
#
# {'meteo', 'sit', 'suzanne', 'weather', 'global', 'warming', 'weathercaster', 'christian', 'divide', 'bohan', 'forecaster', 'spencer'}
# ---
#
# {'claim', 'cause', 'cowgate', 'headline', 'global', 'false', 'warming', 'say', 'report', 'livestock', 'read', 'expert'}
# ---
#
# {'remove', 'global', 'warming', 'datum', 'disagree', 'theory'}
# ---
#
# {'global', 'tcot', 'warming', 'death', 'freeze', 'activist', 'antarctica'}
# ---
#
# {'prepare', 'compromise', 'yahoo', 'greentech', 'green', 'climate', 'bill', 'reuters', 'senator', 'change'}
# ---
#
# {'global', 'catastrophe', 'warming', 'fraud', 'pretend', 'know', 'surplus', 'people', 'climate', 'change'}
# ---
#
# {'gandhi', 'filmmaker', 'climate', 'delhi', 'win', 'documentary', 'change', 'rohit'}
# ---
#
# {'baby', 'series', 'lowdown', 'climate', 'change', 'question'}
# ---
#
# {'baby', 'series', 'lowdown', 'climate', 'change', 'question'}
# ---
#
# {'bat', 'lizard', 'bird', 'fight', 'climate', 'change'}
# ---
#
# {'econ', 'resource', 'natural', 'climate', 'krugman', 'change'}
# ---
#
# {'econ', 'resource', 'natural', 'climate', 'krugman', 'change'}
# ---
#
# {'charity', 'senior', 'job', 'officer', 'climate', 'oxfam', 'change', 'press'}
# ---
# {'paul', 'make', 'good', 'krugman', 'love', 'economic', 'climate', 'jasencomstock', 'change', 'primer'}
# ---
#
# {'long', 'exploration', 'horizon', 'post', 'climate', 'change'}
# ---
#
# {'stop', 'join', 'global', 'warming', 'kill', 'valero', 'want'}
# ---
#
# {'introduce', 'track', 'month', 'global', 'warming', 'bill', 'sweeping', 'senate', 'climate', 'flop', 'change'}
# ---
#
# {'violence', 'elect', 'right', 'ecojustice', 'daily', 'system', 'climate', 'change'}
# ---
#
# {'global', 'warming', 'answer', 'think', 'hoax', 'question', 'find'}
# ---
#
# {'effort', 'global', 'international', 'warming', 'negotia', 'bonn', 'agree', 'continue'}
# ---
#
# {'process', 'time', 'million', 'year', 'call', 'alaska', 'thirty', 'climate', 'vanish', 'change', 'tree', 'palm'}
# ---
#
# {'scientist', 'global', 'warm', 'challenge', 'intl', 'conference'}
# ---
#
# {'telegraph', 'today', 'refute', 'second', 'global', 'daily', 'warming', 'study', 'meat', 'declare', 'oppose', 'view'}
# ---
#
# {'consistent', 'fanatic', 'environmentalist', 'global', 'point', 'warming', 'clash', 'redstate', 'prove'}
# ---
#
# {'major', 'water', 'global', 'pollution', 'warming', 'source'}
# ---
#
# {'news', 'global', 'liberalfascism', 'warming', 'climate', 'ecocide', 'tcot', 'prosecute'}
# ---
#
# {'bat', 'lizard', 'important', 'bird', 'role', 'play', 'fight', 'earth', 'climate', 'change'}
# ---
#
# {'bat', 'lizard', 'important', 'bird', 'role', 'play', 'fight', 'earth', 'climate', 'change'}
# ---
#
# {'bat', 'lizard', 'important', 'bird', 'role', 'play', 'fight', 'earth', 'climate', 'change'}
# ---
#
# {'bat', 'lizard', 'important', 'bird', 'role', 'play', 'fight', 'earth', 'climate', 'change'}
# ---
#
# {'bat', 'lizard', 'important', 'bird', 'role', 'play', 'fight', 'earth', 'climate', 'change'}
# ---
#
# {'use', 'global', 'serve', 'fuel', 'warming', 'america', 'dilemma', 'barrel', 'fossil', 'need', 'million'}
# ---
#
# {'shrink', 'sheep', 'mystery', 'climate', 'change'}
# ---
#
# {'weather', 'climb', 'global', 'warming', 'august', 'unbelievable', 'chalk'}
# ---
#
# {'favor', 'abandon', 'global', 'tcot', 'warming', 'luntz', 'say', 'phrase', 'climate', 'change'}
# ---
#
# {'scientist', 'virginia', 'investigate', 'global', 'warm', 'mann'}
# ---
#
# {'global', 'ocra', 'warming', 'enjoy', 'parody', 'tube', 'ipcc'}
# ---
#
# {'golfer', 'dare', 'make', 'global', 'warming', 'tell', 'eyed'}
# ---
#
# {'claim', 'hair', 'brain', 'global', 'warming', 'scientifically', 'ippc', 'tcot', 'climategate', 'challenge', 'theory'}
# ---

# %% [markdown]
# ## Modeling

# %%
new_data = data.iloc[indices]

# %%
prepr_tweets = [" ".join(each) for each in preprocessed_tweets]
new_data['cleaned_tweet'] = prepr_tweets
new_data.head()
# Out:
#                                                tweet existence  \
# 0  Global warming report urges governments to act...       Yes
# 1  Fighting poverty and global warming in Africa ...       Yes
# 2  Carbon offsets: How a Vatican forest failed to...       Yes
# 3  Carbon offsets: How a Vatican forest failed to...       Yes
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...       Yes
#
#    existence.confidence  word_count  \
# 0                1.0000          18
# 1                1.0000           8
# 2                0.8786          12
# 3                1.0000          12
# 4                0.8087          11
#
#                                        cleaned_tweet
# 0  belgium increase global face warming report hu...
# 1                poverty global fight africa warming
# 2  offset carbon global warming vatican reduce fa...
# 3  offset carbon global warming vatican reduce fa...
# 4        uruguay tool need vulnerable climate change

# %%
len(prepr_tweets), data.shape, new_data.shape
# Out:
# (5544, (5960, 4), (5544, 5))

# %%
# TF IDF
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split
import collections, numpy

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(new_data['cleaned_tweet'].astype('U'))

tf = TfidfVectorizer()
text_tf = tf.fit_transform(new_data['cleaned_tweet'].astype('U'))
# print(text_tf)

# %%
new_data.isna().sum()
# Out:
# tweet                   0
# existence               0
# existence.confidence    0
# word_count              0
# cleaned_tweet           0
# dtype: int64

# %%
# compute similarity using cosine similarity
cos_sim=cosine_similarity(text_tf, text_tf)
print(cos_sim)
# Out:
# [[1.         0.03273816 0.02203327 ... 0.02147607 0.02021837 0.0164164 ]
#  [0.03273816 1.         0.03854919 ... 0.03757431 0.03537386 0.02872197]
#  [0.02203327 0.03854919 1.         ... 0.02528807 0.02380713 0.01933031]
#  ...
#  [0.02147607 0.03757431 0.02528807 ... 1.         0.02320507 0.01884147]
#  [0.02021837 0.03537386 0.02380713 ... 0.02320507 1.         0.01773806]
#  [0.0164164  0.02872197 0.01933031 ... 0.01884147 0.01773806 1.        ]]

# %%
# splitting data 

X_train, X_test, y_train, y_test = train_test_split(cos_sim, new_data['existence'], test_size=0.2, random_state=33)
print(" Test Data Shape:", X_test.shape)
print(" Train Data Shape:",X_train.shape)
# Out:
#  Test Data Shape: (1109, 5544)
#  Train Data Shape: (4435, 5544)

# %%
pos = (y_test == 'Yes').sum()
neg = (y_test == 'No').sum()
postrain = (y_train == 'Yes').sum()
negtrain = (y_train == 'No').sum()
total = pos + neg
print(" Test Data Positive Sentiments :", pos)
print(" Test Data Negative Sentiments :",neg)
print(" Train Data Positive Sentiments :", postrain)
print(" Train Data Positive Sentiments :",negtrain)
new_data['existence'].value_counts()
# Out:
#  Test Data Positive Sentiments : 588
#  Test Data Negative Sentiments : 198
#  Train Data Positive Sentiments : 2261
#  Train Data Positive Sentiments : 817
# Yes        2849
# neutral    1680
# No         1015
# Name: existence, dtype: int64

# %%
# perform algoritma KNN
from sklearn.metrics import accuracy_score, cohen_kappa_score
from sklearn.metrics import precision_score, auc,recall_score, f1_score,roc_curve,confusion_matrix, classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm
from sklearn.model_selection import cross_val_score
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.svm import LinearSVC

# %%
clfs = [
    svm.SVC(kernel='linear').fit(X_train, y_train),
#     LinearSVC().fit(X_train, y_train),
    DecisionTreeClassifier().fit(X_train, y_train),
    KNeighborsClassifier(n_neighbors=7).fit(X_train, y_train)
]

# %%
MLA_columns = []
MLA_compare = pd.DataFrame(columns = MLA_columns)

# %%
row_index = 0
for clf in clfs:
    print('===============================================\n')
    print("**********{}***********".format(clf.__class__.__name__))
    predicted = clf.predict(X_test)
#     tn, fp, fn, tp = confusion_matrix(y_test, predicted).ravel()
    MLA_name = clf.__class__.__name__
    MLA_compare.loc[row_index,'MLA Name'] = MLA_name
    MLA_compare.loc[row_index, 'MLA Train Accuracy'] = round(clf.score(X_train, y_train), 2)
    MLA_compare.loc[row_index, 'MLA Test Accuracy'] = round( accuracy_score(y_test,predicted), 2)
    MLA_compare.loc[row_index, 'MLA Precision'] = round( precision_score(y_test,predicted, average="macro"), 2)
    MLA_compare.loc[row_index, 'MLA Recall'] = round( recall_score(y_test,predicted, average="macro"), 2)
    MLA_compare.loc[row_index, 'MLA F1 Score'] = round( f1_score(y_test,predicted, average="macro"), 2)
    MLA_compare.loc[row_index, 'error_rate'] = round( 1-accuracy_score(y_test,predicted), 2)
    MLA_compare.loc[row_index, 'cross val score'] = cross_val_score(clf, cos_sim,new_data['existence'], cv=10).mean()
    row_index+=1
# Out:
# ===============================================
#
# **********SVC***********
# ===============================================
#
# **********DecisionTreeClassifier***********

# %%
MLA_compare.sort_values(by = ['MLA Test Accuracy'], ascending = False, inplace = True)
MLA_compare

# %% [markdown]
# ## Random Under Sampling

# %%
from imblearn.over_sampling import RandomOverSampler,SMOTE
from imblearn.under_sampling import RandomUnderSampler

# %%
# splitting data 

X_train, X_test, y_train, y_test = train_test_split(cos_sim, new_data['existence'], test_size=0.2, random_state=33)
print(" Test Data Shape:", X_test.shape)
print(" Train Data Shape:",X_train.shape)

# %%
X_train,y_train = RandomUnderSampler(random_state = 21).fit_resample(X_train,y_train)
# X_train,y_train = RandomOverSampler(random_state = 21).fit_resample(X_train,y_train)

# %%
X_train.shape, y_train.shape

# %%
under_MLA_columns = []
under_MLA_compare = pd.DataFrame(columns = under_MLA_columns)

# %%
under_clfs = [
    svm.SVC(kernel='linear').fit(X_train, y_train),
#     LinearSVC(C=0.0001).fit(X_train, y_train),
    DecisionTreeClassifier().fit(X_train, y_train),
    KNeighborsClassifier(n_neighbors=7).fit(X_train, y_train)
]

# %%
row_index = 0
for clf in under_clfs:
    print('===============================================\n')
    print("**********{}***********".format(clf.__class__.__name__))
    predicted = clf.predict(X_test)
#     tn, fp, fn, tp = confusion_matrix(y_test, predicted).ravel()
    under_MLA_name = clf.__class__.__name__
    under_MLA_compare.loc[row_index,'MLA Name'] = under_MLA_name
    under_MLA_compare.loc[row_index, 'MLA Train Accuracy'] = round(clf.score(X_train, y_train), 2)
    under_MLA_compare.loc[row_index, 'MLA Test Accuracy'] = round( accuracy_score(y_test,predicted), 2)
    under_MLA_compare.loc[row_index, 'MLA Precision'] = round( precision_score(y_test,predicted, average="macro"), 2)
    under_MLA_compare.loc[row_index, 'MLA Recall'] = round( recall_score(y_test,predicted, average="macro"), 2)
    under_MLA_compare.loc[row_index, 'MLA F1 Score'] = round( f1_score(y_test,predicted, average="macro"), 2)
    under_MLA_compare.loc[row_index, 'error_rate'] = round( 1-accuracy_score(y_test,predicted), 2)
    under_MLA_compare.loc[row_index, 'cross val score'] = cross_val_score(clf, cos_sim,new_data['existence'], cv=10).mean()
    row_index+=1

# %%
under_MLA_compare.sort_values(by = ['MLA Test Accuracy'], ascending = False, inplace = True)
under_MLA_compare

# %% [markdown]
# ## Random Over Sampling

# %%
# splitting data 

X_train, X_test, y_train, y_test = train_test_split(cos_sim, new_data['existence'], test_size=0.2, random_state=33)
print(" Test Data Shape:", X_test.shape)
print(" Train Data Shape:",X_train.shape)

# %%
# Xtrain,ytrain = RandomUnderSampler(random_state = 21).fit_resample(X_train,y_train)
X_train,y_train = RandomOverSampler(random_state = 21).fit_resample(X_train,y_train)

# %%
X_train.shape, y_train.shape

# %%
over_MLA_columns = []
over_MLA_compare = pd.DataFrame(columns = over_MLA_columns)

# %%
over_clfs = [
    svm.SVC(kernel='linear').fit(X_train, y_train),
#     LinearSVC(C=0.0001).fit(X_train, y_train),

    DecisionTreeClassifier().fit(X_train, y_train),
    KNeighborsClassifier(n_neighbors=7).fit(X_train, y_train)
]

# %%
row_index = 0
for clf in over_clfs:
    print('===============================================\n')
    print("**********{}***********".format(clf.__class__.__name__))
    predicted = clf.predict(X_test)
#     tn, fp, fn, tp = confusion_matrix(y_test, predicted).ravel()
    over_MLA_name = clf.__class__.__name__
    over_MLA_compare.loc[row_index,'MLA Name'] = over_MLA_name
    over_MLA_compare.loc[row_index, 'MLA Train Accuracy'] = round(clf.score(X_train, y_train), 2)
    over_MLA_compare.loc[row_index, 'MLA Test Accuracy'] = round( accuracy_score(y_test,predicted), 2)
    over_MLA_compare.loc[row_index, 'MLA Precision'] = round( precision_score(y_test,predicted, average="macro"), 2)
    over_MLA_compare.loc[row_index, 'MLA Recall'] = round( recall_score(y_test,predicted, average="macro"), 2)
    over_MLA_compare.loc[row_index, 'MLA F1 Score'] = round( f1_score(y_test,predicted, average="macro"), 2)
    over_MLA_compare.loc[row_index, 'error_rate'] = round( 1-accuracy_score(y_test,predicted), 2)
    over_MLA_compare.loc[row_index, 'cross val score'] = cross_val_score(clf, cos_sim,new_data['existence'], cv=10).mean()
    row_index+=1

# %% [markdown]
# ## SMOTE

# %%
# splitting data 
X_train, X_test, y_train, y_test = train_test_split(cos_sim, new_data['existence'], test_size=0.2, random_state=33)
print(" Test Data Shape:", X_test.shape)
print(" Train Data Shape:",X_train.shape)

# %%
from imblearn.over_sampling import SMOTE

oversample = SMOTE(k_neighbors=5)
X_train,y_train = oversample.fit_resample(X_train,y_train)
X_train.shape,y_train.shape

# %%
SMOTE_MLA_columns = []
SMOTE_MLA_compare = pd.DataFrame(columns = SMOTE_MLA_columns)

# %%
smote_clfs = [
    svm.SVC(kernel='linear').fit(X_train, y_train),
#     LinearSVC(C=0.0001).fit(X_train, y_train),

    DecisionTreeClassifier().fit(X_train, y_train),
    KNeighborsClassifier(n_neighbors=7).fit(X_train, y_train)
]

# %%
row_index = 0
for clf in smote_clfs:
    print('===============================================\n')
    print("**********{}***********".format(clf.__class__.__name__))
    predicted = clf.predict(X_test)
#     tn, fp, fn, tp = confusion_matrix(y_test, predicted).ravel()
    SMOTE_MLA_name = clf.__class__.__name__
    SMOTE_MLA_compare.loc[row_index,'MLA Name'] = SMOTE_MLA_name
    SMOTE_MLA_compare.loc[row_index, 'MLA Train Accuracy'] = round(clf.score(X_train, y_train), 2)
    SMOTE_MLA_compare.loc[row_index, 'MLA Test Accuracy'] = round( accuracy_score(y_test,predicted), 2)
    SMOTE_MLA_compare.loc[row_index, 'MLA Precision'] = round( precision_score(y_test,predicted, average="macro"), 2)
    SMOTE_MLA_compare.loc[row_index, 'MLA Recall'] = round( recall_score(y_test,predicted, average="macro"), 2)
    SMOTE_MLA_compare.loc[row_index, 'MLA F1 Score'] = round( f1_score(y_test,predicted, average="macro"), 2)
    SMOTE_MLA_compare.loc[row_index, 'error_rate'] = round( 1-accuracy_score(y_test,predicted), 2)
    SMOTE_MLA_compare.loc[row_index, 'cross val score'] = cross_val_score(clf, cos_sim,new_data['existence'], cv=10).mean()
    row_index+=1

# %%
MLA_compare

# %%
under_MLA_compare

# %%
over_MLA_compare

# %%
SMOTE_MLA_compare

# %%
# import pickle
# # pickling the vectorizer
# pickle.dump(tf, open('vectorizer', 'wb'))
# # pickling the model
# pickle.dump(clfs[0], open('svm_classifier_89', 'wb'))
