# %% [markdown]
# <a href="https://colab.research.google.com/github/sqiprasanna/climate_change_tweets_sentiment_analysis/blob/main/SVG_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import spacy
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt 
from itertools import chain
from wordcloud import WordCloud, STOPWORDS 
# !pip install xlrd==1.2.0
import cufflinks as cf
import regex as re
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
# !pip install xlrd==1.2.0
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# data = pd.read_csv('/content/1377884570_tweet_global_warming.csv',encoding="unicode_escape",engine="python")
data = pd.read_csv('1377884570_tweet_global_warming.csv',encoding="unicode_escape",engine="python")

data.head()
# Out:
#                                                tweet existence  \
# 0  Global warming report urges governments to act...       Yes
# 1  Fighting poverty and global warming in Africa ...       Yes
# 2  Carbon offsets: How a Vatican forest failed to...       Yes
# 3  Carbon offsets: How a Vatican forest failed to...       Yes
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...       Yes
#
#    existence.confidence
# 0                1.0000
# 1                1.0000
# 2                0.8786
# 3                1.0000
# 4                0.8087

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
print(data['existence'].value_counts())
# Out:
# Y      2554
# N      1053
# Yes     557
# No       61
# Name: existence, dtype: int64

# %%
data['word_count'] = data['tweet'].apply(lambda x: len(x.split(" ")))
data = data.drop_duplicates()
data = data.dropna()
data.loc[data['existence'] == 'Y','existence'] = "Yes"
data.loc[data['existence'] == 'N','existence'] = "No"
print(data.shape)
data.dropna()
data.loc[data['existence'] == np.nan,'existence'] = "No"
print(data['existence'].value_counts())
print(data.shape)
data.head()
# Out:
# (4134, 4)
# Yes    3029
# No     1105
# Name: existence, dtype: int64
# (4134, 4)
#                                                tweet existence  \
# 0  Global warming report urges governments to act...       Yes
# 1  Fighting poverty and global warming in Africa ...       Yes
# 2  Carbon offsets: How a Vatican forest failed to...       Yes
# 3  Carbon offsets: How a Vatican forest failed to...       Yes
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...       Yes
#
#    existence.confidence  word_count
# 0                1.0000          18
# 1                1.0000           8
# 2                0.8786          12
# 3                1.0000          12
# 4                0.8087          11

# %%
tweets = data["tweet"]
tweets
# Out:
# 0       Global warming report urges governments to act...
# 1       Fighting poverty and global warming in Africa ...
# 2       Carbon offsets: How a Vatican forest failed to...
# 3       Carbon offsets: How a Vatican forest failed to...
# 4       URUGUAY: Tools Needed for Those Most Vulnerabl...
#                               ...
# 6084    It's 83_Á and climbing in NYC. August weather...
# 6085    @bloodless_coup "The phrase 'global warming' s...
# 6087    Global warming you tube parody you will enjoy ...
# 6088    One-Eyed Golfer: Don't dare tell me about glob...
# 6089    man made global warming a hair brained theory ...
# Name: tweet, Length: 4134, dtype: object

# %% [markdown]
# For Preprocessing we have used

# %%
### Source: https://spacy.io/usage/linguistic-features

def spacyPipeline(tweets):
    nlp = spacy.load('en_core_web_sm')
    
    MIN_TWEET_LEN = 5
    
    indices = []
    preprocessed_tweets = []
    for index, t in enumerate(tweets):
        
        doc = nlp(t)
        filtered_tweet = set()
        
        for token in doc:
            # print(token, " | ", spacy.explain(token.pos_))
            if (token.lemma_ not in filtered_tweet) and checkWord(token):
                filtered_tweet.add(token.lemma_.lower())
        
        if len(filtered_tweet) >= MIN_TWEET_LEN:
            print(filtered_tweet,"\n---\n")
            preprocessed_tweets.append(filtered_tweet)
            indices.append(index)
    
    return preprocessed_tweets, indices

# %% [markdown]
# count no of mentions in each tweet

# %%
pattern=r'@\w+'
count_mentions = tweets.apply(lambda tweet: len(re.findall(pattern, tweet)))
count_mentions
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 6084    0
# 6085    1
# 6087    0
# 6088    0
# 6089    0
# Name: tweet, Length: 4134, dtype: int64

# %% [markdown]
# count no of hashtags in each tweet

# %%
pattern=r'#\w+'
print(tweets)
count_hashtags = tweets.apply(lambda tweet: len(re.findall(pattern, tweet)))
print(count_hashtags)
# Out:
# 0       Global warming report urges governments to act...
# 1       Fighting poverty and global warming in Africa ...
# 2       Carbon offsets: How a Vatican forest failed to...
# 3       Carbon offsets: How a Vatican forest failed to...
# 4       URUGUAY: Tools Needed for Those Most Vulnerabl...
#                               ...
# 6084    It's 83_Á and climbing in NYC. August weather...
# 6085    @bloodless_coup "The phrase 'global warming' s...
# 6087    Global warming you tube parody you will enjoy ...
# 6088    One-Eyed Golfer: Don't dare tell me about glob...
# 6089    man made global warming a hair brained theory ...
# Name: tweet, Length: 4134, dtype: object
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 6084    0
# 6085    2
# 6087    2
# 6088    0
# 6089    3
# Name: tweet, Length: 4134, dtype: int64

# %% [markdown]
# count no of links in each tweet

# %%
pattern=r'http.?://[^\s]+[\s]?'
count_urls = tweets.apply(lambda tweet: len(re.findall(pattern, tweet)))

# %%
#print the total number of hashtags, mentions and urls.

# %%
print("Mentions:",count_mentions.sum())
print("Hashtags:",count_hashtags.sum())
print("Urls:",count_urls.sum())
# Out:
# Mentions: 1536
# Hashtags: 1551
# Urls: 2699

# %%
def splitWords(t):
    splitTweet = []
    t = t.split(' ')
    
    for word in t:
        res = re.search(r'[A-Z]', word)
        if res is not None:
            ch = word[res.span()[0]]
            words = re.split(r'[A-Z]', word)
            splitTweet.extend([words[0], ch + words[1]])
        else:
            splitTweet.extend(re.split(r'["|,;!|:*]', word))
    
    return ' '.join(splitTweet)

# %%
def checkWord(token):
    negations = ['not', 'no']
    fillers = ['link', 'http']
    return (not token.is_stop) and (token.is_alpha) and (token.text not in fillers) and ((token.text in negations) or (len(token.text) > 3))

# %%
def preprocess(tweets):

    whiteList=['climate','change','earth','global','warming','planet']

    #Remove mentions
    count=0
    mentions_tweets = [re.findall('@\w+', tweet) for tweet in tweets]

    #Remove hash sign
    hash_tweets = [re.findall('#\w+', tweet) for tweet in tweets]

    #Remove urls
    urls_tweets = [re.findall(r'http.?://[^\s]+[\s]?', tweet) for tweet in tweets]


    #Convert all to lowercase
    tweets = [t.lower() for t in tweets]
    
    # Process tweets through spaCy pipeline
    tweets, indices = spacyPipeline(tweets)
    
    # print(tweets)
    return tweets,hash_tweets,urls_tweets,mentions_tweets,indices

# %%
def generateWordCloud(tweets):
    allwords = " ".join(set(chain.from_iterable(tweets)))
    wordcloud = WordCloud(width = 800, height = 800, 
                    background_color ='white', 
                    stopwords = set(STOPWORDS), 
                    min_font_size = 10).generate(allwords)

    plt.axis("off") 
    plt.tight_layout(pad = 0) 

    plt.figure(figsize = (7, 7), facecolor = 'white', edgecolor='blue') 
    plt.imshow(wordcloud) 

    plt.show()

# %%
preprocessed_tweets,hash_tweets,urls_tweets,mentions_tweets,indices_pre = preprocess(tweets)
# preprocessed_tweets
# Out:
# Streaming output truncated to the last 5000 lines.
# ---
#
# {'climate', 'exist', 'summer', 'winter', 'spring', 'change', 'fall', 'justsaye'}
# ---
#
# {'obama', 'global', 'blast', 'snow', 'warming', 'snobama', 'ipcc', 'rate', 'star', 'video', 'youtube'}
# ---
#
# {'climate', 'thing', 'industry', 'easi', 'take', 'change', 'mail', 'come', 'curb', 'seattle', 'junk'}
# ---
#
# {'global', 'tcot', 'blizzard', 'little', 'warming', 'inhofe', 'gore', 'family', 'expense'}
# ---
#
# {'great', 'global', 'tcot', 'warming', 'collapse'}
# ---
#
# {'global', 'want', 'yeah', 'carbon', 'increase', 'warming', 'footprint'}
# ---
#
# {'sore', 'global', 'feel', 'snow', 'foot', 'dig', 'warming'}
# ---
#
# {'climate', 'global', 'consensus', 'fast', 'change', 'bogus', 'warming', 'fade'}
# ---
#
# {'obama', 'cover', 'global', 'climategate', 'tcot', 'hand', 'snow', 'washington', 'promise', 'warming', 'year'}
# ---
#
# {'global', 'report', 'expose', 'claim', 'ipcc', 'false', 'warming', 'hysteria'}
# ---
#
# {'global', 'fail', 'warming', 'power', 'beer'}
# ---
#
# {'inveigh', 'aspect', 'global', 'hoax', 'warming', 'rightwing', 'nutcase', 'encourage', 'favorite', 'snowstorm'}
# ---
#
# {'climate', 'help', 'mind', 'change', 'people', 'certaintly', 'storm', 'fleeting', 'type'}
# ---
#
# {'climate', 'global', 'think', 'amuse', 'snow', 'change', 'close', 'denier', 'wryly', 'warming', 'refer', 'mark'}
# ---
#
# {'global', 'middle', 'snowy', 'thatn', 'nicer', 'winter', 'warming', 'sound', 'damn'}
# ---
#
# {'heavily', 'global', 'snow', 'imminent', 'sign', 'washington', 'storm', 'historic', 'explain', 'gore', 'warming', 'year'}
# ---
#
# {'heavily', 'global', 'snow', 'imminent', 'sign', 'washington', 'storm', 'historic', 'explain', 'gore', 'warming', 'year'}
# ---
#
# {'climate', 'chamber', 'brake', 'toyota', 'probably', 'tell', 'hear', 'change'}
# ---
#
# {'climate', 'brake', 'toyota', 'digg', 'question', 'change', 'like'}
# ---
#
# {'global', 'nearly', 'good', 'inch', 'shut', 'area', 'warming'}
# ---
#
# {'global', 'consensus', 'fast', 'bogus', 'warming', 'fade'}
# ---
#
# {'finally', 'global', 'pitch', 'home', 'warming', 'reschedule', 'schedule', 'think'}
# ---
#
# {'global', 'consensus', 'fast', 'bogus', 'warming', 'fade'}
# ---
#
# {'global', 'consensus', 'fast', 'wente', 'mail', 'toronto', 'margaret', 'explain', 'bogus', 'globe', 'warming', 'fade'}
# ---
#
# {'climate', 'froth', 'hear', 'mouth', 'change', 'denier', 'weather', 'practically', 'confuse', 'snowstorm'}
# ---
#
# {'global', 'consensus', 'fast', 'bogus', 'warming', 'fade'}
# ---
#
# {'global', 'consensus', 'fast', 'bogus', 'warming', 'fade'}
# ---
#
# {'global', 'consensus', 'fast', 'wente', 'mail', 'toronto', 'margaret', 'explain', 'bogus', 'globe', 'warming', 'fade'}
# ---
#
# {'global', 'consensus', 'fast', 'bogus', 'warming', 'fade'}
# ---
#
# {'global', 'thing', 'morning', 'warming', 'think'}
# ---
#
# {'heavily', 'global', 'snow', 'imminent', 'sign', 'washington', 'storm', 'historic', 'explain', 'gore', 'warming', 'year'}
# ---
#
# {'global', 'debunk', 'news', 'source', 'world', 'establish', 'reality', 'warming', 'credible'}
# ---
#
# {'climate', 'untrustworthy', 'change', 'india', 'ipcc', 'abandon', 'intergovernmental', 'panel'}
# ---
#
# {'case', 'global', 'believe', 'health', 'care', 'idont', 'national', 'warming', 'stimulus'}
# ---
#
# {'climate', 'reveal', 'change', 'impact', 'ocean'}
# ---
#
# {'climate', 'brake', 'toyota', 'tell', 'digg', 'change', 'prius', 'green'}
# ---
#
# {'great', 'ipccs', 'article', 'global', 'claim', 'people', 'convince', 'explain', 'warming', 'reason'}
# ---
#
# {'climate', 'thing', 'michael', 'mifflin', 'change', 'good', 'scott', 'dunder', 'sabre'}
# ---
#
# {'global', 'hell', 'east', 'warming', 'wish', 'have', 'coast', 'love', 'frozen', 'time', 'dear'}
# ---
#
# {'great', 'global', 'paper', 'warming', 'collapse'}
# ---
#
# {'climate', 'mother', 'right', 'robert', 'change', 'people', 'world', 'boliv', 'earth', 'kick', 'eshelman', 'conference'}
# ---
#
# {'obama', 'cover', 'global', 'climategate', 'tcot', 'hand', 'snow', 'washington', 'promise', 'warming', 'year'}
# ---
#
# {'representative', 'climate', 'claim', 'aim', 'change', 'population', 'state', 'control', 'conspiracy', 'utah'}
# ---
#
# {'climate', 'cause', 'winter', 'change', 'harsh'}
# ---
#
# {'global', 'skelton', 'outlaw', 'behest', 'coal', 'peterson', 'king', 'warming', 'collin'}
# ---
#
# {'climate', 'thing', 'michael', 'mifflin', 'change', 'good', 'scott', 'dunder', 'sabre'}
# ---
#
# {'global', 'blower', 'snow', 'go', 'bad', 'warming', 'get'}
# ---
#
# {'welcome', 'climate', 'follow', 'twitter', 'blogger', 'roommate', 'change', 'make', 'stop'}
# ---
#
# {'representative', 'climate', 'claim', 'aim', 'change', 'population', 'state', 'control', 'conspiracy', 'utah'}
# ---
#
# {'wash', 'global', 'believe', 'brain', 'snow', 'institution', 'check', 'warming', 'year'}
# ---
#
# {'climate', 'wildlife', 'invasive', 'specie', 'change', 'climatechange'}
# ---
#
# {'obama', 'cover', 'global', 'climategate', 'tcot', 'hand', 'snow', 'washington', 'promise', 'warming', 'year'}
# ---
#
# {'heavily', 'global', 'snow', 'imminent', 'sign', 'washington', 'storm', 'historic', 'explain', 'gore', 'warming', 'year'}
# ---
#
# {'global', 'scientist', 'assertation', 'refute', 'warming', 'committee', 'utah'}
# ---
#
# {'global', 'fight', 'anthropogenic', 'snowpocalypse', 'need', 'effort', 'warming', 'redouble', 'remind'}
# ---
#
# {'increa', 'global', 'government', 'come', 'knee', 'ftsn', 'discredit', 'european', 'jerk', 'warming', 'news', 'alarmist'}
# ---
#
# {'climate', 'communicate', 'challenge', 'series', 'change'}
# ---
#
# {'heavily', 'global', 'snow', 'imminent', 'sign', 'washington', 'storm', 'historic', 'explain', 'gore', 'warming', 'year'}
# ---
#
# {'heavily', 'global', 'snow', 'imminent', 'sign', 'washington', 'storm', 'historic', 'explain', 'gore', 'warming', 'year'}
# ---
#
# {'heavily', 'global', 'snow', 'imminent', 'sign', 'washington', 'storm', 'historic', 'explain', 'gore', 'warming', 'year'}
# ---
#
# {'global', 'shovel', 'maddow', 'snow', 'warming', 'cold', 'accord', 'weather', 'proof', 'hour'}
# ---
#
# {'global', 'drift', 'snow', 'foot', 'fire', 'good', 'warming'}
# ---
#
# {'global', 'scoop', 'foot', 'driveway', 'motivated', 'loooooooooooooooooooooong', 'warming', 'try'}
# ---
#
# {'global', 'sunny', 'snow', 'adjust', 'washington', 'hahaha', 'heavy'}
# ---
#
# {'global', 'work', 'scientist', 'cause', 'snomg', 'ready', 'east', 'hard', 'number', 'anglia', 'assure', 'cook', 'warming'}
# ---
#
# {'global', 'work', 'scientist', 'cause', 'snomg', 'ready', 'east', 'hard', 'number', 'anglia', 'assure', 'cook', 'warming'}
# ---
#
# {'climate', 'unaltered', 'say', 'change', 'possible', 'level', 'high', 'look', 'model'}
# ---
#
# {'climate', 'real', 'debate', 'change', 'climatechange', 'manmade', 'bill', 'fuck'}
# ---
#
# {'climate', 'strong', 'change', 'storm', 'wrong', 'model'}
# ---
#
# {'climate', 'sigh', 'solar', 'factor', 'change', 'mydadisascienceprofessor', 'earth', 'activity', 'model', 'magnetic', 'field'}
# ---
#
# {'climate', 'strong', 'change', 'consistent', 'storm', 'model'}
# ---
#
# {'climate', 'useful', 'bother', 'mind', 'change', 'funding', 'research', 'taxis', 'pay'}
# ---
#
# {'global', 'thatsright', 'hate', 'winter', 'warming'}
# ---
#
# {'plane', 'global', 'punch', 'point', 'prepared', 'hoax', 'evidence', 'storm', 'friend', 'warming'}
# ---
#
# {'global', 'oddball', 'homepage', 'story', 'winter', 'link', 'check', 'weather', 'warming'}
# ---
#
# {'obama', 'global', 'tcot', 'evidence', 'beck', 'overwhelming', 'live', 'fall', 'warming', 'teaparty'}
# ---
#
# {'obama', 'report', 'global', 'tcot', 'evidence', 'beck', 'overwhelming', 'check', 'live', 'warming', 'teaparty'}
# ---
#
# {'global', 'boot', 'tell', 'like', 'storm', 'monday', 'gore', 'warming'}
# ---
#
# {'global', 'connote', 'temperature', 'know', 'physical', 'high', 'warming'}
# ---
#
# {'virginia', 'global', 'release', 'single', 'contend', 'inane', 'farce', 'warming', 'video', 'snowstorm'}
# ---
#
# {'global', 'today', 'cause', 'snomg', 'hear', 'blizzard', 'claim', 'come', 'suspect', 'usual', 'warming'}
# ---
#
# {'climate', 'invasive', 'specie', 'business', 'change', 'blog', 'india', 'period', 'thrive', 'news'}
# ---
#
# {'global', 'tcot', 'video', 'blog', 'inch', 'warming', 'post'}
# ---
#
# {'climate', 'global', 'snow', 'grasp', 'change', 'state', 'idiot', 'refute'}
# ---
#
# {'mean', 'global', 'send', 'concisely', 'idiot', 'storm', 'warming', 'year', 'farce', 'think'}
# ---
#
# {'global', 'tcot', 'right', 'record', 'evidence', 'overwhelming', 'housegop', 'fall', 'warming'}
# ---
#
# {'global', 'exist', 'agree', 'course', 'prius', 'disaster', 'warming', 'prove', 'think'}
# ---
#
# {'killer', 'climate', 'global', 'fail', 'seriously', 'stupid', 'antiscience', 'inch', 'warming'}
# ---
#
# {'student', 'global', 'fact', 'debate', 'grad', 'like', 'warm', 'earth', 'study', 'open', 'undergrad', 'science', 'prove'}
# ---
#
# {'skepticism', 'global', 'snomg', 'tempt', 'conflate', 'unfollow', 'warming'}
# ---
#
# {'climate', 'verizon', 'denialist', 'snowpocalypse', 'blizzard', 'tell', 'change', 'deep', 'inch', 'come', 'call', 'live', 'fodder'}
# ---
#
# {'climate', 'einnews', 'invasive', 'specie', 'change', 'talkiesinvasive', 'india', 'period', 'thrive', 'news', 'portugal'}
# ---
#
# {'great', 'global', 'attend', 'challenge', 'excellent', 'policy', 'meeting', 'shop', 'warming', 'board', 'present'}
# ---
#
# {'global', 'settle', 'sloppy', 'warming', 'science'}
# ---
#
# {'global', 'settle', 'sloppy', 'warming', 'science'}
# ---
#
# {'global', 'report', 'settle', 'sloppy', 'accord', 'ipcc', 'publish', 'dutch', 'warming', 'science', 'news'}
# ---
#
# {'climate', 'accelerated', 'fast', 'grow', 'forest', 'change', 'growth', 'drive', 'appear'}
# ---
#
# {'climate', 'danger', 'change', 'clear', 'know', 'video', 'present', 'human'}
# ---
#
# {'climate', 'say', 'head', 'farm', 'change', 'cost', 'study', 'legislation'}
# ---
#
# {'global', 'climategate', 'problem', 'sound', 'warming', 'science'}
# ---
#
# {'global', 'exist', 'agree', 'prius', 'disaster', 'warming', 'prove', 'think'}
# ---
#
# {'climate', 'resources', 'deny', 'change', 'pass', 'resolution', 'crazy', 'existence', 'committee', 'utah'}
# ---
#
# {'global', 'tcot', 'shovel', 'foot', 'go', 'washington', 'warming'}
# ---
#
# {'wait', 'climate', 'snowmageddon', 'story', 'caption', 'change', 'joke', 'drudge', 'matter', 'time', 'corny', 'juxtapose'}
# ---
#
# {'global', 'tcot', 'shovel', 'foot', 'go', 'washington', 'warming'}
# ---
#
# {'global', 'snow', 'blizzard', 'warming', 'rich', 'galen'}
# ---
#
# {'global', 'energy', 'take', 'calif', 'regul', 'company', 'activist', 'warming', 'news', 'february'}
# ---
#
# {'global', 'record', 'take', 'temperature', 'reach', 'tibet', 'high', 'warming', 'green'}
# ---
#
# {'global', 'climategate', 'problem', 'tcot', 'iamthemob', 'sound', 'warming', 'science'}
# ---
#
# {'virginia', 'global', 'snow', 'short', 'bunk', 'warming'}
# ---
#
# {'virginia', 'mock', 'global', 'mcdonnell', 'like', 'trust', 'party', 'warming', 'republican', 'science'}
# ---
#
# {'virginia', 'mock', 'global', 'mcdonnell', 'like', 'trust', 'party', 'warming', 'republican', 'science'}
# ---
#
# {'climate', 'home', 'picture', 'change', 'subject'}
# ---
#
# {'antarctic', 'climate', 'partake', 'change', 'research', 'bulgaria', 'expedition'}
# ---
#
# {'obama', 'climate', 'endanger', 'pika', 'change', 'protect'}
# ---
#
# {'write', 'global', 'rare', 'fail', 'snow', 'winter', 'column', 'funny', 'warming'}
# ---
#
# {'climate', 'reveal', 'change', 'impact', 'ocean', 'news'}
# ---
#
# {'climate', 'change', 'surprise', 'epic', 'snowstorm'}
# ---
#
# {'global', 'wild', 'card', 'percent', 'stratospheric', 'vapor', 'water', 'warm', 'earth', 'drop', 'mile'}
# ---
#
# {'climate', 'form', 'body', 'change', 'malthusian', 'india', 'failure'}
# ---
#
# {'climate', 'extra', 'moisture', 'snowy', 'winter', 'change', 'warm', 'duncery', 'action', 'bring'}
# ---
#
# {'climate', 'contribute', 'snowmageddon', 'change', 'snomgasm'}
# ---
#
# {'global', 'northern', 'record', 'winter', 'hemisphere', 'cold', 'snowfall', 'china', 'warming', 'europe'}
# ---
#
# {'global', 'snow', 'stop', 'unlesss', 'fall', 'warming'}
# ---
#
# {'wait', 'weird', 'global', 'blizzard', 'snowbomb', 'wave', 'consistent', 'reminder', 'warming', 'video'}
# ---
#
# {'climate', 'global', 'health', 'today', 'view', 'forum', 'start', 'change', 'presentation', 'philanthropy'}
# ---
#
# {'climate', 'hill', 'health', 'today', 'cannon', 'dirksen', 'house', 'senate', 'change', 'briefing', 'capitol', 'cosponsor', 'human'}
# ---
#
# {'climate', 'agree', 'change', 'lawmaker', 'population', 'control', 'ruse'}
# ---
#
# {'climate', 'centre', 'fund', 'luck', 'change', 'good', 'technology', 'alp', 'adaptation', 'austrian'}
# ---
#
# {'global', 'make', 'funny', 'real', 'warming'}
# ---
#
# {'global', 'ride', 'storm', 'call', 'historical', 'time', 'warming', 'hunker'}
# ---
#
# {'climate', 'different', 'deny', 'change', 'abstinence', 'info'}
# ---
#
# {'global', 'exciting', 'conclusion', 'policy', 'palin', 'stewart', 'warming', 'video', 'foreign'}
# ---
#
# {'global', 'scientist', 'pachauri', 'lead', 'warm', 'label'}
# ---
#
# {'climate', 'government', 'pika', 'find', 'wwfus', 'change', 'risk'}
# ---
#
# {'climate', 'government', 'pika', 'find', 'wwfus', 'change', 'risk'}
# ---
#
# {'climate', 'thing', 'michael', 'change', 'good', 'scott'}
# ---
#
# {'climate', 'thing', 'michael', 'change', 'good', 'scott'}
# ---
#
# {'climate', 'thing', 'michael', 'change', 'good', 'scott'}
# ---
#
# {'pete', 'global', 'terrorism', 'crisis', 'tell', 'combat', 'financial', 'leave', 'warming', 'energy'}
# ---
#
# {'climate', 'geopolitical', 'change', 'destabilizing', 'force', 'post'}
# ---
#
# {'global', 'overall', 'pretty', 'head', 'consider', 'target', 'warming', 'orderly'}
# ---
#
# {'global', 'result', 'wonder', 'massive', 'shut', 'warming', 'snowstorm'}
# ---
#
# {'ambassador', 'pablo', 'climate', 'mother', 'right', 'change', 'people', 'bolivian', 'world', 'earth', 'summit', 'solon'}
# ---
#
# {'climate', 'dailykos', 'listen', 'anymore', 'change', 'lead', 'military', 'republican'}
# ---
#
# {'climate', 'mainstream', 'grow', 'argument', 'political', 'australia', 'change', 'scepticism', 'movement', 'fringe'}
# ---
#
# {'impossible', 'climate', 'bitch', 'minute', 'change', 'rumplestiltzkin', 'meeting', 'fuckin'}
# ---
#
# {'climate', 'cause', 'show', 'mann', 'stick', 'graph', 'change', 'scrutiny', 'legit', 'hockey', 'intense', 'human'}
# ---
#
# {'global', 'seriously', 'head', 'warming', 'think'}
# ---
#
# {'climate', 'insure', 'change', 'talk', 'katrina', 'extreme', 'weather', 'expert', 'video'}
# ---
#
# {'climate', 'threaten', 'free', 'sync', 'security', 'change', 'national'}
# ---
#
# {'global', 'thank', 'plan', 'snowpocalypse', 'like', 'need', 'ruin', 'warming', 'birthday'}
# ---
#
# {'climate', 'reveal', 'change', 'acidity', 'world', 'impact', 'ocean', 'increase'}
# ---
#
# {'climate', 'reveal', 'change', 'acidity', 'world', 'impact', 'ocean', 'increase'}
# ---
#
# {'climate', 'danger', 'change', 'clear', 'post', 'present'}
# ---
#
# {'report', 'global', 'mistake', 'elevation', 'ipcc', 'warming', 'hysteria', 'netherlands'}
# ---
#
# {'climate', 'contest', 'comment', 'sure', 'change', 'world', 'check', 'leave', 'video'}
# ---
#
# {'climate', 'michael', 'corrupt', 'change', 'fanatic', 'barone', 'science'}
# ---
#
# {'climate', 'thank', 'snowpocalypse', 'change', 'kick', 'dare', 'bring', 'skis'}
# ---
#
# {'climate', 'awards', 'community', 'help', 'adapt', 'noaa', 'change', 'grant', 'mini'}
# ---
#
# {'glaciergate', 'global', 'climategate', 'start', 'go', 'truth', 'denier', 'love', 'warming'}
# ---
#
# {'glaciergate', 'global', 'climategate', 'start', 'go', 'truth', 'denier', 'love', 'warming'}
# ---
#
# {'climate', 'threaten', 'free', 'sync', 'security', 'change', 'national'}
# ---
#
# {'great', 'global', 'problem', 'caruba', 'truth', 'bryan', 'walsh', 'magazine', 'alan', 'career', 'time', 'warming'}
# ---
#
# {'climate', 'body', 'blast', 'greenpeace', 'change'}
# ---
#
# {'climate', 'global', 'battle', 'discovery', 'enlist', 'drug', 'warming', 'technique'}
# ---
#
# {'climate', 'invasive', 'thoreau', 'change', 'wood', 'plant', 'beneficiary'}
# ---
#
# {'climate', 'change', 'center', 'check', 'info', 'foundation', 'green', 'philanthropy'}
# ---
#
# {'climate', 'invasive', 'thoreau', 'change', 'wood', 'plant', 'beneficiary', 'eurekalert'}
# ---
#
# {'climate', 'poll', 'hand', 'play', 'change', 'denier', 'misreading'}
# ---
#
# {'climate', 'body', 'blast', 'greenpeace', 'change'}
# ---
#
# {'obama', 'climate', 'proven', 'tcot', 'tell', 'public', 'lindsay', 'change', 'need', 'love', 'graham', 'get'}
# ---
#
# {'climate', 'wetland', 'previously', 'change', 'sensitive', 'pothole', 'prairie', 'waterfowl', 'think'}
# ---
#
# {'global', 'event', 'prepare', 'warming', 'weekend', 'costco'}
# ---
#
# {'climate', 'indicator', 'methane', 'change', 'green'}
# ---
#
# {'climate', 'foundry', 'consensus', 'cloudy', 'scientific', 'change', 'post'}
# ---
#
# {'global', 'show', 'discuss', 'political', 'talk', 'fiction', 'warming', 'science'}
# ---
#
# {'global', 'laden', 'doomsayer', 'warming', 'join'}
# ---
#
# {'global', 'today', 'blizzard', 'tomorrow', 'call', 'real', 'warming'}
# ---
#
# {'climate', 'morning', 'geopolitic', 'mapping', 'country', 'important', 'team', 'change', 'block', 'think'}
# ---
#
# {'climate', 'sequel', 'result', 'change', 'population', 'lack', 'decline', 'wolverine', 'canada'}
# ---
#
# {'global', 'foot', 'warming', 'weekend', 'expect'}
# ---
#
# {'climate', 'threat', 'interesting', 'change', 'intel', 'surprisingly', 'compare', 'assessment'}
# ---
#
# {'global', 'technique', 'battle', 'help', 'discovery', 'drug', 'warming', 'post'}
# ---
#
# {'global', 'outside', 'start', 'snow', 'aerosol', 'warming', 'cheer', 'spray'}
# ---
#
# {'climate', 'say', 'political', 'retech', 'align', 'require', 'change', 'politic', 'efficiency', 'energycollectiv', 'economic', 'recession', 'energy', 'pena'}
# ---
#
# {'glaciergate', 'global', 'climategate', 'start', 'go', 'truth', 'denier', 'love', 'warming'}
# ---
#
# {'climate', 'industry', 'change', 'mining', 'coal', 'odd', 'caucus'}
# ---
#
# {'climate', 'say', 'official', 'change', 'error', 'despite', 'robust', 'science', 'panel'}
# ---
#
# {'climate', 'fund', 'wildlife', 'provide', 'vice', 'change', 'world', 'president', 'seek'}
# ---
#
# {'climate', 'small', 'step', 'change', 'environment', 'approach', 'transformative', 'inspire'}
# ---
#
# {'global', 'scientist', 'tcot', 'get', 'ihatethemedia', 'warming', 'message', 'warner', 'koko'}
# ---
#
# {'fossil', 'climate', 'threat', 'fuel', 'change', 'national'}
# ---
#
# {'fossil', 'climate', 'tcot', 'threat', 'fuel', 'change', 'national'}
# ---
#
# {'global', 'weekend', 'foot', 'come', 'warming', 'lovely'}
# ---
#
# {'climate', 'small', 'step', 'change', 'environment', 'approach', 'transformative', 'inspire'}
# ---
#
# {'british', 'global', 'stick', 'statistician', 'slam', 'hockey', 'gore', 'warming'}
# ---
#
# {'vancouver', 'global', 'record', 'line', 'snow', 'trend', 'winter', 'have', 'warm', 'call', 'doubt', 'warming'}
# ---
#
# {'global', 'whack', 'inside', 'upside', 'god', 'warming'}
# ---
#
# {'climate', 'senator', 'pretty', 'security', 'change', 'tie', 'issue', 'warner'}
# ---
#
# {'climate', 'senator', 'pretty', 'security', 'change', 'tie', 'issue', 'warner'}
# ---
#
# {'climate', 'senator', 'pretty', 'security', 'change', 'tie', 'issue', 'warner'}
# ---
#
# {'climate', 'senator', 'pretty', 'security', 'change', 'tie', 'issue', 'warner'}
# ---
#
# {'global', 'barney', 'frank', 'warming', 'go', 'like', 'heist', 'issue', 'jail'}
# ---
#
# {'vancouver', 'global', 'record', 'line', 'snow', 'trend', 'winter', 'warm', 'call', 'doubt', 'warming'}
# ---
#
# {'vancouver', 'global', 'record', 'line', 'snow', 'trend', 'winter', 'warm', 'call', 'doubt', 'warming'}
# ---
#
# {'climate', 'senator', 'pretty', 'security', 'change', 'tie', 'issue', 'warner'}
# ---
#
# {'hill', 'devote', 'article', 'global', 'bash', 'climate', 'noisemachine', 'baseless', 'attack', 'gore', 'warming'}
# ---
#
# {'global', 'tcot', 'ocra', 'cbiz', 'ratigan', 'snow', 'massive', 'explain', 'proof', 'dylan', 'warming', 'teaparty', 'libtard'}
# ---
#
# {'global', 'tcot', 'ocra', 'cbiz', 'ratigan', 'snow', 'massive', 'explain', 'proof', 'dylan', 'warming', 'teaparty', 'libtard'}
# ---
#
# {'global', 'tcot', 'record', 'msnbc', 'ocra', 'snow', 'east', 'reporter', 'insist', 'warming'}
# ---
#
# {'climate', 'scientist', 'believe', 'snowpocalypse', 'evidence', 'change', 'warming'}
# ---
#
# {'cite', 'global', 'country', 'hoax', 'official', 'warming', 'live', 'elect', 'proof', 'embarrassed', 'snowstorm'}
# ---
#
# {'global', 'believer', 'blizzard', 'warm', 'earthquake'}
# ---
#
# {'climate', 'believe', 'scientist', 'evidence', 'snowpocalypse', 'change', 'warm', 'evidnce', 'glbl', 'warmg'}
# ---
#
# {'decide', 'global', 'gloat', 'snow', 'rep', 'proof', 'warming', 'get'}
# ---
#
# {'climate', 'global', 'original', 'bizarre', 'change', 'funny', 'snowfall', 'warming', 'symptom', 'idiocy'}
# ---
#
# {'global', 'believe', 'read', 'snow', 'excess', 'people', 'make', 'reality', 'book', 'warming', 'think'}
# ---
#
# {'global', 'tcot', 'unreal', 'ocra', 'analysis', 'yahoo', 'blizzard', 'bad', 'make', 'warming'}
# ---
#
# {'climate', 'voice', 'global', 'group', 'bolivia', 'guardian', 'talk', 'change', 'head', 'poor', 'frontline', 'cochabamba', 'warming'}
# ---
#
# {'climate', 'change', 'reform', 'end', 'intergovernmental', 'panel'}
# ---
#
# {'global', 'snow', 'contradict', 'moron', 'theory', 'hysterical', 'hannity', 'storm', 'gore', 'warming'}
# ---
#
# {'climate', 'evolution', 'change', 'like', 'real'}
# ---
#
# {'global', 'blizzard', 'claim', 'bad', 'make', 'magazine', 'time', 'warming'}
# ---
#
# {'global', 'tcot', 'ocra', 'world', 'fragrant', 'warming'}
# ---
#
# {'obama', 'global', 'tcot', 'want', 'dfnse', 'element', 'strategy', 'warming'}
# ---
#
# {'tiny', 'climate', 'robin', 'banker', 'billion', 'change', 'tackle', 'poverty', 'hood'}
# ---
#
# {'definitely', 'article', 'global', 'blogger', 'tell', 'need', 'warming', 'shit'}
# ---
#
# {'climate', 'voice', 'global', 'group', 'bolivia', 'guardian', 'talk', 'change', 'head', 'poor', 'frontline', 'cochabamba', 'warming'}
# ---
#
# {'climate', 'collide', 'snow', 'change', 'warm', 'need', 'storm', 'word', 'drop', 'science', 'recent'}
# ---
#
# {'global', 'march', 'beach', 'worry', 'warming', 'swimming'}
# ---
#
# {'global', 'say', 'invent', 'internet', 'gore', 'warming', 'think'}
# ---
#
# {'cripple', 'global', 'agency', 'phone', 'tcot', 'ocra', 'blizzard', 'warm', 'announce'}
# ---
#
# {'skeptical', 'global', 'near', 'morning', 'effect', 'earthquakeinillinois', 'everybody', 'warming', 'think'}
# ---
#
# {'global', 'line', 'power', 'state', 'warming', 'reading'}
# ---
#
# {'global', 'fail', 'blizzard', 'bad', 'make', 'time', 'warming'}
# ---
#
# {'climate', 'modification', 'envelope', 'political', 'change', 'good', 'lack', 'like', 'weather', 'barrier', 'datum'}
# ---
#
# {'climate', 'industry', 'read', 'birth', 'change', 'entirely', 'portal'}
# ---
#
# {'follow', 'climate', 'disclosure', 'read', 'opportunitie', 'change', 'risk', 'guidance'}
# ---
#
# {'finally', 'global', 'believe', 'jerz', 'snowpocalypse', 'subpar', 'warming'}
# ---
#
# {'global', 'postpone', 'irony', 'snow', 'senate', 'hearing', 'drip', 'warmer', 'impact', 'warming', 'committee', 'algore'}
# ---
#
# {'global', 'hitler', 'climategate', 'warming', 'rate', 'star', 'video', 'youtube'}
# ---
#
# {'global', 'hitler', 'climategate', 'tweetcongress', 'check', 'michellemalkin', 'warming', 'video', 'teaparty'}
# ---
#
# {'snake', 'global', 'palin', 'warming', 'science', 'bunch'}
# ---
#
# {'climate', 'snowmageddon', 'irony', 'change', 'love', 'rearrange', 'announcement'}
# ---
#
# {'global', 'belief', 'sogb', 'role', 'purchasing', 'warming', 'green', 'human'}
# ---
#
# {'climate', 'global', 'proponent', 'change', 'consider', 'normal', 'warming'}
# ---
#
# {'climate', 'global', 'change', 'live', 'word', 'benefit'}
# ---
#
# {'climate', 'accelerate', 'conflict', 'say', 'security', 'change', 'issue', 'instability', 'energy'}
# ---
#
# {'global', 'mythbuster', 'thing', 'episode', 'confirm', 'warming', 'think'}
# ---
#
# {'melt', 'production', 'global', 'crop', 'away', 'warming'}
# ---
#
# {'climate', 'colorado', 'calif', 'change', 'tree', 'water', 'die', 'hurricane', 'katrina'}
# ---
#
# {'climate', 'article', 'chemical', 'integral', 'change', 'management', 'life', 'guest', 'daily'}
# ---
#
# {'climate', 'attention', 'spite', 'dragger', 'moron', 'change', 'knuckle', 'unusual', 'snowfall'}
# ---
#
# {'climate', 'global', 'anymore', 'change', 'oops', 'know'}
# ---
#
# {'global', 'tough', 'ledger', 'sledding', 'warming', 'star', 'alarmist'}
# ---
#
# {'create', 'global', 'tcot', 'white', 'green', 'head', 'politic', 'washington', 'warm', 'office', 'snowstorm', 'house'}
# ---
#
# {'climate', 'change', 'population', 'control', 'news'}
# ---
#
# {'global', 'unfollowe', 'cartoon', 'trite', 'warming', 'idiotic', 'mark'}
# ---
#
# {'global', 'vacation', 'summer', 'extended', 'darn', 'wrong', 'warming'}
# ---
#
# {'wash', 'global', 'record', 'snow', 'con', 'tomorrow', 'clearly', 'fall', 'warming', 'get', 'brilliant'}
# ---
#
# {'dust', 'global', 'morning', 'snow', 'inch', 'suppose', 'fairy', 'warming', 'sprinkle', 'tonight'}
# ---
#
# {'climate', 'agency', 'outside', 'dang', 'change', 'spend', 'cold', 'control', 'brilliant'}
# ---
#
# {'climate', 'april', 'stage', 'senate', 'change', 'unveiling', 'bill', 'rally'}
# ---
#
# {'climate', 'denial', 'rise', 'change', 'level'}
# ---
#
# {'obama', 'climate', 'agency', 'taxpayer', 'propose', 'change', 'excellent', 'service', 'administration', 'study', 'apparently'}
# ---
#
# {'global', 'fast', 'arctic', 'degrading', 'warming', 'think'}
# ---
#
# {'global', 'heart', 'cause', 'right', 'likely', 'winter', 'dagger', 'warming', 'republican', 'wing'}
# ---
#
# {'global', 'group', 'winter', 'people', 'warming', 'activist', 'displeased'}
# ---
#
# {'mean', 'thing', 'global', 'winter', 'stupid', 'warming', 'people', 'love', 'storm', 'shut', 'dear', 'think'}
# ---
#
# {'mean', 'thing', 'global', 'winter', 'stupid', 'warming', 'people', 'love', 'storm', 'shut', 'dear', 'think'}
# ---
#
# {'climate', 'global', 'crisis', 'hoax', 'warming'}
# ---
#
# {'climate', 'agency', 'form', 'change', 'federal', 'green'}
# ---
#
# {'climate', 'agency', 'form', 'change', 'service', 'ocean', 'national', 'federal'}
# ---
#
# {'global', 'small', 'foot', 'left', 'slightly', 'shoe', 'warming', 'look'}
# ---
#
# {'climate', 'voice', 'bolivia', 'guardian', 'talk', 'change', 'poor'}
# ---
#
# {'global', 'prevent', 'way', 'renewable', 'warming', 'energy'}
# ---
#
# {'global', 'intellectual', 'cause', 'manufacture', 'sowell', 'warming', 'youtube', 'thomas'}
# ---
#
# {'global', 'intellectual', 'peter', 'manufacture', 'sowell', 'robinson', 'warming', 'youtube', 'thomas'}
# ---
#
# {'great', 'global', 'tcot', 'warming', 'greenpolice', 'collapse'}
# ---
#
# {'climate', 'whoa', 'scandal', 'go', 'change', 'come', 'movement', 'science'}
# ---
#
# {'global', 'fast', 'grow', 'tree', 'make', 'warming', 'green'}
# ---
#
# {'climate', 'resource', 'ecomonday', 'change', 'water', 'major', 'impact', 'reuter', 'news', 'shrink'}
# ---
#
# {'devil', 'global', 'deserve', 'way', 'stop', 'ipcc', 'warming'}
# ---
#
# {'climate', 'solar', 'winter', 'experience', 'bad', 'change', 'cold', 'crush'}
# ---
#
# {'climate', 'summer', 'solar', 'change', 'minimum', 'imply', 'effort', 'intense', 'year'}
# ---
#
# {'british', 'global', 'insurer', 'social', 'association', 'economic', 'warming', 'consequence'}
# ---
#
# {'global', 'right', 'fear', 'audi', 'play', 'crazy', 'police', 'denier', 'warming', 'green', 'wing'}
# ---
#
# {'great', 'global', 'warmer', 'algore', 'warming', 'collapse'}
# ---
#
# {'global', 'near', 'record', 'view', 'washington', 'storm', 'terra', 'warming'}
# ---
#
# {'skepticism', 'global', 'finally', 'cambio', 'tcot', 'latin', 'climatechange', 'icot', 'america', 'warming'}
# ---
#
# {'global', 'acidification', 'risk', 'ocean', 'hidden', 'warming'}
# ---
#
# {'ipccs', 'gaffe', 'global', 'glacier', 'chairman', 'credibilty', 'swindle', 'increase', 'warming', 'vice', 'think'}
# ---
#
# {'melt', 'global', 'mean', 'snow', 'evidence', 'totally', 'yeah', 'warming'}
# ---
#
# {'climate', 'global', 'blog', 'change', 'center', 'compass'}
# ---
#
# {'global', 'warming', 'tomorrow', 'inch', 'damn'}
# ---
#
# {'global', 'shine', 'snow', 'chicago', 'warming', 'grass', 'karma', 'february'}
# ---
#
# {'climate', 'say', 'tcot', 'want', 'evidence', 'change', 'preach', 'care', 'libpoem', 'gore'}
# ---
#
# {'leader', 'global', 'fact', 'pachauri', 'world', 'warming', 'embattle'}
# ---
#
# {'mean', 'global', 'snow', 'cold', 'month', 'warming'}
# ---
#
# {'sceptic', 'climate', 'remain', 'priority', 'change', 'despite'}
# ---
#
# {'climate', 'scientist', 'tcot', 'want', 'role', 'change', 'lead', 'truth', 'block', 'office'}
# ---
#
# {'folk', 'global', 'tcot', 'libpoem', 'cold', 'storm', 'gore', 'warming', 'freeze'}
# ---
#
# {'folk', 'global', 'tcot', 'libpoem', 'cold', 'storm', 'gore', 'warming', 'freeze'}
# ---
#
# {'folk', 'global', 'tcot', 'cold', 'storm', 'gore', 'warming', 'freeze', 'libtard'}
# ---
#
# {'climate', 'say', 'tcot', 'want', 'evidence', 'change', 'preach', 'care', 'libpoem', 'gore'}
# ---
#
# {'climate', 'say', 'tcot', 'want', 'evidence', 'change', 'preach', 'care', 'libpoem', 'gore'}
# ---
#
# {'global', 'scientist', 'cold', 'cartoonist', 'word', 'real', 'warming', 'editorial'}
# ---
#
# {'global', 'juan', 'tell', 'walk', 'warming', 'stop', 'studio', 'damn', 'pick'}
# ---
#
# {'great', 'global', 'cause', 'hell', 'weather', 'warming', 'alarmist'}
# ---
#
# {'climate', 'home', 'australia', 'change', 'inspection', 'force', 'phony', 'expensive', 'agenda'}
# ---
#
# {'great', 'global', 'tcot', 'warming', 'well', 'unraveling', 'professional', 'look', 'job', 'alarmist', 'think'}
# ---
#
# {'happen', 'global', 'hear', 'preach', 'aman', 'national', 'warming'}
# ---
#
# {'climate', 'copenhagen', 'geldof', 'change', 'talk', 'summit'}
# ---
#
# {'melt', 'global', 'ignorance', 'spot', 'warming'}
# ---
#
# {'global', 'persist', 'snow', 'winter', 'inch', 'warming', 'myth'}
# ---
#
# {'climate', 'paralyze', 'winter', 'capital', 'change', 'mild', 'chicago', 'nation', 'pile'}
# ---
#
# {'climate', 'global', 'scientist', 'narrative', 'consensus', 'basic', 'overwhelming', 'bluff', 'warming'}
# ---
#
# {'global', 'tcot', 'ocra', 'interest', 'warming', 'conference'}
# ---
#
# {'global', 'battle', 'discovery', 'enlist', 'drug', 'warming', 'technique'}
# ---
#
# {'global', 'problem', 'truth', 'magazine', 'time', 'warming', 'gore'}
# ---
#
# {'global', 'problem', 'nobel', 'norwegian', 'truth', 'magazine', 'time', 'warming', 'committee'}
# ---
#
# {'global', 'collection', 'amusement', 'small', 'cold', 'cartoon', 'real', 'warming', 'editorial'}
# ---
#
# {'climate', 'form', 'climategate', 'body', 'warmer', 'change', 'india'}
# ---
#
# {'climate', 'report', 'term', 'right', 'observable', 'change', 'valuable', 'impact', 'visible', 'invlvmnt', 'think'}
# ---
#
# {'chamber', 'congressman', 'evil', 'global', 'liberal', 'interesting', 'washington', 'speech', 'warming', 'house'}
# ---
#
# {'melt', 'global', 'say', 'economy', 'arctic', 'cost', 'study', 'warming', 'trillion'}
# ---
#
# {'climate', 'melt', 'global', 'say', 'economy', 'arctic', 'change', 'cost', 'study', 'intergovernmental', 'trillion', 'panel'}
# ---
#
# {'global', 'fact', 'fanatic', 'gore', 'warming', 'brush'}
# ---
#
# {'climate', 'global', 'scientist', 'warmer', 'admit', 'warming', 'uncertainty'}
# ---
#
# {'climate', 'scientist', 'say', 'john', 'distinguished', 'change', 'worry', 'christy'}
# ---
#
# {'climate', 'news', 'change', 'year', 'manipulate', 'datum'}
# ---
#
# {'sceptic', 'global', 'scientist', 'climategate', 'email', 'tcot', 'ocra', 'question', 'leak', 'police', 'warming'}
# ---
#
# {'climate', 'fight', 'clean', 'change', 'demand', 'thisisourmoment', 'energy', 'join'}
# ---
#
# {'global', 'scientist', 'archive', 'warming', 'mail', 'seat', 'state', 'skeptic', 'penn'}
# ---
#
# {'global', 'scientist', 'archive', 'warming', 'mail', 'seat', 'state', 'skeptic', 'penn'}
# ---
#
# {'global', 'work', 'greenpeace', 'change', 'stop', 'world', 'warming', 'look'}
# ---
#
# {'fossil', 'climate', 'redstate', 'great', 'chart', 'vladimir', 'tcot', 'threat', 'fuel', 'change', 'blog', 'national', 'include'}
# ---
#
# {'global', 'luck', 'help', 'warming', 'good', 'stop', 'family'}
# ---
#
# {'melt', 'global', 'say', 'news', 'prove', 'glacier', 'false', 'warming', 'datum'}
# ---
#
# {'climate', 'global', 'warm', 'stop', 'warming'}
# ---
#
# {'global', 'economy', 'show', 'record', 'unemployment', 'rise', 'sign', 'cold', 'sound', 'fall', 'warming', 'think'}
# ---
#
# {'climate', 'schultz', 'change', 'university', 'harvard', 'long', 'glen', 'culture'}
# ---
#
# {'climate', 'thing', 'theoffice', 'michael', 'change', 'good', 'scott'}
# ---
#
# {'global', 'arguement', 'existence', 'bane', 'warming'}
# ---
#
# {'global', 'climategate', 'tcot', 'ocra', 'disclose', 'warming', 'shareholder', 'risk', 'demand', 'firm'}
# ---
#
# {'climate', 'economy', 'energy', 'future', 'help', 'propose', 'brighten', 'change', 'blog', 'state', 'wisconsin', 'post', 'legislation'}
# ---
#
# {'global', 'recycle', 'burn', 'contributor', 'gallon', 'major', 'carbon', 'dioxide', 'warming', 'create'}
# ---
#
# {'global', 'liberal', 'secular', 'sacred', 'warming', 'cow', 'religion'}
# ---
#
# {'climate', 'michael', 'corrupt', 'change', 'fanatic', 'gopusa', 'barone', 'science'}
# ---
#
# {'climate', 'tcot', 'ocra', 'change', 'ruse', 'unravels'}
# ---
#
# {'climate', 'change', 'olympic', 'bronze', 'get'}
# ---
#
# {'climate', 'british', 'inquiry', 'tcot', 'find', 'change', 'check', 'reality', 'distortion', 'science', 'datum'}
# ---
#
# {'pilot', 'global', 'tcot', 'ocra', 'episode', 'warming'}
# ---
#
# {'happen', 'global', 'snow', 'stop', 'maple', 'pack', 'syrup', 'warming'}
# ---
#
# {'climate', 'global', 'kid', 'war', 'scene', 'warming'}
# ---
#
# {'global', 'debunk', 'denier', 'page', 'swindle', 'warming'}
# ---
#
# {'global', 'contribute', 'kid', 'ozone', 'warming', 'standard'}
# ---
#
# {'obama', 'climate', 'global', 'clean', 'right', 'solution', 'coal', 'bill', 'warming', 'energy'}
# ---
#
# {'obama', 'climate', 'global', 'clean', 'right', 'solution', 'coal', 'bill', 'warming', 'energy'}
# ---
#
# {'global', 'intellectualism', 'snow', 'fine', 'anti', 'photo', 'warming', 'myth', 'brooklynmutt'}
# ---
#
# {'climate', 'global', 'fact', 'logic', 'argument', 'change', 'people', 'like', 'warming'}
# ---
#
# {'climate', 'doubter', 'twain', 'right', 'change', 'washington', 'spur', 'snowmaggedon', 'expect', 'mark'}
# ---
#
# {'climate', 'doubter', 'twain', 'right', 'change', 'washington', 'spur', 'snowmaggedon', 'expect', 'mark'}
# ---
#
# {'lately', 'global', 'record', 'want', 'snow', 'trend', 'hear', 'break', 'expert', 'gore', 'warming', 'fall'}
# ---
#
# {'sheet', 'global', 'polar', 'vulnerable', 'orlean', 'earth', 'moderate', 'warming', 'southern'}
# ---
#
# {'massachusetts', 'global', 'crisis', 'main', 'picture', 'worth', 'strike', 'scare', 'redux', 'warming', 'cambridge', 'moonbattery'}
# ---
#
# {'global', 'hurricane', 'drought', 'protective', 'dent', 'increase', 'warming', 'shield', 'atlantic'}
# ---
#
# {'global', 'tcot', 'record', 'hold', 'snow', 'senate', 'disprove', 'meeting', 'fall', 'warming', 'illiterate'}
# ---
#
# {'global', 'show', 'snow', 'book', 'gore', 'warming', 'straight', 'news'}
# ---
#
# {'brewer', 'global', 'claim', 'heavy', 'snowfall', 'warming', 'video', 'prove'}
# ---
#
# {'global', 'cause', 'warming', 'frame', 'reference', 'snowstorm'}
# ---
#
# {'global', 'tcot', 'summer', 'snow', 'winter', 'disprove', 'warming', 'prove'}
# ---
#
# {'global', 'tcot', 'summer', 'snow', 'winter', 'disprove', 'warming', 'prove'}
# ---
#
# {'global', 'tcot', 'summer', 'snow', 'winter', 'disprove', 'warming', 'prove'}
# ---
#
# {'climate', 'tcot', 'temp', 'record', 'hot', 'hear', 'change', 'hemisphere', 'denier', 'dear', 'southern'}
# ---
#
# {'climate', 'receive', 'corp', 'change', 'world', 'check', 'exxonmobil', 'skeptic', 'newspaper'}
# ---
#
# {'climate', 'global', 'fight', 'grow', 'amid', 'time', 'washington', 'federal', 'warming', 'accuracy', 'office', 'datum'}
# ---
#
# {'global', 'fear', 'guilt', 'mandate', 'social', 'like', 'obesity', 'control', 'govt', 'child', 'high', 'warming', 'taxis', 'economically', 'seek'}
# ---
#
# {'global', 'senseless', 'switch', 'priority', 'primary', 'regain', 'concern', 'democrats', 'control', 'warming', 'house'}
# ---
#
# {'push', 'global', 'tcot', 'elite', 'todate', 'social', 'power', 'enrich', 'child', 'gore', 'warming', 'obesity', 'agenda'}
# ---
#
# {'happen', 'climate', 'global', 'snowmageddon', 'probably', 'east', 'answer', 'wonder', 'coast', 'blizzarde', 'warming'}
# ---
#
# {'climate', 'evolution', 'change', 'like', 'real'}
# ---
#
# {'global', 'believe', 'malleable', 'climategate', 'snow', 'idiot', 'cont', 'storm', 'warming', 'prove', 'think'}
# ---
#
# {'global', 'architecture', 'battle', 'white', 'nytime', 'climatechange', 'warming', 'roof'}
# ---
#
# {'climate', 'blizzard', 'claim', 'change', 'people', 'tomorrow', 'disprove', 'clearly'}
# ---
#
# {'global', 'pathetic', 'liberal', 'represent', 'fanatic', 'woman', 'stmt', 'ensler', 'warming', 'vaginas', 'behar', 'yack'}
# ---
#
# {'climate', 'student', 'dissertation', 'tcot', 'claim', 'change', 'outrage', 'base', 'panel', 'medium'}
# ---
#
# {'global', 'snowmageddon', 'disprove', 'wrong', 'warming', 'think'}
# ---
#
# {'report', 'fact', 'global', 'blizzard', 'stupid', 'time', 'bad', 'make', 'junk', 'warming', 'science', 'think'}
# ---
#
# {'global', 'baltimore', 'snow', 'theory', 'england', 'warming'}
# ---
#
# {'climate', 'say', 'change', 'tepid', 'agreement', 'envoy', 'china'}
# ---
#
# {'global', 'indicate', 'scientific', 'review', 'world', 'major', 'fragrant', 'warming', 'london'}
# ---
#
# {'global', 'west', 'northwest', 'magnitude', 'part', 'chicago', 'jolt', 'quake', 'warming', 'illinois', 'mile', 'earthquake'}
# ---
#
# {'global', 'blizzard', 'bad', 'make', 'warming', 'snowstorm'}
# ---
#
# {'happen', 'global', 'wednesday', 'brandon', 'bryan', 'walsh', 'alex', 'warming', 'snowstorm'}
# ---
#
# {'climate', 'invasive', 'source', 'thoreau', 'change', 'wood', 'plant', 'beneficiary', 'science', 'daily'}
# ---
#
# {'mock', 'global', 'believe', 'ackroyd', 'ignorant', 'quote', 'idiot', 'palin', 'slut', 'warming', 'anchor', 'behar'}
# ---
#
# {'climate', 'organic', 'effect', 'change', 'farming', 'earth'}
# ---
#
# {'liberalism', 'pathetic', 'global', 'monologue', 'topic', 'vagina', 'demente', 'important', 'warming', 'think'}
# ---
#
# {'global', 'fonda', 'people', 'cont', 'freaking', 'crank', 'jane', 'certifiably', 'rest', 'warming'}
# ---
#
# {'true', 'global', 'thing', 'exist', 'winter', 'false', 'warming', 'hysteria', 'prove', 'presume'}
# ---
#
# {'true', 'global', 'thing', 'exist', 'winter', 'false', 'warming', 'hysteria', 'prove', 'presume'}
# ---
#
# {'global', 'deluge', 'warming', 'tonight', 'expect'}
# ---
#
# {'global', 'energy', 'ford', 'unveil', 'warming', 'news', 'february'}
# ---
#
# {'global', 'natural', 'change', 'clockwork', 'like', 'state', 'kind', 'warming', 'landscape'}
# ---
#
# {'snake', 'global', 'angeles', 'call', 'palin', 'warming', 'science', 'bunch'}
# ---
#
# {'climate', 'humor', 'winter', 'change', 'worshiper', 'sense', 'proof', 'expense'}
# ---
#
# {'global', 'support', 'credence', 'newt', 'like', 'warming', 'give'}
# ---
#
# {'creator', 'global', 'monologue', 'vagina', 'tsunamis', 'tell', 'look', 'palin', 'proof', 'warming', 'brilliant', 'earthquake'}
# ---
#
# {'snake', 'climate', 'global', 'governor', 'dismiss', 'change', 'research', 'palin', 'warming', 'news', 'alaska'}
# ---
#
# {'wait', 'global', 'tcot', 'snomg', 'hear', 'trend', 'environitwit', 'ecofascism', 'warming'}
# ---
#
# {'global', 'scientist', 'tcot', 'lunch', 'break', 'warm', 'photo'}
# ---
#
# {'acorn', 'global', 'prostitution', 'tcot', 'nambla', 'democrat', 'support', 'atheist', 'beck', 'abortion', 'homosexuality', 'party', 'warming', 'eciu', 'news'}
# ---
#
# {'climate', 'hoax', 'change', 'like', 'cold', 'love', 'lottery'}
# ---
#
# {'climate', 'tcot', 'sciencefail', 'go', 'change', 'warm', 'justsayin', 'asshat', 'matter'}
# ---
#
# {'conservative', 'global', 'suspend', 'ballot', 'thought', 'measure', 'warming', 'california'}
# ---
#
# {'climate', 'vancouver', 'venue', 'stubborn', 'absence', 'snow', 'change', 'washington', 'denier', 'olympics', 'squawk'}
# ---
#
# {'global', 'snomg', 'officially', 'hear', 'joke', 'need', 'crack', 'warming', 'save', 'create'}
# ---
#
# {'global', 'salt', 'question', 'bernick', 'lake', 'city', 'democrats', 'legislature', 'formally', 'warming', 'utah', 'house'}
# ---
#
# {'big', 'global', 'like', 'theory', 'noahs', 'rain', 'warming', 'supporter', 'fuck'}
# ---
#
# {'global', 'illusion', 'extend', 'hologram', 'lalala', 'warming'}
# ---
#
# {'climate', 'snake', 'dismiss', 'change', 'palin', 'science'}
# ---
#
# {'snake', 'global', 'event', 'today', 'speak', 'call', 'palin', 'warming', 'science', 'bunch'}
# ---
#
# {'snake', 'global', 'event', 'today', 'speak', 'call', 'palin', 'warming', 'science', 'bunch'}
# ---
#
# {'climate', 'conservative', 'global', 'brain', 'noisemachine', 'winter', 'weather', 'attack', 'warming', 'freeze', 'medium'}
# ---
#
# {'climate', 'solar', 'change', 'combat', 'expert', 'energy'}
# ---
#
# {'climate', 'longnowfoundation', 'version', 'change', 'recalculate', 'foratv', 'watch'}
# ---
#
# {'global', 'wednesday', 'winter', 'public', 'tomorrow', 'close', 'snowstorm', 'warming', 'school', 'expect'}
# ---
#
# {'snake', 'global', 'call', 'palin', 'warming', 'science', 'bunch'}
# ---
#
# {'global', 'fast', 'angeles', 'prompt', 'break', 'hard', 'fall', 'area', 'warming', 'news', 'evacuation'}
# ---
#
# {'snake', 'global', 'task', 'sarah', 'palin', 'force', 'warming', 'science', 'bunch', 'alaska'}
# ---
#
# {'climate', 'sierra', 'future', 'place', 'peril', 'winter', 'change', 'alp', 'olympic'}
# ---
#
# {'global', 'fast', 'grow', 'forest', 'tree', 'warming'}
# ---
#
# {'great', 'global', 'truth', 'come', 'warming', 'collapse'}
# ---
#
# {'snake', 'truthdig', 'global', 'logging', 'research', 'call', 'palin', 'speech', 'warming', 'science'}
# ---
#
# {'climate', 'global', 'stoopid', 'change', 'storm'}
# ---
#
# {'climate', 'solar', 'change', 'combat', 'expert', 'energy'}
# ---
#
# {'geoengineere', 'climate', 'inevitable', 'play', 'pretense', 'false', 'energy'}
# ---
#
# {'great', 'upcoming', 'global', 'denyer', 'near', 'work', 'shooting', 'greenpeace', 'perfect', 'warming', 'video'}
# ---
#
# {'global', 'allegation', 'clear', 'launch', 'expert', 'investigation', 'warming'}
# ---
#
# {'climate', 'edition', 'change', 'thread', 'open', 'tuesday'}
# ---
#
# {'global', 'thing', 'beforemetscardsend', 'warming', 'past'}
# ---
#
# {'climate', 'obama', 'big', 'want', 'snowbama', 'snow', 'change', 'go', 'brace', 'know', 'denier', 'blame', 'extremist'}
# ---
#
# {'melt', 'global', 'away', 'effect', 'warm', 'warming'}
# ---
#
# {'melt', 'global', 'production', 'crop', 'away', 'warming'}
# ---
#
# {'climate', 'mean', 'global', 'nature', 'stupid', 'change', 'oops', 'people', 'cooling', 'argh', 'oop', 'blame', 'warming', 'planet'}
# ---
#
# {'global', 'host', 'precipitation', 'result', 'ratigan', 'climat', 'snowpocalypse', 'claim', 'heavy', 'blame', 'warming'}
# ---
#
# {'global', 'institute', 'grandchild', 'james', 'warn', 'earth', 'storm', 'book', 'hansen', 'warming'}
# ---
#
# {'ultimate', 'global', 'shocking', 'warming', 'store', 'information', 'ebook'}
# ---
#
# {'obama', 'climate', 'government', 'tcot', 'help', 'adapt', 'business', 'noaa', 'live', 'planet', 'create'}
# ---
#
# {'report', 'global', 'cali', 'environment', 'implement', 'attack', 'opponent', 'warming'}
# ---
#
# {'global', 'scientist', 'montgomery', 'winter', 'harsh', 'despite', 'jeff', 'real', 'warming', 'news', 'february', 'journal'}
# ---
#
# {'report', 'global', 'undermine', 'exxon', 'public', 'acceptance', 'campaign', 'warming', 'orchestrate'}
# ---
#
# {'global', 'heat', 'take', 'everyday', 'ipcc', 'dark', 'real', 'warming', 'climb', 'myth'}
# ---
#
# {'agency', 'report', 'global', 'propose', 'herald', 'administration', 'warm', 'study', 'news', 'durango'}
# ---
#
# {'climate', 'global', 'climategate', 'tcot', 'take', 'snow', 'tlot', 'washington', 'joke', 'ipcc', 'warming', 'think'}
# ---
#
# {'global', 'scientist', 'cont', 'crooked', 'warming', 'medium'}
# ---
#
# {'global', 'sincerely', 'effect', 'stop', 'deadly', 'solution', 'earth', 'warming', 'instant'}
# ---
#
# {'skeptical', 'global', 'poll', 'statewide', 'show', 'percent', 'nevadan', 'think'}
# ---
#
# {'global', 'tcot', 'find', 'million', 'gore', 'warming', 'protest'}
# ---
#
# {'climate', 'report', 'change', 'error', 'ipcc'}
# ---
#
# {'climate', 'global', 'change', 'warming', 'prove', 'datum'}
# ---
#
# {'climate', 'note', 'sunstein', 'change', 'justice', 'look', 'cass'}
# ---
#
# {'obama', 'agency', 'climate', 'work', 'want', 'change', 'study', 'dollar'}
# ---
#
# {'global', 'say', 'rogge', 'course', 'world', 'worry', 'warming', 'entire'}
# ---
#
# {'climate', 'screw', 'report', 'snow', 'east', 'change', 'darn', 'cold', 'maybe', 'freeze', 'green'}
# ---
#
# {'warmi', 'global', 'draconian', 'fight', 'view', 'rush', 'new', 'theory', 'regulation', 'warming', 'impose', 'blow'}
# ---
#
# {'global', 'fact', 'cause', 'archive', 'blog', 'toolshed', 'warming', 'green', 'myth'}
# ---
#
# {'global', 'fact', 'archive', 'evidence', 'blog', 'toolshed', 'warming', 'green', 'myth'}
# ---
#
# {'global', 'scientist', 'spring', 'warming', 'begin', 'week', 'early'}
# ---
#
# {'global', 'justify', 'like', 'yeah', 'real', 'warming', 'fake'}
# ---
#
# {'bomb', 'global', 'worker', 'scolding', 'debt', 'govt', 'hard', 'china', 'time', 'warming', 'president', 'shame'}
# ---
#
# {'climate', 'migration', 'change', 'alter', 'whale', 'gray'}
# ---
#
# {'climate', 'migration', 'change', 'alter', 'whale', 'gray'}
# ---
#
# {'climate', 'migration', 'change', 'alter', 'whale', 'gray'}
# ---
#
# {'global', 'ozone', 'boost', 'layer', 'warming', 'save'}
# ---
#
# {'mean', 'thing', 'global', 'winter', 'stupid', 'warming', 'people', 'love', 'storm', 'shut', 'dear', 'think'}
# ---
#
# {'global', 'way', 'stop', 'fundamental', 'warming'}
# ---
#
# {'climate', 'cause', 'change', 'decline', 'wolverine', 'canada'}
# ---
#
# {'inadvertently', 'global', 'definitive', 'propose', 'moron', 'warming', 'brilliant'}
# ---
#
# {'climate', 'agency', 'form', 'times', 'angeles', 'change', 'federal'}
# ---
#
# {'mean', 'thing', 'global', 'winter', 'stupid', 'warming', 'people', 'love', 'storm', 'shut', 'dear', 'think'}
# ---
#
# {'global', 'result', 'pseudo', 'scientific', 'research', 'ipcc', 'trust', 'time', 'warming', 'long', 'hydrology'}
# ---
#
# {'global', 'scientist', 'effect', 'water', 'major', 'tie', 'warming'}
# ---
#
# {'global', 'alternative', 'source', 'warm', 'warming', 'energy'}
# ---
#
# {'kennedy', 'global', 'predict', 'tcot', 'robert', 'snow', 'month', 'warming'}
# ---
#
# {'global', 'scientist', 'hire', 'fraud', 'india', 'ipcc', 'trust', 'study', 'lie', 'warming', 'long', 'corruption'}
# ---
#
# {'global', 'work', 'april', 'senate', 'unveil', 'swindle', 'bill', 'warming', 'video'}
# ---
#
# {'climate', 'organic', 'thing', 'go', 'farm', 'change', 'know', 'rest', 'easy'}
# ---
#
# {'obama', 'agency', 'climate', 'deal', 'globalwarminghoax', 'change', 'powerelitescam', 'create'}
# ---
#
# {'global', 'wealth', 'free', 'elite', 'manipulation', 'theme', 'social', 'power', 'promote', 'bird', 'despise', 'like', 'gore', 'warming', 'seek'}
# ---
#
# {'climate', 'agency', 'tcot', 'white', 'comment', 'propose', 'change', 'study', 'post', 'house'}
# ---
#
# {'climate', 'agency', 'propose', 'change', 'administration', 'study'}
# ---
#
# {'climate', 'agency', 'propose', 'change', 'administration', 'study'}
# ---
#
# {'climate', 'hear', 'lose', 'change', 'munichre', 'kind', 'allianz', 'surprised', 'lot', 'insurance'}
# ---
#
# {'global', 'stand', 'cause', 'arise', 'likely', 'australia', 'drought', 'warming', 'long'}
# ---
#
# {'global', 'scientist', 'climategate', 'contemplate', 'skeptic', 'warming', 'suicide'}
# ---
#
# {'climate', 'agency', 'obama', 'form', 'repor', 'propose', 'change', 'administration', 'study', 'federal'}
# ---
#
# {'global', 'africa', 'pbls', 'warming', 'science'}
# ---
#
# {'climate', 'agency', 'form', 'change', 'service', 'federal'}
# ---
#
# {'climate', 'happen', 'global', 'scandal', 'expose', 'change', 'stuff', 'maaaan', 'hope', 'real', 'warming', 'science'}
# ---
#
# {'production', 'global', 'report', 'free', 'cover', 'opalesque', 'commodity', 'briefing', 'update', 'warming', 'rice', 'daily'}
# ---
#
# {'global', 'event', 'algae', 'current', 'control', 'warming', 'news'}
# ---
#
# {'global', 'work', 'april', 'senate', 'unveil', 'swindle', 'bill', 'warming', 'video'}
# ---
#
# {'global', 'event', 'algae', 'current', 'control', 'warming', 'news'}
# ---
#
# {'global', 'retrain', 'worker', 'address', 'coal', 'warming', 'green', 'job'}
# ---
#
# {'climate', 'accelerated', 'fast', 'grow', 'daily', 'forest', 'change', 'growth', 'drive', 'science', 'appear'}
# ---
#
# {'obama', 'global', 'strong', 'healthcare', 'peace', 'care', 'have', 'marxism', 'warming', 'base', 'myth', 'religion'}
# ---
#
# {'global', 'healing', 'hole', 'ozone', 'warming'}
# ---
#
# {'daughter', 'global', 'say', 'cool', 'warming'}
# ---
#
# {'global', 'hurricane', 'drought', 'protective', 'dent', 'increase', 'warming', 'shield', 'atlantic'}
# ---
#
# {'climate', 'core', 'change', 'water', 'impact', 'expert'}
# ---
#
# {'climate', 'ignore', 'media', 'change', 'storm'}
# ---
#
# ...
# ---
#
# {'global', 'mercury', 'soar', 'blame', 'environmentalist', 'attribute'}
# ---
#
# {'global', 'believe', 'april', 'minneapolis', 'spring', 'letter', 'warm', 'skeptic', 'freeze'}
# ---
#
# {'frighten', 'global', 'liberal', 'find', 'meet', 'like', 'badly', 'sarah', 'palin', 'warming', 'get'}
# ---
#
# {'global', 'volcano', 'matai', 'link', 'warming', 'earthquake'}
# ---
#
# {'climate', 'cover', 'volcano', 'question', 'change', 'answer'}
# ---
#
# {'global', 'solution', 'tough', 'emission', 'control', 'greenhouse', 'warming', 'nation'}
# ---
#
# {'climate', 'great', 'global', 'believe', 'group', 'conversation', 'natural', 'explanati', 'blunder', 'warming', 'potential'}
# ---
#
# {'phil', 'global', 'figure', 'action', 'hope', 'redeye', 'warming', 'tugboat'}
# ---
#
# {'global', 'madness', 'cause', 'lovecraftian', 'thawing', 'uncover', 'induce', 'bury', 'gaze', 'warming', 'shit'}
# ---
#
# {'climate', 'cover', 'volcano', 'question', 'change', 'answer'}
# ---
#
# {'climate', 'cover', 'volcano', 'question', 'change', 'answer', 'suvs', 'think'}
# ---
#
# {'suuuuure', 'global', 'land', 'cause', 'sea', 'flow', 'warn', 'glacier', 'warming', 'earthquake'}
# ---
#
# {'climate', 'neutral', 'corp', 'aim', 'change', 'promote', 'carbon', 'news'}
# ---
#
# {'global', 'april', 'talk', 'topi', 'presentation', 'film', 'warming', 'scientifique', 'present'}
# ---
#
# {'global', 'kiddo', 'think', 'miss', 'newyork', 'florida', 'waiting', 'win', 'warming', 'nice'}
# ---
#
# {'global', 'kiddo', 'think', 'miss', 'newyork', 'florida', 'waiting', 'win', 'warming', 'nice'}
# ---
#
# {'global', 'kiddo', 'think', 'miss', 'newyork', 'florida', 'waiting', 'win', 'warming', 'nice'}
# ---
#
# {'global', 'kiddo', 'think', 'miss', 'newyork', 'florida', 'waiting', 'win', 'warming', 'nice'}
# ---
#
# {'global', 'kiddo', 'think', 'miss', 'newyork', 'florida', 'waiting', 'win', 'warming', 'nice'}
# ---
#
# {'global', 'speak', 'theater', 'loorz', 'clim', 'presentation', 'palace', 'warming', 'year', 'give', 'alec'}
# ---
#
# {'climate', 'cover', 'volcano', 'question', 'change', 'answer'}
# ---
#
# {'climate', 'cover', 'volcano', 'question', 'change', 'answer'}
# ---
#
# {'global', 'climategate', 'ignore', 'scandal', 'advance', 'left', 'warming', 'wing', 'agenda'}
# ---
#
# {'global', 'rich', 'journalism', 'warming', 'decade', 'calle', 'advocacy', 'year', 'noye'}
# ---
#
# {'climate', 'ardebate', 'deny', 'primary', 'change', 'realize', 'arkansa', 'taxer', 'fair'}
# ---
#
# {'global', 'meet', 'appetit', 'calculator', 'management', 'carbon', 'company', 'warming', 'food', 'weight'}
# ---
#
# {'british', 'global', 'doubter', 'tcot', 'nobama', 'want', 'tlot', 'throw', 'lawyer', 'cide', 'warming', 'taxandtrade', 'jail'}
# ---
#
# {'climate', 'global', 'tcot', 'freedom', 'volcanic', 'tlot', 'check', 'blame', 'eruption', 'warming', 'icelandic', 'iceland'}
# ---
#
# {'climate', 'cover', 'volcano', 'question', 'change', 'answer', 'iceland', 'eruption', 'eyjafjallajo', 'mountain'}
# ---
#
# {'initiative', 'global', 'ballot', 'teamster', 'weigh', 'city', 'state', 'warming', 'california'}
# ---
#
# {'climate', 'april', 'tuesday', 'change', 'redaction', 'failure', 'avoid', 'ahora', 'seek'}
# ---
#
# {'climate', 'neutral', 'corp', 'aim', 'change', 'promote', 'carbon', 'news'}
# ---
#
# {'climate', 'report', 'solar', 'change', 'environment', 'renewable', 'cleantech', 'green', 'energy'}
# ---
#
# {'climate', 'true', 'change', 'come', 'dream', 'theologian', 'totalitarian'}
# ---
#
# {'climate', 'instead', 'phrase', 'change', 'good', 'like', 'environmentally', 'damage', 'respectful', 'word', 'behavior'}
# ---
#
# {'climate', 'supply', 'tourism', 'effect', 'change', 'post'}
# ---
#
# {'global', 'bizarre', 'view', 'interesting', 'unforseen', 'number', 'satirical', 'warming', 'consequence'}
# ---
#
# {'climate', 'institute', 'solar', 'lecture', 'change', 'energy'}
# ---
#
# {'folk', 'global', 'flower', 'go', 'tree', 'plant', 'warming', 'hillary', 'gavan'}
# ---
#
# {'critic', 'global', 'manzi', 'effective', 'data', 'drive', 'zealot', 'warming'}
# ---
#
# {'climate', 'global', 'houston', 'hoax', 'talk', 'expert', 'warming', 'pollution', 'alarmist'}
# ---
#
# {'climate', 'free', 'bonnaroo', 'change', 'good', 'download', 'album'}
# ---
#
# {'global', 'earth', 'marklevinshow', 'smack', 'zealot', 'warming'}
# ---
#
# {'climate', 'scientist', 'help', 'change', 'understand', 'watch', 'video', 'amazing', 'image'}
# ---
#
# {'global', 'mother', 'bolivia', 'lifeline', 'combat', 'earth', 'summit', 'warming', 'worl', 'seek'}
# ---
#
# {'climate', 'mancuso', 'julia', 'senate', 'change', 'miller', 'pass', 'bode', 'legislation'}
# ---
#
# {'climate', 'system', 'organic', 'consumer', 'change', 'earthday', 'assoc'}
# ---
#
# {'obama', 'light', 'global', 'bulb', 'change', 'truth', 'brian', 'warming', 'solve', 'fuck', 'house'}
# ---
#
# {'average', 'global', 'thought', 'rise', 'warming', 'refer'}
# ---
#
# {'global', 'mainstream', 'journalism', 'warming', 'decade', 'call', 'advocacy', 'year'}
# ---
#
# {'global', 'naughton', 'help', 'tomorrow', 'american', 'come', 'earth', 'million', 'warming', 'homework', 'schoolchil'}
# ---
#
# {'global', 'comedian', 'joke', 'know', 'warming', 'datum'}
# ---
#
# {'global', 'article', 'tcot', 'liberal', 'cultism', 'excellent', 'warming', 'fellow'}
# ---
#
# {'climate', 'convention', 'global', 'perception', 'change', 'intl', 'public', 'hunger', 'agricultural', 'biotech', 'highlight'}
# ---
#
# {'climate', 'change', 'open', 'tiquipaya', 'morale', 'conference'}
# ---
#
# {'climate', 'encyclopedia', 'guide', 'visual', 'change', 'weather', 'complete', 'recommend'}
# ---
#
# {'climate', 'hit', 'change', 'river', 'need', 'disaster', 'delta', 'video', 'california'}
# ---
#
# {'inconvenient', 'climate', 'fight', 'change', 'stop', 'teen', 'shop', 'youth'}
# ---
#
# {'inconvenient', 'climate', 'fight', 'change', 'stop', 'teen', 'shop', 'youth'}
# ---
#
# {'global', 'want', 'kill', 'stop', 'join', 'warming', 'valero'}
# ---
#
# {'climate', 'global', 'volcano', 'change', 'trigger', 'warming', 'think'}
# ---
#
# {'climate', 'folk', 'global', 'pollution', 'switch', 'fight', 'change', 'warming', 'message'}
# ---
#
# {'global', 'reduce', 'effect', 'major', 'company', 'warming'}
# ---
#
# {'climate', 'biotechnology', 'innovation', 'reduce', 'role', 'change', 'emission', 'summit', 'leadership', 'highlight'}
# ---
#
# {'inconvenient', 'climate', 'change', 'tackle', 'youth'}
# ---
#
# {'climate', 'bolivia', 'interview', 'change', 'watch', 'conference', 'cochabamba', 'star', 'pocahontas'}
# ---
#
# {'global', 'tell', 'blog', 'ocregister', 'warming', 'hoot', 'exactly'}
# ---
#
# {'climate', 'sustainability', 'change', 'address', 'win'}
# ---
#
# {'global', 'economist', 'view', 'profit', 'good', 'talk', 'class', 'confuse', 'warming', 'think'}
# ---
#
# {'global', 'lukas', 'environmentalism', 'claim', 'ethanol', 'dark', 'environmentalist', 'moral', 'carrie', 'warming'}
# ---
#
# {'climate', 'better', 'change', 'buyer', 'dumb', 'loser'}
# ---
#
# {'climate', 'workshop', 'today', 'vegas', 'desert', 'usgs', 'change'}
# ---
#
# {'climate', 'report', 'mother', 'jones', 'change', 'back', 'impact', 'launch', 'slate', 'response', 'wire', 'atlantic'}
# ---
#
# {'climate', 'report', 'mother', 'jones', 'change', 'back', 'impact', 'launch', 'slate', 'response', 'wire', 'atlantic'}
# ---
#
# {'climate', 'indigenous', 'global', 'thank', 'partcipation', 'people', 'change', 'world', 'summit', 'sister', 'earthright'}
# ---
#
# {'climate', 'slowly', 'start', 'evolution', 'change', 'polarbear', 'cutie'}
# ---
#
# {'alarmism', 'global', 'reach', 'apex', 'world', 'run', 'short', 'time', 'warming'}
# ---
#
# {'climate', 'thing', 'different', 'global', 'cause', 'atmosphere', 'change', 'increase', 'warming'}
# ---
#
# {'climate', 'ppls', 'earthweek', 'bolivia', 'change', 'people', 'world', 'earthday', 'conference'}
# ---
#
# {'global', 'feel', 'fight', 'good', 'like', 'warm', 'fantasy', 'video', 'youtube'}
# ---
#
# {'global', 'rasmussen', 'voter', 'report', 'april', 'seriously', 'monday', 'corner', 'skeptic', 'warming'}
# ---
#
# {'climate', 'scientist', 'rehabilitate', 'news', 'volcanic', 'change', 'brkg', 'sue', 'eruption', 'announce', 'get', 'panel', 'iceland'}
# ---
#
# {'global', 'set', 'april', 'record', 'prove', 'warming', 'heatwave'}
# ---
#
# {'global', 'thaw', 'turn', 'reuters', 'cause', 'climat', 'oslo', 'decade', 'cap', 'come', 'ashe', 'warming', 'myth'}
# ---
#
# {'alarmism', 'global', 'world', 'run', 'short', 'time', 'warming', 'pollution'}
# ---
#
# {'climate', 'treehugger', 'political', 'effect', 'change', 'environment', 'economic', 'earthquake'}
# ---
#
# {'mckibben', 'global', 'bill', 'talk', 'cool', 'time', 'warming', 'changin'}
# ---
#
# {'climate', 'adapt', 'change', 'hominid', 'past'}
# ---
#
# {'great', 'climate', 'aspect', 'history', 'site', 'natural', 'change', 'break', 'environment', 'earth', 'news'}
# ---
#
# {'signal', 'global', 'volcano', 'tcot', 'msnbc', 'carter', 'glenn', 'jimmy', 'smoke', 'send', 'beck', 'gore', 'warming', 'news', 'nowplaying', 'algore'}
# ---
#
# {'global', 'government', 'come', 'knee', 'discredit', 'prison', 'european', 'jerk', 'warming', 'alarmist'}
# ---
#
# {'ambassador', 'pablo', 'climate', 'mother', 'right', 'change', 'people', 'bolivian', 'world', 'earth', 'summit', 'solon'}
# ---
#
# {'climate', 'miss', 'heat', 'concern', 'sign', 'change', 'reappear', 'earth', 'eventually'}
# ---
#
# {'climate', 'april', 'bolivia', 'slap', 'change', 'slice', 'summit', 'million', 'dollar', 'ecuador'}
# ---
#
# {'global', 'doubleday', 'take', 'talese', 'page', 'mcewan'}
# ---
#
# {'climate', 'global', 'say', 'fraud', 'change', 'quote', 'oxburgh', 'balance', 'warming'}
# ---
#
# {'climate', 'change', 'illuminate', 'post', 'science'}
# ---
#
# {'climate', 'event', 'community', 'farmington', 'talk', 'change', 'library', 'earth', 'embrace', 'green', 'energy'}
# ---
#
# {'climate', 'nuclear', 'change', 'power', 'solution'}
# ---
#
# {'climate', 'system', 'seasonal', 'solar', 'allergy', 'change', 'make', 'bad', 'blame', 'gore'}
# ---
#
# {'climate', 'change', 'reach', 'tackle', 'excuse'}
# ---
#
# {'relation', 'human', 'global', 'volcano', 'contribute', 'emit', 'wonder', 'joke', 'lie', 'warming', 'farce', 'iceland'}
# ---
#
# {'climate', 'probly', 'fact', 'volcano', 'guru', 'change', 'wrong', 'get', 'rant', 'iceland'}
# ---
#
# {'global', 'tcot', 'come', 'blame', 'eruption', 'gore', 'warming'}
# ---
#
# {'global', 'show', 'pressure', 'warming', 'public', 'disbelieve', 'world', 'game', 'importance', 'experien', 'detractor'}
# ---
#
# {'global', 'reliable', 'unchanging', 'sign', 'like', 'gravity', 'warming'}
# ---
#
# {'climate', 'predict', 'outcome', 'apocalypsenow', 'exciting', 'change', 'hard', 'green', 'revolution'}
# ---
#
# {'climate', 'alternative', 'place', 'graph', 'change', 'science'}
# ---
#
# {'climate', 'finally', 'economy', 'definitely', 'read', 'krugman', 'change', 'build', 'worthwhile', 'green'}
# ---
#
# {'global', 'intelligence', 'remain', 'logic', 'evidence', 'debate', 'unpersuade', 'consider', 'nutcase', 'discourage', 'warming', 'human'}
# ---
#
# {'global', 'view', 'probably', 'represent', 'skeptic', 'warming'}
# ---
#
# {'climate', 'global', 'scientist', 'fire', 'exaggerate', 'warming'}
# ---
#
# {'climate', 'affect', 'tool', 'miss', 'future', 'heat', 'source', 'change', 'current', 'accoun', 'observational', 'science', 'daily'}
# ---
#
# {'global', 'thing', 'johnson', 'watch', 'nathanael', 'warming', 'california', 'solve'}
# ---
#
# {'account', 'believ', 'global', 'return', 'soon', 'miss', 'scientist', 'roughly', 'half', 'heat', 'warming'}
# ---
#
# {'climate', 'global', 'evidence', 'change', 'market', 'inconclusive', 'armageddo', 'warming', 'year'}
# ---
#
# {'climate', 'light', 'oven', 'lock', 'switch', 'change', 'dial', 'carbon', 'abrupt'}
# ---
#
# {'global', 'scientist', 'miss', 'find', 'heat', 'beef', 'monitoring', 'way', 'need', 'measure', 'expert', 'warming'}
# ---
#
# {'climate', 'happen', 'idea', 'reduce', 'change', 'good', 'know', 'carbon', 'grant'}
# ---
#
# {'climate', 'cite', 'health', 'refinery', 'local', 'effect', 'change', 'negative', 'study'}
# ---
#
# {'global', 'channel', 'hoax', 'promote', 'theory', 'weather', 'conspiracy', 'warming'}
# ---
#
# {'average', 'catch', 'global', 'cali', 'scare', 'strange', 'weather', 'call', 'bullshit', 'warming', 'get'}
# ---
#
# {'global', 'free', 'discuss', 'polar', 'adventurer', 'explorer', 'program', 'renowned', 'warming', 'steger', 'present'}
# ---
#
# {'climate', 'nightmare', 'change', 'creepy', 'ridiculous', 'night'}
# ---
#
# {'global', 'scientist', 'staudt', 'series', 'amanda', 'extreme', 'weather', 'warming'}
# ---
#
# {'statement', 'global', 'positive', 'tinto', 'clean', 'chiaro', 'preston', 'thankfully', 'warming', 'energy'}
# ---
#
# {'chris', 'wise', 'global', 'heart', 'jersey', 'wallet', 'christie', 'warming', 'governor'}
# ---
#
# {'climate', 'prevent', 'public', 'change', 'willingness', 'post'}
# ---
#
# {'global', 'doubleday', 'take', 'talese', 'page', 'mcewan'}
# ---
#
# {'climate', 'change', 'reach', 'tackle', 'excuse'}
# ---
#
# {'december', 'global', 'scientist', 'nations', 'send', 'letter', 'control', 'united', 'warming'}
# ---
#
# {'obese', 'global', 'cause', 'people', 'society', 'otago', 'time', 'warming', 'daily', 'create'}
# ---
#
# {'climate', 'turn', 'country', 'change', 'water', 'world', 'coastal'}
# ---
#
# {'daniel', 'climate', 'plan', 'post', 'change', 'greentech', 'esty', 'huffington'}
# ---
#
# {'global', 'pelosi', 'contend', 'newt', 'need', 'gingrich', 'defend', 'commercial', 'warming', 'green', 'seek'}
# ---
#
# {'liberalism', 'global', 'statement', 'make', 'have', 'warming', 'calendar'}
# ---
#
# {'regulator', 'global', 'brookl', 'safety', 'treehugger', 'blankenship', 'warming', 'brian', 'silly', 'video', 'merchant'}
# ---
#
# {'global', 'read', 'peer', 'truly', 'review', 'calif', 'gulf', 'warming', 'california'}
# ---
#
# {'massey', 'global', 'safety', 'idea', 'miner', 'warming', 'care', 'dead', 'silly', 'energy'}
# ---
#
# {'global', 'jesse', 'ambush', 'gore', 'warming', 'video', 'brilliant', 'woodrow'}
# ---
#
# {'global', 'disagree', 'remove', 'theory', 'warming', 'datum'}
# ---
#
# {'global', 'tcot', 'antarctica', 'death', 'warming', 'freeze', 'activist'}
# ---
#
# {'climate', 'pretend', 'global', 'fraud', 'catastrophe', 'change', 'people', 'know', 'surplus', 'warming'}
# ---
#
# {'climate', 'question', 'series', 'change', 'baby', 'lowdown'}
# ---
#
# {'climate', 'question', 'series', 'change', 'baby', 'lowdown'}
# ---
#
# {'resource', 'econ', 'climate', 'natural', 'krugman', 'change'}
# ---
#
# {'resource', 'econ', 'climate', 'natural', 'krugman', 'change'}
# ---
#
# {'climate', 'senior', 'press', 'charity', 'officer', 'change', 'oxfam', 'job'}
# ---
#
# {'climate', 'primer', 'jasencomstock', 'krugman', 'change', 'good', 'make', 'economic', 'love', 'paul'}
# ---
#
# {'climate', 'system', 'ecojustice', 'right', 'change', 'elect', 'violence', 'daily'}
# ---
#
# {'bonn', 'global', 'international', 'continue', 'agree', 'effort', 'warming', 'negotia'}
# ---
#
# {'climate', 'thirty', 'vanish', 'palm', 'tree', 'change', 'call', 'million', 'time', 'year', 'alaska', 'process'}
# ---
#
# {'global', 'declare', 'today', 'view', 'oppose', 'telegraph', 'meat', 'study', 'refute', 'warming', 'second', 'daily'}
# ---
#
# {'global', 'source', 'water', 'major', 'warming', 'pollution'}
# ---
#
# {'climate', 'global', 'liberalfascism', 'tcot', 'prosecute', 'ecocide', 'warming', 'news'}
# ---
#
# {'climate', 'fight', 'lizard', 'important', 'play', 'change', 'role', 'bird', 'earth', 'bat'}
# ---
#
# {'climate', 'fight', 'lizard', 'important', 'play', 'change', 'role', 'bird', 'earth', 'bat'}
# ---
#
# {'climate', 'fight', 'lizard', 'important', 'play', 'change', 'role', 'bird', 'earth', 'bat'}
# ---
#
# {'climate', 'fight', 'lizard', 'important', 'play', 'change', 'role', 'bird', 'earth', 'bat'}
# ---
#
# {'climate', 'fight', 'lizard', 'important', 'play', 'change', 'role', 'bird', 'earth', 'bat'}
# ---
#
# {'fossil', 'dilemma', 'global', 'use', 'million', 'fuel', 'need', 'serve', 'america', 'warming', 'barrel'}
# ---
#
# {'global', 'chalk', 'august', 'unbelievable', 'weather', 'warming', 'climb'}
# ---
#
# {'climate', 'global', 'say', 'favor', 'tcot', 'phrase', 'change', 'abandon', 'luntz', 'warming'}
# ---
#
# {'global', 'parody', 'enjoy', 'ocra', 'tube', 'ipcc', 'warming'}
# ---
#
# {'global', 'tell', 'eyed', 'make', 'dare', 'warming', 'golfer'}
# ---
#
# {'global', 'hair', 'scientifically', 'brain', 'challenge', 'tcot', 'climategate', 'ippc', 'claim', 'theory', 'warming'}
# ---

# %% [markdown]
# Checking after prepocessing hashtags and urls

# %%
pattern='@\w+'
# count_hashtags = preprocessed_tweets.apply(lambda tweet: len(re.findall(pattern, tweet)))
count_hashtags = [len(re.findall(pattern," ".join(t))) for t in preprocessed_tweets]
sum(count_hashtags)
# Out:
# 0

# %%
pattern=r'http.?://[^\s]+[\s]?'
# count_urls = tweets.apply(lambda tweet: len(re.findall(pattern, tweet)))
count_urls = [len(re.findall(pattern," ".join(t))) for t in preprocessed_tweets]
sum(count_urls)
# Out:
# 0

# %%
print(sum(count_hashtags))
# Out:
# 0

# %% [markdown]
# ## VISUALIZATIONS
# https://towardsdatascience.com/a-complete-exploratory-data-analysis-and-visualization-for-text-data-29fb1b96fb6a
#
# https://github.com/yrtnsari/Sentiment-Analysis-NLP-with-Python/blob/main/wordcloud.ipynb

# %%
pos_tweets=data[data['existence']=='Yes']
pos_tweets.head()
# Out:
#                                                tweet existence  \
# 0  Global warming report urges governments to act...       Yes
# 1  Fighting poverty and global warming in Africa ...       Yes
# 2  Carbon offsets: How a Vatican forest failed to...       Yes
# 3  Carbon offsets: How a Vatican forest failed to...       Yes
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...       Yes
#
#    existence.confidence  word_count
# 0                1.0000          18
# 1                1.0000           8
# 2                0.8786          12
# 3                1.0000          12
# 4                0.8087          11

# %%
data_pos=data[data['existence']=='Yes']
hashtags = data_pos["tweet"].apply(lambda x: pd.value_counts(re.findall('(#\w+)', x.lower() ))).sum(axis=0).to_frame().reset_index().sort_values(by=0,ascending=False)
hashtags.columns = ['hashtag','occurences']

# %%
hashtags.head(10)
# Out:
#             hashtag  occurences
# 58         #climate       138.0
# 245           #tcot        69.0
# 119          #green        47.0
# 188             #p2        47.0
# 60   #climatechange        36.0
# 209      #saveterra        31.0
# 76        #earthday        24.0
# 80             #eco        23.0
# 113         #global        18.0
# 114  #globalwarming        15.0

# %%
data_pos_mentions=data[data['existence']=='Yes']
mentions = data_pos_mentions["tweet"].apply(lambda x: pd.value_counts(re.findall('(@\w+)', x.lower() ))).sum(axis=0).to_frame().reset_index().sort_values(by=0,ascending=False)
mentions.columns = ['mentions','occurences']

# %%
mentions.head(10)
# Out:
#            mentions  occurences
# 411    @newsongreen        30.0
# 93          @change        22.0
# 569           @time        14.0
# 284   @humanitynews        11.0
# 581     @treehugger        10.0
# 389           @mmfa         9.0
# 469       @qorianka         8.0
# 412       @newsweek         8.0
# 252    @greenforyou         7.0
# 303  @invasivenotes         7.0

# %%
data_neg=data[data['existence']=='No']
hashtags = data_neg["tweet"].apply(lambda x: pd.value_counts(re.findall('(#\w+)', x.lower() ))).sum(axis=0).to_frame().reset_index().sort_values(by=0,ascending=False)
hashtags.columns = ['hashtag','occurences']

# %%
hashtags.head(10)
# Out:
#           hashtag  occurences
# 123         #tcot       118.0
# 93            #p2        38.0
# 23       #climate        36.0
# 124     #teaparty        25.0
# 49        #global        18.0
# 25   #climategate        18.0
# 53           #gop        16.0
# 113          #sgp        15.0
# 127         #tlot        10.0
# 92          #ocra        10.0

# %%
data_neg_mentions=data[data['existence']=='No']
mentions_neg = data_neg["tweet"].apply(lambda x: pd.value_counts(re.findall('(@\w+)', x.lower() ))).sum(axis=0).to_frame().reset_index().sort_values(by=0,ascending=False)
mentions_neg.columns = ['mentions','occurences']

# %%
mentions_neg.head(10)
# Out:
#            mentions  occurences
# 14          @algore        10.0
# 96   @drudge_report         8.0
# 233   @newtgingrich         7.0
# 259   @redostoneage         7.0
# 8          @addthis         7.0
# 212   @mattyglesias         7.0
# 289  @stephenathome         5.0
# 124   @globeandmail         5.0
# 231    @newsbusters         4.0
# 72         @cubachi         4.0

# %% [markdown]
# Collect the positive tweets that contain hashtags

# %%
pre_tweet_pos,pos_hash_tweets,pos_urls_tweets,pos_mentions_tweets,indices_pos=preprocess(pos_tweets.tweet)
# Out:
# Streaming output truncated to the last 5000 lines.
# ---
#
# {'big', 'climate', 'problem', 'freeride', 'change', 'barrett', 'action'}
# ---
#
# {'black', 'global', 'people', 'world', 'coal', 'mine', 'warming'}
# ---
#
# {'climate', 'price', 'bolivia', 'change', 'people', 'put', 'world', 'kick', 'cochabamba', 'conference'}
# ---
#
# {'climate', 'tool', 'crunch', 'supercomputer', 'nasa', 'data', 'change', 'aim', 'earth', 'launch', 'time'}
# ---
#
# {'kandi', 'climate', 'lili', 'kari', 'bolivia', 'change', 'people', 'world', 'friend', 'conference'}
# ---
#
# {'global', 'volcano', 'angry', 'warming', 'iceland'}
# ---
#
# {'climate', 'mother', 'right', 'greenpeace', 'change', 'people', 'wave', 'world', 'make', 'earth', 'conference'}
# ---
#
# {'global', 'country', 'danger', 'official', 'agree', 'break', 'stop', 'warming', 'process', 'collapse'}
# ---
#
# {'mean', 'global', 'scientist', 'thing', 'cause', 'rise', 'justin', 'foot', 'world', 'ocean', 'biebe', 'warming'}
# ---
#
# {'mean', 'global', 'scientist', 'thing', 'cause', 'rise', 'justin', 'foot', 'world', 'ocean', 'biebe', 'warming'}
# ---
#
# {'global', 'allergy', 'bad', 'blame', 'cwrrmi', 'warming'}
# ---
#
# {'climate', 'global', 'greed', 'nonsense', 'change', 'warming', 'science'}
# ---
#
# {'climate', 'report', 'hurrah', 'step', 'stage', 'real', 'change', 'pass', 'close', 'stop', 'vote', 'target', 'bill', 'cdnpoli'}
# ---
#
# {'climate', 'read', 'change', 'good', 'tackle', 'afford'}
# ---
#
# {'climate', 'collex', 'africa', 'sustainability', 'data', 'change', 'well', 'involve', 'farmer', 'monitor'}
# ---
#
# {'screw', 'global', 'tomato', 'lunch', 'russia', 'warming', 'burger'}
# ---
#
# {'climate', 'global', 'reduce', 'change', 'good', 'flatulence', 'gas', 'warming', 'greenhouse', 'news'}
# ---
#
# {'climate', 'clean', 'community', 'change', 'address', 'polluted'}
# ---
#
# {'climate', 'wine', 'grape', 'tell', 'story', 'monkey', 'change', 'need', 'ashlander'}
# ---
#
# {'maine', 'global', 'likely', 'allergy', 'warming', 'worsen'}
# ---
#
# {'climate', 'problem', 'literature', 'story', 'change', 'solution', 'large', 'real', 'environmental'}
# ---
#
# {'plantsuccess', 'climate', 'afternoon', 'manufac', 'energy', 'talk', 'change', 'leadership', 'soundoff', 'conference'}
# ---
#
# {'climate', 'guide', 'modern', 'change', 'complete'}
# ---
#
# {'climate', 'event', 'organize', 'change', 'cool', 'earth', 'illuminate', 'week', 'science'}
# ---
#
# {'climate', 'climategate', 'hooey', 'change', 'proof', 'real', 'bunch'}
# ---
#
# {'wait', 'climate', 'say', 'group', 'michigan', 'change', 'allergy', 'kick', 'think'}
# ---
#
# {'global', 'industry', 'start', 'place', 'fortunegreen', 'chouinard', 'warming', 'clothing', 'yvon'}
# ---
#
# {'climate', 'report', 'sniffly', 'spring', 'change', 'allergy', 'make', 'extreme'}
# ---
#
# {'climate', 'guide', 'modern', 'change', 'warm', 'world', 'complete'}
# ---
#
# {'climate', 'progress', 'guide', 'modern', 'change', 'complete'}
# ---
#
# {'melt', 'global', 'say', 'quick', 'stop', 'chocolate', 'warming'}
# ---
#
# {'climate', 'philosophy', 'thing', 'cycle', 'specie', 'business', 'change', 'trade', 'religion'}
# ---
#
# {'climate', 'email', 'report', 'east', 'wrongdoing', 'change', 'clear', 'call', 'anglia', 'election', 'mention'}
# ---
#
# {'politician', 'global', 'bolivia', 'warming', 'cool', 'summit', 'star', 'hollywood', 'join'}
# ---
#
# {'lately', 'global', 'factor', 'rebound', 'warm', 'bee', 'decline', 'variety', 'area', 'environmental'}
# ---
#
# {'climate', 'connection', 'achoo', 'spring', 'allergy', 'change', 'learn', 'drive'}
# ---
#
# {'climate', 'clean', 'vattenfall', 'change', 'lone', 'wolf', 'energy'}
# ---
#
# {'climate', 'trading', 'forbiden', 'technology', 'change', 'fertilizer', 'emission', 'benchmark', 'excercise'}
# ---
#
# {'climate', 'progress', 'guide', 'modern', 'change', 'need', 'world', 'complete', 'datum'}
# ---
#
# {'climate', 'wait', 'wakeup', 'april', 'consumer', 'walk', 'change', 'action'}
# ---
#
# {'climate', 'event', 'visit', 'husting', 'change', 'care', 'poverty'}
# ---
#
# {'climate', 'follow', 'event', 'visit', 'husting', 'change', 'care', 'poverty'}
# ---
#
# {'climate', 'visayas', 'gather', 'stakeholder', 'western', 'conf', 'concern', 'change', 'tackle', 'regional'}
# ---
#
# {'article', 'global', 'opportunity', 'environment', 'warming'}
# ---
#
# {'global', 'pelosi', 'gingrich', 'defend', 'commercial', 'warming'}
# ---
#
# {'climate', 'hobart', 'father', 'change', 'cousteau', 'repeat', 'warning', 'message', 'spread'}
# ---
#
# {'climate', 'problem', 'read', 'story', 'change', 'good', 'solution', 'large', 'real', 'environmental'}
# ---
#
# {'climate', 'global', 'clim', 'question', 'effect', 'change', 'open'}
# ---
#
# {'climate', 'news', 'change', 'research', 'documentary', 'state', 'possible', 'cousteau', 'underwater', 'message', 'spread'}
# ---
#
# {'climate', 'statement', 'synche', 'geol', 'drive', 'change', 'ipcc', 'society', 'update', 'acad', 'human'}
# ---
#
# {'global', 'know', 'real', 'warming', 'look', 'reason'}
# ---
#
# {'global', 'want', 'kill', 'stop', 'join', 'warming', 'valero'}
# ---
#
# {'climate', 'accelerate', 'soil', 'change', 'warm', 'carbon', 'study'}
# ---
#
# {'climate', 'light', 'logbook', 'clue', 'study', 'keeper', 'shed'}
# ---
#
# {'climate', 'light', 'logbook', 'clue', 'study', 'keeper', 'shed'}
# ---
#
# {'global', 'yike', 'occur', 'like', 'sound', 'rough', 'warming'}
# ---
#
# {'global', 'home', 'help', 'improvement', 'warming', 'stop', 'consider', 'large', 'earth', 'check', 'project'}
# ---
#
# {'climate', 'liberal', 'sure', 'change', 'pass', 'vote', 'bill', 'wednesday'}
# ---
#
# {'climate', 'colloquium', 'community', 'talk', 'change', 'water', 'coastal', 'caldwell', 'open', 'tonight', 'join'}
# ---
#
# {'climate', 'statement', 'synche', 'geol', 'drive', 'change', 'ipcc', 'society', 'update', 'acad', 'human'}
# ---
#
# {'climate', 'pretty', 'awesome', 'change', 'breakdown'}
# ---
#
# {'peru', 'climate', 'tsunami', 'cause', 'change', 'example', 'deadly', 'glaci', 'giant', 'fall', 'real'}
# ---
#
# {'global', 'nitrous', 'cause', 'mabye', 'absolve', 'grazing', 'warming', 'cow', 'oxide'}
# ---
#
# {'melt', 'global', 'fast', 'laugh', 'stupid', 'warming', 'cream'}
# ---
#
# {'obama', 'finally', 'climate', 'ready', 'change', 'tough', 'bill'}
# ---
#
# {'climate', 'count', 'global', 'efficiency', 'renewable', 'state', 'enable', 'bill', 'warming', 'scale', 'mandate'}
# ---
#
# {'climate', 'global', 'humanity', 'angeles', 'destroy', 'warming'}
# ---
#
# {'climate', 'global', 'humanity', 'angeles', 'destroy', 'warming'}
# ---
#
# {'unveile', 'global', 'clean', 'warming', 'state', 'revise', 'unveil', 'bill', 'wisconsin', 'scale', 'energy'}
# ---
#
# {'pilot', 'climate', 'global', 'mansion', 'green', 'limos', 'change', 'world', 'warming', 'celebrity'}
# ---
#
# {'climate', 'global', 'fact', 'guess', 'nasa', 'change', 'warming', 'notice', 'think'}
# ---
#
# {'climate', 'change', 'open', 'tiquipaya', 'morale', 'conference'}
# ---
#
# {'climate', 'global', 'fact', 'guess', 'nasa', 'change', 'warming', 'notice', 'think'}
# ---
#
# {'pilot', 'climate', 'global', 'mansion', 'green', 'limos', 'change', 'world', 'warming', 'celebrity'}
# ---
#
# {'politician', 'global', 'bypassgfw', 'bolivia', 'warming', 'cool', 'summit', 'star', 'green', 'hollywood', 'join'}
# ---
#
# {'obama', 'pick', 'push', 'suprem', 'climate', 'melt', 'slush', 'change', 'hurry', 'daddy', 'stimuli', 'bill', 'try'}
# ---
#
# {'climate', 'teacher', 'high', 'change', 'word', 'school', 'spread'}
# ---
#
# {'climate', 'pollutant', 'low', 'change', 'impact', 'emission', 'level', 'greenhouse', 'benefit', 'pump'}
# ---
#
# {'global', 'feel', 'heat', 'effect', 'warming', 'suffer'}
# ---
#
# {'global', 'sustainability', 'security', 'warming', 'whgc', 'major', 'come', 'issue', 'creation'}
# ---
#
# {'climate', 'change', 'world', 'forward', 'negotiation'}
# ---
#
# {'climate', 'organic', 'guide', 'agriculture', 'security', 'change', 'food'}
# ---
#
# {'climate', 'gove', 'want', 'nutjob', 'list', 'people', 'forget', 'change', 'denier', 'creationist', 'school'}
# ---
#
# {'neraka', 'global', 'bumi', 'kayak', 'udah', 'let', 'stop', 'bocor', 'warming', 'liat'}
# ---
#
# {'climate', 'wait', 'work', 'internship', 'change', 'fancy', 'campaign', 'coolest', 'fill'}
# ---
#
# {'day', 'climate', 'sensibly', 'show', 'legged', 'animal', 'behave', 'time', 'change', 'impact', 'high'}
# ---
#
# {'average', 'climate', 'tomorrow', 'change', 'degree', 'accord', 'celsius', 'mixi', 'year', 'news'}
# ---
#
# {'climate', 'global', 'warming', 'cooling', 'study', 'greenland', 'past', 'year'}
# ---
#
# {'climate', 'global', 'claim', 'change', 'disprove', 'glaci', 'national', 'glacier', 'warming', 'science', 'alarmist', 'park'}
# ---
#
# {'global', 'slowly', 'gilaaa', 'panas', 'kill', 'warming'}
# ---
#
# {'minimise', 'global', 'summer', 'abnormal', 'effect', 'change', 'run', 'weather', 'warming', 'humid'}
# ---
#
# {'climate', 'sustainable', 'global', 'withstand', 'change', 'super', 'structure'}
# ---
#
# {'global', 'return', 'point', 'suggest', 'study', 'warming'}
# ---
#
# {'climate', 'international', 'award', 'filmmaker', 'change', 'india', 'gandhi', 'documentary', 'delhi', 'win', 'rohit'}
# ---
#
# {'global', 'nations', 'kill', 'enviroment', 'united', 'warming'}
# ---
#
# {'climate', 'mexico', 'host', 'talk', 'change', 'round', 'summit', 'news'}
# ---
#
# {'climate', 'mean', 'point', 'reduce', 'take', 'support', 'change', 'impact', 'choose', 'action', 'buffer', 'word'}
# ---
#
# {'climate', 'deny', 'peace', 'crime', 'change', 'tolerant', 'leave', 'guilty'}
# ---
#
# {'global', 'volcano', 'angry', 'warming', 'iceland'}
# ---
#
# {'global', 'thank', 'hot', 'americans', 'kerala', 'get', 'hotter'}
# ---
#
# {'true', 'global', 'place', 'prove', 'foll', 'prediction', 'warming', 'disappear', 'europe'}
# ---
#
# {'global', 'want', 'peace', 'world', 'click', 'warming'}
# ---
#
# {'global', 'obesity', 'homelessness', 'warming', 'illiteracy', 'deforestation'}
# ---
#
# {'global', 'branson', 'earthday', 'message', 'richard', 'house'}
# ---
#
# {'climate', 'government', 'deal', 'change', 'climatechange', 'company'}
# ---
#
# {'climate', 'global', 'change', 'capable', 'project', 'year', 'model'}
# ---
#
# {'climate', 'accelerate', 'hit', 'home', 'ominous', 'sign', 'change', 'india', 'warming', 'see'}
# ---
#
# {'climate', 'believe', 'slowly', 'important', 'business', 'ireversable', 'change', 'stop', 'earth'}
# ---
#
# {'climate', 'tool', 'crunch', 'supercomputer', 'nasa', 'gift', 'change', 'data', 'earth', 'time'}
# ---
#
# {'vancouver', 'climate', 'global', 'april', 'ottawa', 'maker', 'change', 'policy', 'anti', 'poverty', 'activist'}
# ---
#
# {'climate', 'cherry', 'threat', 'japan', 'blossom', 'change'}
# ---
#
# {'climate', 'global', 'volcano', 'tcot', 'agriculture', 'volcanic', 'change', 'eruption', 'increase', 'benefit', 'iceland'}
# ---
#
# {'reverse', 'climate', 'forest', 'combat', 'change', 'decline'}
# ---
#
# {'climate', 'senator', 'bill', 'bipartisan', 'change', 'compromise', 'create'}
# ---
#
# {'great', 'climate', 'witness', 'story', 'change', 'material', 'impact', 'look', 'medium', 'human'}
# ---
#
# {'great', 'climate', 'witness', 'story', 'change', 'material', 'impact', 'look', 'medium', 'human'}
# ---
#
# {'great', 'climate', 'witness', 'story', 'change', 'material', 'impact', 'check', 'look', 'medium', 'human'}
# ---
#
# {'climate', 'diary', 'labour', 'front', 'change', 'carbon'}
# ---
#
# {'climate', 'important', 'change', 'organization', 'world', 'check'}
# ---
#
# {'climate', 'dust', 'archive', 'gather', 'scottish', 'lesson', 'clue', 'change', 'lie', 'news'}
# ---
#
# {'climate', 'dust', 'archive', 'gather', 'scottish', 'lesson', 'clue', 'change', 'lie', 'news'}
# ---
#
# {'climate', 'capitalism', 'profitable', 'change', 'climatechange', 'solution', 'green'}
# ---
#
# {'reverse', 'climate', 'forest', 'combat', 'change', 'decline'}
# ---
#
# {'climate', 'volcano', 'nwnl', 'read', 'hold', 'nile', 'change', 'river', 'link', 'expedition', 'uganda', 'europe'}
# ---
#
# {'climate', 'ignore', 'inaction', 'iceberg', 'worth', 'change', 'fret', 'address', 'cost', 'look'}
# ---
#
# {'climate', 'say', 'deal', 'slim', 'change', 'prospect', 'denmark', 'year'}
# ---
#
# {'climate', 'problem', 'change', 'talk', 'coal', 'wind', 'realise'}
# ---
#
# {'climate', 'global', 'right', 'introduce', 'senate', 'change', 'month', 'track', 'bill', 'warming', 'sweeping', 'news'}
# ---
#
# {'day', 'climate', 'believe', 'record', 'change', 'hard', 'real', 'past', 'see', 'earthquake'}
# ---
#
# {'climate', 'global', 'warming', 'change', 'psychological', 'profiling'}
# ---
#
# {'climate', 'chief', 'global', 'remove', 'document', 'noaa', 'change', 'accuse', 'enforcement', 'shred', 'warming', 'post'}
# ---
#
# {'climate', 'mean', 'global', 'change', 'mayan', 'prediction', 'warming', 'planet', 'think'}
# ---
#
# {'climate', 'agency', 'satellite', 'blast', 'change', 'check', 'space', 'european', 'enviro', 'launch'}
# ---
#
# {'climate', 'statement', 'turn', 'episode', 'change', 'convoluted', 'brilliant'}
# ---
#
# {'climate', 'showcase', 'climat', 'aim', 'change', 'tackle', 'exhibition', 'celebrity', 'fill', 'highlight', 'photo'}
# ---
#
# {'climate', 'article', 'times', 'excellent', 'change', 'rational', 'economic', 'trade', 'york'}
# ---
#
# {'progress', 'climate', 'chance', 'small', 'change', 'make', 'agreement', 'bind', 'forge'}
# ---
#
# {'climate', 'supply', 'change', 'water', 'sanitation', 'focus', 'vision', 'face', 'resilience'}
# ---
#
# {'climate', 'article', 'comprehensive', 'krugman', 'change', 'economic', 'paul', 'brilliant'}
# ---
#
# {'climate', 'xinhua', 'mexico', 'result', 'change', 'concrete', 'conference', 'danish', 'hainan', 'expect'}
# ---
#
# {'climate', 'chance', 'deal', 'topic', 'slim', 'change', 'prospect', 'agreement', 'bind', 'forge', 'news'}
# ---
#
# {'climate', 'follow', 'pledge', 'government', 'release', 'press', 'receive', 'unfccc', 'list', 'change', 'conclusion'}
# ---
#
# {'welcome', 'global', 'capitalism', 'delegate', 'bolivian', 'sound', 'blame', 'cochabamba', 'president'}
# ---
#
# {'climate', 'scientist', 'say', 'threat', 'dhabi', 'capital', 'change', 'cont', 'expert', 'flood', 'face'}
# ---
#
# {'climate', 'true', 'fight', 'explanation', 'krugman', 'change', 'utterly', 'dtgt', 'superb', 'economic', 'paul'}
# ---
#
# {'climate', 'negotiator', 'gather', 'reinvigorate', 'talk', 'change'}
# ---
#
# {'climate', 'bonn', 'xinhua', 'proper', 'remain', 'change', 'platform', 'talk', 'writer', 'xiaoyan', 'boer', 'huang', 'german'}
# ---
#
# {'climate', 'say', 'active', 'change', 'tackle', 'china', 'president', 'vice'}
# ---
#
# {'welcome', 'global', 'capitalism', 'delegate', 'bolivian', 'sound', 'blame', 'cochabamba', 'president'}
# ---
#
# {'climate', 'costa', 'biodiversity', 'rica', 'effect', 'change', 'monteverde'}
# ---
#
# {'global', 'twitter', 'warming', 'close', 'existence', 'bring', 'forewarn', 'block', 'rapture', 'perpetuate'}
# ---
#
# {'global', 'twitter', 'warming', 'foewarne', 'close', 'existence', 'bring', 'block', 'rapture', 'perpetuate'}
# ---
#
# {'climate', 'plan', 'change', 'american', 'north', 'promote', 'climatechange', 'nafta'}
# ---
#
# {'climate', 'global', 'change', 'stop', 'warming', 'post'}
# ---
#
# {'soup', 'halt', 'global', 'stonesoupdayton', 'stone', 'hear', 'warming', 'tree', 'people', 'planting', 'importance'}
# ---
#
# {'global', 'cause', 'scientific', 'like', 'test', 'warming', 'post', 'prove'}
# ---
#
# {'climate', 'global', 'park', 'change', 'prospect', 'lay'}
# ---
#
# {'global', 'recycle', 'pencil', 'stop', 'packaging', 'warming', 'base', 'paper'}
# ---
#
# {'climate', 'fact', 'change', 'rational', 'response', 'hysteria', 'look'}
# ---
#
# {'climate', 'fradulent', 'griffin', 'change', 'fertilizer', 'call', 'nick', 'science', 'cambridge'}
# ---
#
# {'climate', 'goody', 'email', 'send', 'change', 'deni'}
# ---
#
# {'climate', 'invasive', 'temperature', 'change', 'associate', 'warm', 'aid', 'speed'}
# ---
#
# {'climate', 'threaten', 'include', 'bridge', 'change', 'impact', 'chaotic', 'intense', 'food', 'worsen'}
# ---
#
# {'global', 'sunday', 'enviroment', 'warming', 'conference'}
# ---
#
# {'average', 'global', 'hybrid', 'switch', 'reduce', 'dairy', 'eat', 'american', 'meat', 'emission', 'egg', 'warming'}
# ---
#
# {'global', 'planetsure', 'awesome', 'way', 'go', 'cool', 'alarming', 'warming', 'green'}
# ---
#
# {'global', 'sign', 'pole', 'north', 'rain', 'warming', 'think'}
# ---
#
# {'climate', 'joplin', 'denniston', 'change', 'column', 'globe', 'elliott', 'guest'}
# ---
#
# {'climate', 'denniston', 'change', 'column', 'elliott', 'guest'}
# ---
#
# {'global', 'volcano', 'angry', 'discovery', 'earth', 'warming', 'iceland'}
# ---
#
# {'swedish', 'global', 'cause', 'main', 'accord', 'expert', 'warming'}
# ---
#
# {'climate', 'denial', 'change', 'blog', 'cold', 'crock', 'week'}
# ---
#
# {'climate', 'denial', 'humanitarian', 'change', 'cold', 'crock', 'week', 'news'}
# ---
#
# {'climate', 'scientific', 'change', 'american', 'reform', 'intergovernmental', 'panel'}
# ---
#
# {'brewer', 'global', 'contessa', 'cause', 'msnbc', 'tcot', 'sure', 'pretty', 'warming', 'snowstorm'}
# ---
#
# {'climate', 'torch', 'pembina', 'carry', 'institute', 'change', 'tough', 'emission', 'auto', 'schwarzenegger', 'standard'}
# ---
#
# {'climate', 'production', 'crop', 'reduce', 'africa', 'change', 'environmentalresearchweb'}
# ---
#
# {'rightblog', 'global', 'pound', 'work', 'report', 'tcot', 'right', 'east', 'snow', 'coast', 'warming', 'teaparty'}
# ---
#
# {'vancouver', 'climate', 'pinch', 'humanitarian', 'winter', 'change', 'olympics', 'news'}
# ---
#
# {'climate', 'winger', 'americablog', 'right', 'blizzard', 'claim', 'prove', 'change', 'news', 'doesn'}
# ---
#
# {'climate', 'scientist', 'pembina', 'change', 'error', 'significance', 'exaggerate', 'globe', 'columnist'}
# ---
#
# {'climate', 'winger', 'americablog', 'right', 'blizzard', 'claim', 'prove', 'change', 'news'}
# ---
#
# {'climate', 'series', 'change', 'city', 'worldnew'}
# ---
#
# {'climate', 'boing', 'boe', 'change', 'understand'}
# ---
#
# {'environmental', 'climate', 'teach', 'calculator', 'change', 'policy', 'carbon', 'footprint'}
# ---
#
# {'climate', 'media', 'network', 'change', 'disprove', 'action', 'matter', 'snowstorm'}
# ---
#
# {'climate', 'melt', 'change', 'acrtic', 'glacier'}
# ---
#
# {'climate', 'robin', 'help', 'support', 'change', 'tackle', 'poverty', 'hood'}
# ---
#
# {'climate', 'data', 'noaa', 'change', 'public', 'share', 'portal'}
# ---
#
# {'climate', 'fight', 'montreal', 'change', 'public', 'book', 'duchess'}
# ---
#
# {'bright', 'global', 'washington', 'major', 'close', 'storm', 'force', 'federal', 'warming', 'york'}
# ---
#
# {'climate', 'agriculture', 'mitigation', 'institute', 'change', 'ecologic', 'german'}
# ---
#
# {'accelerate', 'climate', 'reuters', 'recipe', 'migration', 'change', 'social', 'alertnet'}
# ---
#
# {'climate', 'midnight', 'ghost', 'change', 'action', 'neighbor', 'inspire'}
# ---
#
# {'browner', 'climate', 'director', 'energy', 'oneart', 'white', 'change', 'policy', 'office', 'carol', 'house'}
# ---
#
# {'global', 'point', 'argument', 'support', 'mind', 'blind', 'ideologue', 'progressive', 'talking', 'mccain', 'warming', 'legislation'}
# ---
#
# {'climate', 'small', 'change', 'time', 'news', 'think'}
# ---
#
# {'climate', 'agency', 'leader', 'sustainable', 'government', 'propose', 'business', 'change', 'federal', 'green', 'environmental'}
# ---
#
# {'melt', 'global', 'away', 'effect', 'warm', 'warming'}
# ---
#
# {'climate', 'affect', 'disclosure', 'business', 'change', 'public', 'interpretive', 'issue', 'guidance'}
# ---
#
# {'climate', 'campaigner', 'senior', 'change', 'humanright', 'vacancy', 'energy'}
# ---
#
# {'climate', 'disclosure', 'change', 'adopt', 'guidance'}
# ---
#
# {'climate', 'idea', 'help', 'change', 'tackle', 'call', 'mayor', 'londoner'}
# ---
#
# {'climate', 'change', 'world', 'earth', 'fragrant', 'news'}
# ---
#
# {'global', 'salt', 'dangerous', 'potentialsaltwarslogan', 'warming'}
# ---
#
# {'climate', 'hill', 'change', 'need', 'axelrod', 'wire'}
# ---
#
# {'climate', 'soil', 'underestimate', 'yahoo', 'change', 'impact', 'study', 'news'}
# ---
#
# {'global', 'right', 'well', 'good', 'world', 'weather', 'live', 'child', 'warming'}
# ---
#
# {'affect', 'global', 'cause', 'truly', 'negatively', 'destructive', 'pattern', 'world', 'weather', 'warming', 'planet'}
# ---
#
# {'global', 'deal', 'alternative', 'source', 'warming', 'harm', 'time', 'issue', 'planet', 'energy'}
# ---
#
# {'global', 'cause', 'warming', 'world', 'weather', 'control', 'time', 'issue', 'get', 'violent'}
# ---
#
# {'global', 'fact', 'cause', 'archive', 'blog', 'toolshed', 'warming', 'green', 'myth'}
# ---
#
# {'global', 'home', 'solar', 'effect', 'power', 'thermal', 'warming', 'application'}
# ---
#
# {'global', 'medicine', 'way', 'stop', 'fundamental', 'warming'}
# ---
#
# {'climate', 'agency', 'form', 'local', 'change', 'news', 'oregon'}
# ---
#
# {'climate', 'agency', 'propose', 'change', 'administration', 'study'}
# ---
#
# {'obama', 'agency', 'climate', 'houston', 'start', 'chronicle', 'change', 'national'}
# ---
#
# {'climate', 'encana', 'free', 'pemb', 'price', 'change', 'pass', 'need', 'million', 'pollution'}
# ---
#
# {'climate', 'agency', 'form', 'change', 'service', 'federal'}
# ---
#
# {'climate', 'crisis', 'natural', 'tell', 'change', 'solution', 'neglect', 'expert', 'canada', 'northumberland'}
# ---
#
# {'climate', 'future', 'adapt', 'rmet', 'change', 'city', 'college', 'imperial', 'meeting', 'london'}
# ---
#
# {'climate', 'dispatch', 'pentagon', 'threat', 'security', 'change', 'consider', 'national'}
# ---
#
# {'climate', 'browner', 'director', 'natgas', 'tremendous', 'opportunity', 'change', 'energy', 'think'}
# ---
#
# {'climate', 'global', 'tree', 'change', 'stop', 'plant', 'warming', 'cut'}
# ---
#
# {'climate', 'global', 'blast', 'arctic', 'winter', 'change', 'real', 'warming', 'prove', 'gore'}
# ---
#
# {'climate', 'disclose', 'change', 'paul', 'risk', 'realist', 'real', 'driessen'}
# ---
#
# {'climate', 'great', 'ray', 'specie', 'sting', 'change', 'vulnerability', 'barrierreef', 'shark'}
# ---
#
# {'sceptic', 'climate', 'free', 'remain', 'priority', 'comment', 'change', 'despite', 'editorial'}
# ---
#
# {'mean', 'global', 'igloo', 'warming', 'sachs', 'sell', 'grimey', 'eskimos', 'goldman', 'damage', 'flood', 'insurance'}
# ---
#
# {'climate', 'point', 'starting', 'epoch', 'change', 'woman', 'million', 'time'}
# ---
#
# {'climate', 'change', 'research', 'india', 'need', 'saran', 'shyam', 'calcuttatube'}
# ---
#
# {'climate', 'read', 'analysis', 'review', 'change', 'policy', 'ethical', 'contribution', 'wire'}
# ---
#
# {'climate', 'susty', 'thought', 'change', 'market', 'issue'}
# ---
#
# {'climate', 'change', 'need', 'saran', 'shyam', 'information', 'precise'}
# ---
#
# {'climate', 'core', 'yahoo', 'change', 'water', 'impact', 'expert', 'news'}
# ---
#
# {'climate', 'invasive', 'help', 'change', 'plant', 'time', 'hindustan'}
# ---
#
# {'climate', 'fight', 'change', 'rope', 'india', 'panel'}
# ---
#
# {'climate', 'scientist', 'crop', 'change', 'manila', 'endure', 'bulletin', 'develop'}
# ---
#
# {'climate', 'leader', 'religious', 'awareness', 'laureate', 'nobel', 'indiavision', 'change', 'news'}
# ---
#
# {'climate', 'difference', 'versus', 'rudd', 'change', 'crikey', 'abbott'}
# ---
#
# {'climate', 'minister', 'step', 'change', 'action', 'coal'}
# ---
#
# {'great', 'global', 'climategate', 'mess', 'warming', 'collapse'}
# ---
#
# {'climate', 'ball', 'disco', 'combat', 'change', 'space'}
# ---
#
# {'climate', 'trading', 'fail', 'humanitarian', 'combat', 'change', 'emission', 'news'}
# ---
#
# {'climate', 'instead', 'curse', 'change', 'empower', 'movement', 'dark', 'post', 'huffington'}
# ---
#
# {'climate', 'education', 'western', 'australia', 'change', 'abroad', 'drought', 'link', 'carbon', 'proof', 'study', 'base'}
# ---
#
# {'underway', 'global', 'suspend', 'warm', 'emission', 'effort', 'greenhouse', 'california'}
# ---
#
# {'climate', 'west', 'australian', 'change', 'drought', 'proof'}
# ---
#
# {'production', 'global', 'report', 'cite', 'annual', 'university', 'study', 'warming', 'rice', 'conference'}
# ---
#
# {'climate', 'change', 'impact', 'glaci', 'response', 'complex'}
# ---
#
# {'climate', 'colo', 'effect', 'change', 'denver', 'conservationist', 'post', 'see'}
# ---
#
# {'climate', 'core', 'change', 'water', 'impact', 'expert', 'news'}
# ---
#
# {'climate', 'humanitarian', 'change', 'drought', 'proof', 'news'}
# ---
#
# {'climate', 'global', 'copenhagen', 'reduction', 'world', 'develop', 'warming', 'proposal'}
# ---
#
# {'climate', 'core', 'change', 'water', 'reuter', 'impacts'}
# ---
#
# {'climate', 'core', 'humanitarian', 'change', 'water', 'impact', 'reuter', 'expert', 'news'}
# ---
#
# {'climate', 'core', 'humanitarian', 'change', 'water', 'impact', 'expert', 'news'}
# ---
#
# {'climate', 'dallas', 'morning', 'blackbird', 'change', 'plummet', 'suspect', 'number', 'pollution', 'rusty'}
# ---
#
# {'resource', 'affect', 'global', 'prevent', 'alternative', 'negatively', 'impact', 'increase', 'warming', 'planet', 'energy'}
# ---
#
# {'climate', 'try', 'mother', 'jones', 'coverage', 'change', 'collaborative', 'organization', 'news'}
# ---
#
# {'affect', 'global', 'prevent', 'temperature', 'increase', 'warming', 'planet'}
# ---
#
# {'global', 'worldwide', 'cause', 'pattern', 'totally', 'world', 'weather', 'storm', 'mess', 'hurtful', 'warming', 'violent'}
# ---
#
# {'affect', 'global', 'soon', 'rainstorm', 'weather', 'massive', 'terrible', 'warming', 'planet', 'lot'}
# ---
#
# {'climate', 'news', 'humanitarian', 'change', 'impact', 'glaci', 'response', 'complex'}
# ---
#
# {'climate', 'change', 'olympic', 'desperate', 'organiser'}
# ---
#
# {'climate', 'danger', 'change', 'warn', 'governor'}
# ---
#
# {'climate', 'flow', 'change', 'india', 'equity', 'clarity', 'seek'}
# ---
#
# {'climate', 'change', 'olympic', 'desperate', 'organiser'}
# ---
#
# {'climate', 'humanitarian', 'change', 'desperate', 'organiser', 'olympics', 'news'}
# ---
#
# {'global', 'small', 'way', 'stop', 'warming'}
# ---
#
# {'global', 'small', 'step', 'way', 'stop', 'baby', 'warming'}
# ---
#
# {'censor', 'climate', 'mother', 'right', 'change', 'people', 'world', 'earth', 'conference', 'news', 'cochabama'}
# ---
#
# {'climate', 'mother', 'right', 'wpccc', 'change', 'people', 'link', 'world', 'earth', 'conference'}
# ---
#
# {'obama', 'global', 'today', 'enjoy', 'gather', 'discuss', 'blizzard', 'wonder', 'idiot', 'rest', 'hope', 'warming'}
# ---
#
# {'sceptic', 'climate', 'free', 'remain', 'priority', 'comment', 'change', 'despite', 'editorial'}
# ---
#
# {'climate', 'pledge', 'change', 'emission', 'carbon', 'curb', 'china', 'announce'}
# ---
#
# {'climate', 'eastern', 'indigenous', 'himalayas', 'change', 'people', 'vulnerability', 'impact', 'issue'}
# ---
#
# {'global', 'west', 'white', 'pretty', 'picture', 'dang', 'cool', 'warming', 'tonight', 'wing', 'house'}
# ---
#
# {'climate', 'change', 'maple', 'decline', 'syrup', 'hide'}
# ---
#
# {'initiative', 'climate', 'african', 'change', 'youth'}
# ---
#
# {'climate', 'mother', 'right', 'change', 'world', 'earth', 'cochabamba', 'excited', 'conference'}
# ---
#
# {'compliment', 'global', 'archive', 'nasa', 'blog', 'toolshed', 'warming', 'green', 'alarmist'}
# ---
#
# {'climate', 'half', 'pachauri', 'travel', 'head', 'change', 'clock', 'million', 'rajendra', 'panel', 'mile'}
# ---
#
# {'climate', 'free', 'cooperative', 'change', 'video', 'cyberspace'}
# ---
#
# {'climate', 'mother', 'right', 'change', 'people', 'world', 'earth', 'cochabamba', 'conference'}
# ---
#
# {'climate', 'digg', 'change', 'maple', 'decline', 'syrup', 'hide'}
# ---
#
# {'melt', 'global', 'ignorance', 'stake', 'warming'}
# ---
#
# {'melt', 'global', 'ignorance', 'stake', 'warming'}
# ---
#
# {'wash', 'global', 'tcot', 'talk', 'answer', 'surprising', 'week', 'usually', 'warming', 'conference'}
# ---
#
# {'climate', 'indigenous', 'global', 'partcipation', 'people', 'change', 'world', 'summit', 'sister', 'earthright'}
# ---
#
# {'climate', 'doubter', 'belief', 'rise', 'change', 'drain', 'month', 'number', 'away'}
# ---
#
# {'climate', 'journals', 'change', 'facility', 'ecosystem', 'response', 'expect', 'clarify'}
# ---
#
# {'climate', 'affect', 'coie', 'busin', 'change', 'publication', 'perkin', 'update', 'detaildoe', 'news'}
# ---
#
# {'climate', 'danger', 'change', 'clear', 'know', 'video', 'present', 'human'}
# ---
#
# {'climate', 'home', 'change', 'technology', 'solution', 'impact', 'dramatic', 'hydropower', 'smart'}
# ---
#
# {'climate', 'incorporate', 'quality', 'policymake', 'change', 'benefit', 'implication'}
# ---
#
# {'climate', 'nature', 'change', 'maple', 'decline', 'syrup', 'hide', 'news'}
# ---
#
# {'melt', 'global', 'say', 'economy', 'arctic', 'cost', 'study', 'warming', 'trillion'}
# ---
#
# {'climate', 'global', 'phrase', 'change', 'month', 'warming'}
# ---
#
# {'climate', 'nature', 'change', 'maple', 'decline', 'syrup', 'hide', 'news'}
# ---
#
# {'global', 'online', 'climategate', 'term', 'warm', 'weather', 'call', 'coin'}
# ---
#
# {'climate', 'perspective', 'rmet', 'change', 'meeting'}
# ---
#
# {'climate', 'form', 'body', 'rely', 'change', 'india', 'ipcc', 'justwrong'}
# ---
#
# {'climate', 'copenhagen', 'business', 'change', 'brokenhagen', 'post'}
# ---
#
# {'climate', 'astronaught', 'maldive', 'island', 'beautiful', 'change', 'impact', 'space', 'sink', 'post'}
# ---
#
# {'global', 'curb', 'block', 'authority', 'bill', 'warming', 'pollution'}
# ---
#
# {'climate', 'bloody', 'different', 'deny', 'change', 'abstinence', 'week', 'info'}
# ---
#
# {'climate', 'remain', 'telegraph', 'head', 'change', 'ipcc', 'valid', 'insist', 'science'}
# ---
#
# {'climate', 'mean', 'country', 'arab', 'change', 'environment', 'watch'}
# ---
#
# {'global', 'help', 'warming', 'stop', 'family'}
# ---
#
# {'global', 'help', 'stop', 'warming', 'family'}
# ---
#
# {'climate', 'skepticism', 'report', 'scientist', 'global', 'small', 'mistake', 'fuel', 'change', 'error', 'warmin', 'reality'}
# ---
#
# {'climate', 'global', 'warm', 'stop', 'warming'}
# ---
#
# {'climate', 'telegraphnew', 'form', 'say', 'body', 'rely', 'change', 'india', 'ipcc', 'panel'}
# ---
#
# {'geoengineere', 'climate', 'susty', 'change', 'solution', 'potential'}
# ---
#
# {'climate', 'distribute', 'change', 'cost', 'high', 'benefit'}
# ---
#
# {'global', 'endanger', 'economy', 'specie', 'warming', 'save'}
# ---
#
# {'climate', 'predict', 'future', 'change', 'sediment', 'year'}
# ---
#
# {'climate', 'body', 'blast', 'greenpeace', 'change', 'washington', 'examiner'}
# ---
#
# {'global', 'grow', 'propose', 'tree', 'solution', 'large', 'number', 'warming'}
# ---
#
# {'climate', 'accountancy', 'change', 'lead', 'profession'}
# ---
#
# {'climate', 'result', 'change', 'population', 'decline', 'wolverine', 'canada'}
# ---
#
# {'global', 'debunk', 'fossile', 'denier', 'page', 'warming'}
# ---
#
# {'climate', 'responsibility', 'kilcher', 'help', 'figure', 'change', 'public', 'activism', 'celebrity', 'actress'}
# ---
#
# {'climate', 'humanitarian', 'change', 'benefit', 'news'}
# ---
#
# {'climate', 'innovation', 'hand', 'change', 'magazine', 'cosmos', 'absorption', 'energy'}
# ---
#
# {'climate', 'global', 'shape', 'humanitarian', 'change', 'approach', 'denmark', 'davos', 'news'}
# ---
#
# {'global', 'fund', 'department', 'warming', 'defense', 'youtube'}
# ---
#
# {'global', 'help', 'way', 'know', 'stop', 'warming'}
# ---
#
# {'climate', 'accelerated', 'discover', 'fast', 'grow', 'forest', 'change', 'growth', 'ecologist', 'drive', 'appear'}
# ---
#
# {'hill', 'devote', 'article', 'global', 'bash', 'baseless', 'attack', 'gore', 'warming'}
# ---
#
# {'hill', 'item', 'climate', 'geman', 'argument', 'snow', 'change', 'good'}
# ---
#
# {'mean', 'global', 'eilperin', 'snow', 'people', 'wonder', 'juliet', 'warming'}
# ---
#
# {'climate', 'disclose', 'business', 'add', 'change', 'impact', 'patrick', 'vermont', 'parenteau', 'webinar', 'school'}
# ---
#
# {'global', 'snow', 'lack', 'lead', 'flashback', 'warming'}
# ---
#
# {'global', 'foundry', 'snomg', 'snoverit', 'blizzard', 'snotorious', 'proof', 'snomas', 'warming', 'post'}
# ---
#
# {'global', 'say', 'push', 'away', 'snowdrift', 'game', 'time', 'warming'}
# ---
#
# {'global', 'interesting', 'blizzard', 'proof', 'warming'}
# ---
#
# {'conservative', 'global', 'foundry', 'blizzard', 'promote', 'policy', 'proof', 'warming'}
# ---
#
# {'sort', 'global', 'point', 'winter', 'warming', 'like', 'people', 'disprove', 'storm', 'act', 'atlantic'}
# ---
#
# {'climate', 'global', 'worth', 'people', 'gore', 'warming', 'remind'}
# ---
#
# {'mean', 'global', 'snow', 'snowverkill', 'snowpocalypse', 'carbon', 'warming', 'post'}
# ---
#
# {'climate', 'global', 'awesome', 'evidence', 'good', 'survival', 'warming', 'fit'}
# ---
#
# {'complain', 'cancel', 'global', 'piss', 'senate', 'hearing', 'warming', 'contact', 'think'}
# ---
#
# {'global', 'blizzard', 'know', 'come', 'eventually', 'proof', 'warming'}
# ---
#
# {'global', 'foundry', 'blizzard', 'proof', 'warming', 'post'}
# ---
#
# {'climate', 'global', 'blizzard', 'bad', 'make', 'time', 'warming', 'green', 'snowstorm'}
# ---
#
# {'climate', 'responsibility', 'kilcher', 'help', 'figure', 'change', 'public', 'activism', 'celebrity', 'actress'}
# ---
#
# {'global', 'point', 'snow', 'warming', 'try'}
# ---
#
# {'climate', 'predict', 'winter', 'change', 'theory', 'away'}
# ---
#
# {'climate', 'blizzard', 'change', 'coast', 'tie', 'snowstorm'}
# ---
#
# {'climate', 'predict', 'sever', 'change', 'lead', 'theory', 'ocean', 'storm', 'increase', 'temp', 'long'}
# ---
#
# {'climate', 'nature', 'science', 'conservation', 'business', 'change', 'blog', 'cool', 'fighting', 'conservancy', 'green', 'model'}
# ---
#
# {'climate', 'denial', 'change', 'cold', 'crock', 'week'}
# ---
#
# {'global', 'show', 'snow', 'book', 'gore', 'warming', 'straight', 'news'}
# ---
#
# {'climate', 'denial', 'wwfus', 'change', 'washington', 'cold', 'crock', 'week'}
# ---
#
# {'climate', 'denial', 'wwfus', 'change', 'cold', 'crock', 'week'}
# ---
#
# {'global', 'event', 'snow', 'contradiction', 'theory', 'heavy', 'warming'}
# ---
#
# {'climate', 'snowy', 'right', 'record', 'probably', 'winter', 'official', 'change', 'fake'}
# ---
#
# {'climate', 'blizzard', 'change', 'coast', 'tie', 'snowstorm'}
# ---
#
# {'climate', 'mean', 'snow', 'huge', 'seriously', 'change', 'people', 'need', 'idiot', 'storm', 'real', 'look'}
# ---
#
# {'climate', 'global', 'snowmageddon', 'blizzard', 'bad', 'make', 'warming', 'snowstorm'}
# ---
#
# {'climate', 'article', 'change', 'mail', 'alarm', 'sound', 'globe', 'researcher', 'alarmist'}
# ---
#
# {'global', 'news', 'yahoo', 'blizzard', 'bad', 'make', 'warming', 'snowstorm'}
# ---
#
# {'global', 'say', 'refute', 'warming', 'snowstorm'}
# ---
#
# {'global', 'say', 'refute', 'warming', 'snowstorm'}
# ---
#
# {'obama', 'global', 'tcot', 'snowmageddon', 'snow', 'teaparty', 'short', 'warming', 'activist'}
# ---
#
# {'global', 'tcot', 'summer', 'snow', 'winter', 'disprove', 'warming', 'prove'}
# ---
#
# {'obama', 'global', 'snow', 'climatechange', 'short', 'warming'}
# ---
#
# {'climate', 'global', 'package', 'nino', 'clear', 'make', 'like', 'prob', 'storm'}
# ---
#
# {'global', 'knock', 'tcot', 'tree', 'tlot', 'warming'}
# ---
#
# {'global', 'knock', 'tcot', 'tree', 'warming', 'year', 'teaparty'}
# ---
#
# {'climate', 'voice', 'civil', 'santiago', 'change', 'clear', 'society', 'success', 'cochabamba', 'loud'}
# ---
#
# {'climate', 'thank', 'agree', 'unwilling', 'accept', 'change', 'truth'}
# ---
#
# {'global', 'tcot', 'cause', 'sure', 'pretty', 'warming', 'snowstorm'}
# ---
#
# {'climate', 'work', 'reduce', 'hear', 'sign', 'change', 'love', 'carbon', 'action'}
# ---
#
# {'climate', 'global', 'turn', 'change', 'jazz', 'call', 'warming'}
# ---
#
# {'melt', 'global', 'turn', 'summer', 'winter', 'warming', 'tundra', 'cap', 'mess', 'damn'}
# ---
#
# {'climate', 'report', 'scientist', 'global', 'blizzard', 'bad', 'well', 'make', 'warming', 'seek'}
# ---
#
# {'global', 'blizzard', 'bad', 'make', 'warming', 'snowstorm'}
# ---
#
# {'climate', 'mean', 'global', 'msnbc', 'ratigan', 'take', 'snow', 'nonsense', 'denier', 'warming'}
# ---
#
# {'climate', 'show', 'change', 'disprove', 'idiotic', 'snowstorm', 'think'}
# ---
#
# {'climate', 'believe', 'snow', 'continue', 'change', 'reason', 'pile'}
# ---
#
# {'global', 'denier', 'massive', 'flake', 'ammo', 'warming', 'snowstorm'}
# ---
#
# {'climate', 'global', 'scientist', 'article', 'explore', 'mystery', 'lose', 'warming', 'science', 'investigate'}
# ---
#
# {'climate', 'human', 'future', 'alternative', 'change', 'warm', 'world', 'response', 'integrate', 'potential'}
# ---
#
# {'global', 'blizzard', 'resp', 'massive', 'time', 'warming'}
# ---
#
# {'global', 'tell', 'snowpocalypse', 'climatechange', 'warming', 'republic', 'nova'}
# ---
#
# {'global', 'debunk', 'snowpocalypse', 'blizzard', 'bad', 'make', 'wrong', 'warming', 'myth'}
# ---
#
# {'global', 'real', 'need', 'convince', 'skeptic', 'warming', 'snowstorm'}
# ---
#
# {'climate', 'strong', 'kudo', 'lindsay', 'change', 'graham'}
# ---
#
# {'climate', 'mean', 'global', 'snow', 'change'}
# ---
#
# {'climate', 'middle', 'snow', 'snowpocalypse', 'blizzard', 'public', 'wonder', 'change', 'check', 'think'}
# ---
#
# {'climate', 'affect', 'event', 'perception', 'blog', 'wonder', 'bridge', 'major', 'change', 'weather', 'snoverkill', 'late', 'nick'}
# ---
#
# {'definitely', 'global', 'white', 'picket', 'weather', 'apocolyptic', 'warming', 'eff'}
# ---
#
# {'global', 'blizzard', 'claim', 'bad', 'make', 'magazine', 'time', 'warming'}
# ---
#
# {'global', 'snow', 'warming', 'intensify', 'hurricane', 'actually', 'wrong', 'storm', 'surprise'}
# ---
#
# {'global', 'snow', 'fuel', 'conservatives', 'mockery', 'storm', 'warming'}
# ---
#
# {'climate', 'winger', 'right', 'exist', 'blizzard', 'claim', 'change', 'prove'}
# ---
#
# {'global', 'host', 'cause', 'msnbc', 'ratigan', 'snowpocalypse', 'claim', 'dylab', 'warming'}
# ---
#
# {'mean', 'finally', 'global', 'mainstream', 'air', 'snow', 'nonsense', 'rebuttal', 'warming', 'video', 'medium'}
# ---
#
# {'climate', 'winger', 'right', 'exist', 'blizzard', 'claim', 'change', 'prove'}
# ---
#
# {'climate', 'winger', 'right', 'exist', 'blizzard', 'claim', 'change', 'prove'}
# ---
#
# {'climate', 'winger', 'right', 'exist', 'blizzard', 'claim', 'change', 'prove'}
# ---
#
# {'climate', 'winger', 'right', 'exist', 'blizzard', 'claim', 'change', 'prove'}
# ---
#
# {'climate', 'global', 'likely', 'blizzard', 'change', 'make'}
# ---
#
# {'worse', 'global', 'blizzard', 'make', 'warming'}
# ---
#
# {'climate', 'global', 'scientist', 'article', 'explore', 'heat', 'mystery', 'lose', 'warming', 'science', 'investigate'}
# ---
#
# {'global', 'blizzard', 'bad', 'make', 'time', 'warming', 'snowstorm'}
# ---
#
# {'global', 'blizzard', 'bad', 'make', 'time', 'warming', 'snowstorm'}
# ---
#
# {'climate', 'snowmageddon', 'change', 'disprove', 'snowstorm'}
# ---
#
# {'global', 'cause', 'msnbc', 'blizzard', 'accord', 'warming'}
# ---
#
# {'climate', 'summer', 'winter', 'specifically', 'change', 'learn', 'disprove', 'snowstorm', 'school'}
# ---
#
# {'climate', 'tcot', 'change', 'disprove', 'snowstorm'}
# ---
#
# {'climate', 'tcot', 'change', 'disprove', 'snowstorm'}
# ---
#
# {'climate', 'tcot', 'change', 'disprove', 'snowstorm'}
# ---
#
# {'climate', 'earthscan', 'business', 'sign', 'change', 'success', 'earthcast'}
# ---
#
# {'climate', 'global', 'scientist', 'right', 'ratigan', 'snowpocalypse', 'prediction', 'warming'}
# ---
#
# {'global', 'blizzard', 'bad', 'make', 'warming', 'snowstorm', 'reading'}
# ---
#
# {'global', 'snowmageddon', 'bad', 'make', 'bizzard', 'snowtorious', 'warming'}
# ---
#
# {'climate', 'offer', 'senate', 'wapo', 'combat', 'change', 'hope', 'legislation'}
# ---
#
# {'global', 'snowmageddon', 'bad', 'make', 'bizzard', 'snowtorious', 'warming'}
# ---
#
# {'vancouver', 'climate', 'global', 'snow', 'acknowledge', 'drudge', 'game', 'warming'}
# ---
#
# {'climate', 'event', 'problem', 'freak', 'cause', 'change', 'congress', 'convince', 'massive', 'weather', 'disruption'}
# ---
#
# {'climate', 'offer', 'senate', 'combat', 'change', 'clear', 'hope', 'editorial', 'legislation', 'cejapa'}
# ---
#
# {'snowfort', 'climate', 'cozy', 'rent', 'place', 'survive', 'change', 'snomegeddon', 'need', 'snoverkill', 'beware'}
# ---
#
# {'vancouver', 'climate', 'global', 'snow', 'acknowledge', 'drudge', 'kick', 'game', 'warming'}
# ---
#
# {'climate', 'push', 'deny', 'blizzard', 'sadly', 'change', 'chuck', 'conspiracy', 'norris'}
# ---
#
# {'climate', 'york', 'education', 'nasa', 'nyserda', 'change', 'state', 'enable', 'grant', 'clarkson', 'improve'}
# ---
#
# {'climate', 'doubter', 'bud', 'sure', 'change', 'know', 'newsflash'}
# ---
#
# {'global', 'seriously', 'blizzard', 'reach', 'make', 'bad', 'time', 'warming'}
# ---
#
# {'global', 'government', 'argument', 'trade', 'like', 'sound', 'cost', 'shut', 'million', 'federal', 'warming'}
# ---
#
# {'climate', 'wash', 'offer', 'senate', 'combat', 'change', 'editorial', 'hope', 'post', 'legislation'}
# ---
#
# {'happen', 'global', 'blizzard', 'talk', 'make', 'bad', 'need', 'time', 'warming'}
# ---
#
# {'climate', 'want', 'clue', 'change', 'volunteer', 'need', 'budburst', 'plant', 'assess', 'look'}
# ---
#
# {'climate', 'international', 'willing', 'change', 'list', 'page', 'watch'}
# ---
#
# {'climate', 'sceptic', 'give', 'change', 'rational', 'engage', 'fruitcake', 'science', 'discussion', 'field'}
# ---
#
# {'climate', 'wealth', 'release', 'noaa', 'change', 'public', 'datum'}
# ---
#
# {'climate', 'abstract', 'international', 'change', 'research', 'cold', 'chain', 'food'}
# ---
#
# {'climate', 'distribute', 'unequally', 'easily', 'cheaply', 'relatively', 'change', 'like', 'geoeng', 'risk', 'quickly', 'reward'}
# ---
#
# {'outweigh', 'global', 'country', 'question', 'geoeng', 'risk', 'warming', 'respond', 'think'}
# ---
#
# {'climate', 'runaway', 'change', 'takeaway', 'risk', 'moral', 'authority'}
# ---
#
# {'creator', 'global', 'monologue', 'vagina', 'tsunamis', 'tell', 'look', 'palin', 'proof', 'warming', 'brilliant', 'earthquake'}
# ---
#
# {'creator', 'global', 'monologue', 'vagina', 'tsunamis', 'tell', 'look', 'palin', 'proof', 'warming', 'brilliant', 'earthquake'}
# ---
#
# {'creator', 'global', 'tcot', 'monologue', 'vagina', 'tsunamis', 'tell', 'fail', 'look', 'palin', 'proof', 'warming', 'brilliant', 'earthquake'}
# ---
#
# {'global', 'predict', 'extreme', 'weather', 'warming', 'year', 'model'}
# ---
#
# {'global', 'predict', 'extreme', 'weather', 'warming', 'year', 'model'}
# ---
#
# {'climate', 'threaten', 'acidification', 'change', 'type', 'coral'}
# ---
#
# {'climate', 'threaten', 'acidification', 'change', 'type', 'coral'}
# ---
#
# {'day', 'global', 'thank', 'warming', 'close', 'mess', 'freedom'}
# ---
#
# {'global', 'burn', 'kill', 'love', 'earth', 'warming', 'demvdaycard', 'hotter'}
# ---
#
# {'global', 'connect', 'today', 'energy', 'transit', 'electric', 'ford', 'unveil', 'warming', 'news', 'february'}
# ---
#
# {'climate', 'true', 'mother', 'business', 'change', 'financial', 'risk', 'cost', 'coal', 'pay'}
# ---
#
# {'climate', 'conservative', 'global', 'brain', 'noisemachine', 'winter', 'weather', 'attack', 'warming', 'freeze', 'medium'}
# ---
#
# {'climate', 'conservative', 'global', 'brain', 'winter', 'weather', 'attack', 'warming', 'freeze', 'green', 'medium'}
# ---
#
# {'global', 'scientist', 'snow', 'telegraph', 'consistent', 'warming'}
# ---
#
# {'global', 'scientist', 'snow', 'telegraph', 'consistent', 'warming'}
# ---
#
# {'global', 'scientist', 'snow', 'telegraph', 'consistent', 'warming'}
# ---
#
# {'conservative', 'global', 'brain', 'winter', 'weather', 'attack', 'warming', 'freeze', 'medium'}
# ---
#
# {'climate', 'conservative', 'global', 'brain', 'noisemachine', 'winter', 'weather', 'attack', 'warming', 'freeze', 'medium'}
# ---
#
# {'climate', 'conservative', 'global', 'brain', 'noisemachine', 'winter', 'weather', 'attack', 'warming', 'freeze', 'medium'}
# ---
#
# {'climate', 'conservative', 'global', 'brain', 'noisemachine', 'winter', 'weather', 'attack', 'warming', 'freeze', 'medium'}
# ---
#
# {'global', 'think', 'result', 'abuse', 'story', 'like', 'horror', 'stop', 'ashtag', 'human'}
# ---
#
# {'climate', 'disclosure', 'change', 'come', 'impact', 'monday', 'past', 'february'}
# ---
#
# {'global', 'moisture', 'today', 'snowmageddon', 'hit', 'lesson', 'hold', 'blizzard', 'sign', 'warm', 'cold', 'warming'}
# ---
#
# {'resource', 'global', 'topic', 'anthropogenic', 'informative', 'terrific', 'warming', 'combine'}
# ---
#
# {'climate', 'wash', 'global', 'fact', 'detracter', 'snow', 'claim', 'moron', 'change', 'undemine', 'huffpost', 'time', 'base'}
# ---
#
# {'climate', 'dishonest', 'scientist', 'snow', 'change', 'disprove', 'idiot', 'think'}
# ---
#
# {'climate', 'indigenous', 'wake', 'change', 'people', 'mining', 'firm', 'conference'}
# ---
#
# {'climate', 'snow', 'change', 'disprove', 'idiot', 'think'}
# ---
#
# {'climate', 'work', 'help', 'seriously', 'change', 'people'}
# ---
#
# {'climate', 'katz', 'complain', 'global', 'apart', 'proponent', 'debate', 'change', 'fall', 'warming', 'activist'}
# ---
#
# {'global', 'work', 'willful', 'snowmageddon', 'blindness', 'weirding', 'warming', 'theologian'}
# ---
#
# {'obama', 'agency', 'global', 'director', 'qualified', 'teleprompter', 'appoint', 'eminently', 'warming', 'blow'}
# ---
#
# {'climate', 'industry', 'government', 'clim', 'access', 'birth', 'change', 'entirely', 'portal', 'long'}
# ---
#
# {'climate', 'point', 'starting', 'change', 'woman', 'million'}
# ---
#
# {'spontaneous', 'global', 'body', 'combustion', 'warm', 'ignite', 'gas', 'field', 'electrical', 'flammable', 'human'}
# ---
#
# {'climate', 'urge', 'african', 'africa', 'source', 'bloomberg', 'modern', 'change', 'failure', 'farmer', 'innovate', 'offset', 'embrace'}
# ---
#
# {'folk', 'climate', 'blizzard', 'story', 'debate', 'change', 'negate', 'goddammit', 'real', 'science'}
# ---
#
# {'climate', 'believe', 'scientist', 'debate', 'change', 'people', 'real'}
# ---
#
# {'climate', 'fight', 'transit', 'change', 'bill'}
# ---
#
# {'geoengineere', 'diplomatic', 'climate', 'nightmare', 'basic', 'change', 'bad', 'reason'}
# ---
#
# {'global', 'msnbc', 'ratigan', 'snowpocalypse', 'blame', 'warming'}
# ---
#
# {'global', 'msnbc', 'ratigan', 'snowpocalypse', 'blame', 'warming'}
# ---
#
# {'climate', 'interested', 'wildlife', 'change', 'service', 'address', 'fish', 'science'}
# ---
#
# {'global', 'tcot', 'msnbc', 'snomg', 'ratigan', 'snowpocalypse', 'blame', 'warming', 'video'}
# ---
#
# {'climate', 'great', 'habitat', 'echo', 'stream', 'change', 'lake', 'fish', 'chase', 'study', 'researcher', 'science'}
# ---
#
# {'climate', 'industry', 'birth', 'change', 'entirely', 'portal'}
# ---
#
# {'global', 'msnbc', 'ratigan', 'snowpocalypse', 'blame', 'warming'}
# ---
#
# {'climate', 'communicate', 'kate', 'change', 'politic', 'sheppard', 'beat'}
# ---
#
# {'climate', 'invasive', 'change', 'plant', 'aid'}
# ---
#
# {'climate', 'agency', 'form', 'change', 'federal'}
# ---
#
# {'climate', 'aids', 'invasive', 'change', 'plant', 'aid', 'news'}
# ---
#
# {'obama', 'global', 'obamateurism', 'read', 'anthropogenic', 'barack', 'maybe', 'memo', 'warming'}
# ---
#
# {'climate', 'imperative', 'lens', 'change', 'policy', 'examine', 'ethical', 'practical', 'reason'}
# ---
#
# {'climate', 'release', 'temperature', 'chem', 'change', 'warm', 'world', 'plant', 'fragrant'}
# ---
#
# {'global', 'times', 'climategate', 'jennifer', 'haberkorn', 'washington', 'federal', 'warming', 'office'}
# ---
#
# {'half', 'global', 'right', 'logic', 'policy', 'ipcc', 'david', 'despite', 'king', 'warming'}
# ---
#
# {'climate', 'attention', 'snow', 'change', 'lobbyist', 'congress', 'anti', 'member', 'hope', 'pay'}
# ---
#
# {'climate', 'event', 'precipitation', 'scientist', 'exclusively', 'change', 'consistent', 'theory', 'heavy', 'weather', 'attribute'}
# ---
#
# {'climate', 'challenge', 'help', 'adapt', 'noaa', 'head', 'change', 'service', 'tackle', 'mitigate', 'locke'}
# ---
#
# {'global', 'snowpocalypse', 'stop', 'inch', 'region', 'warming', 'tuesday', 'wednesday'}
# ---
#
# {'mean', 'global', 'tcot', 'snow', 'washington', 'cold', 'month', 'warming', 'examiner'}
# ---
#
# {'climate', 'trend', 'noaa', 'colleague', 'change', 'service', 'special', 'launch', 'track'}
# ---
#
# {'great', 'global', 'masters', 'blog', 'storm', 'jeff', 'warming'}
# ---
#
# {'climate', 'core', 'change', 'water', 'impact', 'expert'}
# ---
#
# {'tlkibg', 'metro', 'global', 'snowless', 'warming'}
# ---
#
# {'global', 'undermine', 'exxon', 'public', 'acceptance', 'campaign', 'warming', 'orchestrate'}
# ---
#
# {'pablo', 'climate', 'volcano', 'change', 'impact', 'iceland'}
# ---
#
# {'climate', 'blizzard', 'noaa', 'change', 'rearrange', 'announcement'}
# ---
#
# {'climate', 'global', 'cause', 'necessarily', 'local', 'change', 'stfu', 'denier', 'need', 'large', 'storm', 'increase', 'warming', 'temp', 'look'}
# ---
#
# {'climate', 'obama', 'say', 'wildlife', 'times', 'administr', 'pika', 'change', 'blog', 'service', 'imperil', 'fish', 'york'}
# ---
#
# {'global', 'cause', 'reduce', 'unemployment', 'specified', 'emission', 'level', 'warming', 'greenhouse', 'drop', 'year'}
# ---
#
# {'batman', 'global', 'say', 'well', 'warming'}
# ---
#
# {'pablo', 'climate', 'volcano', 'change', 'impact', 'iceland'}
# ---
#
# {'mean', 'thing', 'global', 'winter', 'stupid', 'warming', 'people', 'love', 'storm', 'shut', 'dear', 'think'}
# ---
#
# {'mean', 'global', 'snow', 'cold', 'month', 'warming'}
# ---
#
# {'mean', 'global', 'snow', 'cold', 'month', 'warming'}
# ---
#
# {'climate', 'push', 'group', 'outside', 'continue', 'senate', 'change', 'despite', 'odd', 'bill', 'long'}
# ---
#
# {'climate', 'landmark', 'report', 'programme', 'head', 'environment', 'conclusion', 'change', 'defend'}
# ---
#
# ...
# ---
#
# {'climate', 'health', 'biodiversity', 'start', 'sustainability', 'hopkins', 'change', 'johns', 'public', 'environ', 'impact', 'loss', 'child'}
# ---
#
# {'virginia', 'global', 'scientist', 'emerge', 'inspector', 'mann', 'gene', 'warm', 'state', 'word', 'foxnew', 'investigate'}
# ---
#
# {'climate', 'report', 'change', 'center', 'recommendation', 'concrete', 'response', 'structure', 'federal', 'deliver'}
# ---
#
# {'melt', 'global', 'skeptic', 'fear', 'cyclical', 'glucose', 'stickiness', 'warm', 'candy', 'earth', 'crowd', 'rock', 'warming', 'raise', 'mountain'}
# ---
#
# {'global', 'think', 'cause', 'excess', 'effect', 'somerfield', 'warming', 'environmental', 'mark'}
# ---
#
# {'british', 'global', 'candidate', 'right', 'frightening', 'cspan', 'debate', 'truth', 'watch', 'leftist', 'warming', 'include'}
# ---
#
# {'climate', 'lowell', 'cincinnati', 'geologist', 'change', 'pattern', 'university', 'historic', 'study'}
# ---
#
# {'global', 'problem', 'hoax', 'hopkins', 'real', 'warming', 'prove', 'mark'}
# ---
#
# {'climate', 'gile', 'countr', 'africa', 'change', 'sarah', 'slade', 'strange', 'palin', 'mccarthyism', 'think'}
# ---
#
# {'climate', 'global', 'government', 'cause', 'story', 'claim', 'change', 'begin', 'promise', 'warming'}
# ---
#
# {'climate', 'representativ', 'ridge', 'change', 'center', 'dana', 'conference', 'mass', 'focus', 'environmental'}
# ---
#
# {'folk', 'sweat', 'offshore', 'safe', 'global', 'drilling', 'promise', 'warming'}
# ---
#
# {'climate', 'agency', 'fuzzy', 'scientist', 'government', 'inter', 'suggest', 'deal', 'change', 'extinction', 'hub', 'bring', 'mass'}
# ---
#
# {'global', 'cause', 'angus', 'overpopulation', 'people', 'number', 'warming', 'dissect'}
# ---
#
# {'climate', 'site', 'nasa', 'award', 'change', 'good', 'vote', 'science', 'webby'}
# ---
#
# {'climate', 'global', 'report', 'indicator', 'release', 'dummy', 'change', 'warming'}
# ---
#
# {'climate', 'effect', 'monitoring', 'change', 'instrument', 'national', 'increase', 'focus', 'environmental'}
# ---
#
# {'climate', 'effect', 'monitoring', 'change', 'instrument', 'national', 'increase', 'focus', 'environmental'}
# ---
#
# {'climate', 'fidel', 'castro', 'change', 'warn', 'aftermath'}
# ---
#
# {'climate', 'nations', 'cause', 'natural', 'change', 'column', 'consider', 'united', 'intergovernmental', 'panel'}
# ---
#
# {'climate', 'global', 'warming', 'change', 'possible', 'issue'}
# ---
#
# {'climate', 'climategate', 'clean', 'unit', 'review', 'change', 'independent', 'bill', 'get', 'science'}
# ---
#
# {'global', 'problem', 'fight', 'tcot', 'poop', 'need', 'proof', 'whale', 'warming'}
# ---
#
# {'climate', 'espritsdefolie', 'volcano', 'cause', 'believable', 'semi', 'hear', 'evidence', 'change', 'earthquake'}
# ---
#
# {'climate', 'volcano', 'cause', 'believable', 'semi', 'evidence', 'change', 'earthquake'}
# ---
#
# {'climate', 'volcano', 'cause', 'believable', 'semi', 'evidence', 'change', 'earthquake'}
# ---
#
# {'climate', 'volcano', 'cause', 'believable', 'semi', 'evidence', 'change', 'earthquake'}
# ---
#
# {'accelerate', 'global', 'april', 'produce', 'soil', 'microbe', 'warming', 'expect', 'london'}
# ---
#
# {'cameron', 'global', 'medium', 'right', 'urge', 'matthews', 'james', 'dangerous', 'denier', 'trash', 'warming', 'wing'}
# ---
#
# {'global', 'engineer', 'volcano', 'cause', 'matai', 'blogger', 'claim', 'huffpo', 'warming', 'post', 'huffington'}
# ---
#
# {'cameron', 'global', 'medium', 'right', 'urge', 'matthews', 'james', 'dangerous', 'denier', 'trash', 'warming', 'wing'}
# ---
#
# {'politician', 'global', 'say', 'pundit', 'snow', 'warming', 'look'}
# ---
#
# {'archiv', 'cameron', 'global', 'urge', 'matthews', 'geoffrey', 'james', 'dangerous', 'denier', 'trash', 'warming', 'dickens'}
# ---
#
# {'climate', 'senator', 'introduce', 'aim', 'change', 'reuter', 'prepare', 'compromise', 'kerry'}
# ---
#
# {'climate', 'global', 'graham', 'lieberman', 'bill', 'warming', 'kerry', 'energy'}
# ---
#
# {'princeton', 'global', 'lecture', 'scholar', 'university', 'ledger', 'warming', 'star', 'cloud'}
# ---
#
# {'awful', 'climate', 'sen', 'near', 'swamp', 'future', 'change', 'need', 'news', 'legislation'}
# ---
#
# {'awful', 'climate', 'near', 'resident', 'future', 'change', 'nevada', 'news', 'legislation'}
# ---
#
# {'climate', 'threaten', 'tripartisan', 'today', 'point', 'arizona', 'immigration', 'change', 'legislation', 'upend'}
# ---
#
# {'climate', 'copenhagen', 'change', 'allow', 'lag', 'cynthia', 'conference', 'year', 'green', 'energy'}
# ---
#
# {'global', 'pelosi', 'gingrich', 'defend', 'commercial', 'warming'}
# ---
#
# {'global', 'delay', 'group', 'teamster', 'union', 'warming', 'official', 'major', 'measure', 'effort', 'oppose', 'california'}
# ---
#
# {'environmental', 'climate', 'island', 'rise', 'step', 'change', 'address', 'issu', 'rhode', 'anchor', 'mandate'}
# ---
#
# {'climate', 'battle', 'solar', 'change', 'mcewan'}
# ---
#
# {'global', 'wish', 'pant', 'warming', 'iceland'}
# ---
#
# {'global', 'mercury', 'soar', 'blame', 'environmentalist', 'attribute'}
# ---
#
# {'global', 'believe', 'april', 'minneapolis', 'spring', 'letter', 'warm', 'skeptic', 'freeze'}
# ---
#
# {'global', 'volcano', 'matai', 'link', 'warming', 'earthquake'}
# ---
#
# {'climate', 'cover', 'volcano', 'question', 'change', 'answer'}
# ---
#
# {'global', 'solution', 'tough', 'emission', 'control', 'greenhouse', 'warming', 'nation'}
# ---
#
# {'global', 'madness', 'cause', 'lovecraftian', 'thawing', 'uncover', 'induce', 'bury', 'gaze', 'warming', 'shit'}
# ---
#
# {'climate', 'cover', 'volcano', 'question', 'change', 'answer'}
# ---
#
# {'climate', 'neutral', 'corp', 'aim', 'change', 'promote', 'carbon', 'news'}
# ---
#
# {'global', 'april', 'talk', 'topi', 'presentation', 'film', 'warming', 'scientifique', 'present'}
# ---
#
# {'global', 'kiddo', 'think', 'miss', 'newyork', 'florida', 'waiting', 'win', 'warming', 'nice'}
# ---
#
# {'global', 'kiddo', 'think', 'miss', 'newyork', 'florida', 'waiting', 'win', 'warming', 'nice'}
# ---
#
# {'global', 'kiddo', 'think', 'miss', 'newyork', 'florida', 'waiting', 'win', 'warming', 'nice'}
# ---
#
# {'global', 'kiddo', 'think', 'miss', 'newyork', 'florida', 'waiting', 'win', 'warming', 'nice'}
# ---
#
# {'global', 'speak', 'theater', 'loorz', 'clim', 'presentation', 'palace', 'warming', 'year', 'give', 'alec'}
# ---
#
# {'climate', 'cover', 'volcano', 'question', 'change', 'answer'}
# ---
#
# {'climate', 'cover', 'volcano', 'question', 'change', 'answer'}
# ---
#
# {'global', 'meet', 'appetit', 'calculator', 'management', 'carbon', 'company', 'warming', 'food', 'weight'}
# ---
#
# {'british', 'global', 'doubter', 'tcot', 'nobama', 'want', 'tlot', 'throw', 'lawyer', 'cide', 'warming', 'taxandtrade', 'jail'}
# ---
#
# {'climate', 'global', 'tcot', 'freedom', 'volcanic', 'tlot', 'check', 'blame', 'eruption', 'warming', 'icelandic', 'iceland'}
# ---
#
# {'climate', 'cover', 'volcano', 'question', 'change', 'answer', 'iceland', 'eruption', 'eyjafjallajo', 'mountain'}
# ---
#
# {'initiative', 'global', 'ballot', 'teamster', 'weigh', 'city', 'state', 'warming', 'california'}
# ---
#
# {'climate', 'april', 'tuesday', 'change', 'redaction', 'failure', 'avoid', 'ahora', 'seek'}
# ---
#
# {'climate', 'neutral', 'corp', 'aim', 'change', 'promote', 'carbon', 'news'}
# ---
#
# {'climate', 'report', 'solar', 'change', 'environment', 'renewable', 'cleantech', 'green', 'energy'}
# ---
#
# {'climate', 'instead', 'phrase', 'change', 'good', 'like', 'environmentally', 'damage', 'respectful', 'word', 'behavior'}
# ---
#
# {'climate', 'supply', 'tourism', 'effect', 'change', 'post'}
# ---
#
# {'global', 'bizarre', 'view', 'interesting', 'unforseen', 'number', 'satirical', 'warming', 'consequence'}
# ---
#
# {'climate', 'institute', 'solar', 'lecture', 'change', 'energy'}
# ---
#
# {'climate', 'free', 'bonnaroo', 'change', 'good', 'download', 'album'}
# ---
#
# {'climate', 'scientist', 'help', 'change', 'understand', 'watch', 'video', 'amazing', 'image'}
# ---
#
# {'global', 'mother', 'bolivia', 'lifeline', 'combat', 'earth', 'summit', 'warming', 'worl', 'seek'}
# ---
#
# {'climate', 'mancuso', 'julia', 'senate', 'change', 'miller', 'pass', 'bode', 'legislation'}
# ---
#
# {'climate', 'system', 'organic', 'consumer', 'change', 'earthday', 'assoc'}
# ---
#
# {'obama', 'light', 'global', 'bulb', 'change', 'truth', 'brian', 'warming', 'solve', 'fuck', 'house'}
# ---
#
# {'average', 'global', 'thought', 'rise', 'warming', 'refer'}
# ---
#
# {'global', 'mainstream', 'journalism', 'warming', 'decade', 'call', 'advocacy', 'year'}
# ---
#
# {'global', 'naughton', 'help', 'tomorrow', 'american', 'come', 'earth', 'million', 'warming', 'homework', 'schoolchil'}
# ---
#
# {'climate', 'convention', 'global', 'perception', 'change', 'intl', 'public', 'hunger', 'agricultural', 'biotech', 'highlight'}
# ---
#
# {'climate', 'change', 'open', 'tiquipaya', 'morale', 'conference'}
# ---
#
# {'climate', 'encyclopedia', 'guide', 'visual', 'change', 'weather', 'complete', 'recommend'}
# ---
#
# {'climate', 'hit', 'change', 'river', 'need', 'disaster', 'delta', 'video', 'california'}
# ---
#
# {'inconvenient', 'climate', 'fight', 'change', 'stop', 'teen', 'shop', 'youth'}
# ---
#
# {'inconvenient', 'climate', 'fight', 'change', 'stop', 'teen', 'shop', 'youth'}
# ---
#
# {'global', 'want', 'kill', 'stop', 'join', 'warming', 'valero'}
# ---
#
# {'climate', 'global', 'volcano', 'change', 'trigger', 'warming', 'think'}
# ---
#
# {'global', 'reduce', 'effect', 'major', 'company', 'warming'}
# ---
#
# {'climate', 'biotechnology', 'innovation', 'reduce', 'role', 'change', 'emission', 'summit', 'leadership', 'highlight'}
# ---
#
# {'inconvenient', 'climate', 'change', 'tackle', 'youth'}
# ---
#
# {'climate', 'sustainability', 'change', 'address', 'win'}
# ---
#
# {'global', 'economist', 'view', 'profit', 'good', 'talk', 'class', 'confuse', 'warming', 'think'}
# ---
#
# {'global', 'lukas', 'environmentalism', 'claim', 'ethanol', 'dark', 'environmentalist', 'moral', 'carrie', 'warming'}
# ---
#
# {'climate', 'workshop', 'today', 'vegas', 'desert', 'usgs', 'change'}
# ---
#
# {'climate', 'report', 'mother', 'jones', 'change', 'back', 'impact', 'launch', 'slate', 'response', 'wire', 'atlantic'}
# ---
#
# {'climate', 'report', 'mother', 'jones', 'change', 'back', 'impact', 'launch', 'slate', 'response', 'wire', 'atlantic'}
# ---
#
# {'climate', 'indigenous', 'global', 'thank', 'partcipation', 'people', 'change', 'world', 'summit', 'sister', 'earthright'}
# ---
#
# {'climate', 'slowly', 'start', 'evolution', 'change', 'polarbear', 'cutie'}
# ---
#
# {'alarmism', 'global', 'reach', 'apex', 'world', 'run', 'short', 'time', 'warming'}
# ---
#
# {'climate', 'thing', 'different', 'global', 'cause', 'atmosphere', 'change', 'increase', 'warming'}
# ---
#
# {'climate', 'ppls', 'earthweek', 'bolivia', 'change', 'people', 'world', 'earthday', 'conference'}
# ---
#
# {'global', 'set', 'april', 'record', 'prove', 'warming', 'heatwave'}
# ---
#
# {'global', 'thaw', 'turn', 'reuters', 'cause', 'climat', 'oslo', 'decade', 'cap', 'come', 'ashe', 'warming', 'myth'}
# ---
#
# {'alarmism', 'global', 'world', 'run', 'short', 'time', 'warming', 'pollution'}
# ---
#
# {'climate', 'treehugger', 'political', 'effect', 'change', 'environment', 'economic', 'earthquake'}
# ---
#
# {'mckibben', 'global', 'bill', 'talk', 'cool', 'time', 'warming', 'changin'}
# ---
#
# {'climate', 'adapt', 'change', 'hominid', 'past'}
# ---
#
# {'great', 'climate', 'aspect', 'history', 'site', 'natural', 'change', 'break', 'environment', 'earth', 'news'}
# ---
#
# {'ambassador', 'pablo', 'climate', 'mother', 'right', 'change', 'people', 'bolivian', 'world', 'earth', 'summit', 'solon'}
# ---
#
# {'climate', 'miss', 'heat', 'concern', 'sign', 'change', 'reappear', 'earth', 'eventually'}
# ---
#
# {'climate', 'april', 'bolivia', 'slap', 'change', 'slice', 'summit', 'million', 'dollar', 'ecuador'}
# ---
#
# {'climate', 'change', 'illuminate', 'post', 'science'}
# ---
#
# {'climate', 'event', 'community', 'farmington', 'talk', 'change', 'library', 'earth', 'embrace', 'green', 'energy'}
# ---
#
# {'climate', 'nuclear', 'change', 'power', 'solution'}
# ---
#
# {'climate', 'system', 'seasonal', 'solar', 'allergy', 'change', 'make', 'bad', 'blame', 'gore'}
# ---
#
# {'relation', 'human', 'global', 'volcano', 'contribute', 'emit', 'wonder', 'joke', 'lie', 'warming', 'farce', 'iceland'}
# ---
#
# {'global', 'show', 'pressure', 'warming', 'public', 'disbelieve', 'world', 'game', 'importance', 'experien', 'detractor'}
# ---
#
# {'global', 'reliable', 'unchanging', 'sign', 'like', 'gravity', 'warming'}
# ---
#
# {'climate', 'predict', 'outcome', 'apocalypsenow', 'exciting', 'change', 'hard', 'green', 'revolution'}
# ---
#
# {'climate', 'alternative', 'place', 'graph', 'change', 'science'}
# ---
#
# {'climate', 'finally', 'economy', 'definitely', 'read', 'krugman', 'change', 'build', 'worthwhile', 'green'}
# ---
#
# {'climate', 'affect', 'tool', 'miss', 'future', 'heat', 'source', 'change', 'current', 'accoun', 'observational', 'science', 'daily'}
# ---
#
# {'global', 'thing', 'johnson', 'watch', 'nathanael', 'warming', 'california', 'solve'}
# ---
#
# {'climate', 'light', 'oven', 'lock', 'switch', 'change', 'dial', 'carbon', 'abrupt'}
# ---
#
# {'global', 'scientist', 'miss', 'find', 'heat', 'beef', 'monitoring', 'way', 'need', 'measure', 'expert', 'warming'}
# ---
#
# {'climate', 'happen', 'idea', 'reduce', 'change', 'good', 'know', 'carbon', 'grant'}
# ---
#
# {'climate', 'cite', 'health', 'refinery', 'local', 'effect', 'change', 'negative', 'study'}
# ---
#
# {'global', 'free', 'discuss', 'polar', 'adventurer', 'explorer', 'program', 'renowned', 'warming', 'steger', 'present'}
# ---
#
# {'global', 'scientist', 'staudt', 'series', 'amanda', 'extreme', 'weather', 'warming'}
# ---
#
# {'statement', 'global', 'positive', 'tinto', 'clean', 'chiaro', 'preston', 'thankfully', 'warming', 'energy'}
# ---
#
# {'chris', 'wise', 'global', 'heart', 'jersey', 'wallet', 'christie', 'warming', 'governor'}
# ---
#
# {'climate', 'prevent', 'public', 'change', 'willingness', 'post'}
# ---
#
# {'global', 'doubleday', 'take', 'talese', 'page', 'mcewan'}
# ---
#
# {'obese', 'global', 'cause', 'people', 'society', 'otago', 'time', 'warming', 'daily', 'create'}
# ---
#
# {'climate', 'turn', 'country', 'change', 'water', 'world', 'coastal'}
# ---
#
# {'daniel', 'climate', 'plan', 'post', 'change', 'greentech', 'esty', 'huffington'}
# ---
#
# {'global', 'tcot', 'antarctica', 'death', 'warming', 'freeze', 'activist'}
# ---
#
# {'climate', 'question', 'series', 'change', 'baby', 'lowdown'}
# ---
#
# {'climate', 'question', 'series', 'change', 'baby', 'lowdown'}
# ---
#
# {'resource', 'econ', 'climate', 'natural', 'krugman', 'change'}
# ---
#
# {'resource', 'econ', 'climate', 'natural', 'krugman', 'change'}
# ---
#
# {'climate', 'senior', 'press', 'charity', 'officer', 'change', 'oxfam', 'job'}
# ---
#
# {'climate', 'primer', 'jasencomstock', 'krugman', 'change', 'good', 'make', 'economic', 'love', 'paul'}
# ---
#
# {'climate', 'system', 'ecojustice', 'right', 'change', 'elect', 'violence', 'daily'}
# ---
#
# {'bonn', 'global', 'international', 'continue', 'agree', 'effort', 'warming', 'negotia'}
# ---
#
# {'climate', 'thirty', 'vanish', 'palm', 'tree', 'change', 'call', 'million', 'time', 'year', 'alaska', 'process'}
# ---
#
# {'global', 'declare', 'today', 'view', 'oppose', 'telegraph', 'meat', 'study', 'refute', 'warming', 'second', 'daily'}
# ---
#
# {'global', 'source', 'water', 'major', 'warming', 'pollution'}
# ---
#
# {'climate', 'global', 'liberalfascism', 'tcot', 'prosecute', 'ecocide', 'warming', 'news'}
# ---
#
# {'climate', 'fight', 'lizard', 'important', 'play', 'change', 'role', 'bird', 'earth', 'bat'}
# ---
#
# {'climate', 'fight', 'lizard', 'important', 'play', 'change', 'role', 'bird', 'earth', 'bat'}
# ---
#
# {'climate', 'fight', 'lizard', 'important', 'play', 'change', 'role', 'bird', 'earth', 'bat'}
# ---
#
# {'climate', 'fight', 'lizard', 'important', 'play', 'change', 'role', 'bird', 'earth', 'bat'}
# ---
#
# {'climate', 'fight', 'lizard', 'important', 'play', 'change', 'role', 'bird', 'earth', 'bat'}
# ---
#
# {'fossil', 'dilemma', 'global', 'use', 'million', 'fuel', 'need', 'serve', 'america', 'warming', 'barrel'}
# ---
#
# {'global', 'chalk', 'august', 'unbelievable', 'weather', 'warming', 'climb'}
# ---
#
# {'climate', 'global', 'say', 'favor', 'tcot', 'phrase', 'change', 'abandon', 'luntz', 'warming'}
# ---

# %%
generateWordCloud(pre_tweet_pos)

# %% [markdown]
# Negative tweets visualization

# %%
neg_tweets=data[data['existence']=='No']
neg_tweets.head()
# Out:
#                                                 tweet existence  \
# 17  Wait here's an idea: it's natural climate chan...        No
# 31  @New_federalists  i have it on good auth tht g...        No
# 32  Illegal war and the myth of global warming|My ...        No
# 33  the scientific community was scamed by global ...        No
# 35  40 degrees in NYC. please urinate on next libe...        No
#
#     existence.confidence  word_count
# 17                0.6648          14
# 31                0.8197          27
# 32                0.9183          20
# 33                0.9336          12
# 35                1.0000          16

# %%
pre_tweet_neg,neg_hash_tweets,neg_urls_tweets,neg_mentions_tweets,indices_neg=preprocess (neg_tweets.tweet)
# Out:
# {'wait', 'climate', 'global', 'idea', 'natural', 'change', 'induce', 'warming', 'human'}
# ---
#
# {'global', 'tcot', 'cause', 'good', 'fungus', 'fortunate', 'warming', 'auth'}
# ---
#
# {'illegal', 'global', 'main', 'platform', 'campaign', 'election', 'myth'}
# ---
#
# {'global', 'scam', 'community', 'scientific', 'warming', 'green'}
# ---
#
# {'global', 'scum', 'liberal', 'change', 'degree', 'urinate', 'warming'}
# ---
#
# {'global', 'ocra', 'ucot', 'mississippi', 'tornado', 'tornadocot', 'tlot', 'warm', 'tycot', 'gore', 'race'}
# ---
#
# {'global', 'scam', 'settle', 'confirm', 'stop', 'book', 'warming', 'sussman'}
# ---
#
# {'global', 'believe', 'angel', 'exist', 'cause', 'jesus', 'tcot', 'miracle', 'rationalist', 'alien', 'fairy', 'warming', 'human'}
# ---
#
# {'climate', 'killer', 'tsunami', 'peruvian', 'change', 'lake', 'proof', 'glaci', 'fall', 'fracture', 'create'}
# ---
#
# {'climate', 'global', 'hack', 'hoax', 'warming', 'change', 'palin', 'real', 'algore', 'science', 'gore'}
# ---
#
# {'journal', 'global', 'scientist', 'stranger', 'nature', 'anti', 'wrong', 'magazine', 'warming', 'academic'}
# ---
#
# {'climate', 'global', 'difference', 'nasa', 'accord', 'weather', 'baloney', 'measure', 'expert', 'warming'}
# ---
#
# {'true', 'computer', 'global', 'belive', 'idiot', 'forensic', 'expert', 'warming'}
# ---
#
# {'artic', 'global', 'looney', 'liberal', 'home', 'bite', 'learn', 'come', 'frost', 'toon', 'warming', 'alarmist'}
# ---
#
# {'regulator', 'global', 'safety', 'blankenship', 'warming', 'silly'}
# ---
#
# {'wait', 'climate', 'global', 'idea', 'natural', 'change', 'induce', 'warming', 'human'}
# ---
#
# {'climate', 'global', 'read', 'change', 'warm'}
# ---
#
# {'global', 'tcot', 'cause', 'good', 'fungus', 'fortunate', 'warming', 'auth'}
# ---
#
# {'illegal', 'global', 'main', 'platform', 'campaign', 'election', 'myth'}
# ---
#
# {'happen', 'global', 'read', 'spring', 'winter', 'care', 'cold', 'live', 'warming'}
# ---
#
# {'global', 'scam', 'community', 'scientific', 'warming', 'green'}
# ---
#
# {'global', 'artist', 'scam', 'truly', 'billion', 'worth', 'award', 'decade', 'credit', 'close', 'gore', 'warming', 'energy'}
# ---
#
# {'global', 'climategate', 'tcot', 'scam', 'warming', 'policy', 'world', 'current', 'decline', 'lie', 'hide', 'epic', 'job'}
# ---
#
# {'global', 'scum', 'liberal', 'change', 'degree', 'urinate', 'warming'}
# ---
#
# {'global', 'scam', 'settle', 'confirm', 'stop', 'book', 'warming', 'sussman'}
# ---
#
# {'boycott', 'global', 'buy', 'tcot', 'siemen', 'change', 'advertisement', 'teaparty'}
# ---
#
# {'global', 'scam', 'arctic', 'rescue', 'cold', 'warmist', 'transport', 'warming', 'activist'}
# ---
#
# {'global', 'volcano', 'cause', 'climategate', 'upset', 'warming'}
# ---
#
# {'climate', 'killer', 'tsunami', 'peruvian', 'change', 'lake', 'proof', 'glaci', 'fall', 'fracture', 'create'}
# ---
#
# {'climate', 'global', 'hack', 'hoax', 'warming', 'change', 'palin', 'real', 'algore', 'science', 'gore'}
# ---
#
# {'journal', 'global', 'scientist', 'stranger', 'nature', 'anti', 'wrong', 'magazine', 'warming', 'academic'}
# ---
#
# {'global', 'like', 'goldman', 'warming', 'exec'}
# ---
#
# {'climate', 'global', 'difference', 'nasa', 'accord', 'weather', 'baloney', 'measure', 'expert', 'warming'}
# ---
#
# {'voice', 'global', 'case', 'michael', 'syste', 'fraud', 'tracy', 'public', 'warming', 'early', 'school'}
# ---
#
# {'true', 'computer', 'global', 'belive', 'idiot', 'forensic', 'expert', 'warming'}
# ---
#
# {'artic', 'global', 'looney', 'liberal', 'home', 'bite', 'learn', 'come', 'frost', 'toon', 'warming', 'alarmist'}
# ---
#
# {'global', 'content', 'copyright', 'heat', 'property', 'warming', 'people', 'author', 'degree', 'dear', 'message'}
# ---
#
# {'global', 'southern', 'wear', 'visit', 'fanatic', 'come', 'jacket', 'glove', 'warming', 'freeze', 'california'}
# ---
#
# {'climate', 'leadersdebate', 'fact', 'hoax', 'change', 'well', 'target', 'bullshit', 'gore'}
# ---
#
# {'climate', 'scandal', 'fraud', 'solar', 'change', 'power', 'spain'}
# ---
#
# {'climate', 'global', 'fraud', 'change', 'ethanol', 'warming'}
# ---
#
# {'heavily', 'global', 'climategate', 'invest', 'international', 'freedom', 'despite', 'control', 'leave', 'warming', 'hysteria', 'impose', 'human'}
# ---
#
# {'obama', 'global', 'mention', 'minute', 'fail', 'hoax', 'earth', 'warming', 'video'}
# ---
#
# {'global', 'suggest', 'lecture', 'alm', 'imaginary', 'politely', 'watch', 'warming', 'motorsport', 'nascar'}
# ---
#
# {'climate', 'read', 'tell', 'change', 'crowd', 'hang'}
# ---
#
# {'global', 'liberal', 'socialist', 'gagnon', 'dupe', 'like', 'warming', 'propaganda'}
# ---
#
# {'global', 'believe', 'international', 'perpetrate', 'order', 'sell', 'conditioner', 'conspiracy', 'warming'}
# ---
#
# {'global', 'reduce', 'peril', 'warm', 'carbon', 'wrong', 'model', 'greenhouse', 'experiment', 'dirt'}
# ---
#
# {'global', 'safety', 'blankenship', 'warming', 'call', 'regulation', 'effort', 'silly'}
# ---
#
# {'global', 'safety', 'labor', 'blankenship', 'warming', 'union', 'anti', 'call', 'regulation', 'effort', 'silly'}
# ---
#
# {'climate', 'distraction', 'change', 'responsibly', 'earthday', 'earth', 'sway', 'treat'}
# ---
#
# {'global', 'cushman', 'parent', 'care', 'gingrich', 'jackie', 'sister', 'old', 'warming', 'join'}
# ---
#
# {'regulator', 'global', 'safety', 'blankenship', 'warming', 'call', 'silly'}
# ---
#
# {'global', 'safety', 'warming', 'rule', 'call', 'coal', 'silly'}
# ---
#
# {'climate', 'obama', 'backass', 'sure', 'go', 'good', 'change', 'world', 'imperil', 'graham', 'douche', 'agenda'}
# ---
#
# {'global', 'safety', 'warming', 'crazy', 'rule', 'call', 'coal', 'silly'}
# ---
#
# {'climate', 'fight', 'change', 'lead', 'military'}
# ---
#
# {'climate', 'global', 'stay', 'home', 'change', 'migratory', 'bird', 'strategy', 'proof', 'warming', 'green'}
# ---
#
# {'climate', 'offer', 'combat', 'change', 'approach', 'summit', 'cochabamba'}
# ---
#
# {'global', 'start', 'spring', 'little', 'storm', 'season', 'late', 'warming', 'year'}
# ---
#
# {'wait', 'climate', 'global', 'idea', 'natural', 'change', 'induce', 'warming', 'human'}
# ---
#
# {'climate', 'report', 'global', 'release', 'treehugger', 'brooklyn', 'brian', 'action', 'unequivocal', 'warming', 'merchant'}
# ---
#
# {'global', 'hekla', 'volcano', 'mother', 'earth', 'warming', 'ashtag', 'icelandic', 'earthquake'}
# ---
#
# {'climate', 'global', 'read', 'change', 'warm'}
# ---
#
# {'global', 'tcot', 'cause', 'good', 'fungus', 'fortunate', 'warming', 'auth'}
# ---
#
# {'illegal', 'global', 'main', 'platform', 'campaign', 'election', 'myth'}
# ---
#
# {'happen', 'global', 'read', 'spring', 'winter', 'care', 'cold', 'live', 'warming'}
# ---
#
# {'global', 'scam', 'community', 'scientific', 'warming', 'green'}
# ---
#
# {'global', 'artist', 'scam', 'truly', 'billion', 'worth', 'award', 'decade', 'credit', 'close', 'gore', 'warming', 'energy'}
# ---
#
# {'global', 'climategate', 'tcot', 'scam', 'warming', 'policy', 'world', 'current', 'decline', 'lie', 'hide', 'epic', 'job'}
# ---
#
# {'global', 'scum', 'liberal', 'change', 'degree', 'urinate', 'warming'}
# ---
#
# {'global', 'ocra', 'ucot', 'mississippi', 'tornado', 'tornadocot', 'tlot', 'warm', 'tycot', 'gore', 'race'}
# ---
#
# {'global', 'scam', 'settle', 'confirm', 'stop', 'book', 'warming', 'sussman'}
# ---
#
# {'boycott', 'global', 'buy', 'tcot', 'siemen', 'change', 'advertisement', 'teaparty'}
# ---
#
# {'global', 'sit', 'low', 'break', 'antarctica', 'vostok', 'forecast', 'warming'}
# ---
#
# {'global', 'tcot', 'scam', 'arctic', 'rescue', 'cold', 'warmist', 'transport', 'warming', 'activist'}
# ---
#
# {'global', 'volcano', 'cause', 'climategate', 'upset', 'warming'}
# ---
#
# {'global', 'believe', 'angel', 'exist', 'cause', 'jesus', 'tcot', 'miracle', 'rationalist', 'alien', 'fairy', 'warming', 'human'}
# ---
#
# {'climate', 'global', 'tcot', 'chiller', 'possibility', 'horror', 'consider', 'wrong', 'warming', 'monster', 'model'}
# ---
#
# {'climate', 'killer', 'tsunami', 'peruvian', 'change', 'lake', 'proof', 'glaci', 'fall', 'fracture', 'create'}
# ---
#
# {'global', 'sigh', 'tcot', 'ucot', 'cbiz', 'exonerate', 'huge', 'relief', 'fart', 'rectum', 'gore', 'warming', 'teaparty'}
# ---
#
# {'global', 'sigh', 'tcot', 'ucot', 'cbiz', 'exonerate', 'huge', 'relief', 'fart', 'rectum', 'gore', 'warming', 'teaparty'}
# ---
#
# {'climate', 'global', 'hack', 'hoax', 'warming', 'change', 'palin', 'real', 'algore', 'science', 'gore'}
# ---
#
# {'headache', 'global', 'threaten', 'argue', 'flunk', 'teacher', 'hoax', 'tell', 'grandson', 'warming'}
# ---
#
# {'global', 'like', 'goldman', 'warming', 'exec'}
# ---
#
# {'voice', 'global', 'case', 'michael', 'syste', 'fraud', 'tracy', 'public', 'warming', 'early', 'school'}
# ---
#
# {'true', 'computer', 'global', 'belive', 'idiot', 'forensic', 'expert', 'warming'}
# ---
#
# {'artic', 'global', 'looney', 'liberal', 'home', 'bite', 'learn', 'come', 'frost', 'toon', 'warming', 'alarmist'}
# ---
#
# {'global', 'content', 'copyright', 'heat', 'property', 'warming', 'people', 'author', 'degree', 'dear', 'message'}
# ---
#
# {'global', 'southern', 'wear', 'visit', 'fanatic', 'come', 'jacket', 'glove', 'warming', 'freeze', 'california'}
# ---
#
# {'climate', 'leadersdebate', 'fact', 'hoax', 'change', 'well', 'target', 'bullshit', 'gore'}
# ---
#
# {'climate', 'scandal', 'fraud', 'solar', 'change', 'power', 'spain'}
# ---
#
# {'climate', 'global', 'fraud', 'change', 'ethanol', 'warming'}
# ---
#
# {'obama', 'global', 'mention', 'minute', 'fail', 'hoax', 'earth', 'warming', 'video'}
# ---
#
# {'global', 'suggest', 'lecture', 'alm', 'imaginary', 'politely', 'watch', 'warming', 'motorsport', 'nascar'}
# ---
#
# {'climate', 'tcot', 'read', 'tell', 'change', 'crowd', 'hang'}
# ---
#
# {'global', 'liberal', 'socialist', 'gagnon', 'dupe', 'like', 'warming', 'propaganda'}
# ---
#
# {'global', 'believe', 'international', 'perpetrate', 'order', 'sell', 'conditioner', 'conspiracy', 'warming'}
# ---
#
# {'climate', 'global', 'government', 'fraud', 'agree', 'danger', 'change', 'telegraph', 'world', 'warming', 'process'}
# ---
#
# {'global', 'reduce', 'peril', 'warm', 'carbon', 'wrong', 'model', 'greenhouse', 'experiment', 'dirt'}
# ---
#
# {'connecticut', 'global', 'buy', 'candidate', 'assume', 'regardless', 'senate', 'warming'}
# ---
#
# {'climate', 'difference', 'hit', 'green', 'change', 'come', 'chinese', 'party', 'instruction'}
# ---
#
# {'consc', 'global', 'heart', 'thousand', 'alexia', 'earth', 'million', 'warming', 'park'}
# ---
#
# {'climate', 'global', 'fact', 'whisper', 'separate', 'book', 'chinese', 'shock', 'warming', 'science', 'culture'}
# ---
#
# {'global', 'safety', 'blankenship', 'warming', 'call', 'regulation', 'effort', 'silly'}
# ---
#
# {'global', 'safety', 'labor', 'blankenship', 'warming', 'union', 'anti', 'call', 'regulation', 'effort', 'silly'}
# ---
#
# {'sceptic', 'climate', 'politician', 'steal', 'business', 'run', 'year'}
# ---
#
# {'climate', 'believe', 'reveal', 'plan', 'copy', 'change', 'negotiate', 'machine', 'leave'}
# ---
#
# {'climate', 'grit', 'change', 'american', 'put', 'watch', 'medium'}
# ---
#
# {'day', 'temper', 'global', 'say', 'start', 'warming', 'reporting', 'see'}
# ---
#
# {'climate', 'modern', 'version', 'change', 'good', 'substitute', 'denier', 'propaganda', 'poster'}
# ---
#
# {'climate', 'global', 'tcot', 'tlot', 'address', 'iccc', 'skeptic', 'warming'}
# ---
#
# {'global', 'control', 'warming', 'racist', 'think'}
# ---
#
# {'global', 'humanity', 'threat', 'lean', 'nuclear', 'warming', 'dangerous', 'double', 'famine', 'week', 'annihilation'}
# ---
#
# {'climate', 'case', 'global', 'change', 'make', 'worried', 'warming', 'americans'}
# ---
#
# {'climate', 'global', 'social', 'justice', 'change', 'dark', 'fingernail', 'hang', 'warming', 'climb', 'replace'}
# ---
#
# {'global', 'believe', 'cause', 'april', 'ellis', 'good', 'warming', 'americans', 'news', 'human'}
# ---
#
# {'global', 'say', 'survey', 'city', 'retail', 'warming', 'americans', 'investor'}
# ---
#
# {'climate', 'global', 'assumption', 'suggest', 'warming', 'datum'}
# ---
#
# {'panic', 'global', 'senate', 'debate', 'await', 'begin', 'attack', 'warming', 'long', 'energy', 'realclearpolitic'}
# ---
#
# {'global', 'contribute', 'fart', 'depletion', 'ozone', 'layer', 'warming'}
# ---
#
# {'global', 'delay', 'money', 'pour', 'foe', 'campaign', 'warming', 'california'}
# ---
#
# {'global', 'county', 'discussi', 'commission', 'staff', 'laura', 'writer', 'warming', 'involved', 'dispute', 'otero', 'london'}
# ---
#
# {'global', 'push', 'mexico', 'liberal', 'read', 'government', 'temperature', 'democrats', 'despite', 'warming', 'datum'}
# ---
#
# {'global', 'miss', 'heat', 'warming', 'account', 'measurement'}
# ---
#
# {'global', 'cushman', 'parent', 'care', 'gingrich', 'jackie', 'sister', 'old', 'warming', 'join'}
# ---
#
# {'regulator', 'global', 'safety', 'blankenship', 'warming', 'silly'}
# ---
#
# {'regulator', 'global', 'safety', 'blankenship', 'warming', 'call', 'silly'}
# ---
#
# {'global', 'safety', 'warming', 'rule', 'call', 'coal', 'silly'}
# ---
#
# {'global', 'feel', 'right', 'april', 'winter', 'like', 'shower', 'warming'}
# ---
#
# {'climate', 'position', 'atmosphere', 'cause', 'today', 'assume', 'change', 'untenable', 'hypothesis'}
# ---
#
# {'global', 'believe', 'cause', 'expose', 'hoboken', 'warm', 'truth', 'information', 'human'}
# ---
#
# {'global', 'merit', 'debate', 'libertarian', 'market', 'warming', 'proposal'}
# ---
#
# {'climate', 'deny', 'peace', 'crime', 'change', 'tolerant', 'leave', 'guilty'}
# ---
#
# {'climate', 'useful', 'offer', 'note', 'talk', 'change', 'head', 'need', 'realism'}
# ---
#
# {'character', 'global', 'limit', 'powerful', 'list', 'forget', 'world', 'keep', 'maybe', 'deni', 'warming'}
# ---
#
# {'climate', 'global', 'cause', 'claim', 'change', 'joke', 'govt', 'warming'}
# ---
#
# {'global', 'buy', 'rise', 'warm', 'ocean', 'carbon', 'estate', 'million', 'gore', 'level', 'footprint'}
# ---
#
# {'global', 'buy', 'rise', 'warm', 'ocean', 'carbon', 'estate', 'million', 'gore', 'level', 'footprint'}
# ---
#
# {'global', 'yeah', 'jackass', 'warming', 'hypocritical', 'footprint'}
# ---
#
# {'global', 'parody', 'like', 'tube', 'ipcc', 'warming'}
# ---
#
# {'global', 'report', 'say', 'cause', 'mental', 'illness', 'cont', 'warming'}
# ---
#
# {'profiteering', 'obama', 'global', 'official', 'warming', 'energy'}
# ---
#
# {'climate', 'train', 'fire', 'sheep', 'change', 'people', 'like', 'freight', 'bill', 'nation', 'slaughter', 'load'}
# ---
#
# {'climate', 'tcot', 'reid', 'change', 'like', 'stop', 'world', 'save', 'teaparty'}
# ---
#
# {'climate', 'email', 'right', 'rage', 'leak', 'change', 'sachs', 'goldman', 'remember', 'furor', 'wing'}
# ---
#
# {'global', 'town', 'sudden', 'heck', 'cold', 'speech', 'gore', 'warming'}
# ---
#
# {'global', 'iguana', 'talk', 'tree', 'love', 'frozen', 'fall', 'warming'}
# ---
#
# {'global', 'prediction', 'concentration', 'false', 'warming', 'projection'}
# ---
#
# {'obama', 'global', 'administration', 'profiteer', 'warming'}
# ---
#
# {'catch', 'global', 'factor', 'talk', 'jesse', 'gore', 'warming', 'producer', 'watter'}
# ---
#
# {'global', 'article', 'good', 'actually', 'weak', 'warming', 'statistic', 'think'}
# ---
#
# {'climate', 'miss', 'argument', 'tornado', 'snowpocalypse', 'change', 'link', 'forget', 'win'}
# ---
#
# {'climate', 'chance', 'cloudy', 'change', 'post'}
# ---
#
# {'walter', 'global', 'cover', 'social', 'ftsn', 'warming', 'williams'}
# ---
#
# {'climate', 'bill', 'professor', 'tell', 'lindseygrahamisatool', 'final', 'poison', 'change', 'consider', 'finish', 'paper'}
# ---
#
# {'global', 'tcot', 'find', 'million', 'gore', 'warming', 'protest'}
# ---
#
# {'ahead', 'global', 'blooming', 'gardens', 'verdant', 'need', 'rain', 'fall', 'warming', 'schedule', 'field'}
# ---
#
# {'climate', 'sustainable', 'twerp', 'support', 'change', 'pull', 'graham', 'lindsey', 'legislation', 'think'}
# ---
#
# {'climate', 'think', 'liberal', 'whitehouse', 'want', 'change', 'advance', 'state', 'church', 'separation'}
# ---
#
# {'global', 'climategate', 'problem', 'victim', 'freakonomic', 'walk', 'state', 'angle', 'warming'}
# ---
#
# {'global', 'fact', 'tcot', 'regard', 'scientific', 'little', 'pursue', 'public', 'warm', 'policy', 'opinion', 'agenda'}
# ---
#
# {'whitney', 'climate', 'skeptic', 'victory', 'hoax', 'change', 'song', 'jake', 'singe'}
# ---
#
# {'whitney', 'climate', 'skeptic', 'victory', 'hoax', 'change', 'song', 'jake', 'singe'}
# ---
#
# {'global', 'fact', 'tcot', 'regard', 'scientific', 'little', 'pursue', 'public', 'warm', 'policy', 'opinion', 'agenda'}
# ---
#
# {'global', 'believe', 'host', 'money', 'radio', 'gore', 'warming', 'sussman', 'medium'}
# ---
#
# {'climate', 'great', 'director', 'tcot', 'threat', 'change', 'avatar', 'wwii', 'reality', 'leave', 'teaparty'}
# ---
#
# {'global', 'rhetoric', 'know', 'earth', 'discredit', 'warming', 'alarmist'}
# ---
#
# {'climate', 'tcot', 'suggest', 'forum', 'debate', 'change', 'moron', 'independent', 'woman', 'legitimacy', 'try'}
# ---
#
# {'global', 'safety', 'digg', 'warming', 'rule', 'call', 'coal', 'silly'}
# ---
#
# {'global', 'fact', 'tcot', 'regard', 'scientific', 'little', 'pursue', 'public', 'warm', 'policy', 'opinion', 'agenda'}
# ---
#
# {'indigenist', 'viola', 'mother', 'capitalism', 'global', 'bolivian', 'earth', 'blame', 'camp', 'edtrls', 'wilkin', 'warming', 'president'}
# ---
#
# {'global', 'rhetoric', 'know', 'earth', 'discredit', 'warming', 'alarmist'}
# ---
#
# {'global', 'rhetoric', 'know', 'earth', 'discredit', 'warming', 'alarmist'}
# ---
#
# {'global', 'say', 'probably', 'eyeball', 'head', 'burn', 'earth', 'maybe', 'warming'}
# ---
#
# {'climate', 'global', 'denial', 'wouldn', 'lindzen', 'discredit', 'warming', 'science', 'richard', 'alarmist'}
# ---
#
# {'mean', 'global', 'scientist', 'thing', 'cause', 'rise', 'justin', 'foot', 'world', 'ocean', 'biebe', 'warming'}
# ---
#
# {'climate', 'global', 'fraud', 'change', 'acid', 'ocean', 'warming'}
# ---
#
# {'climate', 'conservative', 'history', 'change', 'pass', 'vote', 'wrong', 'accountability', 'tonight'}
# ---
#
# {'climate', 'global', 'anthropogenic', 'change', 'warming', 'climatism', 'religion'}
# ---
#
# {'global', 'tcot', 'bolivia', 'graph', 'tlot', 'major', 'study', 'junk', 'warming', 'science', 'teaparty'}
# ---
#
# {'global', 'exaggerated', 'hockey', 'stick', 'temperature', 'rise', 'graph', 'slam', 'study', 'attack', 'warming'}
# ---
#
# {'global', 'safety', 'inslee', 'warming', 'silly'}
# ---
#
# {'global', 'huckabe', 'hoax', 'dump', 'warming', 'daily'}
# ---
#
# {'climate', 'global', 'fact', 'advocate', 'agree', 'change', 'know', 'skeptic', 'warming', 'green'}
# ---
#
# {'global', 'idea', 'hate', 'truly', 'people', 'warm', 'warming', 'year', 'myth', 'think'}
# ---
#
# {'thanx', 'global', 'enjoy', 'break', 'cold', 'weather', 'hope', 'warming', 'get'}
# ---
#
# {'climate', 'true', 'global', 'scam', 'solar', 'power', 'change', 'major', 'warming'}
# ---
#
# {'great', 'bestseller', 'global', 'amazon', 'help', 'nonfiction', 'currently', 'blunder', 'warming', 'rank'}
# ---
#
# {'climate', 'help', 'senate', 'change', 'democrats', 'time', 'worried', 'graham', 'move', 'bill', 'quietly', 'lindsey'}
# ---
#
# {'global', 'endlessly', 'bleat', 'hoax', 'crony', 'gore', 'warming', 'medium'}
# ---
#
# {'true', 'global', 'healthcare', 'allergy', 'bad', 'cost', 'drive', 'warming'}
# ---
#
# {'true', 'global', 'kill', 'cheer', 'warming'}
# ---
#
# {'global', 'tcot', 'angry', 'foot', 'secular', 'fickle', 'cool', 'proselytize', 'world', 'seanhannity', 'worship', 'warming'}
# ---
#
# {'global', 'nearly', 'change', 'famous', 'temperamental', 'actually', 'mood', 'warming', 'london'}
# ---
#
# {'peru', 'climate', 'retreat', 'glacial', 'huge', 'change', 'break', 'hualcan', 'block', 'glacier', 'weekend'}
# ---
#
# {'global', 'lake', 'truth', 'know', 'hahaha', 'goat', 'warming', 'level'}
# ---
#
# {'weird', 'global', 'phenomenon', 'stay', 'answer', 'like', 'haha', 'blame', 'warming'}
# ---
#
# {'climate', 'mafia', 'global', 'style', 'change', 'put', 'sound', 'warming', 'science'}
# ---
#
# {'climate', 'say', 'ignore', 'history', 'change', 'growth', 'approach', 'economic', 'cut'}
# ---
#
# {'climate', 'global', 'domino', 'climategate', 'fast', 'change', 'fall', 'warming'}
# ---
#
# {'climate', 'say', 'ignore', 'history', 'fail', 'change', 'growth', 'approach', 'economic', 'cut'}
# ---
#
# {'climate', 'global', 'doomsday', 'change', 'call', 'warming'}
# ---
#
# {'climate', 'right', 'jolly', 'animal', 'industrial', 'farming', 'unsurprisingly', 'change', 'farmer', 'exaggrtd', 'discush', 'think'}
# ---
#
# {'climate', 'global', 'nasa', 'change', 'alter', 'warming', 'datum', 'create'}
# ---
#
# {'climate', 'global', 'fascia', 'climategate', 'evidence', 'change', 'mail', 'warming', 'prima'}
# ---
#
# {'climate', 'global', 'change', 'lyin', 'warming', 'indoctrination'}
# ---
#
# {'climate', 'global', 'fact', 'advocate', 'agree', 'change', 'know', 'skeptic', 'warming', 'green'}
# ---
#
# {'climate', 'global', 'fact', 'guess', 'nasa', 'change', 'warming', 'notice', 'think'}
# ---
#
# {'climate', 'global', 'logic', 'cafe', 'change', 'people', 'kill', 'death', 'warming', 'save', 'green', 'standard'}
# ---
#
# {'climate', 'mafia', 'global', 'style', 'change', 'put', 'sound', 'warming', 'science'}
# ---
#
# {'climate', 'sokol', 'change', 'buffets', 'american', 'fortunegreen', 'david', 'coal', 'embarassment', 'shame'}
# ---
#
# {'regulator', 'global', 'safety', 'wonk', 'room', 'blankenship', 'warming', 'call', 'silly'}
# ---
#
# {'global', 'pretty', 'pointer', 'weathercaster', 'meteorologist', 'warming', 'think'}
# ---
#
# {'climate', 'sort', 'hate', 'wish', 'change', 'talk', 'action', 'rubbish'}
# ---
#
# {'global', 'fraud', 'help', 'divide', 'weathercaster', 'gore', 'warming'}
# ---
#
# {'global', 'sigh', 'exonerate', 'huge', 'relief', 'fart', 'rectum', 'gore', 'warming'}
# ---
#
# {'virginia', 'global', 'west', 'safety', 'warming', 'rule', 'call', 'coal', 'silly'}
# ---
#
# {'global', 'xtra', 'amazing', 'consideration', 'want', 'take', 'let', 'negative', 'possibility', 'warming', 'green'}
# ---
#
# {'climate', 'meta', 'change', 'meteorologist', 'reporting'}
# ---
#
# {'climate', 'system', 'global', 'illusion', 'change', 'sensitive', 'drspencer', 'warming'}
# ---
#
# {'climate', 'tcot', 'hoax', 'nazism', 'globalwarme', 'change', 'comparable', 'teaparty', 'wing', 'think'}
# ---
#
# {'climate', 'global', 'climategate', 'change', 'investigation', 'warming'}
# ---
#
# {'climate', 'global', 'greed', 'nonsense', 'change', 'warming', 'science'}
# ---
#
# {'climate', 'global', 'anthropogenic', 'effect', 'change', 'earth', 'warming', 'barely', 'planet', 'notice'}
# ---
#
# {'climate', 'today', 'blizzard', 'change', 'uncle', 'yeah', 'year', 'bear'}
# ---
#
# {'climate', 'senator', 'bill', 'noooooo', 'change', 'stop', 'augh', 'prepare', 'compromise'}
# ---
#
# {'climate', 'system', 'global', 'illusion', 'change', 'sensitive', 'drspencer', 'warming'}
# ---
#
# {'global', 'cause', 'lemming', 'political', 'continue', 'warming', 'fantasy', 'gore', 'perpetuate'}
# ---
#
# {'global', 'property', 'coloradoan', 'oceanfront', 'move', 'warming', 'plot'}
# ---
#
# {'climate', 'folk', 'global', 'pollution', 'switch', 'fight', 'change', 'warming', 'message'}
# ---
#
# {'screw', 'global', 'weather', 'warming', 'fuck'}
# ---
#
# {'global', 'scientist', 'anti', 'wrong', 'warming'}
# ---
#
# {'sweat', 'global', 'bath', 'nearly', 'ewww', 'degree', 'warming'}
# ---
#
# {'tcot', 'ocra', 'scam', 'agree', 'warming', 'teaparty', 'think'}
# ---
#
# {'climate', 'scheme', 'turnbull', 'coalition', 'stupid', 'change', 'policy', 'carbon', 'abatement'}
# ---
#
# {'climate', 'change', 'pass', 'resolution', 'imply', 'conspiracy', 'utah', 'house'}
# ---
#
# {'tribble', 'global', 'glory', 'liberal', 'morning', 'blizzard', 'tami', 'unbelievable', 'idiot', 'blame', 'warming', 'hhrs'}
# ---
#
# {'global', 'loon', 'ignorant', 'tell', 'warming', 'scream'}
# ---
#
# {'sleet', 'global', 'today', 'houston', 'love', 'warming'}
# ---
#
# {'global', 'asap', 'need', 'call', 'gore', 'warming', 'respond'}
# ---
#
# {'global', 'democrat', 'blizzard', 'make', 'tlot', 'sell', 'hard', 'warming', 'think'}
# ---
#
# {'global', 'tcot', 'unreal', 'analysis', 'yahoo', 'blizzard', 'bad', 'make', 'idiot', 'warming'}
# ---
#
# {'climate', 'winger', 'americablog', 'right', 'blizzard', 'claim', 'prove', 'change', 'news'}
# ---
#
# {'climate', 'scientist', 'pembina', 'change', 'error', 'significance', 'exaggerate', 'globe', 'columnist'}
# ---
#
# {'happen', 'climate', 'global', 'warming', 'snowstorm'}
# ---
#
# {'global', 'result', 'blizzard', 'warm', 'accord', 'love', 'time'}
# ---
#
# {'climate', 'miss', 'sustainability', 'series', 'change', 'check', 'video', 'ric'}
# ---
#
# {'global', 'thing', 'cause', 'list', 'blog', 'sppi', 'complete', 'warming'}
# ---
#
# {'finally', 'global', 'hoax', 'emission', 'proof', 'familysecuritymatter', 'warming'}
# ---
#
# {'climate', 'scientist', 'quote', 'change', 'environment', 'independent', 'discredit', 'fabricate'}
# ---
#
# {'climate', 'health', 'artist', 'rush', 'steal', 'money', 'care', 'change', 'die', 'gore'}
# ---
#
# {'statement', 'global', 'winter', 'public', 'make', 'week', 'gore', 'warming', 'ground', 'human'}
# ---
#
# {'climate', 'freak', 'mvmt', 'change', 'youth'}
# ---
#
# {'climate', 'snake', 'disagree', 'agree', 'dismiss', 'change', 'palin', 'science'}
# ---
#
# {'global', 'cancel', 'irony', 'senate', 'hearing', 'warming'}
# ---
#
# {'global', 'right', 'guess', 'vacation', 'cold', 'weather', 'warming'}
# ---
#
# {'global', 'say', 'support', 'stupid', 'nerd', 'know', 'progressive', 'mccain', 'warming', 'supporter', 'legislation'}
# ---
#
# {'climate', 'government', 'regulate', 'want', 'change', 'party', 'vague'}
# ---
#
# {'global', 'believe', 'peace', 'anthropagenic', 'islam', 'demand', 'warming', 'religion'}
# ---
#
# {'climate', 'government', 'regulate', 'want', 'change', 'party', 'vague'}
# ---
#
# {'global', 'fund', 'polar', 'east', 'heated', 'money', 'cheap', 'spend', 'coast', 'move', 'warming', 'bear'}
# ---
#
# {'global', 'social', 'knee', 'ftsn', 'discredit', 'jerk', 'warming', 'alarmist'}
# ---
#
# {'liken', 'snake', 'global', 'climate', 'warm', 'palin', 'study'}
# ---
#
# {'climate', 'global', 'government', 'wackos', 'change', 'tree', 'hug', 'fall', 'warming', 'grip'}
# ---
#
# {'climate', 'global', 'crisis', 'hoax', 'warming'}
# ---
#
# {'great', 'global', 'channel', 'aire', 'swindle', 'warming', 'think'}
# ---
#
# {'humanity', 'global', 'purpose', 'fraud', 'prosecute', 'crime', 'warming', 'court', 'belong'}
# ---
#
# {'global', 'intellectual', 'manufacture', 'sowell', 'commentator', 'warming', 'youtube', 'thomas'}
# ---
#
# {'climate', 'sceptic', 'push', 'scientist', 'authority', 'change', 'call', 'prominent', 'embattle', 'panel', 'join'}
# ---
#
# {'climate', 'gain', 'uaid', 'change', 'denier', 'momentum'}
# ---
#
# {'underway', 'suspend', 'global', 'warm', 'emission', 'effort', 'greenhouse', 'california'}
# ---
#
# {'climate', 'boldly', 'stupidity', 'change', 'go', 'blunder', 'ipcc', 'late'}
# ---
#
# {'global', 'tcot', 'hhrs', 'scam', 'parliament', 'warming', 'member', 'rip', 'hysteria'}
# ---
#
# {'global', 'nature', 'tcot', 'invention', 'disgrace', 'internet', 'leave', 'gore', 'warming'}
# ---
#
# {'climate', 'email', 'scandal', 'lose', 'faith', 'change', 'public', 'leak', 'environment', 'guardian', 'science'}
# ---
#
# {'finally', 'global', 'philly', 'tcot', 'naaahhhaaaa', 'sheeple', 'understand', 'brainwash', 'warming'}
# ---
#
# {'mean', 'global', 'tcot', 'snow', 'cold', 'month', 'warming'}
# ---
#
# {'great', 'global', 'tcot', 'climatechange', 'warming', 'collapse'}
# ---
#
# {'climate', 'scientist', 'online', 'change', 'mail', 'consider', 'suicide'}
# ---
#
# {'climate', 'report', 'telegraph', 'change', 'error', 'ipcc'}
# ---
#
# {'global', 'work', 'snow', 'washington', 'area', 'warming', 'gore'}
# ---
#
# {'climate', 'home', 'australia', 'change', 'inspection', 'force', 'phony', 'expensive', 'agenda'}
# ---
#
# {'climate', 'change', 'lawmaker', 'population', 'control', 'ruse'}
# ---
#
# {'progress', 'representative', 'climate', 'popula', 'claim', 'aim', 'change', 'state', 'conspiracy', 'utah', 'think'}
# ---
#
# {'climate', 'follower', 'lose', 'debate', 'change', 'centreright', 'gore'}
# ---
#
# {'climate', 'denialist', 'division', 'change', 'need', 'richardson'}
# ---
#
# {'global', 'cite', 'tcot', 'threat', 'undie', 'security', 'terrorist', 'worry', 'warming', 'temp', 'planet'}
# ---
#
# {'great', 'global', 'settle', 'good', 'warm', 'reality', 'science', 'collapse'}
# ---
#
# {'global', 'cite', 'threat', 'undie', 'security', 'terrorist', 'worry', 'warming', 'temp', 'planet'}
# ---
#
# {'climate', 'sceptic', 'australia', 'change', 'christopher', 'monckton', 'youtube', 'lord'}
# ---
#
# {'british', 'global', 'skeptical', 'tcot', 'suddenly', 'warming'}
# ---
#
# {'menace', 'climate', 'heliogenic', 'phantom', 'billion', 'change', 'waste', 'chase'}
# ---
#
# {'global', 'predict', 'unemployment', 'people', 'democrats', 'warming', 'year', 'teaparty', 'jail'}
# ---
#
# {'virginia', 'global', 'toyota', 'snow', 'tree', 'prius', 'area', 'warming', 'look'}
# ---
#
# {'global', 'tcot', 'propaganda', 'majority', 'warming', 'news', 'disbelieve'}
# ---
#
# {'global', 'nature', 'mother', 'occur', 'tell', 'blizzard', 'forget', 'gore', 'warming'}
# ---
#
# {'global', 'thing', 'today', 'tcot', 'wonderful', 'snow', 'storm', 'warming', 'save'}
# ---
#
# {'resource', 'global', 'believe', 'money', 'warming', 'well', 'live', 'matter', 'save'}
# ---
#
# {'global', 'analysis', 'logical', 'disprove', 'model', 'warming', 'niche'}
# ---
#
# {'rightblog', 'global', 'tcot', 'right', 'remain', 'houston', 'want', 'teaparty', 'play', 'tomorrow', 'cold', 'warming', 'golf', 'think'}
# ---
#
# {'climate', 'conservative', 'foundry', 'consensus', 'cloudy', 'scientific', 'change', 'policy', 'news'}
# ---
#
# {'climate', 'british', 'council', 'change', 'spend', 'referendum', 'million', 'propaganda'}
# ---
#
# {'climate', 'michael', 'diigo', 'corrupt', 'change', 'fanatic', 'barone', 'science'}
# ---
#
# {'climate', 'diigo', 'tag', 'corrupt', 'post', 'change', 'fanatic', 'loseaneye', 'ecomental', 'science', 'realclearpolitic'}
# ---
#
# {'climate', 'tcot', 'snomg', 'story', 'whiner', 'change', 'tlot', 'warm', 'weather'}
# ---
#
# {'hill', 'devote', 'article', 'global', 'bash', 'climate', 'noisemachine', 'baseless', 'attack', 'gore', 'warming'}
# ---
#
# {'snake', 'global', 'warm', 'sarah', 'call', 'palin', 'study', 'science'}
# ---
#
# {'global', 'miss', 'warm', 'cold', 'warming', 'get'}
# ---
#
# {'global', 'foundry', 'blizzard', 'proof', 'warming', 'post'}
# ---
#
# {'great', 'global', 'rise', 'blue', 'east', 'sacrifice', 'warming'}
# ---
#
# {'global', 'sure', 'snow', 'involve', 'know', 'warming', 'year'}
# ---
#
# {'global', 'catch', 'tcot', 'cause', 'story', 'time', 'mag', 'physicist', 'destroy', 'warming', 'brrr', 'snowstorm'}
# ---
#
# {'global', 'little', 'chicken', 'fall', 'redeye', 'warming', 'brrr'}
# ---
#
# {'global', 'thing', 'snowpocalypse', 'wish', 'warming', 'snowmaggedon'}
# ---
#
# {'mean', 'global', 'help', 'gore', 'warming', 'see'}
# ---
#
# {'wait', 'obama', 'global', 'snow', 'stan', 'activist', 'warming', 'keye'}
# ---
#
# {'obama', 'global', 'tcot', 'snow', 'teaparty', 'warming', 'activist'}
# ---
#
# {'global', 'cancel', 'lemme', 'tell', 'senate', 'hearing', 'warm', 'weather', 'stuff', 'warming'}
# ---
#
# {'climate', 'threat', 'grave', 'harp', 'change', 'accuse', 'page', 'fearmongere', 'editorial'}
# ---
#
# {'global', 'snowy', 'record', 'winter', 'break', 'warming', 'year'}
# ---
#
# {'climate', 'global', 'thank', 'blizzard', 'change', 'coast', 'tie', 'warming', 'snowstorm'}
# ---
#
# {'global', 'cancel', 'tcot', 'laugh', 'senate', 'hearing', 'weather', 'warming', 'loud'}
# ---
#
# {'global', 'tcot', 'snowmageddon', 'result', 'snow', 'reply', 'syracuse', 'king', 'warming', 'ask', 'activist'}
# ---
#
# {'global', 'cancel', 'tcot', 'laugh', 'senate', 'hearing', 'weather', 'warming', 'loud'}
# ---
#
# {'obama', 'global', 'tcot', 'snowmageddon', 'snow', 'teaparty', 'short', 'warming', 'activist'}
# ---
#
# {'global', 'unit', 'vent', 'refrigerant', 'gas', 'increase', 'warming', 'greenhouse'}
# ---
#
# {'climate', 'global', 'cause', 'luck', 'snow', 'change', 'people', 'warm', 'sell', 'good', 'call', 'understand', 'think'}
# ---
#
# {'global', 'snow', 'claim', 'message', 'lack', 'forget', 'people', 'warming', 'year'}
# ---
#
# {'obama', 'global', 'tcot', 'snowmageddon', 'snow', 'teaparty', 'short', 'warming', 'activist'}
# ---
#
# {'global', 'knock', 'msnbc', 'capandtrade', 'tree', 'redeye', 'warming', 'year'}
# ---
#
# {'climate', 'global', 'today', 'money', 'story', 'wish', 'have', 'cold', 'page', 'warming'}
# ---
#
# {'global', 'event', 'idea', 'tomorrow', 'book', 'gore', 'warming'}
# ---
#
# {'climate', 'nite', 'global', 'scientist', 'idea', 'supervise', 'toyoto', 'change', 'executive', 'late', 'engineer'}
# ---
#
# {'climate', 'difference', 'tcot', 'glennbeck', 'change', 'weather', 'teaparty'}
# ---
#
# {'climate', 'climategate', 'tcot', 'snow', 'combat', 'enact', 'change', 'program', 'govt', 'fall', 'federal'}
# ---
#
# {'global', 'government', 'tcot', 'hoax', 'snowpocalypse', 'reassess', 'shut', 'federal', 'warming', 'snowmaggedon'}
# ---
#
# {'global', 'tcot', 'climategate', 'snowpocalypse', 'effect', 'gore', 'warming'}
# ---
#
# {'wait', 'global', 'guy', 'sign', 'mind', 'warming', 'snowstorm', 'think'}
# ---
#
# {'mean', 'finally', 'global', 'snow', 'nonsense', 'rebuttal', 'warming'}
# ---
#
# {'happen', 'global', 'blizzard', 'gore', 'warming'}
# ---
#
# {'finally', 'mean', 'global', 'treehugger', 'mainstream', 'air', 'snow', 'nonsense', 'rebuttal', 'warming', 'medium'}
# ---
#
# {'global', 'tcot', 'cause', 'msnbc', 'host', 'ratigan', 'snowpocalypse', 'claim', 'dylab', 'warming', 'accuracy'}
# ---
#
# {'global', 'laugh', 'inhofe', 'ipcc', 'warming', 'get'}
# ---
#
# {'global', 'group', 'candidate', 'train', 'tory', 'mouth', 'dismiss', 'waterboarde', 'back', 'warming', 'rightwe'}
# ---
#
# {'global', 'laugh', 'inhofe', 'ipcc', 'warming', 'get'}
# ---
#
# {'global', 'snow', 'contradict', 'theory', 'hannity', 'storm', 'gore', 'warming'}
# ---
#
# {'climate', 'branding', 'global', 'mighta', 'point', 'instead', 'warming', 'change', 'well', 'call', 'snomas', 'chaos'}
# ---
#
# {'case', 'global', 'snow', 'bury', 'area', 'warming', 'appear'}
# ---
#
# {'great', 'global', 'adam', 'smith', 'state', 'boost', 'opponent', 'warming', 'williams'}
# ---
#
# {'report', 'global', 'warming', 'shocking', 'honest', 'ipcc', 'junk', 'matter', 'science', 'medium'}
# ---
#
# {'report', 'global', 'warming', 'ipcc', 'junk', 'matter', 'science', 'medium'}
# ---
#
# {'climate', 'event', 'problem', 'freak', 'cause', 'change', 'congress', 'convince', 'massive', 'weather', 'disruption'}
# ---
#
# {'obama', 'global', 'buy', 'shovel', 'morning', 'ready', 'snow', 'white', 'good', 'warming', 'house'}
# ---
#
# {'climate', 'event', 'problem', 'freak', 'cause', 'change', 'congress', 'convince', 'massive', 'weather', 'disruption'}
# ---
#
# {'obama', 'global', 'buy', 'shovel', 'morning', 'ready', 'snow', 'white', 'good', 'warming', 'house'}
# ---
#
# {'global', 'soon', 'start', 'talk', 'warm', 'patent', 'conspiracy', 'plus', 'haarp', 'navy', 'paper'}
# ---
#
# {'global', 'guy', 'hire', 'record', 'take', 'care', 'book', 'rewrite', 'warming', 'year', 'agenda'}
# ---
#
# {'climate', 'global', 'tcot', 'miss', 'climategate', 'heat', 'change', 'warming', 'green'}
# ---
#
# {'global', 'seriously', 'blizzard', 'reach', 'make', 'bad', 'libs', 'time', 'warming'}
# ---
#
# {'global', 'cahmaaahn', 'snow', 'blizzard', 'bad', 'make', 'warm', 'time', 'warming', 'snowstorm'}
# ---
#
# {'climate', 'conservative', 'snow', 'change', 'congress', 'admit', 'recess', 'conspiracy', 'fall', 'time'}
# ---
#
# {'climate', 'record', 'change', 'die', 'snowfall', 'legislation'}
# ---
#
# {'finally', 'global', 'climategate', 'hoax', 'emission', 'proof', 'warming'}
# ---
#
# {'climate', 'conservative', 'change', 'admit', 'conspiracy', 'time', 'eddriscoll'}
# ---
#
# {'global', 'say', 'channel', 'snow', 'go', 'uncle', 'weather', 'freaky', 'gore', 'warming', 'cry'}
# ---
#
# {'goessling', 'global', 'shannon', 'take', 'rule', 'warming', 'court'}
# ---
#
# {'global', 'snow', 'contradict', 'theory', 'hysterical', 'hannity', 'storm', 'gore', 'warming'}
# ---
#
# {'global', 'snow', 'contradict', 'theory', 'hysterical', 'hannity', 'storm', 'gore', 'warming'}
# ---
#
# {'global', 'cancel', 'tcot', 'irony', 'senate', 'hearing', 'drudge', 'headline', 'warming'}
# ---
#
# {'climate', 'global', 'problem', 'somebody', 'instead', 'change', 'course', 'call', 'cont', 'warming'}
# ---
#
# {'global', 'scientist', 'snow', 'telegraph', 'consistent', 'warming'}
# ---
#
# {'conservative', 'global', 'brain', 'winter', 'weather', 'attack', 'warming', 'freeze', 'medium'}
# ---
#
# {'global', 'cancel', 'snow', 'senate', 'hearing', 'lmao', 'course', 'warming', 'horrible'}
# ---
#
# {'global', 'cancel', 'snow', 'senate', 'hearing', 'course', 'warming'}
# ---
#
# {'global', 'cancel', 'snow', 'senate', 'hearing', 'course', 'warming'}
# ---
#
# {'day', 'obama', 'push', 'middle', 'agency', 'snowmageddon', 'global', 'seriously', 'administration', 'study', 'warming'}
# ---
#
# {'global', 'press', 'hoax', 'warming', 'enable', 'watchdog'}
# ---
#
# {'global', 'sunny', 'way', 'like', 'blame', 'warming'}
# ---
#
# {'global', 'igloo', 'laden', 'snow', 'warming', 'inhofe', 'build', 'gore', 'family', 'spokesman'}
# ---
#
# {'global', 'tcot', 'igloo', 'laden', 'snow', 'warming', 'inhofe', 'build', 'gore', 'family'}
# ---
#
# {'mock', 'senator', 'global', 'igloo', 'warming', 'build', 'family'}
# ---
#
# {'global', 'alarmism', 'unsubstantiated', 'soft', 'attack', 'time', 'warming', 'underbelly'}
# ---
#
# {'global', 'well', 'stuff', 'warming', 'snowstorm'}
# ---
#
# {'global', 'snow', 'nutjob', 'sign', 'go', 'uncle', 'gore', 'warming', 'cry'}
# ---
#
# {'global', 'snowmageddon', 'snow', 'go', 'disprove', 'uncle', 'clearly', 'gore', 'warming', 'cry'}
# ---
#
# {'politician', 'global', 'advisor', 'claim', 'clever', 'cold', 'weather', 'time', 'warming', 'science', 'prove'}
# ---
#
# {'global', 'comfort', 'wish', 'crazy', 'joke', 'people', 'possible', 'obvious', 'warming', 'give'}
# ---
#
# {'global', 'comfort', 'wish', 'crazy', 'joke', 'people', 'possible', 'obvious', 'warming', 'give'}
# ---
#
# {'global', 'comfort', 'wish', 'crazy', 'joke', 'people', 'possible', 'obvious', 'warming', 'give'}
# ---
#
# {'global', 'yesterday', 'amuse', 'blizzard', 'noaa', 'disrupt', 'warming', 'announcement', 'office', 'create'}
# ---
#
# {'obama', 'global', 'tcot', 'want', 'start', 'stop', 'pre', 'federal', 'warming', 'office', 'create'}
# ---
#
# {'mean', 'global', 'snow', 'real', 'warming', 'respond'}
# ---
#
# {'global', 'fact', 'nature', 'mother', 'snow', 'left', 'conspiracy', 'bring', 'reinforce', 'warming', 'wing'}
# ---
#
# {'global', 'support', 'relevant', 'weather', 'warming', 'apparently'}
# ---
#
# {'climate', 'global', 'grin', 'blizzrd', 'change', 'feds', 'rearrange', 'warming', 'announcement', 'office'}
# ---
#
# {'global', 'climategate', 'support', 'relevant', 'weather', 'warming', 'apparently'}
# ---
#
# {'global', 'delay', 'blizzard', 'funny', 'govt', 'warming', 'announce', 'office'}
# ---
#
# {'global', 'snow', 'can', 'wish', 'warning', 'aquanet', 'warming', 'speed', 'process', 'girl'}
# ---
#
# {'climate', 'half', 'pachauri', 'travel', 'head', 'change', 'clock', 'million', 'bust', 'rajendra', 'panel', 'mile'}
# ---
#
# {'global', 'tcot', 'snow', 'globalwarme', 'possible', 'warming'}
# ---
#
# {'climate', 'blizzard', 'laughable', 'noaa', 'change', 'rearrange', 'announcement'}
# ---
#
# {'global', 'bandwagon', 'ready', 'snowpocalypse', 'globalcoole', 'sign', 'know', 'cool', 'warming'}
# ---
#
# {'great', 'climate', 'global', 'tcot', 'continue', 'ipcc', 'meltdown', 'warming', 'alarmist'}
# ---
#
# {'obama', 'global', 'press', 'snow', 'administration', 'clueless', 'tracker', 'conference', 'warming', 'announce', 'ground'}
# ---
#
# {'global', 'thank', 'east', 'coast', 'forecast', 'warming', 'snowstorm'}
# ---
#
# {'fly', 'mean', 'global', 'kennedy', 'robert', 'snow', 'cold', 'month', 'warming'}
# ---
#
# {'global', 'debunk', 'basic', 'scientific', 'law', 'physics', 'physicist', 'warming', 'violate', 'paper'}
# ---
#
# {'climate', 'global', 'rise', 'warming', 'change', 'predictably', 'unpredictable', 'enviros', 'issue', 'temp', 'drop'}
# ---
#
# {'underway', 'global', 'suspend', 'capandtrade', 'climatechange', 'effort', 'warming', 'california'}
# ---
#
# {'global', 'room', 'inch', 'run', 'warming'}
# ---
#
# {'global', 'snow', 'damn', 'panda', 'warming'}
# ---
#
# {'mean', 'global', 'result', 'judge', 'snow', 'manbearpig', 'cold', 'month', 'warming', 'intention'}
# ---
#
# {'great', 'mean', 'global', 'tcot', 'snow', 'cold', 'piece', 'month', 'warming', 'teaparty'}
# ---
#
# {'finger', 'limit', 'global', 'tcot', 'shovel', 'hell', 'numb', 'tue', 'tweetability', 'inch', 'forecast', 'warming', 'freeze'}
# ---
#
# {'global', 'exist', 'team', 'go', 'htink', 'sorry', 'plain', 'warming'}
# ---
#
# {'global', 'exist', 'pale', 'team', 'warming'}
# ---
#
# {'global', 'say', 'july', 'like', 'love', 'warming', 'remind'}
# ---
#
# {'mean', 'global', 'say', 'bobby', 'suck', 'snow', 'cold', 'month', 'time', 'warming', 'warp'}
# ---
#
# {'climate', 'half', 'pachauri', 'travel', 'head', 'change', 'clock', 'million', 'bust', 'rajendra', 'panel', 'mile'}
# ---
#
# {'wait', 'global', 'climategate', 'thnx', 'scam', 'fail', 'go', 'hope', 'toasty', 'warming', 'office', 'nice'}
# ---
#
# {'global', 'justin', 'damn', 'inch', 'warming', 'get', 'tuesday', 'exactly'}
# ---
#
# {'okay', 'complain', 'global', 'lately', 'snow', 'talk', 'inch', 'come', 'warming', 'tuesday', 'notice'}
# ---
#
# {'heavily', 'global', 'snow', 'imminent', 'sign', 'washington', 'storm', 'historic', 'explain', 'gore', 'warming', 'year'}
# ---
#
# {'climate', 'journalistic', 'scandal', 'scientific', 'steyn', 'change', 'massive', 'failure', 'mark'}
# ---
#
# {'fly', 'mean', 'global', 'kennedy', 'robert', 'snow', 'cold', 'month', 'warming'}
# ---
#
# {'global', 'scam', 'prolly', 'real', 'warming', 'york'}
# ---
#
# {'global', 'fact', 'tcot', 'cause', 'tlot', 'aid', 'palin', 'pope', 'warming', 'reagan', 'teaparty'}
# ---
#
# {'mean', 'global', 'snomg', 'snow', 'cold', 'month', 'oop', 'warming'}
# ---
#
# {'global', 'arm', 'sore', 'shovel', 'south', 'hand', 'home', 'hurt', 'washington', 'tweet', 'fall', 'warming', 'mile'}
# ---
#
# {'mean', 'global', 'snow', 'washington', 'cold', 'month', 'warming', 'examiner'}
# ---
#
# {'global', 'sore', 'feel', 'shovel', 'snomg', 'algorelie', 'driveway', 'sidewalk', 'warming', 'amazing'}
# ---
#
# {'global', 'believe', 'seriouly', 'lie', 'warming'}
# ---
#
# {'obama', 'global', 'wealth', 'blast', 'snow', 'warming', 'snobama', 'ipcc', 'bwaahaa', 'presidentpalin'}
# ---
#
# {'obama', 'global', 'tcot', 'ocra', 'blast', 'snow', 'snobama', 'ipcc', 'warming', 'teaparty'}
# ---
#
# {'climate', 'exist', 'summer', 'winter', 'spring', 'change', 'fall', 'justsaye'}
# ---
#
# {'obama', 'global', 'blast', 'snow', 'warming', 'snobama', 'ipcc', 'rate', 'star', 'video', 'youtube'}
# ---
#
# {'global', 'tcot', 'blizzard', 'little', 'warming', 'inhofe', 'gore', 'family', 'expense'}
# ---
#
# {'great', 'global', 'tcot', 'warming', 'collapse'}
# ---
#
# {'global', 'want', 'yeah', 'carbon', 'increase', 'warming', 'footprint'}
# ---
#
# {'sore', 'global', 'feel', 'snow', 'foot', 'dig', 'warming'}
# ---
#
# {'climate', 'global', 'consensus', 'fast', 'change', 'bogus', 'warming', 'fade'}
# ---
#
# {'global', 'report', 'expose', 'claim', 'ipcc', 'false', 'warming', 'hysteria'}
# ---
#
# {'global', 'fail', 'warming', 'power', 'beer'}
# ---
#
# {'climate', 'help', 'mind', 'change', 'people', 'certaintly', 'storm', 'fleeting', 'type'}
# ---
#
# {'global', 'middle', 'snowy', 'thatn', 'nicer', 'winter', 'warming', 'sound', 'damn'}
# ---
#
# {'heavily', 'global', 'snow', 'imminent', 'sign', 'washington', 'storm', 'historic', 'explain', 'gore', 'warming', 'year'}
# ---
#
# {'heavily', 'global', 'snow', 'imminent', 'sign', 'washington', 'storm', 'historic', 'explain', 'gore', 'warming', 'year'}
# ---
#
# {'global', 'nearly', 'good', 'inch', 'shut', 'area', 'warming'}
# ---
#
# {'global', 'consensus', 'fast', 'bogus', 'warming', 'fade'}
# ---
#
# {'global', 'consensus', 'fast', 'bogus', 'warming', 'fade'}
# ---
#
# {'global', 'consensus', 'fast', 'wente', 'mail', 'toronto', 'margaret', 'explain', 'bogus', 'globe', 'warming', 'fade'}
# ---
#
# {'global', 'consensus', 'fast', 'bogus', 'warming', 'fade'}
# ---
#
# {'global', 'consensus', 'fast', 'bogus', 'warming', 'fade'}
# ---
#
# {'global', 'consensus', 'fast', 'wente', 'mail', 'toronto', 'margaret', 'explain', 'bogus', 'globe', 'warming', 'fade'}
# ---
#
# {'global', 'consensus', 'fast', 'bogus', 'warming', 'fade'}
# ---
#
# {'global', 'thing', 'morning', 'warming', 'think'}
# ---
#
# {'global', 'debunk', 'news', 'source', 'world', 'establish', 'reality', 'warming', 'credible'}
# ---
#
# {'climate', 'untrustworthy', 'change', 'india', 'ipcc', 'abandon', 'intergovernmental', 'panel'}
# ---
#
# {'case', 'global', 'believe', 'health', 'care', 'idont', 'national', 'warming', 'stimulus'}
# ---
#
# {'great', 'ipccs', 'article', 'global', 'claim', 'people', 'convince', 'explain', 'warming', 'reason'}
# ---
#
# {'global', 'hell', 'east', 'warming', 'wish', 'have', 'coast', 'love', 'frozen', 'time', 'dear'}
# ---
#
# {'great', 'global', 'paper', 'warming', 'collapse'}
# ---
#
# {'obama', 'cover', 'global', 'climategate', 'tcot', 'hand', 'snow', 'washington', 'promise', 'warming', 'year'}
# ---
#
# {'representative', 'climate', 'claim', 'aim', 'change', 'population', 'state', 'control', 'conspiracy', 'utah'}
# ---
#
# {'welcome', 'climate', 'follow', 'twitter', 'blogger', 'roommate', 'change', 'make', 'stop'}
# ---
#
# {'representative', 'climate', 'claim', 'aim', 'change', 'population', 'state', 'control', 'conspiracy', 'utah'}
# ---
#
# {'wash', 'global', 'believe', 'brain', 'snow', 'institution', 'check', 'warming', 'year'}
# ---
#
# {'heavily', 'global', 'snow', 'imminent', 'sign', 'washington', 'storm', 'historic', 'explain', 'gore', 'warming', 'year'}
# ---
#
# {'global', 'scientist', 'assertation', 'refute', 'warming', 'committee', 'utah'}
# ---
#
# {'increa', 'global', 'government', 'come', 'knee', 'ftsn', 'discredit', 'european', 'jerk', 'warming', 'news', 'alarmist'}
# ---
#
# {'heavily', 'global', 'snow', 'imminent', 'sign', 'washington', 'storm', 'historic', 'explain', 'gore', 'warming', 'year'}
# ---
#
# {'heavily', 'global', 'snow', 'imminent', 'sign', 'washington', 'storm', 'historic', 'explain', 'gore', 'warming', 'year'}
# ---
#
# {'heavily', 'global', 'snow', 'imminent', 'sign', 'washington', 'storm', 'historic', 'explain', 'gore', 'warming', 'year'}
# ---
#
# {'global', 'shovel', 'maddow', 'snow', 'warming', 'cold', 'accord', 'weather', 'proof', 'hour'}
# ---
#
# {'global', 'drift', 'snow', 'foot', 'fire', 'good', 'warming'}
# ---
#
# {'global', 'scoop', 'foot', 'driveway', 'motivated', 'loooooooooooooooooooooong', 'warming', 'try'}
# ---
#
# {'global', 'sunny', 'snow', 'adjust', 'washington', 'hahaha', 'heavy'}
# ---
#
# {'global', 'work', 'scientist', 'cause', 'snomg', 'ready', 'east', 'hard', 'number', 'anglia', 'assure', 'cook', 'warming'}
# ---
#
# {'global', 'work', 'scientist', 'cause', 'snomg', 'ready', 'east', 'hard', 'number', 'anglia', 'assure', 'cook', 'warming'}
# ---
#
# {'climate', 'strong', 'change', 'storm', 'wrong', 'model'}
# ---
#
# {'climate', 'sigh', 'solar', 'factor', 'change', 'mydadisascienceprofessor', 'earth', 'activity', 'model', 'magnetic', 'field'}
# ---
#
# {'climate', 'strong', 'change', 'consistent', 'storm', 'model'}
# ---
#
# {'climate', 'useful', 'bother', 'mind', 'change', 'funding', 'research', 'taxis', 'pay'}
# ---
#
# {'obama', 'global', 'tcot', 'evidence', 'beck', 'overwhelming', 'live', 'fall', 'warming', 'teaparty'}
# ---
#
# {'global', 'boot', 'tell', 'like', 'storm', 'monday', 'gore', 'warming'}
# ---
#
# {'virginia', 'global', 'release', 'single', 'contend', 'inane', 'farce', 'warming', 'video', 'snowstorm'}
# ---
#
# {'global', 'today', 'cause', 'snomg', 'hear', 'blizzard', 'claim', 'come', 'suspect', 'usual', 'warming'}
# ---
#
# {'global', 'exist', 'agree', 'course', 'prius', 'disaster', 'warming', 'prove', 'think'}
# ---
#
# {'student', 'global', 'fact', 'debate', 'grad', 'like', 'warm', 'earth', 'study', 'open', 'undergrad', 'science', 'prove'}
# ---
#
# {'climate', 'verizon', 'denialist', 'snowpocalypse', 'blizzard', 'tell', 'change', 'deep', 'inch', 'come', 'call', 'live', 'fodder'}
# ---
#
# {'global', 'settle', 'sloppy', 'warming', 'science'}
# ---
#
# {'global', 'settle', 'sloppy', 'warming', 'science'}
# ---
#
# {'global', 'report', 'settle', 'sloppy', 'accord', 'ipcc', 'publish', 'dutch', 'warming', 'science', 'news'}
# ---
#
# {'global', 'exist', 'agree', 'prius', 'disaster', 'warming', 'prove', 'think'}
# ---
#
# {'climate', 'resources', 'deny', 'change', 'pass', 'resolution', 'crazy', 'existence', 'committee', 'utah'}
# ---
#
# {'global', 'snow', 'blizzard', 'warming', 'rich', 'galen'}
# ---
#
# {'virginia', 'global', 'snow', 'short', 'bunk', 'warming'}
# ---
#
# {'virginia', 'mock', 'global', 'mcdonnell', 'like', 'trust', 'party', 'warming', 'republican', 'science'}
# ---
#
# {'write', 'global', 'rare', 'fail', 'snow', 'winter', 'column', 'funny', 'warming'}
# ---
#
# {'climate', 'extra', 'moisture', 'snowy', 'winter', 'change', 'warm', 'duncery', 'action', 'bring'}
# ---
#
# {'global', 'northern', 'record', 'winter', 'hemisphere', 'cold', 'snowfall', 'china', 'warming', 'europe'}
# ---
#
# ...
# ---
#
# {'global', 'exist', 'agree', 'prius', 'disaster', 'warming', 'prove', 'think'}
# ---
#
# {'panic', 'global', 'scientific', 'like', 'sound', 'drive', 'warming'}
# ---
#
# {'virginia', 'climate', 'mock', 'use', 'snow', 'change', 'attack', 'trade'}
# ---
#
# {'climate', 'laurence', 'political', 'question', 'dismiss', 'change', 'doctrine', 'adler', 'suit', 'tribe'}
# ---
#
# {'happen', 'global', 'hell', 'luck', 'snow', 'pass', 'yeah', 'storm', 'warming'}
# ---
#
# {'global', 'yost', 'thousand', 'release', 'staff', 'november', 'hacker', 'columnist', 'warming', 'keith'}
# ---
#
# {'global', 'yost', 'thousand', 'release', 'staff', 'november', 'hacker', 'columnist', 'warming', 'keith'}
# ---
#
# {'climate', 'global', 'fact', 'point', 'scam', 'propose', 'legislator', 'change', 'population', 'check', 'curb', 'utah'}
# ---
#
# {'abuser', 'global', 'swindle', 'bad', 'child', 'warming', 'greens'}
# ---
#
# {'ardent', 'critic', 'global', 'mike', 'legislator', 'lawmaker', 'target', 'noel', 'warming', 'utah'}
# ---
#
# {'climate', 'chief', 'scientist', 'mistake', 'fuel', 'change', 'admit', 'major', 'study', 'skeptic', 'video'}
# ---
#
# {'climate', 'fuel', 'change', 'skeptic', 'video'}
# ---
#
# {'global', 'metaphor', 'mixed', 'land', 'warming'}
# ---
#
# {'global', 'snow', 'foot', 'go', 'stuck', 'wonder', 'warming', 'expect'}
# ---
#
# {'global', 'strong', 'want', 'message', 'send', 'law', 'lawmaker', 'warming', 'committee', 'seek', 'house'}
# ---
#
# {'pound', 'global', 'east', 'snow', 'stupid', 'go', 'coast', 'warming'}
# ---
#
# {'pound', 'global', 'east', 'snow', 'stupid', 'go', 'coast', 'warming'}
# ---
#
# {'climate', 'michael', 'corrupt', 'change', 'fanatic', 'gopusa', 'barone', 'science'}
# ---
#
# {'climate', 'free', 'change', 'know', 'speech', 'complete', 'maybe'}
# ---
#
# {'global', 'outside', 'world', 'warming', 'freeze'}
# ---
#
# {'phil', 'balt', 'global', 'note', 'winter', 'major', 'impact', 'storm', 'update', 'warming'}
# ---
#
# {'global', 'archive', 'blog', 'toolshed', 'warming', 'green', 'crap'}
# ---
#
# {'vodpod', 'global', 'hoax', 'interview', 'watch', 'warming', 'joseph'}
# ---
#
# {'global', 'tree', 'good', 'high', 'warming', 'thrive', 'news'}
# ---
#
# {'global', 'whiche', 'truth', 'congressional', 'perk', 'distortion', 'warming', 'refer'}
# ---
#
# {'global', 'drive', 'chaney', 'tale', 'maybe', 'fairy', 'warming', 'year', 'dick'}
# ---
#
# {'global', 'driving', 'dick', 'pervert', 'age', 'stupid', 'george', 'suppose', 'explain', 'time', 'warming', 'crap'}
# ---
#
# {'global', 'push', 'cocksucker', 'stop', 'america', 'prison', 'lie', 'warming', 'fake', 'try'}
# ---
#
# {'global', 'buy', 'view', 'rise', 'villa', 'worried', 'ocean', 'million', 'gore', 'warming', 'level'}
# ---
#
# {'climate', 'threaten', 'harm', 'change', 'good', 'congress', 'current', 'earth', 'legislation'}
# ---
#
# {'climate', 'threaten', 'harm', 'change', 'good', 'congress', 'climatechange', 'current', 'earth', 'legislation'}
# ---
#
# {'climate', 'sick', 'guy', 'tcot', 'reid', 'immigration', 'change', 'bill'}
# ---
#
# {'obama', 'rightblog', 'global', 'tcot', 'right', 'administration', 'profiteer', 'warming', 'teaparty'}
# ---
#
# {'obama', 'black', 'global', 'jackson', 'debunk', 'michelle', 'ignorant', 'stupid', 'lisa', 'woman', 'time', 'warming', 'long', 'see'}
# ---
#
# {'profiteering', 'obama', 'global', 'official', 'warming', 'energy'}
# ---
#
# {'climate', 'boss', 'incessantly', 'lecture', 'change'}
# ---
#
# {'climate', 'fraud', 'change', 'treason', 'trade'}
# ---
#
# {'climate', 'validate', 'enjoy', 'change', 'rule', 'regulation', 'science', 'fuck', 'reulator'}
# ---
#
# {'climate', 'senator', 'fucking', 'grahamneed', 'horse', 'lindsay', 'pull', 'change', 'need', 'regulation', 'dumbass', 'dick'}
# ---
#
# {'climate', 'thought', 'hypothosys', 'stupid', 'change', 'waste', 'disprove', 'idiot', 'initiate', 'regulation', 'time', 'one'}
# ---
#
# {'climate', 'politaical', 'report', 'concur', 'change', 'imaginary', 'regulation', 'absolute', 'science', 'datum', 'suicide'}
# ---
#
# {'climate', 'read', 'john', 'lindsay', 'change', 'reaffirmation', 'graham', 'bunk', 'astute', 'kerry', 'science', 'fuck'}
# ---
#
# {'climate', 'dem', 'change', 'abandon', 'maybe'}
# ---
#
# {'suuuuure', 'global', 'tcot', 'cause', 'warming', 'earthquake'}
# ---
#
# {'global', 'say', 'group', 'fraud', 'irony', 'nuff', 'warming', 'love', 'douchebag', 'favorite'}
# ---
#
# {'global', 'tcot', 'challenge', 'reasonable', 'earthday', 'hype', 'warming', 'nice'}
# ---
#
# {'climate', 'global', 'culturemap', 'houston', 'hoax', 'talk', 'expert', 'warming', 'pollution', 'alarmist'}
# ---
#
# {'global', 'buy', 'stay', 'loyal', 'stupid', 'lindsay', 'like', 'graham', 'gore', 'warming', 'having', 'pay', 'publicly'}
# ---
#
# {'climate', 'shadow', 'change', 'earth', 'gore', 'week', 'see'}
# ---
#
# {'climate', 'true', 'change', 'good', 'regulation'}
# ---
#
# {'global', 'tcot', 'fraud', 'data', 'movement', 'hypothesis', 'fudge', 'warming', 'science', 'prove'}
# ---
#
# {'global', 'driving', 'dick', 'pervert', 'age', 'stupid', 'george', 'suppose', 'explain', 'time', 'warming', 'crap'}
# ---
#
# {'global', 'bobsyouruncle', 'tale', 'fairy', 'warming'}
# ---
#
# {'climate', 'forward', 'foot', 'change', 'dems', 'sum', 'leave'}
# ---
#
# {'human', 'global', 'poll', 'warming', 'induce', 'washington', 'state', 'trust', 'unequivocal', 'dept', 'americans', 'declare', 'primarily'}
# ---
#
# {'climate', 'volcano', 'question', 'change', 'blame', 'environmentalist', 'human'}
# ---
#
# {'climate', 'global', 'change', 'tree', 'kill', 'coffee', 'love', 'worry', 'increase', 'warming'}
# ---
#
# {'climate', 'right', 'archive', 'blog', 'change', 'make', 'girl'}
# ---
#
# {'climate', 'cause', 'suggest', 'assume', 'bug', 'anthropogenic', 'change', 'drive', 'medium', 'process'}
# ---
#
# {'wait', 'climate', 'right', 'people', 'world', 'tweet', 'cochabamba', 'green'}
# ---
#
# {'climate', 'global', 'change', 'zeal', 'scamster'}
# ---
#
# {'follow', 'global', 'socialist', 'manipulation', 'democrat', 'political', 'fine', 'prediction', 'jail', 'time', 'warming', 'investigate', 'datum'}
# ---
#
# {'climate', 'snowman', 'picket', 'change', 'twee', 'lethbridge', 'cassons', 'rick', 'office'}
# ---
#
# {'global', 'fund', 'christie', 'awesome', 'million', 'warming', 'governor'}
# ---
#
# {'global', 'safety', 'blankenship', 'warming', 'call', 'regulation', 'effort', 'silly'}
# ---
#
# {'global', 'channel', 'fraud', 'want', 'weather', 'founder', 'gore', 'warming'}
# ---
#
# {'global', 'today', 'know', 'smart', 'warming', 'freeze', 'think'}
# ---
#
# {'climate', 'texas', 'century', 'feel', 'cause', 'change', 'chicago', 'like', 'ecologist', 'accord', 'rigggghhhht'}
# ---
#
# {'climate', 'tcot', 'fight', 'help', 'change', 'poop', 'whale', 'teaparty'}
# ---
#
# {'british', 'global', 'assaults', 'statistician', 'warming', 'datum'}
# ---
#
# {'climate', 'report', 'network', 'change', 'special', 'credibility', 'decline', 'hide', 'science'}
# ---
#
# {'climate', 'report', 'network', 'change', 'special', 'credibility', 'decline', 'hide', 'science'}
# ---
#
# {'fucking', 'global', 'scientist', 'pluto', 'know', 'trust', 'warming', 'planet'}
# ---
#
# {'global', 'crisis', 'advocate', 'credibility', 'warming', 'face'}
# ---
#
# {'climate', 'report', 'network', 'change', 'special', 'credibility', 'decline', 'hide', 'science'}
# ---
#
# {'global', 'nuclear', 'winter', 'ensue', 'control', 'influence', 'warming', 'planet'}
# ---
#
# {'global', 'tcot', 'graph', 'tlot', 'study', 'attack', 'warming', 'hhrs', 'teaparty'}
# ---
#
# {'heartland', 'analyst', 'global', 'report', 'tcot', 'laughable', 'warming', 'tlot', 'state', 'dept'}
# ---
#
# {'climate', 'light', 'global', 'believe', 'recycle', 'wellduh', 'change', 'control', 'warming', 'planet'}
# ---
#
# {'climate', 'global', 'scientist', 'scandal', 'change', 'clear', 'warming', 'attempt'}
# ---
#
# {'sierra', 'global', 'cause', 'club', 'talk', 'know', 'ensue', 'gun', 'warming', 'announce', 'govertainment'}
# ---
#
# {'alarmism', 'global', 'tcot', 'ocra', 'world', 'run', 'short', 'time', 'warming', 'pollution'}
# ---
#
# {'global', 'knee', 'discredit', 'jerk', 'warming', 'alarmist'}
# ---
#
# {'global', 'knee', 'discredit', 'jerk', 'warming', 'alarmist'}
# ---
#
# {'climate', 'fight', 'ridiculous', 'states', 'change', 'misquote', 'get'}
# ---
#
# {'global', 'scientific', 'evolution', 'warming', 'like', 'theory', 'plate', 'destroy', 'tectonic', 'taxis', 'family', 'raise'}
# ---
#
# {'global', 'calculation', 'volcano', 'release', 'kill', 'accord', 'earth', 'time', 'warming', 'science', 'iceland'}
# ---
#
# {'global', 'calculation', 'volcano', 'release', 'kill', 'accord', 'earth', 'time', 'warming', 'science', 'iceland'}
# ---
#
# {'global', 'phone', 'hippie', 'want', 'movie', 'change', 'horror', 'watch', 'warming'}
# ---
#
# {'global', 'thaw', 'suck', 'warming', 'break', 'thumb', 'watch', 'finish', 'past', 'propaganda'}
# ---
#
# {'global', 'yippie', 'liberal', 'movie', 'horror', 'watch', 'warming'}
# ---
#
# {'global', 'dynamic', 'cause', 'shape', 'volcanic', 'winter', 'earth', 'force', 'activity', 'move', 'warming'}
# ---
#
# {'global', 'refuse', 'hoax', 'interview', 'gore', 'warming'}
# ---
#
# {'global', 'fund', 'christie', 'hero', 'million', 'warming'}
# ---
#
# {'climate', 'fact', 'tell', 'saveterra', 'murdoch', 'change', 'globalwarme', 'rupert', 'straight', 'foxnew'}
# ---
#
# {'regulator', 'global', 'government', 'safety', 'tcot', 'blankenship', 'warming', 'accord', 'owner', 'silly'}
# ---
#
# {'global', 'climategate', 'problem', 'victim', 'freakonomic', 'blog', 'warm', 'state'}
# ---
#
# {'climate', 'fact', 'tell', 'saveterra', 'murdoch', 'change', 'globalwarme', 'rupert', 'straight', 'foxnew'}
# ---
#
# {'climate', 'fact', 'tell', 'saveterra', 'murdoch', 'change', 'globalwarme', 'rupert', 'straight', 'foxnew'}
# ---
#
# {'great', 'global', 'aydan', 'healthy', 'home', 'corkern', 'author', 'title', 'sell', 'smart', 'warming'}
# ---
#
# {'theimer', 'global', 'architect', 'stupid', 'marc', 'james', 'earth', 'redd', 'skeptic', 'warming', 'beauchamp'}
# ---
#
# {'melt', 'global', 'cause', 'mar', 'cap', 'warming', 'human'}
# ---
#
# {'climate', 'global', 'enjoy', 'continue', 'spring', 'angeles', 'change', 'north', 'cold', 'weather', 'stuff', 'hope', 'warming'}
# ---
#
# {'global', 'christian', 'debate', 'libertarian', 'market', 'love', 'monitor', 'warming', 'science', 'proposal'}
# ---
#
# {'climate', 'global', 'climatologist', 'forecaster', 'debate', 'change', 'meteorologist', 'television', 'weather', 'doubt'}
# ---
#
# {'global', 'montecito', 'villa', 'money', 'area', 'snap', 'action', 'tipper', 'gore', 'warming'}
# ---
#
# {'global', 'boffin', 'worl', 'peril', 'author', 'warm', 'page', 'carbon', 'wrong', 'lewis', 'model', 'dirt'}
# ---
#
# {'global', 'imagine', 'instead', 'wheel', 'warm', 'hard', 'fall', 'warming'}
# ---
#
# {'global', 'cause', 'clean', 'new', 'confused', 'warming'}
# ---
#
# {'global', 'impressionable', 'kid', 'teacher', 'sure', 'shove', 'hoax', 'go', 'state', 'throat', 'young', 'warming'}
# ---
#
# {'climate', 'average', 'global', 'curr', 'rating', 'review', 'lead', 'brand', 'confusion', 'warming', 'hysteria', 'science'}
# ---
#
# {'global', 'remain', 'scare', 'public', 'american', 'uninformed', 'warming', 'science', 'shabby'}
# ---
#
# {'global', 'prediction', 'concentration', 'false', 'warming', 'projection'}
# ---
#
# {'profiteering', 'obama', 'global', 'tcot', 'official', 'globalwarme', 'warming', 'energy'}
# ---
#
# {'frighten', 'global', 'liberal', 'find', 'meet', 'like', 'badly', 'sarah', 'palin', 'warming', 'get'}
# ---
#
# {'climate', 'great', 'global', 'believe', 'group', 'conversation', 'natural', 'explanati', 'blunder', 'warming', 'potential'}
# ---
#
# {'phil', 'global', 'figure', 'action', 'hope', 'redeye', 'warming', 'tugboat'}
# ---
#
# {'climate', 'cover', 'volcano', 'question', 'change', 'answer', 'suvs', 'think'}
# ---
#
# {'suuuuure', 'global', 'land', 'cause', 'sea', 'flow', 'warn', 'glacier', 'warming', 'earthquake'}
# ---
#
# {'global', 'kiddo', 'think', 'miss', 'newyork', 'florida', 'waiting', 'win', 'warming', 'nice'}
# ---
#
# {'global', 'climategate', 'ignore', 'scandal', 'advance', 'left', 'warming', 'wing', 'agenda'}
# ---
#
# {'global', 'rich', 'journalism', 'warming', 'decade', 'calle', 'advocacy', 'year', 'noye'}
# ---
#
# {'climate', 'ardebate', 'deny', 'primary', 'change', 'realize', 'arkansa', 'taxer', 'fair'}
# ---
#
# {'climate', 'true', 'change', 'come', 'dream', 'theologian', 'totalitarian'}
# ---
#
# {'folk', 'global', 'flower', 'go', 'tree', 'plant', 'warming', 'hillary', 'gavan'}
# ---
#
# {'critic', 'global', 'manzi', 'effective', 'data', 'drive', 'zealot', 'warming'}
# ---
#
# {'climate', 'global', 'houston', 'hoax', 'talk', 'expert', 'warming', 'pollution', 'alarmist'}
# ---
#
# {'global', 'earth', 'marklevinshow', 'smack', 'zealot', 'warming'}
# ---
#
# {'global', 'comedian', 'joke', 'know', 'warming', 'datum'}
# ---
#
# {'global', 'article', 'tcot', 'liberal', 'cultism', 'excellent', 'warming', 'fellow'}
# ---
#
# {'climate', 'folk', 'global', 'pollution', 'switch', 'fight', 'change', 'warming', 'message'}
# ---
#
# {'climate', 'bolivia', 'interview', 'change', 'watch', 'conference', 'cochabamba', 'star', 'pocahontas'}
# ---
#
# {'global', 'tell', 'blog', 'ocregister', 'warming', 'hoot', 'exactly'}
# ---
#
# {'climate', 'better', 'change', 'buyer', 'dumb', 'loser'}
# ---
#
# {'global', 'feel', 'fight', 'good', 'like', 'warm', 'fantasy', 'video', 'youtube'}
# ---
#
# {'global', 'rasmussen', 'voter', 'report', 'april', 'seriously', 'monday', 'corner', 'skeptic', 'warming'}
# ---
#
# {'climate', 'scientist', 'rehabilitate', 'news', 'volcanic', 'change', 'brkg', 'sue', 'eruption', 'announce', 'get', 'panel', 'iceland'}
# ---
#
# {'signal', 'global', 'volcano', 'tcot', 'msnbc', 'carter', 'glenn', 'jimmy', 'smoke', 'send', 'beck', 'gore', 'warming', 'news', 'nowplaying', 'algore'}
# ---
#
# {'global', 'government', 'come', 'knee', 'discredit', 'prison', 'european', 'jerk', 'warming', 'alarmist'}
# ---
#
# {'global', 'doubleday', 'take', 'talese', 'page', 'mcewan'}
# ---
#
# {'climate', 'global', 'say', 'fraud', 'change', 'quote', 'oxburgh', 'balance', 'warming'}
# ---
#
# {'climate', 'change', 'reach', 'tackle', 'excuse'}
# ---
#
# {'climate', 'probly', 'fact', 'volcano', 'guru', 'change', 'wrong', 'get', 'rant', 'iceland'}
# ---
#
# {'global', 'tcot', 'come', 'blame', 'eruption', 'gore', 'warming'}
# ---
#
# {'global', 'intelligence', 'remain', 'logic', 'evidence', 'debate', 'unpersuade', 'consider', 'nutcase', 'discourage', 'warming', 'human'}
# ---
#
# {'global', 'view', 'probably', 'represent', 'skeptic', 'warming'}
# ---
#
# {'climate', 'global', 'scientist', 'fire', 'exaggerate', 'warming'}
# ---
#
# {'account', 'believ', 'global', 'return', 'soon', 'miss', 'scientist', 'roughly', 'half', 'heat', 'warming'}
# ---
#
# {'climate', 'global', 'evidence', 'change', 'market', 'inconclusive', 'armageddo', 'warming', 'year'}
# ---
#
# {'global', 'channel', 'hoax', 'promote', 'theory', 'weather', 'conspiracy', 'warming'}
# ---
#
# {'average', 'catch', 'global', 'cali', 'scare', 'strange', 'weather', 'call', 'bullshit', 'warming', 'get'}
# ---
#
# {'climate', 'nightmare', 'change', 'creepy', 'ridiculous', 'night'}
# ---
#
# {'climate', 'change', 'reach', 'tackle', 'excuse'}
# ---
#
# {'december', 'global', 'scientist', 'nations', 'send', 'letter', 'control', 'united', 'warming'}
# ---
#
# {'global', 'pelosi', 'contend', 'newt', 'need', 'gingrich', 'defend', 'commercial', 'warming', 'green', 'seek'}
# ---
#
# {'liberalism', 'global', 'statement', 'make', 'have', 'warming', 'calendar'}
# ---
#
# {'regulator', 'global', 'brookl', 'safety', 'treehugger', 'blankenship', 'warming', 'brian', 'silly', 'video', 'merchant'}
# ---
#
# {'global', 'read', 'peer', 'truly', 'review', 'calif', 'gulf', 'warming', 'california'}
# ---
#
# {'massey', 'global', 'safety', 'idea', 'miner', 'warming', 'care', 'dead', 'silly', 'energy'}
# ---
#
# {'global', 'jesse', 'ambush', 'gore', 'warming', 'video', 'brilliant', 'woodrow'}
# ---
#
# {'global', 'disagree', 'remove', 'theory', 'warming', 'datum'}
# ---
#
# {'climate', 'pretend', 'global', 'fraud', 'catastrophe', 'change', 'people', 'know', 'surplus', 'warming'}
# ---
#
# {'global', 'parody', 'enjoy', 'ocra', 'tube', 'ipcc', 'warming'}
# ---
#
# {'global', 'tell', 'eyed', 'make', 'dare', 'warming', 'golfer'}
# ---
#
# {'global', 'hair', 'scientifically', 'brain', 'challenge', 'tcot', 'climategate', 'ippc', 'claim', 'theory', 'warming'}
# ---

# %%
generateWordCloud(pre_tweet_neg)

# %%
# generateWordCloud([t.split(' ') for t in tweets])
generateWordCloud(preprocessed_tweets)

# %%
import nltk
preprocessed_tweets
flat_list = []
for sublist in preprocessed_tweets:
    for item in sublist:
        flat_list.append(item)

# %%
bigrams_series = (pd.Series(nltk.ngrams(flat_list, 2)).value_counts())[:10]

# %%
bigrams_series.sort_values().plot.barh(color='blue', width=.9, figsize=(12, 8))
plt.title('10 Most Frequently Occuring Bigrams')
plt.ylabel('Bigram')
plt.xlabel('Number of Occurances')
# Out:
# Text(0.5, 0, 'Number of Occurances')

# %%
data['existence.confidence'].plot(
    kind='hist',
    bins=30,
    title='Tweet Sentiment Distribution ')

# %%
data['word_count'].plot(
    kind='hist',
    # xTitle = "Word Count",
    bins=50,
    title='Tweet Word Count Distribution')

# %%
print(data.groupby(by=["existence"]).sum())
data.groupby(by=["existence"]).sum().plot(kind = 'bar',title = "Existence Distribution")
# Out:
#            existence.confidence  word_count
# existence
# No                     840.8694       18845
# Yes                   2474.1951       47302

# %%
# The distribution of top unigrams before removing stop words
from sklearn.feature_extraction.text import CountVectorizer

def get_top_n_words(corpus, n=None):
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items() if len(word) > 3 and word not in set(STOPWORDS)]
    # words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

common_words = get_top_n_words(data['tweet'], 20)
for word, freq in common_words:
    print(word, freq)
df1 = pd.DataFrame(common_words, columns = ['tweet' , 'word_count'])
display(df1.head())

df1.groupby('tweet').sum()['word_count'].sort_values(ascending=False).plot(
    kind='bar', title='Top 20 words in review before preprocessing')
# Out:
# global 2437
# warming 2360
# climate 2355
# change 2155
# link 489
# retwt 218
# snow 217
# tcot 187
# news 177
# science 162
# oohja 158
# green 150
# will 149
# earth 131
# world 130
# report 129
# gore 112
# time 103
# scientists 102
# energy 102
#      tweet  word_count
# 0   global        2437
# 1  warming        2360
# 2  climate        2355
# 3   change        2155
# 4     link         489

# %%
allwords = list(chain.from_iterable(preprocessed_tweets))
df2 = pd.DataFrame(allwords,columns = ["words"])
df2['words'].value_counts()[:20].plot(kind='bar', title='Top 20 words in review after preprocessing')
# allwords
# preprocessed_tweets

# %%
data.head()
# Out:
#                                                tweet existence  \
# 0  Global warming report urges governments to act...       Yes
# 1  Fighting poverty and global warming in Africa ...       Yes
# 2  Carbon offsets: How a Vatican forest failed to...       Yes
# 3  Carbon offsets: How a Vatican forest failed to...       Yes
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...       Yes
#
#    existence.confidence  word_count
# 0                1.0000          18
# 1                1.0000           8
# 2                0.8786          12
# 3                1.0000          12
# 4                0.8087          11

# %%
prepr_tweets = [" ".join(each) for each in preprocessed_tweets]
data_new=data.iloc[indices_pre]
data_new['cleaned_tweet'] = prepr_tweets
data_new.head()
# Out:
#                                                tweet existence  \
# 0  Global warming report urges governments to act...       Yes
# 1  Fighting poverty and global warming in Africa ...       Yes
# 2  Carbon offsets: How a Vatican forest failed to...       Yes
# 3  Carbon offsets: How a Vatican forest failed to...       Yes
# 4  URUGUAY: Tools Needed for Those Most Vulnerabl...       Yes
#
#    existence.confidence  word_count  \
# 0                1.0000          18
# 1                1.0000           8
# 2                0.8786          12
# 3                1.0000          12
# 4                0.8087          11
#
#                                        cleaned_tweet
# 0  report global government urge world hunger inc...
# 1                global fight africa poverty warming
# 2  global reduce fail vatican forest warming carb...
# 3  global reduce fail vatican forest warming carb...
# 4        climate tool uruguay vulnerable change need

# %%
len(prepr_tweets), data.shape
# Out:
# (3865, (4134, 4))

# %% [markdown]
# ## TF IDF & modelling

# %%
# TF IDF
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split,cross_validate
import collections, numpy
import numpy as np, pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
data.isna().sum()
# Out:
# tweet                   0
# existence               0
# existence.confidence    0
# word_count              0
# dtype: int64

# %%
X_train, X_test, y_train, y_test_nb= train_test_split(data_new.cleaned_tweet,data_new['existence'], test_size=0.2, random_state=33)

# %% [markdown]
# Use MultinomialNB

# %%
model_nb = make_pipeline(TfidfVectorizer(), MultinomialNB())
model_nb.fit(X_train, y_train)
predicted_categories_NB = model_nb.predict(X_test)

# %% [markdown]
# Create apickle file for webapp

# %%
import pickle
pickle.dump(model_nb,open("model.pkl",'wb'))

# %%
# plot the confusion matrix
mat = confusion_matrix(y_test_nb, predicted_categories_NB)
sns.heatmap(mat.T, square = True, annot=True, fmt = "d", xticklabels=y_train.unique(),yticklabels=y_train.unique())
plt.xlabel("true labels")
plt.ylabel("predicted label")
plt.show()
print("The testing accuracy is {}".format(accuracy_score(y_test_nb, predicted_categories_NB)))
print("The training accuracy is {}".format(accuracy_score(y_train, model_nb.predict(X_train))))
# Out:
# The testing accuracy is 0.7826649417852523
# The training accuracy is 0.869340232858991

# %%
#Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score
scores_Naive_Bayes = cross_val_score(model_nb, data_new.cleaned_tweet,data_new['existence'], cv=10, scoring="accuracy")
print(scores_Naive_Bayes)
meanScore = scores_Naive_Bayes.mean()
print(meanScore * 100)
# Out:
# [0.81136951 0.77777778 0.80361757 0.74418605 0.77002584 0.7746114
#  0.74611399 0.75388601 0.79792746 0.77202073]
# 77.51536329678275

# %% [markdown]
# Random Forest Imbalanced classes

# %%
X_train, X_test, y_train, y_test = train_test_split(data_new.cleaned_tweet,data_new['existence'], test_size=0.3, random_state=33)

# %%
from sklearn.ensemble import RandomForestClassifier
model_random_forest = make_pipeline(TfidfVectorizer(), RandomForestClassifier())
model_random_forest.fit(X_train, y_train)
predicted_categories_random_forest = model_random_forest.predict(X_test)

# %%
# plot the confusion matrix
mat = confusion_matrix(y_test, predicted_categories_random_forest)
sns.heatmap(mat.T, square = True, annot=True, fmt = "d", xticklabels=y_train.unique(),yticklabels=y_train.unique())
plt.xlabel("true labels")
plt.ylabel("predicted label")
plt.show()
print("The testing accuracy is {}".format(accuracy_score(y_test, predicted_categories_random_forest)))
print("The training accuracy is {}".format(accuracy_score(y_train, model_random_forest.predict(X_train))))
# Out:
# The testing accuracy is 0.825
# The training accuracy is 0.9866913123844732

# %%
scores_random_forest = cross_val_score(model_random_forest, data_new.cleaned_tweet,data_new['existence'], cv=10, scoring="accuracy")
print(scores_random_forest)
meanScore = scores_random_forest.mean()
print(meanScore * 100)
# Out:
# [0.88113695 0.82945736 0.84237726 0.79069767 0.77777778 0.77720207
#  0.71761658 0.79792746 0.79792746 0.78756477]
# 79.99685370392685

# %% [markdown]
# Comparisions between models

# %%
results=[]
names=[]
results.append(scores_random_forest)
names.append("Random_Forest")


results.append(scores_Naive_Bayes)
names.append("Naive Bayes")



# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %%
 from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

# %%
accu_rf=round(accuracy_score(y_test,predicted_categories_random_forest),3)
f1_score_rf=round(f1_score(y_test,predicted_categories_random_forest,average="binary",pos_label="Yes"), 3)
Precision_rf=round(precision_score(y_test,predicted_categories_random_forest,average="binary",pos_label="Yes"),3)
Recall_rf=round(recall_score(y_test,predicted_categories_random_forest,average="binary",pos_label="Yes"),3)
print('Accuracy:',accu_rf)
print('F1_Score:',f1_score_rf)
print('Recall_Score:',Precision_rf)
print('Precision_Score:',Recall_rf)
# Out:
# Accuracy: 0.825
# F1_Score: 0.887
# Recall_Score: 0.832
# Precision_Score: 0.95

# %%
accu_nb=round(accuracy_score(y_test_nb,predicted_categories_NB),3)
f1_score_nb=round(f1_score(y_test_nb,predicted_categories_NB,average="binary",pos_label="Yes"),3)
Precision_nb=round(precision_score(y_test_nb,predicted_categories_NB,average="binary",pos_label="Yes"),3)
Recall_nb=round(recall_score(y_test_nb,predicted_categories_NB,average="binary",pos_label="Yes"),3)
print('Accuracy:',accu_nb)
print('F1_Score:',f1_score_nb)
print('Recall_Score:',Precision_nb)
print('Precision_Score:',Recall_nb)
# Out:
# Accuracy: 0.783
# F1_Score: 0.866
# Recall_Score: 0.775
# Precision_Score: 0.98

# %%
Result_2={
                  'Model':['Random-Forest','Naive Bayes'],
                  'Accuracy(%)':[accu_rf*100,accu_nb*100],
                  'F1_Score(%)':[f1_score_rf*100,f1_score_nb*100],
                  'Precision(%)':[Precision_rf*100,Precision_nb*100],
                  'Recall(%)':[Recall_rf*100,Recall_nb*100]
        
                    }
Result_final=pd.DataFrame(Result_2)

# %%
splot=Result_final.plot(x='Model',y=['Accuracy(%)','F1_Score(%)','Precision(%)','Recall(%)'],kind='bar',figsize=(15,10),cmap='Pastel2',width=0.9)
for p in splot.patches:
    splot.annotate(format(round(p.get_height()), '.0f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0,7),
                   textcoords='offset points')
plt.title('Evaluation Scores For Climate change Data for various Models for imbalanced classes')
plt.ylabel('Percentage')
plt.xlabel('Models')
plt.legend(loc='upper left')
for pos in ['right', 'top', 'bottom', 'left']:
    plt.gca().spines[pos].set_visible(False)
plt.show()

# %%
# performing random over sampling to reduce the imbalance in classes 
from imblearn.over_sampling import RandomOverSampler

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import TruncatedSVD
tf = TfidfVectorizer()
transf_text= tf.fit_transform(data_new['cleaned_tweet'].astype('U'))
transf_text_rf= TruncatedSVD(n_components=2500).fit_transform(transf_text)
transf_text_rf2= TruncatedSVD(n_components=2000).fit_transform(transf_text)
cos_sim=cosine_similarity(transf_text, transf_text)
cos_sim_rf=cosine_similarity(transf_text_rf, transf_text_rf)
cos_sim_rf2=cosine_similarity(transf_text_rf2, transf_text_rf2)
print(cos_sim)
# Out:
# [[1.         0.03091766 0.02065754 ... 0.01956034 0.0190495  0.01513498]
#  [0.03091766 1.         0.03703929 ... 0.035072   0.03415605 0.02713727]
#  [0.02065754 0.03703929 1.         ... 0.02343325 0.02282126 0.01813168]
#  ...
#  [0.01956034 0.035072   0.02343325 ... 1.         0.02160914 0.01716864]
#  [0.0190495  0.03415605 0.02282126 ... 0.02160914 1.         0.01672026]
#  [0.01513498 0.02713727 0.01813168 ... 0.01716864 0.01672026 1.        ]]

# %% [markdown]
# Applying naive Bayes for Balanced classes

# %%
X_train_nb_bal, X_test_nb_bal, y_train_nb_bal, y_test_nb_bal= train_test_split(cos_sim,data_new['existence'], test_size=0.2, random_state=33)

# %%
X_train_nb_bal.shape
# Out:
# (3092, 3865)

# %%
X_train_nb_bal,y_train_nb_bal = RandomOverSampler(random_state = 21).fit_resample(X_train_nb_bal,y_train_nb_bal)

# %%
X_train_nb_bal.shape, y_train_nb_bal.shape
# Out:
# ((4596, 3865), (4596,))

# %%
model_nb_bal = make_pipeline(MultinomialNB())
model_nb_bal.fit(X_train_nb_bal, y_train_nb_bal)
predicted_categories_NB_bal = model_nb_bal.predict(X_test_nb_bal)

# %%
cv_NB, mean_scores_NB = cross_val(X_train_nb_bal, y_train_nb_bal, X_test_nb_bal, y_test_nb_bal, MultinomialNB() )
print(cv_NB)
plot_cross_val(cv_NB)
mean_scores_NB
# Out:
# {'fit_time': array([0.24626422, 0.46874404, 0.22692871, 0.26259041, 0.29134798,
#        0.43924904, 0.34680676, 0.39342833, 0.48493624, 0.51299548]), 'score_time': array([0.08455467, 0.10489035, 0.03358936, 0.04312181, 0.0499773 ,
#        0.07850528, 0.10062432, 0.05822158, 0.08234596, 0.08766317]), 'test_accuracy': array([0.65      , 0.64565217, 0.64347826, 0.63695652, 0.69565217,
#        0.63043478, 0.62962963, 0.62527233, 0.63180828, 0.65577342]), 'train_accuracy': array([0.64337524, 0.64410058, 0.64482592, 0.64555126, 0.63878143,
#        0.64555126, 0.64563693, 0.64612038, 0.64515349, 0.64273628]), 'test_precision': array([0.66829268, 0.657277  , 0.68131868, 0.66666667, 0.71634615,
#        0.64705882, 0.64018692, 0.6407767 , 0.65625   , 0.67661692]), 'train_precision': array([0.6637217 , 0.66518847, 0.66357182, 0.66520307, 0.65856354,
#        0.66611479, 0.66703663, 0.66685083, 0.66483818, 0.66280992]), 'test_recall': array([0.59565217, 0.60869565, 0.53913043, 0.54782609, 0.64782609,
#        0.57391304, 0.59565217, 0.57391304, 0.55021834, 0.59388646]), 'train_recall': array([0.58123791, 0.58027079, 0.58752418, 0.5860735 , 0.57640232,
#        0.58365571, 0.58123791, 0.58365571, 0.58579024, 0.58144031]), 'test_f1_macro': array([0.64896315, 0.64516755, 0.63955355, 0.63404932, 0.69495443,
#        0.62925035, 0.62923366, 0.62432906, 0.62926729, 0.65439382]), 'train_f1_macro': array([0.64199296, 0.64264463, 0.64365587, 0.64429291, 0.63737038,
#        0.64418812, 0.64415471, 0.6447279 , 0.64390459, 0.6413951 ])}
#        accuracy  precision    recall  f1_macro
# train  0.644183   0.664390  0.582729  0.642833
# test   0.644466   0.665079  0.582671  0.642916

# %%
accu_nb_bal=round(accuracy_score(y_test_nb_bal,predicted_categories_NB_bal),3)
f1_score_nb_bal=round(f1_score(y_test_nb_bal,predicted_categories_NB_bal,average="binary",pos_label="Yes"),3)
Precision_nb_bal=round(precision_score(y_test_nb_bal,predicted_categories_NB_bal,average="binary",pos_label="Yes"),3)
Recall_nb_bal=round(recall_score(y_test_nb_bal,predicted_categories_NB_bal,average="binary",pos_label="Yes"),3)
print('Accuracy:',accu_nb_bal)
print('F1_Score:',f1_score_nb_bal)
print('Recall_Score:',Precision_nb_bal)
print('Precision_Score:',Recall_nb_bal)

# %% [markdown]
# Random Sampling Over sampler for Random Forest

# %%
 X_train_rf_bal, X_test_rf_bal, y_train_rf_bal, y_test_rf_bal= train_test_split(cos_sim_rf,data_new['existence'], test_size=0.2, random_state=33)

# %%
X_train_rf_bal,y_train_rf_bal = RandomOverSampler(random_state = 21).fit_resample(X_train_rf_bal,y_train_rf_bal)

# %%
model_random_forest = make_pipeline(RandomForestClassifier())
model_random_forest.fit(X_train_rf_bal, y_train_rf_bal)
predicted_categories_random_forest_bal = model_random_forest.predict(X_test_rf_bal)

# %%
cv_RF, mean_scores_RF = cross_val(X_train_nb_bal, y_train_nb_bal, X_test_nb_bal, y_test_nb_bal, RandomForestClassifier() )
print(cv_RF)
plot_cross_val(cv_RF)
mean_scores_RF

# %%
accu_rf=round(accuracy_score(y_test_rf_bal,predicted_categories_random_forest_bal),3)
f1_score_rf=round(f1_score(y_test_rf_bal,predicted_categories_random_forest_bal,average="binary",pos_label="Yes"), 3)
Precision_rf=round(precision_score(y_test_rf_bal,predicted_categories_random_forest_bal,average="binary",pos_label="Yes"),3)
Recall_rf=round(recall_score(y_test_rf_bal,predicted_categories_random_forest_bal,average="binary",pos_label="Yes"),3)
print('Accuracy:',accu_rf)
print('F1_Score:',f1_score_rf)
print('Recall_Score:',Precision_rf)
print('Precision_Score:',Recall_rf)

# %%
Result_2={
                  'Model':['Random-Forest','Naive Bayes'],
                  'Accuracy(%)':[accu_rf*100,accu_nb_bal*100],
                  'F1_Score(%)':[f1_score_rf*100,f1_score_nb_bal*100],
                  'Precision(%)':[Precision_rf*100,Precision_nb_bal*100],
                  'Recall(%)':[Recall_rf*100,Recall_nb_bal*100]
        
                    }
Result_final=pd.DataFrame(Result_2)

# %%
splot=Result_final.plot(x='Model',y=['Accuracy(%)','F1_Score(%)','Precision(%)','Recall(%)'],kind='bar',figsize=(15,10),cmap='Pastel2',width=0.9)
for p in splot.patches:
    splot.annotate(format(round(p.get_height()), '.0f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0,7),
                   textcoords='offset points')
plt.title('Evaluation Scores For Climate change Data for various Models for balanced classes')
plt.ylabel('Percentage')
plt.xlabel('Models')
plt.legend(loc='upper left')
for pos in ['right', 'top', 'bottom', 'left']:
    plt.gca().spines[pos].set_visible(False)

# %% [markdown]
# SVD

# %%
X_train_rf_bal, X_test_rf_bal, y_train_rf_bal, y_test_rf_bal= train_test_split(cos_sim_rf,data_new['existence'], test_size=0.2, random_state=33)

# %%
X_train_rf_bal,y_train_rf_bal = RandomOverSampler(random_state = 21).fit_resample(X_train_rf_bal,y_train_rf_bal)

# %%
cv_RF, mean_scores_RF = cross_val(X_train_rf_bal, y_train_rf_bal, X_test_rf_bal, y_test_rf_bal, RandomForestClassifier() )
print(cv_RF)
plot_cross_val(cv_RF)
mean_scores_RF
# Out:
# {'fit_time': array([40.49316573, 40.82385516, 41.12343121, 40.05252051, 38.14345646,
#        38.75400305, 38.105124  , 39.45802617, 40.99021649, 39.02043509]), 'score_time': array([0.08402944, 0.09221411, 0.07050705, 0.07148886, 0.07707357,
#        0.07246113, 0.07974434, 0.07608986, 0.06957531, 0.0449903 ]), 'test_accuracy': array([0.89347826, 0.92826087, 0.9       , 0.87608696, 0.94130435,
#        0.92173913, 0.93899782, 0.93028322, 0.93464052, 0.94117647]), 'train_accuracy': array([0.98863636, 0.9881528 , 0.98984526, 0.98839458, 0.98839458,
#        0.98863636, 0.98743051, 0.98791395, 0.98815567, 0.98791395]), 'test_precision': array([0.92488263, 0.9339207 , 0.92990654, 0.90232558, 0.98104265,
#        1.        , 0.99509804, 0.99009901, 0.99502488, 0.99029126]), 'train_precision': array([0.99510044, 0.99753573, 0.99852362, 0.99558391, 0.99558391,
#        0.99607266, 0.99508841, 0.99606686, 0.99607073, 0.99509564]), 'test_recall': array([0.85652174, 0.92173913, 0.86521739, 0.84347826, 0.9       ,
#        0.84347826, 0.8826087 , 0.86956522, 0.87336245, 0.89082969]), 'train_recall': array([0.98210832, 0.9787234 , 0.9811412 , 0.9811412 , 0.9811412 ,
#        0.9811412 , 0.97969052, 0.97969052, 0.98018366, 0.98066699]), 'test_f1_macro': array([0.89333258, 0.92825782, 0.89987887, 0.87595506, 0.94120404,
#        0.92125685, 0.93881632, 0.93004115, 0.93437857, 0.94101521]), 'train_f1_macro': array([0.98863588, 0.98815175, 0.98984449, 0.98839397, 0.98839397,
#        0.98863573, 0.98742971, 0.98791308, 0.98815496, 0.98791335])}
#        accuracy  precision    recall  f1_macro
# train  0.988347   0.996072  0.980563  0.988347
# test   0.920597   0.964259  0.874680  0.920414

# %% [markdown]
# SVD With 2000 components

# %%
X_train_rf_bal, X_test_rf_bal, y_train_rf_bal, y_test_rf_bal= train_test_split(cos_sim_rf2,data_new['existence'], test_size=0.2, random_state=33)

# %%
X_train_rf_bal,y_train_rf_bal = RandomOverSampler(random_state = 21).fit_resample(X_train_rf_bal,y_train_rf_bal)

# %%
cv_RF, mean_scores_RF = cross_val(X_train_rf_bal, y_train_rf_bal, X_test_rf_bal, y_test_rf_bal, RandomForestClassifier() )
print(cv_RF)
plot_cross_val(cv_RF)
mean_scores_RF
# Out:
# {'fit_time': array([36.36205339, 36.02114224, 35.94299698, 36.28916192, 35.64592838,
#        35.75570035, 38.06585932, 37.44232798, 35.85381675, 36.41299605]), 'score_time': array([0.07619882, 0.07253385, 0.09510708, 0.09567809, 0.07073951,
#        0.08137918, 0.08904409, 0.08077717, 0.07164955, 0.05028391]), 'test_accuracy': array([0.89347826, 0.93043478, 0.8826087 , 0.90217391, 0.9326087 ,
#        0.91956522, 0.93899782, 0.93028322, 0.93246187, 0.93246187]), 'train_accuracy': array([0.98863636, 0.9881528 , 0.98984526, 0.98839458, 0.98839458,
#        0.98863636, 0.98743051, 0.98791395, 0.98815567, 0.98791395]), 'test_precision': array([0.91705069, 0.92672414, 0.90740741, 0.9342723 , 0.97156398,
#        1.        , 0.99509804, 0.99009901, 0.995     , 0.98058252]), 'train_precision': array([0.99461576, 0.99509564, 0.99705594, 0.99607073, 0.99461312,
#        0.99558607, 0.99606299, 0.99606686, 0.99509804, 0.99509564]), 'test_recall': array([0.86521739, 0.93478261, 0.85217391, 0.86521739, 0.89130435,
#        0.83913043, 0.8826087 , 0.86956522, 0.86899563, 0.88209607]), 'train_recall': array([0.98259188, 0.9811412 , 0.98259188, 0.98065764, 0.98210832,
#        0.98162476, 0.9787234 , 0.97969052, 0.98115031, 0.98066699]), 'test_f1_macro': array([0.89339312, 0.93043347, 0.88249986, 0.90204012, 0.93249353,
#        0.91904144, 0.93881632, 0.93004115, 0.93217212, 0.93227672]), 'train_f1_macro': array([0.98863595, 0.98815222, 0.98984473, 0.98839389, 0.98839413,
#        0.9886358 , 0.9874295 , 0.98791308, 0.98815513, 0.98791335])}
#        accuracy  precision    recall  f1_macro
# train  0.988347   0.995536  0.981095  0.988347
# test   0.919507   0.961780  0.875109  0.919321

# %%
from sklearn.metrics import make_scorer
from functools import partial
def cross_val(X_train, Y_train, X_test, Y_test, model, folds=10):
    #scoring = ["accuracy", "precision","recall","f1_macro"]
    scoring = {'accuracy': make_scorer(accuracy_score),'precision': make_scorer(precision_score,pos_label="Yes"),'recall': make_scorer(recall_score,pos_label="Yes"),'f1_macro': make_scorer(f1_score,average="macro",pos_label="Yes") }
    cv = cross_validate(model, X_train, Y_train, cv=folds,error_score="raise", return_train_score=True, scoring=scoring, n_jobs=-1)
    
    train_scores = []
    test_scores = []
    
    for metric in scoring:
        train_scores.append(np.mean(cv[f"train_{metric}"]))
        test_scores.append(np.mean(cv[f"test_{metric}"]))
        
    mean_scores = pd.DataFrame((train_scores, test_scores), columns=scoring, index=["train", "test"])
    
    return cv, mean_scores

# %%
def plot_cross_val(cv, folds=10):    
    metrics = ["accuracy", "precision", "recall"]
    colors = ["r", "g", "b", "y"]
    
    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(8,4))
    
    for index, time_ in enumerate(["train", "test"]):
        for num, metric in enumerate(metrics):
            indexer = f"{time_}_{metric}"
            ax[index].plot(np.arange(folds), cv[indexer], color=colors[num])
        
        ax[index].legend(metrics, loc="upper left")
        ax[index].title.set_text(f"Scores during {time_} time")
    
    plt.tight_layout()
    plt.show()
